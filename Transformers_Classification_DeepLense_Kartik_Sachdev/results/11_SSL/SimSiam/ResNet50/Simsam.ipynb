# %%
from __future__ import print_function
import os
import time
import copy
import json
import yaml

import torch.nn as nn
import torch.optim as optim
from torchinfo import summary
import torchvision
from typing import *

# %%
from utils.util import *
from config.data_config import DATASET
from utils.dataset import DefaultDatasetSetupSSL
from self_supervised.losses.contrastive_loss import (
    ContrastiveLossEuclidean,
    ContrastiveLossEmbedding,
    SimCLR_Loss,
    NegativeCosineSimilarity,
)
from self_supervised.losses.sym_neg_cos_sim_loss import SymNegCosineSimilarityLoss

from models.modules.head import BYOLProjectionHead, BYOLPredictionHead
from utils.scheduler import cosine_schedule
from torch.utils.data import DataLoader, random_split
from einops.layers.torch import Rearrange
from config.cvt_config import CvT_CONFIG
from models.transformer_zoo import TransformerModels
import math
from transformers import get_cosine_schedule_with_warmup
from utils.inference import InferenceSSL
import logging

# %%
import torch
import torchvision
from torch import nn

from lightly.loss import NegativeCosineSimilarity
from lightly.models.modules import SimSiamPredictionHead, SimSiamProjectionHead
from lightly.transforms import SimSiamTransform

# %%
batch_size = 128
dataset_name = "Model_II"
dataset_dir = "data"
use_cuda = True
num_workers = 20

log_dir_base = "logger"
classes = DATASET[f"{dataset_name}"]["classes"]
num_classes = len(classes)

# %%
train_config = CvT_CONFIG
learning_rate = train_config["optimizer_config"]["lr"]
num_channels = train_config["channels"]
network_type = train_config["network_type"]
image_size = train_config["image_size"]
optimizer_config = train_config["optimizer_config"]

make_directories([dataset_dir])
seed_everything(seed=42)

# %%
# logging
current_time = time.strftime("%Y-%m-%d-%H-%M-%S", time.localtime())
log_dir = f"{log_dir_base}/{current_time}"
init_logging_handler(log_dir_base, current_time)

# dump config in logger
with open(f"{log_dir}/config.json", "w") as fp:
    json.dump(train_config, fp)

# %%
# paths
model_path_pretrained = os.path.join(
    f"{log_dir}/checkpoint",
   f"{network_type}_pretrained_{dataset_name}_{current_time}.pt",
)

finetuned_model_path = os.path.join(
    f"{log_dir}/checkpoint",
    f"{network_type}_finetune_{dataset_name}_{current_time}.pt",
)

# %%
train_config = CvT_CONFIG
learning_rate = train_config["optimizer_config"]["lr"]
num_channels = train_config["channels"]
network_type = train_config["network_type"]
image_size = train_config["image_size"]
optimizer_config = train_config["optimizer_config"]

make_directories([dataset_dir])
seed_everything(seed=42)

# %%
import albumentations as A
from albumentations.pytorch import ToTensorV2


class SimSiamTransform:
    """Implements the global and local view augmentations for DINO [0].
    """

    def __init__(self):
        pass
    
    def get_transforms(self, 
                       global_crop_size: int = 224,
                       global_crop_scale: Tuple[float, float] = (0.4, 1.0),
                       local_crop_size: int = 96,
                       local_crop_scale: Tuple[float, float] = (0.05, 0.4),):

        # first global crop
        global_transform_0 = A.Compose(
        [
            A.HorizontalFlip(p=0.25),
            A.VerticalFlip(p=0.25),
            A.Resize(global_crop_size, global_crop_size, p=1.0),
            A.RandomResizedCrop(height=global_crop_size, width=global_crop_size),
            A.Rotate(p=0.5), 
            ToTensorV2(),
        ])

        # second global crop
        global_transform_1 = A.Compose(
        [
            A.HorizontalFlip(p=0.5),
            A.VerticalFlip(p=0.25),
            A.Resize(global_crop_size, global_crop_size, p=1.0),
            A.augmentations.GaussNoise(var_limit=(0.002, 0.005), p=0.3),
            ToTensorV2(),
        ])
        
        # transformation for the local small crops
        local_transform = A.Compose(
        [
            A.HorizontalFlip(p=0.25),
            A.VerticalFlip(p=0.25),
            A.Resize(local_crop_size, local_crop_size, p=1.0),
            A.augmentations.GaussianBlur(),
            ToTensorV2(),
        ])
        return [global_transform_0, global_transform_0]

# %%
from utils.dataset import visualize_samples_ssl, DeepLenseDatasetSSL
# trainset
dino_transform = SimSiamTransform()
train_transforms = dino_transform.get_transforms()
train_dataset = DeepLenseDatasetSSL(destination_dir = dataset_dir, transforms = train_transforms, mode="train", dataset_name=dataset_name, download=True, channels=1)
logging.debug(f"train data: {len(train_dataset)}")
visualize_samples_ssl(train_dataset, labels_map=classes, num_rows_inner=1, num_cols_inner=2)
# Out:
# Model_II dataset already exists
# DEBUG:root:train data: 89104
# DEBUG:matplotlib.pyplot:Loaded backend module://matplotlib_inline.backend_inline version unknown.
# DEBUG:matplotlib.pyplot:Loaded backend module://matplotlib_inline.backend_inline version unknown.

# %%
# split in train and valid set
split_ratio = 0.25  # 0.25
valid_len = int(split_ratio * len(train_dataset))
train_len = len(train_dataset) - valid_len

train_dataset, val_set = random_split(train_dataset, [train_len, valid_len])

train_loader = DataLoader(
    dataset=train_dataset,
    batch_size=batch_size,
    shuffle=True,
    num_workers=num_workers,
)

val_loader = DataLoader(
    dataset=val_set, batch_size=batch_size, shuffle=True, num_workers=num_workers
)

# Load test dataset
# testset = default_dataset_setup.get_dataset(mode="val")
# test_loader = DataLoader(dataset=testset, batch_size=batch_size, shuffle=True)

# size check
sample = next(iter(train_loader))
logging.debug("num of classes: ", num_classes)
logging.debug(sample[0].shape)
# Out:
# --- Logging error ---
# Traceback (most recent call last):
#   File "/global/common/software/nersc/pm-2022q4/sw/pytorch/1.13.1/lib/python3.9/logging/__init__.py", line 1083, in emit
#     msg = self.format(record)
#   File "/global/common/software/nersc/pm-2022q4/sw/pytorch/1.13.1/lib/python3.9/logging/__init__.py", line 927, in format
#     return fmt.format(record)
#   File "/global/common/software/nersc/pm-2022q4/sw/pytorch/1.13.1/lib/python3.9/logging/__init__.py", line 663, in format
#     record.message = record.getMessage()
#   File "/global/common/software/nersc/pm-2022q4/sw/pytorch/1.13.1/lib/python3.9/logging/__init__.py", line 367, in getMessage
#     msg = msg % self.args
# TypeError: not all arguments converted during string formatting
# Call stack:
#   File "/global/common/software/nersc/pm-2022q4/sw/pytorch/1.13.1/lib/python3.9/runpy.py", line 197, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/global/common/software/nersc/pm-2022q4/sw/pytorch/1.13.1/lib/python3.9/runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "/global/common/software/nersc/pm-2022q4/sw/pytorch/1.13.1/lib/python3.9/site-packages/ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "/global/common/software/nersc/pm-2022q4/sw/pytorch/1.13.1/lib/python3.9/site-packages/traitlets/config/application.py", line 992, in launch_instance
#     app.start()
#   File "/global/common/software/nersc/pm-2022q4/sw/pytorch/1.13.1/lib/python3.9/site-packages/ipykernel/kernelapp.py", line 712, in start
#     self.io_loop.start()
#   File "/global/common/software/nersc/pm-2022q4/sw/pytorch/1.13.1/lib/python3.9/site-packages/tornado/platform/asyncio.py", line 215, in start
#     self.asyncio_loop.run_forever()
#   File "/global/common/software/nersc/pm-2022q4/sw/pytorch/1.13.1/lib/python3.9/asyncio/base_events.py", line 601, in run_forever
#     self._run_once()
#   File "/global/common/software/nersc/pm-2022q4/sw/pytorch/1.13.1/lib/python3.9/asyncio/base_events.py", line 1905, in _run_once
#     handle._run()
#   File "/global/common/software/nersc/pm-2022q4/sw/pytorch/1.13.1/lib/python3.9/asyncio/events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "/global/common/software/nersc/pm-2022q4/sw/pytorch/1.13.1/lib/python3.9/site-packages/ipykernel/kernelbase.py", line 510, in dispatch_queue
#     await self.process_one()
#   File "/global/common/software/nersc/pm-2022q4/sw/pytorch/1.13.1/lib/python3.9/site-packages/ipykernel/kernelbase.py", line 499, in process_one
#     await dispatch(*args)
#   File "/global/common/software/nersc/pm-2022q4/sw/pytorch/1.13.1/lib/python3.9/site-packages/ipykernel/kernelbase.py", line 406, in dispatch_shell
#     await result
#   File "/global/common/software/nersc/pm-2022q4/sw/pytorch/1.13.1/lib/python3.9/site-packages/ipykernel/kernelbase.py", line 730, in execute_request
#     reply_content = await reply_content
#   File "/global/common/software/nersc/pm-2022q4/sw/pytorch/1.13.1/lib/python3.9/site-packages/ipykernel/ipkernel.py", line 383, in do_execute
#     res = shell.run_cell(
#   File "/global/common/software/nersc/pm-2022q4/sw/pytorch/1.13.1/lib/python3.9/site-packages/ipykernel/zmqshell.py", line 528, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/global/homes/s/sachdevk/.local/perlmutter/pytorch1.13.1/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3009, in run_cell
#     result = self._run_cell(
#   File "/global/homes/s/sachdevk/.local/perlmutter/pytorch1.13.1/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3064, in _run_cell
#     result = runner(coro)
#   File "/global/homes/s/sachdevk/.local/perlmutter/pytorch1.13.1/lib/python3.9/site-packages/IPython/core/async_helpers.py", line 129, in _pseudo_sync_runner
#     coro.send(None)
#   File "/global/homes/s/sachdevk/.local/perlmutter/pytorch1.13.1/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3269, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/global/homes/s/sachdevk/.local/perlmutter/pytorch1.13.1/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3448, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "/global/homes/s/sachdevk/.local/perlmutter/pytorch1.13.1/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3508, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_55291/2935425517.py", line 25, in <module>
#     logging.debug("num of classes: ", num_classes)
# Message: 'num of classes: '
# Arguments: (3,)
# --- Logging error ---
# Traceback (most recent call last):
#   File "/global/common/software/nersc/pm-2022q4/sw/pytorch/1.13.1/lib/python3.9/logging/__init__.py", line 1083, in emit
#     msg = self.format(record)
#   File "/global/common/software/nersc/pm-2022q4/sw/pytorch/1.13.1/lib/python3.9/logging/__init__.py", line 927, in format
#     return fmt.format(record)
#   File "/global/common/software/nersc/pm-2022q4/sw/pytorch/1.13.1/lib/python3.9/logging/__init__.py", line 663, in format
#     record.message = record.getMessage()
#   File "/global/common/software/nersc/pm-2022q4/sw/pytorch/1.13.1/lib/python3.9/logging/__init__.py", line 367, in getMessage
#     msg = msg % self.args
# TypeError: not all arguments converted during string formatting
# Call stack:
#   File "/global/common/software/nersc/pm-2022q4/sw/pytorch/1.13.1/lib/python3.9/runpy.py", line 197, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/global/common/software/nersc/pm-2022q4/sw/pytorch/1.13.1/lib/python3.9/runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "/global/common/software/nersc/pm-2022q4/sw/pytorch/1.13.1/lib/python3.9/site-packages/ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "/global/common/software/nersc/pm-2022q4/sw/pytorch/1.13.1/lib/python3.9/site-packages/traitlets/config/application.py", line 992, in launch_instance
#     app.start()
#   File "/global/common/software/nersc/pm-2022q4/sw/pytorch/1.13.1/lib/python3.9/site-packages/ipykernel/kernelapp.py", line 712, in start
#     self.io_loop.start()
#   File "/global/common/software/nersc/pm-2022q4/sw/pytorch/1.13.1/lib/python3.9/site-packages/tornado/platform/asyncio.py", line 215, in start
#     self.asyncio_loop.run_forever()
#   File "/global/common/software/nersc/pm-2022q4/sw/pytorch/1.13.1/lib/python3.9/asyncio/base_events.py", line 601, in run_forever
#     self._run_once()
#   File "/global/common/software/nersc/pm-2022q4/sw/pytorch/1.13.1/lib/python3.9/asyncio/base_events.py", line 1905, in _run_once
#     handle._run()
#   File "/global/common/software/nersc/pm-2022q4/sw/pytorch/1.13.1/lib/python3.9/asyncio/events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "/global/common/software/nersc/pm-2022q4/sw/pytorch/1.13.1/lib/python3.9/site-packages/ipykernel/kernelbase.py", line 510, in dispatch_queue
#     await self.process_one()
#   File "/global/common/software/nersc/pm-2022q4/sw/pytorch/1.13.1/lib/python3.9/site-packages/ipykernel/kernelbase.py", line 499, in process_one
#     await dispatch(*args)
#   File "/global/common/software/nersc/pm-2022q4/sw/pytorch/1.13.1/lib/python3.9/site-packages/ipykernel/kernelbase.py", line 406, in dispatch_shell
#     await result
#   File "/global/common/software/nersc/pm-2022q4/sw/pytorch/1.13.1/lib/python3.9/site-packages/ipykernel/kernelbase.py", line 730, in execute_request
#     reply_content = await reply_content
#   File "/global/common/software/nersc/pm-2022q4/sw/pytorch/1.13.1/lib/python3.9/site-packages/ipykernel/ipkernel.py", line 383, in do_execute
#     res = shell.run_cell(
#   File "/global/common/software/nersc/pm-2022q4/sw/pytorch/1.13.1/lib/python3.9/site-packages/ipykernel/zmqshell.py", line 528, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/global/homes/s/sachdevk/.local/perlmutter/pytorch1.13.1/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3009, in run_cell
#     result = self._run_cell(
#   File "/global/homes/s/sachdevk/.local/perlmutter/pytorch1.13.1/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3064, in _run_cell
#     result = runner(coro)
#   File "/global/homes/s/sachdevk/.local/perlmutter/pytorch1.13.1/lib/python3.9/site-packages/IPython/core/async_helpers.py", line 129, in _pseudo_sync_runner
#     coro.send(None)
#   File "/global/homes/s/sachdevk/.local/perlmutter/pytorch1.13.1/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3269, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/global/homes/s/sachdevk/.local/perlmutter/pytorch1.13.1/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3448, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "/global/homes/s/sachdevk/.local/perlmutter/pytorch1.13.1/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3508, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_55291/2935425517.py", line 25, in <module>
#     logging.debug("num of classes: ", num_classes)
# Message: 'num of classes: '
# Arguments: (3,)
# DEBUG:root:torch.Size([128, 1, 224, 224])

# %%
class SimSiam(nn.Module):
    def __init__(self, backbone):
        super().__init__()
        self.backbone = backbone
        self.backbone[0] = nn.Conv2d(
            1, 64, kernel_size=7, stride=2, padding=3, bias=False
        )
        self.projection_head = SimSiamProjectionHead(2048, 512, 128)
        self.prediction_head = SimSiamPredictionHead(128, 64, 128)

    def forward(self, x):
        f = self.backbone(x).flatten(start_dim=1)
        z = self.projection_head(f)
        p = self.prediction_head(z)
        z = z.detach()
        return z, p

# %%
# # Create ResNet pretrain model
resnet = torchvision.models.resnet50()
backbone = nn.Sequential(*list(resnet.children())[:-1])

num_ftrs_dict = {
    "resnet18": 512,
    "resnet34": 512,
    "resnet50": 2048,

}

model =  SimSiam(backbone)
device = "cuda" if torch.cuda.is_available() else "cpu"
model.to(device)

summary(model, input_size=(2, 1, 224, 224), device="cuda")
# Out:
# ===============================================================================================
# Layer (type:depth-idx)                        Output Shape              Param #
# ===============================================================================================
# SimSiam                                       [2, 128]                  --
# ├─Sequential: 1-1                             [2, 2048, 1, 1]           --
# │    └─Conv2d: 2-1                            [2, 64, 112, 112]         3,136
# │    └─BatchNorm2d: 2-2                       [2, 64, 112, 112]         128
# │    └─ReLU: 2-3                              [2, 64, 112, 112]         --
# │    └─MaxPool2d: 2-4                         [2, 64, 56, 56]           --
# │    └─Sequential: 2-5                        [2, 256, 56, 56]          --
# │    │    └─Bottleneck: 3-1                   [2, 256, 56, 56]          75,008
# │    │    └─Bottleneck: 3-2                   [2, 256, 56, 56]          70,400
# │    │    └─Bottleneck: 3-3                   [2, 256, 56, 56]          70,400
# │    └─Sequential: 2-6                        [2, 512, 28, 28]          --
# │    │    └─Bottleneck: 3-4                   [2, 512, 28, 28]          379,392
# │    │    └─Bottleneck: 3-5                   [2, 512, 28, 28]          280,064
# │    │    └─Bottleneck: 3-6                   [2, 512, 28, 28]          280,064
# │    │    └─Bottleneck: 3-7                   [2, 512, 28, 28]          280,064
# │    └─Sequential: 2-7                        [2, 1024, 14, 14]         --
# │    │    └─Bottleneck: 3-8                   [2, 1024, 14, 14]         1,512,448
# │    │    └─Bottleneck: 3-9                   [2, 1024, 14, 14]         1,117,184
# │    │    └─Bottleneck: 3-10                  [2, 1024, 14, 14]         1,117,184
# │    │    └─Bottleneck: 3-11                  [2, 1024, 14, 14]         1,117,184
# │    │    └─Bottleneck: 3-12                  [2, 1024, 14, 14]         1,117,184
# │    │    └─Bottleneck: 3-13                  [2, 1024, 14, 14]         1,117,184
# │    └─Sequential: 2-8                        [2, 2048, 7, 7]           --
# │    │    └─Bottleneck: 3-14                  [2, 2048, 7, 7]           6,039,552
# │    │    └─Bottleneck: 3-15                  [2, 2048, 7, 7]           4,462,592
# │    │    └─Bottleneck: 3-16                  [2, 2048, 7, 7]           4,462,592
# │    └─AdaptiveAvgPool2d: 2-9                 [2, 2048, 1, 1]           --
# ├─SimSiamProjectionHead: 1-2                  [2, 128]                  --
# │    └─Sequential: 2-10                       [2, 128]                  --
# │    │    └─Linear: 3-17                      [2, 512]                  1,048,576
# │    │    └─BatchNorm1d: 3-18                 [2, 512]                  1,024
# │    │    └─ReLU: 3-19                        [2, 512]                  --
# │    │    └─Linear: 3-20                      [2, 512]                  262,144
# │    │    └─BatchNorm1d: 3-21                 [2, 512]                  1,024
# │    │    └─ReLU: 3-22                        [2, 512]                  --
# │    │    └─Linear: 3-23                      [2, 128]                  65,536
# │    │    └─BatchNorm1d: 3-24                 [2, 128]                  --
# ├─SimSiamPredictionHead: 1-3                  [2, 128]                  --
# │    └─Sequential: 2-11                       [2, 128]                  --
# │    │    └─Linear: 3-25                      [2, 64]                   8,192
# │    │    └─BatchNorm1d: 3-26                 [2, 64]                   128
# │    │    └─ReLU: 3-27                        [2, 64]                   --
# │    │    └─Linear: 3-28                      [2, 128]                  8,320
# ===============================================================================================
# Total params: 24,896,704
# Trainable params: 24,896,704
# Non-trainable params: 0
# Total mult-adds (G): 8.02
# ===============================================================================================
# Input size (MB): 0.40
# Forward/backward pass size (MB): 355.69
# Params size (MB): 99.59
# Estimated Total Size (MB): 455.67
# ===============================================================================================

# %%
epochs_pretrain = 15
finetune_epochs = 20

# %%
#optimizer
optimizer_pretrain = optim.AdamW(model.parameters(), lr=1e-3, weight_decay = 1e-4)
warmup_epochs = 3
num_train_steps = math.ceil(len(train_loader))
num_warmup_steps= num_train_steps * warmup_epochs
num_training_steps=int(num_train_steps * epochs_pretrain)

#learning rate scheduler
cosine_scheduler = get_cosine_schedule_with_warmup(optimizer_pretrain,num_warmup_steps = num_warmup_steps,num_training_steps =num_training_steps)

# %%
criterion = NegativeCosineSimilarity()

# %%
logging.debug("Starting Training")
for epoch in range(epochs_pretrain):
    total_loss = 0    
    best_loss = float("inf")

    for batch_idx, batch in enumerate(train_loader):
        x0 = batch[0] 
        x1 = batch[1] 
        x0 = x0.to(device)
        x1 = x1.to(device)
        z0, p0 = model(x0)
        z1, p1 = model(x1)
        loss = 0.5 * (criterion(z0, p1) + criterion(z1, p0))
        total_loss += loss.detach()
        loss.backward()
        optimizer_pretrain.step()
        optimizer_pretrain.zero_grad()
        cosine_scheduler.step()
        

        if batch_idx % 10 == 0:
            logging.debug(f"Epoch [{epoch}/{epochs_pretrain}], Batch [{batch_idx}/{len(train_loader)}], Loss: {loss.item()}")

    if total_loss < best_loss:
        best_loss = total_loss
        torch.save(model.state_dict(), model_path_pretrained)

    avg_loss = total_loss / len(train_loader)
    logging.debug(f"epoch: {epoch:>02}, loss: {avg_loss:.5f}")
# Out:
# DEBUG:root:Starting Training
# DEBUG:root:Epoch [0/15], Batch [0/523], Loss: 0.00422169454395771
# DEBUG:root:Epoch [0/15], Batch [10/523], Loss: -0.014204518869519234
# DEBUG:root:Epoch [0/15], Batch [20/523], Loss: -0.021479032933712006
# DEBUG:root:Epoch [0/15], Batch [30/523], Loss: -0.03691413998603821
# DEBUG:root:Epoch [0/15], Batch [40/523], Loss: -0.0650525689125061
# DEBUG:root:Epoch [0/15], Batch [50/523], Loss: -0.08679208904504776
# DEBUG:root:Epoch [0/15], Batch [60/523], Loss: -0.09860868752002716
# DEBUG:root:Epoch [0/15], Batch [70/523], Loss: -0.13895469903945923
# DEBUG:root:Epoch [0/15], Batch [80/523], Loss: -0.1449469029903412
# DEBUG:root:Epoch [0/15], Batch [90/523], Loss: -0.1881406009197235
# DEBUG:root:Epoch [0/15], Batch [100/523], Loss: -0.24074047803878784
# DEBUG:root:Epoch [0/15], Batch [110/523], Loss: -0.30765658617019653
# DEBUG:root:Epoch [0/15], Batch [120/523], Loss: -0.33847999572753906
# DEBUG:root:Epoch [0/15], Batch [130/523], Loss: -0.4069468379020691
# DEBUG:root:Epoch [0/15], Batch [140/523], Loss: -0.39640092849731445
# DEBUG:root:Epoch [0/15], Batch [150/523], Loss: -0.44650447368621826
# DEBUG:root:Epoch [0/15], Batch [160/523], Loss: -0.47602546215057373
# DEBUG:root:Epoch [0/15], Batch [170/523], Loss: -0.5338507890701294
# DEBUG:root:Epoch [0/15], Batch [180/523], Loss: -0.5278323888778687
# DEBUG:root:Epoch [0/15], Batch [190/523], Loss: -0.570654034614563
# DEBUG:root:Epoch [0/15], Batch [200/523], Loss: -0.6376577019691467
# DEBUG:root:Epoch [0/15], Batch [210/523], Loss: -0.6617964506149292
# DEBUG:root:Epoch [0/15], Batch [220/523], Loss: -0.6300102472305298
# DEBUG:root:Epoch [0/15], Batch [230/523], Loss: -0.6823713779449463
# DEBUG:root:Epoch [0/15], Batch [240/523], Loss: -0.7351233959197998
# DEBUG:root:Epoch [0/15], Batch [250/523], Loss: -0.7642323970794678
# DEBUG:root:Epoch [0/15], Batch [260/523], Loss: -0.7892096042633057
# DEBUG:root:Epoch [0/15], Batch [270/523], Loss: -0.8050246834754944
# DEBUG:root:Epoch [0/15], Batch [280/523], Loss: -0.789665699005127
# DEBUG:root:Epoch [0/15], Batch [290/523], Loss: -0.7385156154632568
# DEBUG:root:Epoch [0/15], Batch [300/523], Loss: -0.8288401365280151
# DEBUG:root:Epoch [0/15], Batch [310/523], Loss: -0.8091738224029541
# DEBUG:root:Epoch [0/15], Batch [320/523], Loss: -0.8382375240325928
# DEBUG:root:Epoch [0/15], Batch [330/523], Loss: -0.8451833724975586
# DEBUG:root:Epoch [0/15], Batch [340/523], Loss: -0.8405101299285889
# DEBUG:root:Epoch [0/15], Batch [350/523], Loss: -0.8328502178192139
# DEBUG:root:Epoch [0/15], Batch [360/523], Loss: -0.8364368081092834
# DEBUG:root:Epoch [0/15], Batch [370/523], Loss: -0.8383392095565796
# DEBUG:root:Epoch [0/15], Batch [380/523], Loss: -0.867957592010498
# DEBUG:root:Epoch [0/15], Batch [390/523], Loss: -0.8261981010437012
# DEBUG:root:Epoch [0/15], Batch [400/523], Loss: -0.7983431816101074
# DEBUG:root:Epoch [0/15], Batch [410/523], Loss: -0.8344275951385498
# DEBUG:root:Epoch [0/15], Batch [420/523], Loss: -0.8057319521903992
# DEBUG:root:Epoch [0/15], Batch [430/523], Loss: -0.7711520195007324
# DEBUG:root:Epoch [0/15], Batch [440/523], Loss: -0.8937065005302429
# DEBUG:root:Epoch [0/15], Batch [450/523], Loss: -0.8714562058448792
# DEBUG:root:Epoch [0/15], Batch [460/523], Loss: -0.8346478939056396
# DEBUG:root:Epoch [0/15], Batch [470/523], Loss: -0.8004099130630493
# DEBUG:root:Epoch [0/15], Batch [480/523], Loss: -0.8789722919464111
# DEBUG:root:Epoch [0/15], Batch [490/523], Loss: -0.8847408294677734
# DEBUG:root:Epoch [0/15], Batch [500/523], Loss: -0.8583632707595825
# DEBUG:root:Epoch [0/15], Batch [510/523], Loss: -0.8974621891975403
# DEBUG:root:Epoch [0/15], Batch [520/523], Loss: -0.865293025970459
# DEBUG:root:epoch: 00, loss: -0.59914
# DEBUG:root:Epoch [1/15], Batch [0/523], Loss: -0.8327177166938782
# DEBUG:root:Epoch [1/15], Batch [10/523], Loss: -0.8385344743728638
# DEBUG:root:Epoch [1/15], Batch [20/523], Loss: -0.8840819001197815
# DEBUG:root:Epoch [1/15], Batch [30/523], Loss: -0.87934410572052
# DEBUG:root:Epoch [1/15], Batch [40/523], Loss: -0.9114176630973816
# DEBUG:root:Epoch [1/15], Batch [50/523], Loss: -0.887475848197937
# DEBUG:root:Epoch [1/15], Batch [60/523], Loss: -0.8957278728485107
# DEBUG:root:Epoch [1/15], Batch [70/523], Loss: -0.8605597019195557
# DEBUG:root:Epoch [1/15], Batch [80/523], Loss: -0.8878974914550781
# DEBUG:root:Epoch [1/15], Batch [90/523], Loss: -0.8783817291259766
# DEBUG:root:Epoch [1/15], Batch [100/523], Loss: -0.9112645983695984
# DEBUG:root:Epoch [1/15], Batch [110/523], Loss: -0.9080629944801331
# DEBUG:root:Epoch [1/15], Batch [120/523], Loss: -0.9063116908073425
# DEBUG:root:Epoch [1/15], Batch [130/523], Loss: -0.8679067492485046
# DEBUG:root:Epoch [1/15], Batch [140/523], Loss: -0.8622702360153198
# DEBUG:root:Epoch [1/15], Batch [150/523], Loss: -0.8086585402488708
# DEBUG:root:Epoch [1/15], Batch [160/523], Loss: -0.9060831069946289
# DEBUG:root:Epoch [1/15], Batch [170/523], Loss: -0.8954806923866272
# DEBUG:root:Epoch [1/15], Batch [180/523], Loss: -0.9112523794174194
# DEBUG:root:Epoch [1/15], Batch [190/523], Loss: -0.9194381237030029
# DEBUG:root:Epoch [1/15], Batch [200/523], Loss: -0.8951867818832397
# DEBUG:root:Epoch [1/15], Batch [210/523], Loss: -0.8779682517051697
# DEBUG:root:Epoch [1/15], Batch [220/523], Loss: -0.8896297216415405
# DEBUG:root:Epoch [1/15], Batch [230/523], Loss: -0.9049762487411499
# DEBUG:root:Epoch [1/15], Batch [240/523], Loss: -0.8756255507469177
# DEBUG:root:Epoch [1/15], Batch [250/523], Loss: -0.9212319850921631
# DEBUG:root:Epoch [1/15], Batch [260/523], Loss: -0.8443036079406738
# DEBUG:root:Epoch [1/15], Batch [270/523], Loss: -0.8639217615127563
# DEBUG:root:Epoch [1/15], Batch [280/523], Loss: -0.8762388825416565
# DEBUG:root:Epoch [1/15], Batch [290/523], Loss: -0.865118145942688
# DEBUG:root:Epoch [1/15], Batch [300/523], Loss: -0.897882342338562
# DEBUG:root:Epoch [1/15], Batch [310/523], Loss: -0.8964471817016602
# DEBUG:root:Epoch [1/15], Batch [320/523], Loss: -0.8858377933502197
# DEBUG:root:Epoch [1/15], Batch [330/523], Loss: -0.9017928242683411
# DEBUG:root:Epoch [1/15], Batch [340/523], Loss: -0.8771892189979553
# DEBUG:root:Epoch [1/15], Batch [350/523], Loss: -0.867397665977478
# DEBUG:root:Epoch [1/15], Batch [360/523], Loss: -0.9068902134895325
# DEBUG:root:Epoch [1/15], Batch [370/523], Loss: -0.9011804461479187
# DEBUG:root:Epoch [1/15], Batch [380/523], Loss: -0.8628566265106201
# DEBUG:root:Epoch [1/15], Batch [390/523], Loss: -0.8437511920928955
# DEBUG:root:Epoch [1/15], Batch [400/523], Loss: -0.9290697574615479
# DEBUG:root:Epoch [1/15], Batch [410/523], Loss: -0.8899160623550415
# DEBUG:root:Epoch [1/15], Batch [420/523], Loss: -0.9143316149711609
# DEBUG:root:Epoch [1/15], Batch [430/523], Loss: -0.8714958429336548
# DEBUG:root:Epoch [1/15], Batch [440/523], Loss: -0.9096589088439941
# DEBUG:root:Epoch [1/15], Batch [450/523], Loss: -0.8392984867095947
# DEBUG:root:Epoch [1/15], Batch [460/523], Loss: -0.9066873788833618
# DEBUG:root:Epoch [1/15], Batch [470/523], Loss: -0.8923962116241455
# DEBUG:root:Epoch [1/15], Batch [480/523], Loss: -0.908056914806366
# DEBUG:root:Epoch [1/15], Batch [490/523], Loss: -0.9274240136146545
# DEBUG:root:Epoch [1/15], Batch [500/523], Loss: -0.8926577568054199
# DEBUG:root:Epoch [1/15], Batch [510/523], Loss: -0.9164220094680786
# DEBUG:root:Epoch [1/15], Batch [520/523], Loss: -0.9079779982566833
# DEBUG:root:epoch: 01, loss: -0.88678
# DEBUG:root:Epoch [2/15], Batch [0/523], Loss: -0.889978289604187
# DEBUG:root:Epoch [2/15], Batch [10/523], Loss: -0.9393183588981628
# DEBUG:root:Epoch [2/15], Batch [20/523], Loss: -0.9166072607040405
# DEBUG:root:Epoch [2/15], Batch [30/523], Loss: -0.8873202204704285
# DEBUG:root:Epoch [2/15], Batch [40/523], Loss: -0.9126970767974854
# DEBUG:root:Epoch [2/15], Batch [50/523], Loss: -0.9315930604934692
# DEBUG:root:Epoch [2/15], Batch [60/523], Loss: -0.9344414472579956
# DEBUG:root:Epoch [2/15], Batch [70/523], Loss: -0.9235419631004333
# DEBUG:root:Epoch [2/15], Batch [80/523], Loss: -0.9172704219818115
# DEBUG:root:Epoch [2/15], Batch [90/523], Loss: -0.9132102727890015
# DEBUG:root:Epoch [2/15], Batch [100/523], Loss: -0.9071975946426392
# DEBUG:root:Epoch [2/15], Batch [110/523], Loss: -0.8704811334609985
# DEBUG:root:Epoch [2/15], Batch [120/523], Loss: -0.8729773163795471
# DEBUG:root:Epoch [2/15], Batch [130/523], Loss: -0.8645299673080444
# DEBUG:root:Epoch [2/15], Batch [140/523], Loss: -0.8816262483596802
# DEBUG:root:Epoch [2/15], Batch [150/523], Loss: -0.8846454620361328
# DEBUG:root:Epoch [2/15], Batch [160/523], Loss: -0.8550280928611755
# DEBUG:root:Epoch [2/15], Batch [170/523], Loss: -0.8629668354988098
# DEBUG:root:Epoch [2/15], Batch [180/523], Loss: -0.8889477252960205
# DEBUG:root:Epoch [2/15], Batch [190/523], Loss: -0.876391589641571
# DEBUG:root:Epoch [2/15], Batch [200/523], Loss: -0.8748599886894226
# DEBUG:root:Epoch [2/15], Batch [210/523], Loss: -0.8970973491668701
# DEBUG:root:Epoch [2/15], Batch [220/523], Loss: -0.8636101484298706
# DEBUG:root:Epoch [2/15], Batch [230/523], Loss: -0.8369506597518921
# DEBUG:root:Epoch [2/15], Batch [240/523], Loss: -0.8264713287353516
# DEBUG:root:Epoch [2/15], Batch [250/523], Loss: -0.9051414728164673
# DEBUG:root:Epoch [2/15], Batch [260/523], Loss: -0.8828712105751038
# DEBUG:root:Epoch [2/15], Batch [270/523], Loss: -0.8661775588989258
# DEBUG:root:Epoch [2/15], Batch [280/523], Loss: -0.900462806224823
# DEBUG:root:Epoch [2/15], Batch [290/523], Loss: -0.8998012542724609
# DEBUG:root:Epoch [2/15], Batch [300/523], Loss: -0.9065604209899902
# DEBUG:root:Epoch [2/15], Batch [310/523], Loss: -0.8783212900161743
# DEBUG:root:Epoch [2/15], Batch [320/523], Loss: -0.897415816783905
# DEBUG:root:Epoch [2/15], Batch [330/523], Loss: -0.9084007740020752
# DEBUG:root:Epoch [2/15], Batch [340/523], Loss: -0.8756470680236816
# DEBUG:root:Epoch [2/15], Batch [350/523], Loss: -0.892258882522583
# DEBUG:root:Epoch [2/15], Batch [360/523], Loss: -0.8904682397842407
# DEBUG:root:Epoch [2/15], Batch [370/523], Loss: -0.8434001803398132
# DEBUG:root:Epoch [2/15], Batch [380/523], Loss: -0.874643862247467
# DEBUG:root:Epoch [2/15], Batch [390/523], Loss: -0.8907023668289185
# DEBUG:root:Epoch [2/15], Batch [400/523], Loss: -0.9312436580657959
# DEBUG:root:Epoch [2/15], Batch [410/523], Loss: -0.9517807960510254
# DEBUG:root:Epoch [2/15], Batch [420/523], Loss: -0.8803837299346924
# DEBUG:root:Epoch [2/15], Batch [430/523], Loss: -0.8830362558364868
# DEBUG:root:Epoch [2/15], Batch [440/523], Loss: -0.8316627740859985
# DEBUG:root:Epoch [2/15], Batch [450/523], Loss: -0.9046564102172852
# DEBUG:root:Epoch [2/15], Batch [460/523], Loss: -0.8754560351371765
# DEBUG:root:Epoch [2/15], Batch [470/523], Loss: -0.8376612663269043
# DEBUG:root:Epoch [2/15], Batch [480/523], Loss: -0.8711493611335754
# DEBUG:root:Epoch [2/15], Batch [490/523], Loss: -0.8701349496841431
# DEBUG:root:Epoch [2/15], Batch [500/523], Loss: -0.8249908685684204
# DEBUG:root:Epoch [2/15], Batch [510/523], Loss: -0.879862904548645
# DEBUG:root:Epoch [2/15], Batch [520/523], Loss: -0.857200026512146
# DEBUG:root:epoch: 02, loss: -0.88397
# DEBUG:root:Epoch [3/15], Batch [0/523], Loss: -0.9146668910980225
# DEBUG:root:Epoch [3/15], Batch [10/523], Loss: -0.9128414988517761
# DEBUG:root:Epoch [3/15], Batch [20/523], Loss: -0.8445672988891602
# DEBUG:root:Epoch [3/15], Batch [30/523], Loss: -0.8427624106407166
# DEBUG:root:Epoch [3/15], Batch [40/523], Loss: -0.9008283019065857
# DEBUG:root:Epoch [3/15], Batch [50/523], Loss: -0.8500160574913025
# DEBUG:root:Epoch [3/15], Batch [60/523], Loss: -0.9200661182403564
# DEBUG:root:Epoch [3/15], Batch [70/523], Loss: -0.8588292598724365
# DEBUG:root:Epoch [3/15], Batch [80/523], Loss: -0.8731834888458252
# DEBUG:root:Epoch [3/15], Batch [90/523], Loss: -0.8632880449295044
# DEBUG:root:Epoch [3/15], Batch [100/523], Loss: -0.9135006666183472
# DEBUG:root:Epoch [3/15], Batch [110/523], Loss: -0.8895399570465088
# DEBUG:root:Epoch [3/15], Batch [120/523], Loss: -0.8943676948547363
# DEBUG:root:Epoch [3/15], Batch [130/523], Loss: -0.916912317276001
# DEBUG:root:Epoch [3/15], Batch [140/523], Loss: -0.8892091512680054
# DEBUG:root:Epoch [3/15], Batch [150/523], Loss: -0.8340373635292053
# DEBUG:root:Epoch [3/15], Batch [160/523], Loss: -0.876885175704956
# DEBUG:root:Epoch [3/15], Batch [170/523], Loss: -0.8741797804832458
# DEBUG:root:Epoch [3/15], Batch [180/523], Loss: -0.8537553548812866
# DEBUG:root:Epoch [3/15], Batch [190/523], Loss: -0.8437113761901855
# DEBUG:root:Epoch [3/15], Batch [200/523], Loss: -0.9108374118804932
# DEBUG:root:Epoch [3/15], Batch [210/523], Loss: -0.8879014849662781
# DEBUG:root:Epoch [3/15], Batch [220/523], Loss: -0.9038376212120056
# DEBUG:root:Epoch [3/15], Batch [230/523], Loss: -0.9430534243583679
# DEBUG:root:Epoch [3/15], Batch [240/523], Loss: -0.8836246728897095
# DEBUG:root:Epoch [3/15], Batch [250/523], Loss: -0.834311306476593
# DEBUG:root:Epoch [3/15], Batch [260/523], Loss: -0.8844229578971863
# DEBUG:root:Epoch [3/15], Batch [270/523], Loss: -0.8605800271034241
# DEBUG:root:Epoch [3/15], Batch [280/523], Loss: -0.8864845037460327
# DEBUG:root:Epoch [3/15], Batch [290/523], Loss: -0.8899516463279724
# DEBUG:root:Epoch [3/15], Batch [300/523], Loss: -0.8450847864151001
# DEBUG:root:Epoch [3/15], Batch [310/523], Loss: -0.8643163442611694
# DEBUG:root:Epoch [3/15], Batch [320/523], Loss: -0.9192962646484375
# DEBUG:root:Epoch [3/15], Batch [330/523], Loss: -0.8735003471374512
# DEBUG:root:Epoch [3/15], Batch [340/523], Loss: -0.8744845390319824
# DEBUG:root:Epoch [3/15], Batch [350/523], Loss: -0.8603399395942688
# DEBUG:root:Epoch [3/15], Batch [360/523], Loss: -0.8809010982513428
# DEBUG:root:Epoch [3/15], Batch [370/523], Loss: -0.8615981936454773
# DEBUG:root:Epoch [3/15], Batch [380/523], Loss: -0.8736572861671448
# DEBUG:root:Epoch [3/15], Batch [390/523], Loss: -0.8966057300567627
# DEBUG:root:Epoch [3/15], Batch [400/523], Loss: -0.8506155014038086
# DEBUG:root:Epoch [3/15], Batch [410/523], Loss: -0.8864536285400391
# DEBUG:root:Epoch [3/15], Batch [420/523], Loss: -0.8456078171730042
# DEBUG:root:Epoch [3/15], Batch [430/523], Loss: -0.8432428240776062
# DEBUG:root:Epoch [3/15], Batch [440/523], Loss: -0.904891848564148
# DEBUG:root:Epoch [3/15], Batch [450/523], Loss: -0.8373873233795166
# DEBUG:root:Epoch [3/15], Batch [460/523], Loss: -0.893751323223114
# DEBUG:root:Epoch [3/15], Batch [470/523], Loss: -0.8401987552642822
# DEBUG:root:Epoch [3/15], Batch [480/523], Loss: -0.8576654195785522
# DEBUG:root:Epoch [3/15], Batch [490/523], Loss: -0.8612949848175049
# DEBUG:root:Epoch [3/15], Batch [500/523], Loss: -0.8992332816123962
# DEBUG:root:Epoch [3/15], Batch [510/523], Loss: -0.9273563623428345
# DEBUG:root:Epoch [3/15], Batch [520/523], Loss: -0.9285044074058533
# DEBUG:root:epoch: 03, loss: -0.87335
# DEBUG:root:Epoch [4/15], Batch [0/523], Loss: -0.8938384652137756
# DEBUG:root:Epoch [4/15], Batch [10/523], Loss: -0.8703539967536926
# DEBUG:root:Epoch [4/15], Batch [20/523], Loss: -0.8585458993911743
# DEBUG:root:Epoch [4/15], Batch [30/523], Loss: -0.903454065322876
# DEBUG:root:Epoch [4/15], Batch [40/523], Loss: -0.8843795657157898
# DEBUG:root:Epoch [4/15], Batch [50/523], Loss: -0.8825047612190247
# DEBUG:root:Epoch [4/15], Batch [60/523], Loss: -0.922012209892273
# DEBUG:root:Epoch [4/15], Batch [70/523], Loss: -0.8664224147796631
# DEBUG:root:Epoch [4/15], Batch [80/523], Loss: -0.8998642563819885
# DEBUG:root:Epoch [4/15], Batch [90/523], Loss: -0.9194528460502625
# DEBUG:root:Epoch [4/15], Batch [100/523], Loss: -0.8991578817367554
# DEBUG:root:Epoch [4/15], Batch [110/523], Loss: -0.8773049116134644
# DEBUG:root:Epoch [4/15], Batch [120/523], Loss: -0.8551112413406372
# DEBUG:root:Epoch [4/15], Batch [130/523], Loss: -0.8125165700912476
# DEBUG:root:Epoch [4/15], Batch [140/523], Loss: -0.8678825497627258
# DEBUG:root:Epoch [4/15], Batch [150/523], Loss: -0.9131873846054077
# DEBUG:root:Epoch [4/15], Batch [160/523], Loss: -0.8912801742553711
# DEBUG:root:Epoch [4/15], Batch [170/523], Loss: -0.8871141672134399
# DEBUG:root:Epoch [4/15], Batch [180/523], Loss: -0.8757562041282654
# DEBUG:root:Epoch [4/15], Batch [190/523], Loss: -0.8888322114944458
# DEBUG:root:Epoch [4/15], Batch [200/523], Loss: -0.9311389923095703
# DEBUG:root:Epoch [4/15], Batch [210/523], Loss: -0.9158053994178772
# DEBUG:root:Epoch [4/15], Batch [220/523], Loss: -0.8902180790901184
# DEBUG:root:Epoch [4/15], Batch [230/523], Loss: -0.9033499956130981
# DEBUG:root:Epoch [4/15], Batch [240/523], Loss: -0.9051095843315125
# DEBUG:root:Epoch [4/15], Batch [250/523], Loss: -0.8498407602310181
# DEBUG:root:Epoch [4/15], Batch [260/523], Loss: -0.8928132057189941
# DEBUG:root:Epoch [4/15], Batch [270/523], Loss: -0.884131133556366
# DEBUG:root:Epoch [4/15], Batch [280/523], Loss: -0.8993600010871887
# DEBUG:root:Epoch [4/15], Batch [290/523], Loss: -0.9008176922798157
# DEBUG:root:Epoch [4/15], Batch [300/523], Loss: -0.8864873647689819
# DEBUG:root:Epoch [4/15], Batch [310/523], Loss: -0.8762110471725464
# DEBUG:root:Epoch [4/15], Batch [320/523], Loss: -0.9021212458610535
# DEBUG:root:Epoch [4/15], Batch [330/523], Loss: -0.8884707689285278
# DEBUG:root:Epoch [4/15], Batch [340/523], Loss: -0.8773505687713623
# DEBUG:root:Epoch [4/15], Batch [350/523], Loss: -0.9006114602088928
# DEBUG:root:Epoch [4/15], Batch [360/523], Loss: -0.8713079690933228
# DEBUG:root:Epoch [4/15], Batch [370/523], Loss: -0.8861737847328186
# DEBUG:root:Epoch [4/15], Batch [380/523], Loss: -0.8732892274856567
# DEBUG:root:Epoch [4/15], Batch [390/523], Loss: -0.854030430316925
# DEBUG:root:Epoch [4/15], Batch [400/523], Loss: -0.8543267846107483
# DEBUG:root:Epoch [4/15], Batch [410/523], Loss: -0.9059380292892456
# DEBUG:root:Epoch [4/15], Batch [420/523], Loss: -0.8980450630187988
# DEBUG:root:Epoch [4/15], Batch [430/523], Loss: -0.9017432332038879
# DEBUG:root:Epoch [4/15], Batch [440/523], Loss: -0.8981260657310486
# DEBUG:root:Epoch [4/15], Batch [450/523], Loss: -0.8886802196502686
# DEBUG:root:Epoch [4/15], Batch [460/523], Loss: -0.9280096292495728
# DEBUG:root:Epoch [4/15], Batch [470/523], Loss: -0.9182334542274475
# DEBUG:root:Epoch [4/15], Batch [480/523], Loss: -0.9128296375274658
# DEBUG:root:Epoch [4/15], Batch [490/523], Loss: -0.8698174953460693
# DEBUG:root:Epoch [4/15], Batch [500/523], Loss: -0.8725804090499878
# DEBUG:root:Epoch [4/15], Batch [510/523], Loss: -0.8961109519004822
# DEBUG:root:Epoch [4/15], Batch [520/523], Loss: -0.86338210105896
# DEBUG:root:epoch: 04, loss: -0.88716
# DEBUG:root:Epoch [5/15], Batch [0/523], Loss: -0.9111822843551636
# DEBUG:root:Epoch [5/15], Batch [10/523], Loss: -0.8656238913536072
# DEBUG:root:Epoch [5/15], Batch [20/523], Loss: -0.8464336395263672
# DEBUG:root:Epoch [5/15], Batch [30/523], Loss: -0.8750287294387817
# DEBUG:root:Epoch [5/15], Batch [40/523], Loss: -0.8992860317230225
# DEBUG:root:Epoch [5/15], Batch [50/523], Loss: -0.8812194466590881
# DEBUG:root:Epoch [5/15], Batch [60/523], Loss: -0.8573653101921082
# DEBUG:root:Epoch [5/15], Batch [70/523], Loss: -0.8860622644424438
# DEBUG:root:Epoch [5/15], Batch [80/523], Loss: -0.9053072929382324
# DEBUG:root:Epoch [5/15], Batch [90/523], Loss: -0.8769336938858032
# DEBUG:root:Epoch [5/15], Batch [100/523], Loss: -0.9155607223510742
# DEBUG:root:Epoch [5/15], Batch [110/523], Loss: -0.8827866911888123
# DEBUG:root:Epoch [5/15], Batch [120/523], Loss: -0.8338240385055542
# DEBUG:root:Epoch [5/15], Batch [130/523], Loss: -0.8689579367637634
# DEBUG:root:Epoch [5/15], Batch [140/523], Loss: -0.8348994851112366
# DEBUG:root:Epoch [5/15], Batch [150/523], Loss: -0.8602979779243469
# DEBUG:root:Epoch [5/15], Batch [160/523], Loss: -0.8773512840270996
# DEBUG:root:Epoch [5/15], Batch [170/523], Loss: -0.8043997287750244
# DEBUG:root:Epoch [5/15], Batch [180/523], Loss: -0.8744590282440186
# DEBUG:root:Epoch [5/15], Batch [190/523], Loss: -0.8564244508743286
# DEBUG:root:Epoch [5/15], Batch [200/523], Loss: -0.8979976773262024
# DEBUG:root:Epoch [5/15], Batch [210/523], Loss: -0.894507884979248
# DEBUG:root:Epoch [5/15], Batch [220/523], Loss: -0.8708953857421875
# DEBUG:root:Epoch [5/15], Batch [230/523], Loss: -0.8203392028808594
# DEBUG:root:Epoch [5/15], Batch [240/523], Loss: -0.8549482822418213
# DEBUG:root:Epoch [5/15], Batch [250/523], Loss: -0.8775113821029663
# DEBUG:root:Epoch [5/15], Batch [260/523], Loss: -0.8412511944770813
# DEBUG:root:Epoch [5/15], Batch [270/523], Loss: -0.8486939668655396
# DEBUG:root:Epoch [5/15], Batch [280/523], Loss: -0.8270666003227234
# DEBUG:root:Epoch [5/15], Batch [290/523], Loss: -0.87486332654953
# DEBUG:root:Epoch [5/15], Batch [300/523], Loss: -0.8543054461479187
# DEBUG:root:Epoch [5/15], Batch [310/523], Loss: -0.8733124136924744
# DEBUG:root:Epoch [5/15], Batch [320/523], Loss: -0.9376929402351379
# DEBUG:root:Epoch [5/15], Batch [330/523], Loss: -0.8722258806228638
# DEBUG:root:Epoch [5/15], Batch [340/523], Loss: -0.8926802277565002
# DEBUG:root:Epoch [5/15], Batch [350/523], Loss: -0.9032347798347473
# DEBUG:root:Epoch [5/15], Batch [360/523], Loss: -0.8781006336212158
# DEBUG:root:Epoch [5/15], Batch [370/523], Loss: -0.869877278804779
# DEBUG:root:Epoch [5/15], Batch [380/523], Loss: -0.8364386558532715
# DEBUG:root:Epoch [5/15], Batch [390/523], Loss: -0.8514411449432373
# DEBUG:root:Epoch [5/15], Batch [400/523], Loss: -0.9028767347335815
# DEBUG:root:Epoch [5/15], Batch [410/523], Loss: -0.892561137676239
# DEBUG:root:Epoch [5/15], Batch [420/523], Loss: -0.8437469601631165
# DEBUG:root:Epoch [5/15], Batch [430/523], Loss: -0.8083120584487915
# DEBUG:root:Epoch [5/15], Batch [440/523], Loss: -0.8897371292114258
# DEBUG:root:Epoch [5/15], Batch [450/523], Loss: -0.884820818901062
# DEBUG:root:Epoch [5/15], Batch [460/523], Loss: -0.909417450428009
# DEBUG:root:Epoch [5/15], Batch [470/523], Loss: -0.8566762208938599
# DEBUG:root:Epoch [5/15], Batch [480/523], Loss: -0.9268382787704468
# DEBUG:root:Epoch [5/15], Batch [490/523], Loss: -0.9010379910469055
# DEBUG:root:Epoch [5/15], Batch [500/523], Loss: -0.8712310791015625
# DEBUG:root:Epoch [5/15], Batch [510/523], Loss: -0.8839458227157593
# DEBUG:root:Epoch [5/15], Batch [520/523], Loss: -0.8861643075942993
# DEBUG:root:epoch: 05, loss: -0.87359
# DEBUG:root:Epoch [6/15], Batch [0/523], Loss: -0.8757975101470947
# DEBUG:root:Epoch [6/15], Batch [10/523], Loss: -0.8558269739151001
# DEBUG:root:Epoch [6/15], Batch [20/523], Loss: -0.9296982288360596
# DEBUG:root:Epoch [6/15], Batch [30/523], Loss: -0.8313969373703003
# DEBUG:root:Epoch [6/15], Batch [40/523], Loss: -0.83948814868927
# DEBUG:root:Epoch [6/15], Batch [50/523], Loss: -0.9419586658477783
# DEBUG:root:Epoch [6/15], Batch [60/523], Loss: -0.891593337059021
# DEBUG:root:Epoch [6/15], Batch [70/523], Loss: -0.852237343788147
# DEBUG:root:Epoch [6/15], Batch [80/523], Loss: -0.881531298160553
# DEBUG:root:Epoch [6/15], Batch [90/523], Loss: -0.8534388542175293
# DEBUG:root:Epoch [6/15], Batch [100/523], Loss: -0.9158494472503662
# DEBUG:root:Epoch [6/15], Batch [110/523], Loss: -0.8914860486984253
# DEBUG:root:Epoch [6/15], Batch [120/523], Loss: -0.8715085387229919
# DEBUG:root:Epoch [6/15], Batch [130/523], Loss: -0.8884944319725037
# DEBUG:root:Epoch [6/15], Batch [140/523], Loss: -0.8837944269180298
# DEBUG:root:Epoch [6/15], Batch [150/523], Loss: -0.8749502897262573
# DEBUG:root:Epoch [6/15], Batch [160/523], Loss: -0.8680058717727661
# DEBUG:root:Epoch [6/15], Batch [170/523], Loss: -0.8224326372146606
# DEBUG:root:Epoch [6/15], Batch [180/523], Loss: -0.8316711783409119
# DEBUG:root:Epoch [6/15], Batch [190/523], Loss: -0.8590673208236694
# DEBUG:root:Epoch [6/15], Batch [200/523], Loss: -0.8782302737236023
# DEBUG:root:Epoch [6/15], Batch [210/523], Loss: -0.8905583620071411
# DEBUG:root:Epoch [6/15], Batch [220/523], Loss: -0.8915446996688843
# DEBUG:root:Epoch [6/15], Batch [230/523], Loss: -0.8843851089477539
# DEBUG:root:Epoch [6/15], Batch [240/523], Loss: -0.8772682547569275
# DEBUG:root:Epoch [6/15], Batch [250/523], Loss: -0.8763704299926758
# DEBUG:root:Epoch [6/15], Batch [260/523], Loss: -0.8532634973526001
# DEBUG:root:Epoch [6/15], Batch [270/523], Loss: -0.9227288365364075
# DEBUG:root:Epoch [6/15], Batch [280/523], Loss: -0.8998890519142151
# DEBUG:root:Epoch [6/15], Batch [290/523], Loss: -0.9036313891410828
# DEBUG:root:Epoch [6/15], Batch [300/523], Loss: -0.8832148909568787
# DEBUG:root:Epoch [6/15], Batch [310/523], Loss: -0.923668384552002
# DEBUG:root:Epoch [6/15], Batch [320/523], Loss: -0.8786880970001221
# DEBUG:root:Epoch [6/15], Batch [330/523], Loss: -0.8490118980407715
# DEBUG:root:Epoch [6/15], Batch [340/523], Loss: -0.8827539086341858
# DEBUG:root:Epoch [6/15], Batch [350/523], Loss: -0.8709855079650879
# DEBUG:root:Epoch [6/15], Batch [360/523], Loss: -0.8786677122116089
# DEBUG:root:Epoch [6/15], Batch [370/523], Loss: -0.8800218105316162
# DEBUG:root:Epoch [6/15], Batch [380/523], Loss: -0.8777256608009338
# DEBUG:root:Epoch [6/15], Batch [390/523], Loss: -0.8611663579940796
# DEBUG:root:Epoch [6/15], Batch [400/523], Loss: -0.8887548446655273
# DEBUG:root:Epoch [6/15], Batch [410/523], Loss: -0.9485604763031006
# DEBUG:root:Epoch [6/15], Batch [420/523], Loss: -0.8690143823623657
# DEBUG:root:Epoch [6/15], Batch [430/523], Loss: -0.8813329935073853
# DEBUG:root:Epoch [6/15], Batch [440/523], Loss: -0.8862981796264648
# DEBUG:root:Epoch [6/15], Batch [450/523], Loss: -0.9346074461936951
# DEBUG:root:Epoch [6/15], Batch [460/523], Loss: -0.8956472873687744
# DEBUG:root:Epoch [6/15], Batch [470/523], Loss: -0.8559553027153015
# DEBUG:root:Epoch [6/15], Batch [480/523], Loss: -0.8787402510643005
# DEBUG:root:Epoch [6/15], Batch [490/523], Loss: -0.877994179725647
# DEBUG:root:Epoch [6/15], Batch [500/523], Loss: -0.8390614986419678
# DEBUG:root:Epoch [6/15], Batch [510/523], Loss: -0.8598830699920654
# DEBUG:root:Epoch [6/15], Batch [520/523], Loss: -0.8760936260223389
# DEBUG:root:epoch: 06, loss: -0.87958
# DEBUG:root:Epoch [7/15], Batch [0/523], Loss: -0.796631932258606
# DEBUG:root:Epoch [7/15], Batch [10/523], Loss: -0.8544614315032959
# DEBUG:root:Epoch [7/15], Batch [20/523], Loss: -0.8313241004943848
# DEBUG:root:Epoch [7/15], Batch [30/523], Loss: -0.8522926568984985
# DEBUG:root:Epoch [7/15], Batch [40/523], Loss: -0.8603839874267578
# DEBUG:root:Epoch [7/15], Batch [50/523], Loss: -0.9091766476631165
# DEBUG:root:Epoch [7/15], Batch [60/523], Loss: -0.8644829392433167
# DEBUG:root:Epoch [7/15], Batch [70/523], Loss: -0.8935768604278564
# DEBUG:root:Epoch [7/15], Batch [80/523], Loss: -0.9095919132232666
# DEBUG:root:Epoch [7/15], Batch [90/523], Loss: -0.9049476385116577
# DEBUG:root:Epoch [7/15], Batch [100/523], Loss: -0.8881484270095825
# DEBUG:root:Epoch [7/15], Batch [110/523], Loss: -0.8745688199996948
# DEBUG:root:Epoch [7/15], Batch [120/523], Loss: -0.8836053609848022
# DEBUG:root:Epoch [7/15], Batch [130/523], Loss: -0.8872303366661072
# DEBUG:root:Epoch [7/15], Batch [140/523], Loss: -0.82313072681427
# DEBUG:root:Epoch [7/15], Batch [150/523], Loss: -0.8696672916412354
# DEBUG:root:Epoch [7/15], Batch [160/523], Loss: -0.8126513361930847
# DEBUG:root:Epoch [7/15], Batch [170/523], Loss: -0.8762045502662659
# DEBUG:root:Epoch [7/15], Batch [180/523], Loss: -0.8826395273208618
# DEBUG:root:Epoch [7/15], Batch [190/523], Loss: -0.8879733085632324
# DEBUG:root:Epoch [7/15], Batch [200/523], Loss: -0.9190886616706848
# DEBUG:root:Epoch [7/15], Batch [210/523], Loss: -0.8993849754333496
# DEBUG:root:Epoch [7/15], Batch [220/523], Loss: -0.8757234811782837
# DEBUG:root:Epoch [7/15], Batch [230/523], Loss: -0.8528106212615967
# DEBUG:root:Epoch [7/15], Batch [240/523], Loss: -0.8324286937713623
# DEBUG:root:Epoch [7/15], Batch [250/523], Loss: -0.9030066728591919
# DEBUG:root:Epoch [7/15], Batch [260/523], Loss: -0.8712947964668274
# DEBUG:root:Epoch [7/15], Batch [270/523], Loss: -0.8333268165588379
# DEBUG:root:Epoch [7/15], Batch [280/523], Loss: -0.881840705871582
# DEBUG:root:Epoch [7/15], Batch [290/523], Loss: -0.8460614681243896
# DEBUG:root:Epoch [7/15], Batch [300/523], Loss: -0.8581119775772095
# DEBUG:root:Epoch [7/15], Batch [310/523], Loss: -0.8790059089660645
# DEBUG:root:Epoch [7/15], Batch [320/523], Loss: -0.8903433084487915
# DEBUG:root:Epoch [7/15], Batch [330/523], Loss: -0.8961026668548584
# DEBUG:root:Epoch [7/15], Batch [340/523], Loss: -0.9086130261421204
# DEBUG:root:Epoch [7/15], Batch [350/523], Loss: -0.8490777015686035
# DEBUG:root:Epoch [7/15], Batch [360/523], Loss: -0.8729934692382812
# DEBUG:root:Epoch [7/15], Batch [370/523], Loss: -0.8839951157569885
# DEBUG:root:Epoch [7/15], Batch [380/523], Loss: -0.9070031046867371
# DEBUG:root:Epoch [7/15], Batch [390/523], Loss: -0.8588590621948242
# DEBUG:root:Epoch [7/15], Batch [400/523], Loss: -0.8876198530197144
# DEBUG:root:Epoch [7/15], Batch [410/523], Loss: -0.9184355735778809
# DEBUG:root:Epoch [7/15], Batch [420/523], Loss: -0.9328595399856567
# DEBUG:root:Epoch [7/15], Batch [430/523], Loss: -0.8774574398994446
# DEBUG:root:Epoch [7/15], Batch [440/523], Loss: -0.86347496509552
# DEBUG:root:Epoch [7/15], Batch [450/523], Loss: -0.8958068490028381
# DEBUG:root:Epoch [7/15], Batch [460/523], Loss: -0.9141833186149597
# DEBUG:root:Epoch [7/15], Batch [470/523], Loss: -0.9024109840393066
# DEBUG:root:Epoch [7/15], Batch [480/523], Loss: -0.8819222450256348
# DEBUG:root:Epoch [7/15], Batch [490/523], Loss: -0.8841661214828491
# DEBUG:root:Epoch [7/15], Batch [500/523], Loss: -0.8735951781272888
# DEBUG:root:Epoch [7/15], Batch [510/523], Loss: -0.9056622982025146
# DEBUG:root:Epoch [7/15], Batch [520/523], Loss: -0.9363670349121094
# DEBUG:root:epoch: 07, loss: -0.87846
# DEBUG:root:Epoch [8/15], Batch [0/523], Loss: -0.8833563327789307
# DEBUG:root:Epoch [8/15], Batch [10/523], Loss: -0.8720328211784363
# DEBUG:root:Epoch [8/15], Batch [20/523], Loss: -0.8521178960800171
# DEBUG:root:Epoch [8/15], Batch [30/523], Loss: -0.8679850101470947
# DEBUG:root:Epoch [8/15], Batch [40/523], Loss: -0.8186565637588501
# DEBUG:root:Epoch [8/15], Batch [50/523], Loss: -0.8257564902305603
# DEBUG:root:Epoch [8/15], Batch [60/523], Loss: -0.7957037687301636
# DEBUG:root:Epoch [8/15], Batch [70/523], Loss: -0.851823091506958
# DEBUG:root:Epoch [8/15], Batch [80/523], Loss: -0.8695414066314697
# DEBUG:root:Epoch [8/15], Batch [90/523], Loss: -0.841550350189209
# DEBUG:root:Epoch [8/15], Batch [100/523], Loss: -0.8252565264701843
# DEBUG:root:Epoch [8/15], Batch [110/523], Loss: -0.8440983891487122
# DEBUG:root:Epoch [8/15], Batch [120/523], Loss: -0.8984572887420654
# DEBUG:root:Epoch [8/15], Batch [130/523], Loss: -0.9023046493530273
# DEBUG:root:Epoch [8/15], Batch [140/523], Loss: -0.8818401098251343
# DEBUG:root:Epoch [8/15], Batch [150/523], Loss: -0.8862104415893555
# DEBUG:root:Epoch [8/15], Batch [160/523], Loss: -0.9224041700363159
# DEBUG:root:Epoch [8/15], Batch [170/523], Loss: -0.9119421243667603
# DEBUG:root:Epoch [8/15], Batch [180/523], Loss: -0.9296898245811462
# DEBUG:root:Epoch [8/15], Batch [190/523], Loss: -0.9059564471244812
# DEBUG:root:Epoch [8/15], Batch [200/523], Loss: -0.9536978602409363
# DEBUG:root:Epoch [8/15], Batch [210/523], Loss: -0.9000573754310608
# DEBUG:root:Epoch [8/15], Batch [220/523], Loss: -0.8826421499252319
# DEBUG:root:Epoch [8/15], Batch [230/523], Loss: -0.9444948434829712
# DEBUG:root:Epoch [8/15], Batch [240/523], Loss: -0.9130080342292786
# DEBUG:root:Epoch [8/15], Batch [250/523], Loss: -0.9434144496917725
# DEBUG:root:Epoch [8/15], Batch [260/523], Loss: -0.8972909450531006
# DEBUG:root:Epoch [8/15], Batch [270/523], Loss: -0.9158564805984497
# DEBUG:root:Epoch [8/15], Batch [280/523], Loss: -0.9078851938247681
# DEBUG:root:Epoch [8/15], Batch [290/523], Loss: -0.9012422561645508
# DEBUG:root:Epoch [8/15], Batch [300/523], Loss: -0.8889889717102051
# DEBUG:root:Epoch [8/15], Batch [310/523], Loss: -0.9166074991226196
# DEBUG:root:Epoch [8/15], Batch [320/523], Loss: -0.8967126607894897
# DEBUG:root:Epoch [8/15], Batch [330/523], Loss: -0.911657452583313
# DEBUG:root:Epoch [8/15], Batch [340/523], Loss: -0.913751482963562
# DEBUG:root:Epoch [8/15], Batch [350/523], Loss: -0.9170196056365967
# DEBUG:root:Epoch [8/15], Batch [360/523], Loss: -0.9199773073196411
# DEBUG:root:Epoch [8/15], Batch [370/523], Loss: -0.8245147466659546
# DEBUG:root:Epoch [8/15], Batch [380/523], Loss: -0.8845112323760986
# DEBUG:root:Epoch [8/15], Batch [390/523], Loss: -0.9503523111343384
# DEBUG:root:Epoch [8/15], Batch [400/523], Loss: -0.8688899874687195
# DEBUG:root:Epoch [8/15], Batch [410/523], Loss: -0.9337218999862671
# DEBUG:root:Epoch [8/15], Batch [420/523], Loss: -0.8628469705581665
# DEBUG:root:Epoch [8/15], Batch [430/523], Loss: -0.9189600348472595
# DEBUG:root:Epoch [8/15], Batch [440/523], Loss: -0.8979597091674805
# DEBUG:root:Epoch [8/15], Batch [450/523], Loss: -0.891558051109314
# DEBUG:root:Epoch [8/15], Batch [460/523], Loss: -0.908430814743042
# DEBUG:root:Epoch [8/15], Batch [470/523], Loss: -0.9214406609535217
# DEBUG:root:Epoch [8/15], Batch [480/523], Loss: -0.892841637134552
# DEBUG:root:Epoch [8/15], Batch [490/523], Loss: -0.918853759765625
# DEBUG:root:Epoch [8/15], Batch [500/523], Loss: -0.9305956363677979
# DEBUG:root:Epoch [8/15], Batch [510/523], Loss: -0.954128086566925
# DEBUG:root:Epoch [8/15], Batch [520/523], Loss: -0.8409514427185059
# DEBUG:root:epoch: 08, loss: -0.89292
# DEBUG:root:Epoch [9/15], Batch [0/523], Loss: -0.9329579472541809
# DEBUG:root:Epoch [9/15], Batch [10/523], Loss: -0.9203614592552185
# DEBUG:root:Epoch [9/15], Batch [20/523], Loss: -0.8807867765426636
# DEBUG:root:Epoch [9/15], Batch [30/523], Loss: -0.8896753191947937
# DEBUG:root:Epoch [9/15], Batch [40/523], Loss: -0.8802828788757324
# DEBUG:root:Epoch [9/15], Batch [50/523], Loss: -0.8930037617683411
# DEBUG:root:Epoch [9/15], Batch [60/523], Loss: -0.9134243726730347
# DEBUG:root:Epoch [9/15], Batch [70/523], Loss: -0.881275475025177
# DEBUG:root:Epoch [9/15], Batch [80/523], Loss: -0.9157756567001343
# DEBUG:root:Epoch [9/15], Batch [90/523], Loss: -0.9124515056610107
# DEBUG:root:Epoch [9/15], Batch [100/523], Loss: -0.9096595048904419
# DEBUG:root:Epoch [9/15], Batch [110/523], Loss: -0.8542082905769348
# DEBUG:root:Epoch [9/15], Batch [120/523], Loss: -0.9180893898010254
# DEBUG:root:Epoch [9/15], Batch [130/523], Loss: -0.9050208330154419
# DEBUG:root:Epoch [9/15], Batch [140/523], Loss: -0.9190236330032349
# DEBUG:root:Epoch [9/15], Batch [150/523], Loss: -0.8947688341140747
# DEBUG:root:Epoch [9/15], Batch [160/523], Loss: -0.8956177234649658
# DEBUG:root:Epoch [9/15], Batch [170/523], Loss: -0.9517695307731628
# DEBUG:root:Epoch [9/15], Batch [180/523], Loss: -0.8677090406417847
# DEBUG:root:Epoch [9/15], Batch [190/523], Loss: -0.8857666254043579
# DEBUG:root:Epoch [9/15], Batch [200/523], Loss: -0.9358530044555664
# DEBUG:root:Epoch [9/15], Batch [210/523], Loss: -0.937745988368988
# DEBUG:root:Epoch [9/15], Batch [220/523], Loss: -0.8786642551422119
# DEBUG:root:Epoch [9/15], Batch [230/523], Loss: -0.8965135812759399
# DEBUG:root:Epoch [9/15], Batch [240/523], Loss: -0.9062592387199402
# DEBUG:root:Epoch [9/15], Batch [250/523], Loss: -0.9272908568382263
# DEBUG:root:Epoch [9/15], Batch [260/523], Loss: -0.9400219917297363
# DEBUG:root:Epoch [9/15], Batch [270/523], Loss: -0.9058275818824768
# DEBUG:root:Epoch [9/15], Batch [280/523], Loss: -0.8936419486999512
# DEBUG:root:Epoch [9/15], Batch [290/523], Loss: -0.8857381343841553
# DEBUG:root:Epoch [9/15], Batch [300/523], Loss: -0.9021669626235962
# DEBUG:root:Epoch [9/15], Batch [310/523], Loss: -0.9441114664077759
# DEBUG:root:Epoch [9/15], Batch [320/523], Loss: -0.9019253253936768
# DEBUG:root:Epoch [9/15], Batch [330/523], Loss: -0.9301614761352539
# DEBUG:root:Epoch [9/15], Batch [340/523], Loss: -0.9002785086631775
# DEBUG:root:Epoch [9/15], Batch [350/523], Loss: -0.9046192169189453
# DEBUG:root:Epoch [9/15], Batch [360/523], Loss: -0.8783301711082458
# DEBUG:root:Epoch [9/15], Batch [370/523], Loss: -0.889850378036499
# DEBUG:root:Epoch [9/15], Batch [380/523], Loss: -0.862713634967804
# DEBUG:root:Epoch [9/15], Batch [390/523], Loss: -0.9166979789733887
# DEBUG:root:Epoch [9/15], Batch [400/523], Loss: -0.8910459280014038
# DEBUG:root:Epoch [9/15], Batch [410/523], Loss: -0.9061815738677979
# DEBUG:root:Epoch [9/15], Batch [420/523], Loss: -0.8247228860855103
# DEBUG:root:Epoch [9/15], Batch [430/523], Loss: -0.8793323636054993
# DEBUG:root:Epoch [9/15], Batch [440/523], Loss: -0.9218243956565857
# DEBUG:root:Epoch [9/15], Batch [450/523], Loss: -0.8918095827102661
# DEBUG:root:Epoch [9/15], Batch [460/523], Loss: -0.8597594499588013
# DEBUG:root:Epoch [9/15], Batch [470/523], Loss: -0.8533868789672852
# DEBUG:root:Epoch [9/15], Batch [480/523], Loss: -0.9050760865211487
# DEBUG:root:Epoch [9/15], Batch [490/523], Loss: -0.8613479137420654
# DEBUG:root:Epoch [9/15], Batch [500/523], Loss: -0.8636436462402344
# DEBUG:root:Epoch [9/15], Batch [510/523], Loss: -0.898262619972229
# DEBUG:root:Epoch [9/15], Batch [520/523], Loss: -0.8713076114654541
# DEBUG:root:epoch: 09, loss: -0.89763
# DEBUG:root:Epoch [10/15], Batch [0/523], Loss: -0.8605801463127136
# DEBUG:root:Epoch [10/15], Batch [10/523], Loss: -0.9147956967353821
# DEBUG:root:Epoch [10/15], Batch [20/523], Loss: -0.8512042760848999
# DEBUG:root:Epoch [10/15], Batch [30/523], Loss: -0.9100944995880127
# DEBUG:root:Epoch [10/15], Batch [40/523], Loss: -0.8693935871124268
# DEBUG:root:Epoch [10/15], Batch [50/523], Loss: -0.8869346976280212
# DEBUG:root:Epoch [10/15], Batch [60/523], Loss: -0.8859734535217285
# DEBUG:root:Epoch [10/15], Batch [70/523], Loss: -0.8990544080734253
# DEBUG:root:Epoch [10/15], Batch [80/523], Loss: -0.8930536508560181
# DEBUG:root:Epoch [10/15], Batch [90/523], Loss: -0.8326102495193481
# DEBUG:root:Epoch [10/15], Batch [100/523], Loss: -0.8849160671234131
# DEBUG:root:Epoch [10/15], Batch [110/523], Loss: -0.9373619556427002
# DEBUG:root:Epoch [10/15], Batch [120/523], Loss: -0.8657856583595276
# DEBUG:root:Epoch [10/15], Batch [130/523], Loss: -0.8690252304077148
# DEBUG:root:Epoch [10/15], Batch [140/523], Loss: -0.8542360067367554
# DEBUG:root:Epoch [10/15], Batch [150/523], Loss: -0.8753079175949097
# DEBUG:root:Epoch [10/15], Batch [160/523], Loss: -0.8936376571655273
# DEBUG:root:Epoch [10/15], Batch [170/523], Loss: -0.9135934114456177
# DEBUG:root:Epoch [10/15], Batch [180/523], Loss: -0.8833506107330322
# DEBUG:root:Epoch [10/15], Batch [190/523], Loss: -0.9208278059959412
# DEBUG:root:Epoch [10/15], Batch [200/523], Loss: -0.8915618658065796
# DEBUG:root:Epoch [10/15], Batch [210/523], Loss: -0.8745286464691162
# DEBUG:root:Epoch [10/15], Batch [220/523], Loss: -0.9046844244003296
# DEBUG:root:Epoch [10/15], Batch [230/523], Loss: -0.8846014738082886
# DEBUG:root:Epoch [10/15], Batch [240/523], Loss: -0.9064024686813354
# DEBUG:root:Epoch [10/15], Batch [250/523], Loss: -0.8991729021072388
# DEBUG:root:Epoch [10/15], Batch [260/523], Loss: -0.897618293762207
# DEBUG:root:Epoch [10/15], Batch [270/523], Loss: -0.9122617840766907
# DEBUG:root:Epoch [10/15], Batch [280/523], Loss: -0.874839186668396
# DEBUG:root:Epoch [10/15], Batch [290/523], Loss: -0.8754587173461914
# DEBUG:root:Epoch [10/15], Batch [300/523], Loss: -0.9078034162521362
# DEBUG:root:Epoch [10/15], Batch [310/523], Loss: -0.8945008516311646
# DEBUG:root:Epoch [10/15], Batch [320/523], Loss: -0.9239911437034607
# DEBUG:root:Epoch [10/15], Batch [330/523], Loss: -0.9341861605644226
# DEBUG:root:Epoch [10/15], Batch [340/523], Loss: -0.9193638563156128
# DEBUG:root:Epoch [10/15], Batch [350/523], Loss: -0.902319610118866
# DEBUG:root:Epoch [10/15], Batch [360/523], Loss: -0.9137851595878601
# DEBUG:root:Epoch [10/15], Batch [370/523], Loss: -0.8651214241981506
# DEBUG:root:Epoch [10/15], Batch [380/523], Loss: -0.9237848520278931
# DEBUG:root:Epoch [10/15], Batch [390/523], Loss: -0.8903517723083496
# DEBUG:root:Epoch [10/15], Batch [400/523], Loss: -0.9139918684959412
# DEBUG:root:Epoch [10/15], Batch [410/523], Loss: -0.8780502676963806
# DEBUG:root:Epoch [10/15], Batch [420/523], Loss: -0.888221025466919
# DEBUG:root:Epoch [10/15], Batch [430/523], Loss: -0.9142805933952332
# DEBUG:root:Epoch [10/15], Batch [440/523], Loss: -0.9327566027641296
# DEBUG:root:Epoch [10/15], Batch [450/523], Loss: -0.9062026739120483
# DEBUG:root:Epoch [10/15], Batch [460/523], Loss: -0.9377456903457642
# DEBUG:root:Epoch [10/15], Batch [470/523], Loss: -0.8793402910232544
# DEBUG:root:Epoch [10/15], Batch [480/523], Loss: -0.9111398458480835
# DEBUG:root:Epoch [10/15], Batch [490/523], Loss: -0.923397421836853
# DEBUG:root:Epoch [10/15], Batch [500/523], Loss: -0.9267881512641907
# DEBUG:root:Epoch [10/15], Batch [510/523], Loss: -0.9127689599990845
# DEBUG:root:Epoch [10/15], Batch [520/523], Loss: -0.9086834192276001
# DEBUG:root:epoch: 10, loss: -0.89435
# DEBUG:root:Epoch [11/15], Batch [0/523], Loss: -0.89534592628479
# DEBUG:root:Epoch [11/15], Batch [10/523], Loss: -0.9123553037643433
# DEBUG:root:Epoch [11/15], Batch [20/523], Loss: -0.8755348324775696
# DEBUG:root:Epoch [11/15], Batch [30/523], Loss: -0.9232349395751953
# DEBUG:root:Epoch [11/15], Batch [40/523], Loss: -0.9177520871162415
# DEBUG:root:Epoch [11/15], Batch [50/523], Loss: -0.8918088674545288
# DEBUG:root:Epoch [11/15], Batch [60/523], Loss: -0.9067286252975464
# DEBUG:root:Epoch [11/15], Batch [70/523], Loss: -0.8878653049468994
# DEBUG:root:Epoch [11/15], Batch [80/523], Loss: -0.8766673803329468
# DEBUG:root:Epoch [11/15], Batch [90/523], Loss: -0.9011173844337463
# DEBUG:root:Epoch [11/15], Batch [100/523], Loss: -0.9031840562820435
# DEBUG:root:Epoch [11/15], Batch [110/523], Loss: -0.9202660322189331
# DEBUG:root:Epoch [11/15], Batch [120/523], Loss: -0.8831838369369507
# DEBUG:root:Epoch [11/15], Batch [130/523], Loss: -0.9081015586853027
# DEBUG:root:Epoch [11/15], Batch [140/523], Loss: -0.8843140006065369
# DEBUG:root:Epoch [11/15], Batch [150/523], Loss: -0.8995883464813232
# DEBUG:root:Epoch [11/15], Batch [160/523], Loss: -0.8803939819335938
# DEBUG:root:Epoch [11/15], Batch [170/523], Loss: -0.880776047706604
# DEBUG:root:Epoch [11/15], Batch [180/523], Loss: -0.8526886701583862
# DEBUG:root:Epoch [11/15], Batch [190/523], Loss: -0.917363703250885
# DEBUG:root:Epoch [11/15], Batch [200/523], Loss: -0.8836137056350708
# DEBUG:root:Epoch [11/15], Batch [210/523], Loss: -0.8496474623680115
# DEBUG:root:Epoch [11/15], Batch [220/523], Loss: -0.8873040080070496
# DEBUG:root:Epoch [11/15], Batch [230/523], Loss: -0.8906875252723694
# DEBUG:root:Epoch [11/15], Batch [240/523], Loss: -0.8756779432296753
# DEBUG:root:Epoch [11/15], Batch [250/523], Loss: -0.8888538479804993
# DEBUG:root:Epoch [11/15], Batch [260/523], Loss: -0.881632387638092
# DEBUG:root:Epoch [11/15], Batch [270/523], Loss: -0.8829513788223267
# DEBUG:root:Epoch [11/15], Batch [280/523], Loss: -0.9038920402526855
# DEBUG:root:Epoch [11/15], Batch [290/523], Loss: -0.9017915725708008
# DEBUG:root:Epoch [11/15], Batch [300/523], Loss: -0.8864572048187256
# DEBUG:root:Epoch [11/15], Batch [310/523], Loss: -0.8958977460861206
# DEBUG:root:Epoch [11/15], Batch [320/523], Loss: -0.913093090057373
# DEBUG:root:Epoch [11/15], Batch [330/523], Loss: -0.9240472316741943
# DEBUG:root:Epoch [11/15], Batch [340/523], Loss: -0.9438626766204834
# DEBUG:root:Epoch [11/15], Batch [350/523], Loss: -0.8644332885742188
# DEBUG:root:Epoch [11/15], Batch [360/523], Loss: -0.9065090417861938
# DEBUG:root:Epoch [11/15], Batch [370/523], Loss: -0.8816921710968018
# DEBUG:root:Epoch [11/15], Batch [380/523], Loss: -0.9367667436599731
# DEBUG:root:Epoch [11/15], Batch [390/523], Loss: -0.9207313656806946
# DEBUG:root:Epoch [11/15], Batch [400/523], Loss: -0.8908791542053223
# DEBUG:root:Epoch [11/15], Batch [410/523], Loss: -0.9507613182067871
# DEBUG:root:Epoch [11/15], Batch [420/523], Loss: -0.8530319929122925
# DEBUG:root:Epoch [11/15], Batch [430/523], Loss: -0.9080237150192261
# DEBUG:root:Epoch [11/15], Batch [440/523], Loss: -0.9334069490432739
# DEBUG:root:Epoch [11/15], Batch [450/523], Loss: -0.9259215593338013
# DEBUG:root:Epoch [11/15], Batch [460/523], Loss: -0.8991497755050659
# DEBUG:root:Epoch [11/15], Batch [470/523], Loss: -0.9046522378921509
# DEBUG:root:Epoch [11/15], Batch [480/523], Loss: -0.9348139762878418
# DEBUG:root:Epoch [11/15], Batch [490/523], Loss: -0.922532856464386
# DEBUG:root:Epoch [11/15], Batch [500/523], Loss: -0.9029513597488403
# DEBUG:root:Epoch [11/15], Batch [510/523], Loss: -0.8997202515602112
# DEBUG:root:Epoch [11/15], Batch [520/523], Loss: -0.9162884950637817
# DEBUG:root:epoch: 11, loss: -0.90235
# DEBUG:root:Epoch [12/15], Batch [0/523], Loss: -0.8798266649246216
# DEBUG:root:Epoch [12/15], Batch [10/523], Loss: -0.9022384881973267
# DEBUG:root:Epoch [12/15], Batch [20/523], Loss: -0.9245575666427612
# DEBUG:root:Epoch [12/15], Batch [30/523], Loss: -0.8745616674423218
# DEBUG:root:Epoch [12/15], Batch [40/523], Loss: -0.8792644143104553
# DEBUG:root:Epoch [12/15], Batch [50/523], Loss: -0.9054586291313171
# DEBUG:root:Epoch [12/15], Batch [60/523], Loss: -0.9240633845329285
# DEBUG:root:Epoch [12/15], Batch [70/523], Loss: -0.8934643864631653
# DEBUG:root:Epoch [12/15], Batch [80/523], Loss: -0.9052183628082275
# DEBUG:root:Epoch [12/15], Batch [90/523], Loss: -0.8965189456939697
# DEBUG:root:Epoch [12/15], Batch [100/523], Loss: -0.9263032674789429
# DEBUG:root:Epoch [12/15], Batch [110/523], Loss: -0.9541770219802856
# DEBUG:root:Epoch [12/15], Batch [120/523], Loss: -0.9166362285614014
# DEBUG:root:Epoch [12/15], Batch [130/523], Loss: -0.9095258712768555
# DEBUG:root:Epoch [12/15], Batch [140/523], Loss: -0.9055699110031128
# DEBUG:root:Epoch [12/15], Batch [150/523], Loss: -0.9334367513656616
# DEBUG:root:Epoch [12/15], Batch [160/523], Loss: -0.9350335597991943
# DEBUG:root:Epoch [12/15], Batch [170/523], Loss: -0.9453084468841553
# DEBUG:root:Epoch [12/15], Batch [180/523], Loss: -0.9365931153297424
# DEBUG:root:Epoch [12/15], Batch [190/523], Loss: -0.91562819480896
# DEBUG:root:Epoch [12/15], Batch [200/523], Loss: -0.9455910921096802
# DEBUG:root:Epoch [12/15], Batch [210/523], Loss: -0.9283362627029419
# DEBUG:root:Epoch [12/15], Batch [220/523], Loss: -0.9286375045776367
# DEBUG:root:Epoch [12/15], Batch [230/523], Loss: -0.9369156360626221
# DEBUG:root:Epoch [12/15], Batch [240/523], Loss: -0.9081180095672607
# DEBUG:root:Epoch [12/15], Batch [250/523], Loss: -0.9347920417785645
# DEBUG:root:Epoch [12/15], Batch [260/523], Loss: -0.953658938407898
# DEBUG:root:Epoch [12/15], Batch [270/523], Loss: -0.9457451105117798
# DEBUG:root:Epoch [12/15], Batch [280/523], Loss: -0.9417277574539185
# DEBUG:root:Epoch [12/15], Batch [290/523], Loss: -0.8945746421813965
# DEBUG:root:Epoch [12/15], Batch [300/523], Loss: -0.9357703924179077
# DEBUG:root:Epoch [12/15], Batch [310/523], Loss: -0.906688392162323
# DEBUG:root:Epoch [12/15], Batch [320/523], Loss: -0.9218283295631409
# DEBUG:root:Epoch [12/15], Batch [330/523], Loss: -0.9000677466392517
# DEBUG:root:Epoch [12/15], Batch [340/523], Loss: -0.8846546411514282
# DEBUG:root:Epoch [12/15], Batch [350/523], Loss: -0.912263035774231
# DEBUG:root:Epoch [12/15], Batch [360/523], Loss: -0.9024492502212524
# DEBUG:root:Epoch [12/15], Batch [370/523], Loss: -0.9491649270057678
# DEBUG:root:Epoch [12/15], Batch [380/523], Loss: -0.8821737766265869
# DEBUG:root:Epoch [12/15], Batch [390/523], Loss: -0.9170247316360474
# DEBUG:root:Epoch [12/15], Batch [400/523], Loss: -0.9147477149963379
# DEBUG:root:Epoch [12/15], Batch [410/523], Loss: -0.9245728254318237
# DEBUG:root:Epoch [12/15], Batch [420/523], Loss: -0.9402490258216858
# DEBUG:root:Epoch [12/15], Batch [430/523], Loss: -0.9259234666824341
# DEBUG:root:Epoch [12/15], Batch [440/523], Loss: -0.9259457588195801
# DEBUG:root:Epoch [12/15], Batch [450/523], Loss: -0.9247739315032959
# DEBUG:root:Epoch [12/15], Batch [460/523], Loss: -0.9125332832336426
# DEBUG:root:Epoch [12/15], Batch [470/523], Loss: -0.9420580863952637
# DEBUG:root:Epoch [12/15], Batch [480/523], Loss: -0.9431018829345703
# DEBUG:root:Epoch [12/15], Batch [490/523], Loss: -0.8948452472686768
# DEBUG:root:Epoch [12/15], Batch [500/523], Loss: -0.8879728317260742
# DEBUG:root:Epoch [12/15], Batch [510/523], Loss: -0.9329320192337036
# DEBUG:root:Epoch [12/15], Batch [520/523], Loss: -0.9081094264984131
# DEBUG:root:epoch: 12, loss: -0.91731
# DEBUG:root:Epoch [13/15], Batch [0/523], Loss: -0.967448353767395
# DEBUG:root:Epoch [13/15], Batch [10/523], Loss: -0.9216711521148682
# DEBUG:root:Epoch [13/15], Batch [20/523], Loss: -0.9528438448905945
# DEBUG:root:Epoch [13/15], Batch [30/523], Loss: -0.9375714063644409
# DEBUG:root:Epoch [13/15], Batch [40/523], Loss: -0.947577178478241
# DEBUG:root:Epoch [13/15], Batch [50/523], Loss: -0.9496442079544067
# DEBUG:root:Epoch [13/15], Batch [60/523], Loss: -0.9067535400390625
# DEBUG:root:Epoch [13/15], Batch [70/523], Loss: -0.9283022284507751
# DEBUG:root:Epoch [13/15], Batch [80/523], Loss: -0.9376562833786011
# DEBUG:root:Epoch [13/15], Batch [90/523], Loss: -0.920376718044281
# DEBUG:root:Epoch [13/15], Batch [100/523], Loss: -0.9058158993721008
# DEBUG:root:Epoch [13/15], Batch [110/523], Loss: -0.9192125201225281
# DEBUG:root:Epoch [13/15], Batch [120/523], Loss: -0.9042358994483948
# DEBUG:root:Epoch [13/15], Batch [130/523], Loss: -0.8906906843185425
# DEBUG:root:Epoch [13/15], Batch [140/523], Loss: -0.9067468643188477
# DEBUG:root:Epoch [13/15], Batch [150/523], Loss: -0.9185333847999573
# DEBUG:root:Epoch [13/15], Batch [160/523], Loss: -0.9294840097427368
# DEBUG:root:Epoch [13/15], Batch [170/523], Loss: -0.9100474715232849
# DEBUG:root:Epoch [13/15], Batch [180/523], Loss: -0.8732694387435913
# DEBUG:root:Epoch [13/15], Batch [190/523], Loss: -0.906481146812439
# DEBUG:root:Epoch [13/15], Batch [200/523], Loss: -0.8912909626960754
# DEBUG:root:Epoch [13/15], Batch [210/523], Loss: -0.9060847759246826
# DEBUG:root:Epoch [13/15], Batch [220/523], Loss: -0.8829650282859802
# DEBUG:root:Epoch [13/15], Batch [230/523], Loss: -0.8518956899642944
# DEBUG:root:Epoch [13/15], Batch [240/523], Loss: -0.823151707649231
# DEBUG:root:Epoch [13/15], Batch [250/523], Loss: -0.8536912202835083
# DEBUG:root:Epoch [13/15], Batch [260/523], Loss: -0.8567956686019897
# DEBUG:root:Epoch [13/15], Batch [270/523], Loss: -0.8541626334190369
# DEBUG:root:Epoch [13/15], Batch [280/523], Loss: -0.8916763663291931
# DEBUG:root:Epoch [13/15], Batch [290/523], Loss: -0.889541506767273
# DEBUG:root:Epoch [13/15], Batch [300/523], Loss: -0.8818593621253967
# DEBUG:root:Epoch [13/15], Batch [310/523], Loss: -0.8860024213790894
# DEBUG:root:Epoch [13/15], Batch [320/523], Loss: -0.8836953043937683
# DEBUG:root:Epoch [13/15], Batch [330/523], Loss: -0.8563240766525269
# DEBUG:root:Epoch [13/15], Batch [340/523], Loss: -0.9146575927734375
# DEBUG:root:Epoch [13/15], Batch [350/523], Loss: -0.8763147592544556
# DEBUG:root:Epoch [13/15], Batch [360/523], Loss: -0.8977020382881165
# DEBUG:root:Epoch [13/15], Batch [370/523], Loss: -0.9168645143508911
# DEBUG:root:Epoch [13/15], Batch [380/523], Loss: -0.8810093998908997
# DEBUG:root:Epoch [13/15], Batch [390/523], Loss: -0.8940690755844116
# DEBUG:root:Epoch [13/15], Batch [400/523], Loss: -0.8832135200500488
# DEBUG:root:Epoch [13/15], Batch [410/523], Loss: -0.8783367276191711
# DEBUG:root:Epoch [13/15], Batch [420/523], Loss: -0.8317015767097473
# DEBUG:root:Epoch [13/15], Batch [430/523], Loss: -0.9020932912826538
# DEBUG:root:Epoch [13/15], Batch [440/523], Loss: -0.8751322031021118
# DEBUG:root:Epoch [13/15], Batch [450/523], Loss: -0.8928884863853455
# DEBUG:root:Epoch [13/15], Batch [460/523], Loss: -0.9042369723320007
# DEBUG:root:Epoch [13/15], Batch [470/523], Loss: -0.8669470548629761
# DEBUG:root:Epoch [13/15], Batch [480/523], Loss: -0.906671404838562
# DEBUG:root:Epoch [13/15], Batch [490/523], Loss: -0.8627885580062866
# DEBUG:root:Epoch [13/15], Batch [500/523], Loss: -0.8957064747810364
# DEBUG:root:Epoch [13/15], Batch [510/523], Loss: -0.8909819722175598
# DEBUG:root:Epoch [13/15], Batch [520/523], Loss: -0.8869829177856445
# DEBUG:root:epoch: 13, loss: -0.88982
# DEBUG:root:Epoch [14/15], Batch [0/523], Loss: -0.8906646966934204
# DEBUG:root:Epoch [14/15], Batch [10/523], Loss: -0.8046839237213135
# DEBUG:root:Epoch [14/15], Batch [20/523], Loss: -0.8839142322540283
# DEBUG:root:Epoch [14/15], Batch [30/523], Loss: -0.8977627158164978
# DEBUG:root:Epoch [14/15], Batch [40/523], Loss: -0.8817851543426514
# DEBUG:root:Epoch [14/15], Batch [50/523], Loss: -0.8691675662994385
# DEBUG:root:Epoch [14/15], Batch [60/523], Loss: -0.9002355337142944
# DEBUG:root:Epoch [14/15], Batch [70/523], Loss: -0.8639901876449585
# DEBUG:root:Epoch [14/15], Batch [80/523], Loss: -0.8636429309844971
# DEBUG:root:Epoch [14/15], Batch [90/523], Loss: -0.8509389162063599
# DEBUG:root:Epoch [14/15], Batch [100/523], Loss: -0.8738095164299011
# DEBUG:root:Epoch [14/15], Batch [110/523], Loss: -0.8789706826210022
# DEBUG:root:Epoch [14/15], Batch [120/523], Loss: -0.8996353149414062
# DEBUG:root:Epoch [14/15], Batch [130/523], Loss: -0.862769603729248
# DEBUG:root:Epoch [14/15], Batch [140/523], Loss: -0.8672109842300415
# DEBUG:root:Epoch [14/15], Batch [150/523], Loss: -0.8600530624389648
# DEBUG:root:Epoch [14/15], Batch [160/523], Loss: -0.8568975329399109
# DEBUG:root:Epoch [14/15], Batch [170/523], Loss: -0.8472581505775452
# DEBUG:root:Epoch [14/15], Batch [180/523], Loss: -0.8364603519439697
# DEBUG:root:Epoch [14/15], Batch [190/523], Loss: -0.8749032616615295
# DEBUG:root:Epoch [14/15], Batch [200/523], Loss: -0.8704698085784912
# DEBUG:root:Epoch [14/15], Batch [210/523], Loss: -0.8582870960235596
# DEBUG:root:Epoch [14/15], Batch [220/523], Loss: -0.8718582391738892
# DEBUG:root:Epoch [14/15], Batch [230/523], Loss: -0.8444628715515137
# DEBUG:root:Epoch [14/15], Batch [240/523], Loss: -0.8360787630081177
# DEBUG:root:Epoch [14/15], Batch [250/523], Loss: -0.8112333416938782
# DEBUG:root:Epoch [14/15], Batch [260/523], Loss: -0.876850426197052
# DEBUG:root:Epoch [14/15], Batch [270/523], Loss: -0.8735296726226807
# DEBUG:root:Epoch [14/15], Batch [280/523], Loss: -0.8638666868209839
# DEBUG:root:Epoch [14/15], Batch [290/523], Loss: -0.8818953633308411
# DEBUG:root:Epoch [14/15], Batch [300/523], Loss: -0.8932133913040161
# DEBUG:root:Epoch [14/15], Batch [310/523], Loss: -0.8518538475036621
# DEBUG:root:Epoch [14/15], Batch [320/523], Loss: -0.8669469356536865
# DEBUG:root:Epoch [14/15], Batch [330/523], Loss: -0.8717135190963745
# DEBUG:root:Epoch [14/15], Batch [340/523], Loss: -0.8723297715187073
# DEBUG:root:Epoch [14/15], Batch [350/523], Loss: -0.8680363893508911
# DEBUG:root:Epoch [14/15], Batch [360/523], Loss: -0.8828881978988647
# DEBUG:root:Epoch [14/15], Batch [370/523], Loss: -0.8967044949531555
# DEBUG:root:Epoch [14/15], Batch [380/523], Loss: -0.8683968186378479
# DEBUG:root:Epoch [14/15], Batch [390/523], Loss: -0.8760157823562622
# DEBUG:root:Epoch [14/15], Batch [400/523], Loss: -0.8570869565010071
# DEBUG:root:Epoch [14/15], Batch [410/523], Loss: -0.8160194158554077
# DEBUG:root:Epoch [14/15], Batch [420/523], Loss: -0.8811642527580261
# DEBUG:root:Epoch [14/15], Batch [430/523], Loss: -0.8781145811080933
# DEBUG:root:Epoch [14/15], Batch [440/523], Loss: -0.8963334560394287
# DEBUG:root:Epoch [14/15], Batch [450/523], Loss: -0.8877169489860535
# DEBUG:root:Epoch [14/15], Batch [460/523], Loss: -0.8869474530220032
# DEBUG:root:Epoch [14/15], Batch [470/523], Loss: -0.881128191947937
# DEBUG:root:Epoch [14/15], Batch [480/523], Loss: -0.8634939193725586
# DEBUG:root:Epoch [14/15], Batch [490/523], Loss: -0.8835645318031311
# DEBUG:root:Epoch [14/15], Batch [500/523], Loss: -0.9068660736083984
# DEBUG:root:Epoch [14/15], Batch [510/523], Loss: -0.8548694252967834
# DEBUG:root:Epoch [14/15], Batch [520/523], Loss: -0.882071852684021
# DEBUG:root:epoch: 14, loss: -0.86955

# %%
class FinetuneClassifier(nn.Module):
    def __init__(self, backbone, head):
        super(FinetuneClassifier, self).__init__()
        self.backbone = backbone
        self.head = head

    def forward(self, x):
        z = self.backbone[0](x).flatten(start_dim=1)
        z = self.backbone[1](z)
        z = self.head(z)
        return z

# %%
# load model
backbone = nn.Sequential(model.backbone, model.projection_head)
classification_head = nn.Sequential(
    nn.Linear(128, 512), # num_ftrs_dict["resnet34"]
    nn.ReLU(),
    nn.BatchNorm1d(512),
    nn.Linear(512, num_classes),)

model =  FinetuneClassifier(backbone, classification_head) # num_ftrs_dict["resnet34"]
# model.load_state_dict(torch.load(model_path_pretrained))
summary(model, input_size=(2, 1, 224, 224), device="cuda")
# Out:
# ====================================================================================================
# Layer (type:depth-idx)                             Output Shape              Param #
# ====================================================================================================
# FinetuneClassifier                                 [2, 3]                    --
# ├─Sequential: 1-1                                  --                        --
# │    └─Sequential: 2-1                             [2, 2048, 1, 1]           --
# │    │    └─Conv2d: 3-1                            [2, 64, 112, 112]         3,136
# │    │    └─BatchNorm2d: 3-2                       [2, 64, 112, 112]         128
# │    │    └─ReLU: 3-3                              [2, 64, 112, 112]         --
# │    │    └─MaxPool2d: 3-4                         [2, 64, 56, 56]           --
# │    │    └─Sequential: 3-5                        [2, 256, 56, 56]          215,808
# │    │    └─Sequential: 3-6                        [2, 512, 28, 28]          1,219,584
# │    │    └─Sequential: 3-7                        [2, 1024, 14, 14]         7,098,368
# │    │    └─Sequential: 3-8                        [2, 2048, 7, 7]           14,964,736
# │    │    └─AdaptiveAvgPool2d: 3-9                 [2, 2048, 1, 1]           --
# │    └─SimSiamProjectionHead: 2-2                  [2, 128]                  --
# │    │    └─Sequential: 3-10                       [2, 128]                  1,378,304
# ├─Sequential: 1-2                                  [2, 3]                    --
# │    └─Linear: 2-3                                 [2, 512]                  66,048
# │    └─ReLU: 2-4                                   [2, 512]                  --
# │    └─BatchNorm1d: 2-5                            [2, 512]                  1,024
# │    └─Linear: 2-6                                 [2, 3]                    1,539
# ====================================================================================================
# Total params: 24,948,675
# Trainable params: 24,948,675
# Non-trainable params: 0
# Total mult-adds (G): 8.02
# ====================================================================================================
# Input size (MB): 0.40
# Forward/backward pass size (MB): 355.70
# Params size (MB): 99.79
# Estimated Total Size (MB): 455.89
# ====================================================================================================

# %%
import math
learning_rate = 3e-4 # 3e-4
weight_decay =  0.01

finetune_optimizer = optim.AdamW(
    model.parameters(),
    lr=learning_rate,
    weight_decay=weight_decay,
)



#optimizer
optimizer_finetune = optim.AdamW(model.parameters(), lr=learning_rate) #  weight_decay = 1e-4
warmup_epochs = 3
num_train_steps = math.ceil(len(train_loader))
num_warmup_steps= num_train_steps * warmup_epochs
num_training_steps=int(num_train_steps * finetune_epochs)

#learning rate scheduler
cosine_scheduler = get_cosine_schedule_with_warmup(optimizer_finetune,num_warmup_steps = num_warmup_steps,num_training_steps =num_training_steps)

# %%
finetune_criterion = nn.CrossEntropyLoss()

# %%
def finetune(
    epochs: int,
    model: nn.Module,
    device: Union[int, str],
    train_loader: Any,
    criterion: nn.Module,
    optimizer: nn.Module,
    saved_model_path: str,
    valid_loader: Any,
):
    best_loss = float("inf")
    best_accuracy = float("-inf")
    all_val_loss = []
    all_val_accuracy = []

    # Training loop
    for epoch in range(epochs):
        epoch_loss = 0.0
        model.train()

        for batch_idx, batch in enumerate(train_loader): # for batch_idx, batch in enumerate(train_loader):
            img1 = batch[0].to(device)
            label = batch[-1].to(device)
            optimizer.zero_grad()
            output = model(img1)

            loss = criterion(output, label)
            loss.backward()
            optimizer.step()
            # cosine_scheduler.step()
            epoch_loss += loss
            
             

            if batch_idx % 100 == 0:
                logging.debug(
                    f"Epoch [{epoch}/{epochs}], Batch [{batch_idx}/{len(train_loader)}], Loss: {loss.item()}"
                )

        epoch_loss = epoch_loss / len(train_loader)

        with torch.no_grad():
            logging.debug("====== Eval started ======")
            model.eval()
            epoch_val_accuracy = 0
            epoch_val_loss = 0
            for batch_idx, batch in enumerate(valid_loader): # for batch_idx, batch in enumerate(train_loader):
                data = batch[0].to(device)
                label = batch[-1].to(device)

                val_output = model(data)
                val_loss = criterion(val_output, label)

                acc = (val_output.argmax(dim=1) == label).float().mean()
                epoch_val_accuracy += acc
                epoch_val_loss += val_loss
                
                 

            epoch_val_accuracy = epoch_val_accuracy / len(valid_loader)
            
            if epoch_val_accuracy > best_accuracy:
                best_accuracy = epoch_val_accuracy
                torch.save(model.state_dict(), saved_model_path)
                logging.debug("====== Model saved ======")
            
            epoch_val_loss = epoch_val_loss / len(valid_loader)
            all_val_loss.append(epoch_val_loss)

        all_val_accuracy.append(epoch_val_accuracy.item() * 100)

        logging.debug(
            f"Epoch : {epoch+1} - loss : {epoch_loss:.4f} - val_loss : {epoch_val_loss:.4f} - val_acc: {epoch_val_accuracy:.4f} \n"
        )

# %%
# Training loop
finetune(
    finetune_epochs,
    model,
    device,
    train_loader,
    finetune_criterion,
    finetune_optimizer,
    finetuned_model_path,
    valid_loader=val_loader,
)
# Out:
# DEBUG:root:Epoch [0/20], Batch [0/523], Loss: 1.13822603225708
# DEBUG:root:Epoch [0/20], Batch [100/523], Loss: 1.1152653694152832
# DEBUG:root:Epoch [0/20], Batch [200/523], Loss: 0.8244309425354004
# DEBUG:root:Epoch [0/20], Batch [300/523], Loss: 0.8090019822120667
# DEBUG:root:Epoch [0/20], Batch [400/523], Loss: 0.8175769448280334
# DEBUG:root:Epoch [0/20], Batch [500/523], Loss: 0.8981324434280396
# DEBUG:root:====== Eval started ======
# DEBUG:root:====== Model saved ======
# DEBUG:root:Epoch : 1 - loss : 0.9168 - val_loss : 0.9992 - val_acc: 0.4938
#
# DEBUG:root:Epoch [1/20], Batch [0/523], Loss: 0.8993533849716187
# DEBUG:root:Epoch [1/20], Batch [100/523], Loss: 0.8523505330085754
# DEBUG:root:Epoch [1/20], Batch [200/523], Loss: 0.7733483910560608
# DEBUG:root:Epoch [1/20], Batch [300/523], Loss: 0.8579100966453552
# DEBUG:root:Epoch [1/20], Batch [400/523], Loss: 0.6968896985054016
# DEBUG:root:Epoch [1/20], Batch [500/523], Loss: 0.7521953582763672
# DEBUG:root:====== Eval started ======
# DEBUG:root:====== Model saved ======
# DEBUG:root:Epoch : 2 - loss : 0.7870 - val_loss : 0.7938 - val_acc: 0.5788
#
# DEBUG:root:Epoch [2/20], Batch [0/523], Loss: 0.7631861567497253
# DEBUG:root:Epoch [2/20], Batch [100/523], Loss: 0.6723454594612122
# DEBUG:root:Epoch [2/20], Batch [200/523], Loss: 0.5629228353500366
# DEBUG:root:Epoch [2/20], Batch [300/523], Loss: 0.6293946504592896
# DEBUG:root:Epoch [2/20], Batch [400/523], Loss: 0.4950057566165924
# DEBUG:root:Epoch [2/20], Batch [500/523], Loss: 0.4629456102848053
# DEBUG:root:====== Eval started ======
# DEBUG:root:====== Model saved ======
# DEBUG:root:Epoch : 3 - loss : 0.5734 - val_loss : 0.5075 - val_acc: 0.7788
#
# DEBUG:root:Epoch [3/20], Batch [0/523], Loss: 0.41874027252197266
# DEBUG:root:Epoch [3/20], Batch [100/523], Loss: 0.43116918206214905
# DEBUG:root:Epoch [3/20], Batch [200/523], Loss: 0.46654844284057617
# DEBUG:root:Epoch [3/20], Batch [300/523], Loss: 0.387107789516449
# DEBUG:root:Epoch [3/20], Batch [400/523], Loss: 0.33067068457603455
# DEBUG:root:Epoch [3/20], Batch [500/523], Loss: 0.21164564788341522
# DEBUG:root:====== Eval started ======
# DEBUG:root:====== Model saved ======
# DEBUG:root:Epoch : 4 - loss : 0.3660 - val_loss : 0.3496 - val_acc: 0.8569
#
# DEBUG:root:Epoch [4/20], Batch [0/523], Loss: 0.24383807182312012
# DEBUG:root:Epoch [4/20], Batch [100/523], Loss: 0.21719437837600708
# DEBUG:root:Epoch [4/20], Batch [200/523], Loss: 0.2947235703468323
# DEBUG:root:Epoch [4/20], Batch [300/523], Loss: 0.2230329066514969
# DEBUG:root:Epoch [4/20], Batch [400/523], Loss: 0.24901066720485687
# DEBUG:root:Epoch [4/20], Batch [500/523], Loss: 0.2204141914844513
# DEBUG:root:====== Eval started ======
# DEBUG:root:====== Model saved ======
# DEBUG:root:Epoch : 5 - loss : 0.2870 - val_loss : 0.2510 - val_acc: 0.8916
#
# DEBUG:root:Epoch [5/20], Batch [0/523], Loss: 0.1829044222831726
# DEBUG:root:Epoch [5/20], Batch [100/523], Loss: 0.2447878122329712
# DEBUG:root:Epoch [5/20], Batch [200/523], Loss: 0.22126524150371552
# DEBUG:root:Epoch [5/20], Batch [300/523], Loss: 0.21002544462680817
# DEBUG:root:Epoch [5/20], Batch [400/523], Loss: 0.26641932129859924
# DEBUG:root:Epoch [5/20], Batch [500/523], Loss: 0.22770529985427856
# DEBUG:root:====== Eval started ======
# DEBUG:root:====== Model saved ======
# DEBUG:root:Epoch : 6 - loss : 0.2324 - val_loss : 0.2230 - val_acc: 0.9034
#
# DEBUG:root:Epoch [6/20], Batch [0/523], Loss: 0.17420756816864014
# DEBUG:root:Epoch [6/20], Batch [100/523], Loss: 0.10647616535425186
# DEBUG:root:Epoch [6/20], Batch [200/523], Loss: 0.12335807085037231
# DEBUG:root:Epoch [6/20], Batch [300/523], Loss: 0.18865075707435608
# DEBUG:root:Epoch [6/20], Batch [400/523], Loss: 0.23496301472187042
# DEBUG:root:Epoch [6/20], Batch [500/523], Loss: 0.17129479348659515
# DEBUG:root:====== Eval started ======
# DEBUG:root:Epoch : 7 - loss : 0.2005 - val_loss : 0.2349 - val_acc: 0.8937
#
# DEBUG:root:Epoch [7/20], Batch [0/523], Loss: 0.1771956831216812
# DEBUG:root:Epoch [7/20], Batch [100/523], Loss: 0.1795562505722046
# DEBUG:root:Epoch [7/20], Batch [200/523], Loss: 0.21803684532642365
# DEBUG:root:Epoch [7/20], Batch [300/523], Loss: 0.18794655799865723
# DEBUG:root:Epoch [7/20], Batch [400/523], Loss: 0.13793137669563293
# DEBUG:root:Epoch [7/20], Batch [500/523], Loss: 0.1313885897397995
# DEBUG:root:====== Eval started ======
# DEBUG:root:====== Model saved ======
# DEBUG:root:Epoch : 8 - loss : 0.1812 - val_loss : 0.1842 - val_acc: 0.9194
#
# DEBUG:root:Epoch [8/20], Batch [0/523], Loss: 0.17878881096839905
# DEBUG:root:Epoch [8/20], Batch [100/523], Loss: 0.18841658532619476
# DEBUG:root:Epoch [8/20], Batch [200/523], Loss: 0.15794970095157623
# DEBUG:root:Epoch [8/20], Batch [300/523], Loss: 0.12690886855125427
# DEBUG:root:Epoch [8/20], Batch [400/523], Loss: 0.15793149173259735
# DEBUG:root:Epoch [8/20], Batch [500/523], Loss: 0.253902792930603
# DEBUG:root:====== Eval started ======
# DEBUG:root:====== Model saved ======
# DEBUG:root:Epoch : 9 - loss : 0.1672 - val_loss : 0.1697 - val_acc: 0.9229
#
# DEBUG:root:Epoch [9/20], Batch [0/523], Loss: 0.13844604790210724
# DEBUG:root:Epoch [9/20], Batch [100/523], Loss: 0.17120929062366486
# DEBUG:root:Epoch [9/20], Batch [200/523], Loss: 0.14474178850650787
# DEBUG:root:Epoch [9/20], Batch [300/523], Loss: 0.12876814603805542
# DEBUG:root:Epoch [9/20], Batch [400/523], Loss: 0.14458081126213074
# DEBUG:root:Epoch [9/20], Batch [500/523], Loss: 0.20733940601348877
# DEBUG:root:====== Eval started ======
# DEBUG:root:====== Model saved ======
# DEBUG:root:Epoch : 10 - loss : 0.1565 - val_loss : 0.1313 - val_acc: 0.9390
#
# DEBUG:root:Epoch [10/20], Batch [0/523], Loss: 0.09318026155233383
# DEBUG:root:Epoch [10/20], Batch [100/523], Loss: 0.1185053214430809
# DEBUG:root:Epoch [10/20], Batch [200/523], Loss: 0.09058655053377151
# DEBUG:root:Epoch [10/20], Batch [300/523], Loss: 0.13232886791229248
# DEBUG:root:Epoch [10/20], Batch [400/523], Loss: 0.18521809577941895
# DEBUG:root:Epoch [10/20], Batch [500/523], Loss: 0.13143664598464966
# DEBUG:root:====== Eval started ======
# DEBUG:root:Epoch : 11 - loss : 0.1530 - val_loss : 0.1402 - val_acc: 0.9390
#
# DEBUG:root:Epoch [11/20], Batch [0/523], Loss: 0.12878984212875366
# DEBUG:root:Epoch [11/20], Batch [100/523], Loss: 0.09617175161838531
# DEBUG:root:Epoch [11/20], Batch [200/523], Loss: 0.20294928550720215
# DEBUG:root:Epoch [11/20], Batch [300/523], Loss: 0.2501985430717468
# DEBUG:root:Epoch [11/20], Batch [400/523], Loss: 0.16484040021896362
# DEBUG:root:Epoch [11/20], Batch [500/523], Loss: 0.09647434204816818
# DEBUG:root:====== Eval started ======
# DEBUG:root:Epoch : 12 - loss : 0.1527 - val_loss : 0.1344 - val_acc: 0.9371
#
# DEBUG:root:Epoch [12/20], Batch [0/523], Loss: 0.1155654564499855
# DEBUG:root:Epoch [12/20], Batch [100/523], Loss: 0.09009440988302231
# DEBUG:root:Epoch [12/20], Batch [200/523], Loss: 0.09107033163309097
# DEBUG:root:Epoch [12/20], Batch [300/523], Loss: 0.16202393174171448
# DEBUG:root:Epoch [12/20], Batch [400/523], Loss: 0.10001875460147858
# DEBUG:root:Epoch [12/20], Batch [500/523], Loss: 0.2395518571138382
# DEBUG:root:====== Eval started ======
# DEBUG:root:Epoch : 13 - loss : 0.1454 - val_loss : 0.1617 - val_acc: 0.9259
#
# DEBUG:root:Epoch [13/20], Batch [0/523], Loss: 0.15637582540512085
# DEBUG:root:Epoch [13/20], Batch [100/523], Loss: 0.148603618144989
# DEBUG:root:Epoch [13/20], Batch [200/523], Loss: 0.1584377884864807
# DEBUG:root:Epoch [13/20], Batch [300/523], Loss: 0.16471484303474426
# DEBUG:root:Epoch [13/20], Batch [400/523], Loss: 0.14225450158119202
# DEBUG:root:Epoch [13/20], Batch [500/523], Loss: 0.1325763463973999
# DEBUG:root:====== Eval started ======
# DEBUG:root:Epoch : 14 - loss : 0.1400 - val_loss : 0.1366 - val_acc: 0.9387
#
# DEBUG:root:Epoch [14/20], Batch [0/523], Loss: 0.16714437305927277
# DEBUG:root:Epoch [14/20], Batch [100/523], Loss: 0.10605352371931076
# DEBUG:root:Epoch [14/20], Batch [200/523], Loss: 0.13406650722026825
# DEBUG:root:Epoch [14/20], Batch [300/523], Loss: 0.12331618368625641
# DEBUG:root:Epoch [14/20], Batch [400/523], Loss: 0.20402675867080688
# DEBUG:root:Epoch [14/20], Batch [500/523], Loss: 0.19812577962875366
# DEBUG:root:====== Eval started ======
# DEBUG:root:====== Model saved ======
# DEBUG:root:Epoch : 15 - loss : 0.1327 - val_loss : 0.1287 - val_acc: 0.9416
#
# DEBUG:root:Epoch [15/20], Batch [0/523], Loss: 0.13768739998340607
# DEBUG:root:Epoch [15/20], Batch [100/523], Loss: 0.12115420401096344
# DEBUG:root:Epoch [15/20], Batch [200/523], Loss: 0.13937777280807495
# DEBUG:root:Epoch [15/20], Batch [300/523], Loss: 0.04844065010547638
# DEBUG:root:Epoch [15/20], Batch [400/523], Loss: 0.07807300984859467
# DEBUG:root:Epoch [15/20], Batch [500/523], Loss: 0.160909965634346
# DEBUG:root:====== Eval started ======
# DEBUG:root:Epoch : 16 - loss : 0.1348 - val_loss : 0.1305 - val_acc: 0.9375
#
# DEBUG:root:Epoch [16/20], Batch [0/523], Loss: 0.14921927452087402
# DEBUG:root:Epoch [16/20], Batch [100/523], Loss: 0.12358596175909042
# DEBUG:root:Epoch [16/20], Batch [200/523], Loss: 0.20368781685829163
# DEBUG:root:Epoch [16/20], Batch [300/523], Loss: 0.10711945593357086
# DEBUG:root:Epoch [16/20], Batch [400/523], Loss: 0.11271736770868301
# DEBUG:root:Epoch [16/20], Batch [500/523], Loss: 0.1263752579689026
# DEBUG:root:====== Eval started ======
# DEBUG:root:====== Model saved ======
# DEBUG:root:Epoch : 17 - loss : 0.1271 - val_loss : 0.1282 - val_acc: 0.9428
#
# DEBUG:root:Epoch [17/20], Batch [0/523], Loss: 0.12506863474845886
# DEBUG:root:Epoch [17/20], Batch [100/523], Loss: 0.16115540266036987
# DEBUG:root:Epoch [17/20], Batch [200/523], Loss: 0.15718983113765717
# DEBUG:root:Epoch [17/20], Batch [300/523], Loss: 0.18069617450237274
# DEBUG:root:Epoch [17/20], Batch [400/523], Loss: 0.17507441341876984
# DEBUG:root:Epoch [17/20], Batch [500/523], Loss: 0.10552635043859482
# DEBUG:root:====== Eval started ======
# DEBUG:root:Epoch : 18 - loss : 0.1477 - val_loss : 0.1284 - val_acc: 0.9403
#
# DEBUG:root:Epoch [18/20], Batch [0/523], Loss: 0.06136457994580269
# DEBUG:root:Epoch [18/20], Batch [100/523], Loss: 0.15382757782936096
# DEBUG:root:Epoch [18/20], Batch [200/523], Loss: 0.17179185152053833
# DEBUG:root:Epoch [18/20], Batch [300/523], Loss: 0.1423783153295517
# DEBUG:root:Epoch [18/20], Batch [400/523], Loss: 0.16736218333244324
# DEBUG:root:Epoch [18/20], Batch [500/523], Loss: 0.06836652755737305
# DEBUG:root:====== Eval started ======
# DEBUG:root:====== Model saved ======
# DEBUG:root:Epoch : 19 - loss : 0.1250 - val_loss : 0.1161 - val_acc: 0.9443
#
# DEBUG:root:Epoch [19/20], Batch [0/523], Loss: 0.10904716700315475
# DEBUG:root:Epoch [19/20], Batch [100/523], Loss: 0.07776112854480743
# DEBUG:root:Epoch [19/20], Batch [200/523], Loss: 0.0969143807888031
# DEBUG:root:Epoch [19/20], Batch [300/523], Loss: 0.1322687864303589
# DEBUG:root:Epoch [19/20], Batch [400/523], Loss: 0.08917000889778137
# DEBUG:root:Epoch [19/20], Batch [500/523], Loss: 0.11249927431344986
# DEBUG:root:====== Eval started ======
# DEBUG:root:Epoch : 20 - loss : 0.1269 - val_loss : 0.1229 - val_acc: 0.9432

# %%
test_dataset_dir = dataset_dir
test_dataset = DeepLenseDatasetSSL(destination_dir = test_dataset_dir, transforms = train_transforms, mode="test", dataset_name=dataset_name, download=True, channels=1)
test_loader = DataLoader(
    dataset=test_dataset,
    batch_size=batch_size,
    shuffle=True,
    num_workers=num_workers,
)
# Out:
# Model_II dataset already exists

# %%
channels = 1
infer_obj = InferenceSSL(
    model,
    test_loader,
    device,
    num_classes,
    test_dataset,
    dataset_name,
    labels_map=classes, # classes
    image_size=image_size,
    channels=channels,
    destination_dir="data",
    log_dir=log_dir,  # log_dir
)

infer_obj.infer_plot_roc()
infer_obj.generate_plot_confusion_matrix()
# Out:
# Inference started ...
# DEBUG:matplotlib.colorbar:locator: <matplotlib.ticker.AutoLocator object at 0x7fbad0194190>
# Confusion matrix, without normalization

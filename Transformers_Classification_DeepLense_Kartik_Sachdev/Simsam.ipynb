# %%
# [1] "resnet34", Model_III, : done
# [2] "resnet34", Model_I    : done
# [3] "resnet50", Model_I    :

# %%
from __future__ import print_function
import os
import time
import copy
import json
import yaml

import torch.nn as nn
import torch.optim as optim
from torchinfo import summary
import torchvision
from typing import *

# %%
from utils.util import *
from config.data_config import DATASET
from utils.dataset import DefaultDatasetSetupSSL
from self_supervised.losses.contrastive_loss import (
    ContrastiveLossEuclidean,
    ContrastiveLossEmbedding,
    SimCLR_Loss,
    NegativeCosineSimilarity,
)
from self_supervised.losses.sym_neg_cos_sim_loss import SymNegCosineSimilarityLoss

from models.modules.head import BYOLProjectionHead, BYOLPredictionHead
from utils.scheduler import cosine_schedule
from torch.utils.data import DataLoader, random_split
from einops.layers.torch import Rearrange
from config.cvt_config import CvT_CONFIG
from models.transformer_zoo import TransformerModels
import math
from transformers import get_cosine_schedule_with_warmup
from utils.inference import InferenceSSL
import logging

# %%
import torch
import torchvision
from torch import nn

from lightly.loss import NegativeCosineSimilarity
from lightly.models.modules import SimSiamPredictionHead, SimSiamProjectionHead
from lightly.transforms import SimSiamTransform

# %%
batch_size = 128
dataset_name = "Model_II" 
dataset_dir = "data"
use_cuda = True
num_workers = 8

log_dir_base = "logger"
classes = DATASET[f"{dataset_name}"]["classes"]
num_classes = len(classes)

# %%
train_config = CvT_CONFIG
learning_rate = train_config["optimizer_config"]["lr"]
num_channels = train_config["channels"]
network_type = "ResNet50" # train_config["network_type"]
image_size = train_config["image_size"]
optimizer_config = train_config["optimizer_config"]

make_directories([dataset_dir])
seed_everything(seed=42)

# %%
# logging
current_time = time.strftime("%Y-%m-%d-%H-%M-%S", time.localtime())
log_dir_name = f"{current_time}_SimSiam_{network_type}_{dataset_name}"
log_dir = f"{log_dir_base}/{log_dir_name}"
init_logging_handler(log_dir_base, log_dir_name)

# dump config in logger
with open(f"{log_dir}/config.json", "w") as fp:
    json.dump(train_config, fp)

# %%
# paths
model_path_pretrained = os.path.join(
    f"{log_dir}/checkpoint",
   f"{network_type}_pretrained_{dataset_name}_{current_time}.pt",
)

finetuned_model_path = os.path.join(
    f"{log_dir}/checkpoint",
    f"{network_type}_finetune_{dataset_name}_{current_time}.pt",
)

# %%
train_config = CvT_CONFIG
learning_rate = train_config["optimizer_config"]["lr"]
num_channels = train_config["channels"]
network_type = train_config["network_type"]
image_size = train_config["image_size"]
optimizer_config = train_config["optimizer_config"]

make_directories([dataset_dir])
seed_everything(seed=42)

# %%
import albumentations as A
from albumentations.pytorch import ToTensorV2


class SimSiamTransform:
    """Implements the global and local view augmentations for DINO [0].
    """

    def __init__(self):
        pass
    
    def get_transforms(self, 
                       global_crop_size: int = 224,
                       global_crop_scale: Tuple[float, float] = (0.4, 1.0),
                       local_crop_size: int = 96,
                       local_crop_scale: Tuple[float, float] = (0.05, 0.4),):

        # first global crop
        global_transform_0 = A.Compose(
        [
            A.HorizontalFlip(p=0.25),
            A.VerticalFlip(p=0.25),
            A.Resize(global_crop_size, global_crop_size, p=1.0),
            A.RandomResizedCrop(height=global_crop_size, width=global_crop_size),
            A.Rotate(p=0.5), 
            ToTensorV2(),
        ])

        # second global crop
        global_transform_1 = A.Compose(
        [
            A.HorizontalFlip(p=0.5),
            A.VerticalFlip(p=0.25),
            A.Resize(global_crop_size, global_crop_size, p=1.0),
            A.augmentations.GaussNoise(var_limit=(0.002, 0.005), p=0.3),
            ToTensorV2(),
        ])
        
        # transformation for the local small crops
        local_transform = A.Compose(
        [
            A.HorizontalFlip(p=0.25),
            A.VerticalFlip(p=0.25),
            A.Resize(local_crop_size, local_crop_size, p=1.0),
            A.augmentations.GaussianBlur(),
            ToTensorV2(),
        ])
        return [global_transform_0, global_transform_0]

# %%
from utils.dataset import visualize_samples_ssl, DeepLenseDatasetSSL
# trainset
dino_transform = SimSiamTransform()
train_transforms = dino_transform.get_transforms()
train_dataset = DeepLenseDatasetSSL(destination_dir = dataset_dir, transforms = train_transforms, mode="train", dataset_name=dataset_name, download=True, channels=1)
logging.debug(f"train data: {len(train_dataset)}")
visualize_samples_ssl(train_dataset, labels_map=classes, num_rows_inner=1, num_cols_inner=2)
# Out:
# Model_II dataset already exists
# DEBUG:root:train data: 89104

# %%
len(train_dataset)
# Out:
# 89104

# %%
# split in train and valid set
split_ratio = 0.25  # 0.25
valid_len = int(split_ratio * len(train_dataset))
train_len = len(train_dataset) - valid_len

train_dataset, val_set = random_split(train_dataset, [train_len, valid_len])

train_loader = DataLoader(
    dataset=train_dataset,
    batch_size=batch_size,
    shuffle=True,
    num_workers=num_workers,
)

val_loader = DataLoader(
    dataset=val_set, batch_size=batch_size, shuffle=True, num_workers=num_workers
)

# Load test dataset
# testset = default_dataset_setup.get_dataset(mode="val")
# test_loader = DataLoader(dataset=testset, batch_size=batch_size, shuffle=True)

# size check
sample = next(iter(train_loader))
logging.debug("num of classes: ", num_classes)
logging.debug(sample[0].shape)
# Out:
# --- Logging error ---
# Traceback (most recent call last):
#   File "/global/common/software/nersc/pm-2022q4/sw/pytorch/1.13.1/lib/python3.9/logging/__init__.py", line 1083, in emit
#     msg = self.format(record)
#   File "/global/common/software/nersc/pm-2022q4/sw/pytorch/1.13.1/lib/python3.9/logging/__init__.py", line 927, in format
#     return fmt.format(record)
#   File "/global/common/software/nersc/pm-2022q4/sw/pytorch/1.13.1/lib/python3.9/logging/__init__.py", line 663, in format
#     record.message = record.getMessage()
#   File "/global/common/software/nersc/pm-2022q4/sw/pytorch/1.13.1/lib/python3.9/logging/__init__.py", line 367, in getMessage
#     msg = msg % self.args
# TypeError: not all arguments converted during string formatting
# Call stack:
#   File "/global/common/software/nersc/pm-2022q4/sw/pytorch/1.13.1/lib/python3.9/runpy.py", line 197, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/global/common/software/nersc/pm-2022q4/sw/pytorch/1.13.1/lib/python3.9/runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "/global/common/software/nersc/pm-2022q4/sw/pytorch/1.13.1/lib/python3.9/site-packages/ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "/global/common/software/nersc/pm-2022q4/sw/pytorch/1.13.1/lib/python3.9/site-packages/traitlets/config/application.py", line 992, in launch_instance
#     app.start()
#   File "/global/common/software/nersc/pm-2022q4/sw/pytorch/1.13.1/lib/python3.9/site-packages/ipykernel/kernelapp.py", line 712, in start
#     self.io_loop.start()
#   File "/global/common/software/nersc/pm-2022q4/sw/pytorch/1.13.1/lib/python3.9/site-packages/tornado/platform/asyncio.py", line 215, in start
#     self.asyncio_loop.run_forever()
#   File "/global/common/software/nersc/pm-2022q4/sw/pytorch/1.13.1/lib/python3.9/asyncio/base_events.py", line 601, in run_forever
#     self._run_once()
#   File "/global/common/software/nersc/pm-2022q4/sw/pytorch/1.13.1/lib/python3.9/asyncio/base_events.py", line 1905, in _run_once
#     handle._run()
#   File "/global/common/software/nersc/pm-2022q4/sw/pytorch/1.13.1/lib/python3.9/asyncio/events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "/global/common/software/nersc/pm-2022q4/sw/pytorch/1.13.1/lib/python3.9/site-packages/ipykernel/kernelbase.py", line 510, in dispatch_queue
#     await self.process_one()
#   File "/global/common/software/nersc/pm-2022q4/sw/pytorch/1.13.1/lib/python3.9/site-packages/ipykernel/kernelbase.py", line 499, in process_one
#     await dispatch(*args)
#   File "/global/common/software/nersc/pm-2022q4/sw/pytorch/1.13.1/lib/python3.9/site-packages/ipykernel/kernelbase.py", line 406, in dispatch_shell
#     await result
#   File "/global/common/software/nersc/pm-2022q4/sw/pytorch/1.13.1/lib/python3.9/site-packages/ipykernel/kernelbase.py", line 730, in execute_request
#     reply_content = await reply_content
#   File "/global/common/software/nersc/pm-2022q4/sw/pytorch/1.13.1/lib/python3.9/site-packages/ipykernel/ipkernel.py", line 383, in do_execute
#     res = shell.run_cell(
#   File "/global/common/software/nersc/pm-2022q4/sw/pytorch/1.13.1/lib/python3.9/site-packages/ipykernel/zmqshell.py", line 528, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/global/homes/s/sachdevk/.local/perlmutter/pytorch1.13.1/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3009, in run_cell
#     result = self._run_cell(
#   File "/global/homes/s/sachdevk/.local/perlmutter/pytorch1.13.1/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3064, in _run_cell
#     result = runner(coro)
#   File "/global/homes/s/sachdevk/.local/perlmutter/pytorch1.13.1/lib/python3.9/site-packages/IPython/core/async_helpers.py", line 129, in _pseudo_sync_runner
#     coro.send(None)
#   File "/global/homes/s/sachdevk/.local/perlmutter/pytorch1.13.1/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3269, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/global/homes/s/sachdevk/.local/perlmutter/pytorch1.13.1/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3448, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "/global/homes/s/sachdevk/.local/perlmutter/pytorch1.13.1/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3508, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_931654/2935425517.py", line 25, in <module>
#     logging.debug("num of classes: ", num_classes)
# Message: 'num of classes: '
# Arguments: (3,)
# --- Logging error ---
# Traceback (most recent call last):
#   File "/global/common/software/nersc/pm-2022q4/sw/pytorch/1.13.1/lib/python3.9/logging/__init__.py", line 1083, in emit
#     msg = self.format(record)
#   File "/global/common/software/nersc/pm-2022q4/sw/pytorch/1.13.1/lib/python3.9/logging/__init__.py", line 927, in format
#     return fmt.format(record)
#   File "/global/common/software/nersc/pm-2022q4/sw/pytorch/1.13.1/lib/python3.9/logging/__init__.py", line 663, in format
#     record.message = record.getMessage()
#   File "/global/common/software/nersc/pm-2022q4/sw/pytorch/1.13.1/lib/python3.9/logging/__init__.py", line 367, in getMessage
#     msg = msg % self.args
# TypeError: not all arguments converted during string formatting
# Call stack:
#   File "/global/common/software/nersc/pm-2022q4/sw/pytorch/1.13.1/lib/python3.9/runpy.py", line 197, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/global/common/software/nersc/pm-2022q4/sw/pytorch/1.13.1/lib/python3.9/runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "/global/common/software/nersc/pm-2022q4/sw/pytorch/1.13.1/lib/python3.9/site-packages/ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "/global/common/software/nersc/pm-2022q4/sw/pytorch/1.13.1/lib/python3.9/site-packages/traitlets/config/application.py", line 992, in launch_instance
#     app.start()
#   File "/global/common/software/nersc/pm-2022q4/sw/pytorch/1.13.1/lib/python3.9/site-packages/ipykernel/kernelapp.py", line 712, in start
#     self.io_loop.start()
#   File "/global/common/software/nersc/pm-2022q4/sw/pytorch/1.13.1/lib/python3.9/site-packages/tornado/platform/asyncio.py", line 215, in start
#     self.asyncio_loop.run_forever()
#   File "/global/common/software/nersc/pm-2022q4/sw/pytorch/1.13.1/lib/python3.9/asyncio/base_events.py", line 601, in run_forever
#     self._run_once()
#   File "/global/common/software/nersc/pm-2022q4/sw/pytorch/1.13.1/lib/python3.9/asyncio/base_events.py", line 1905, in _run_once
#     handle._run()
#   File "/global/common/software/nersc/pm-2022q4/sw/pytorch/1.13.1/lib/python3.9/asyncio/events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "/global/common/software/nersc/pm-2022q4/sw/pytorch/1.13.1/lib/python3.9/site-packages/ipykernel/kernelbase.py", line 510, in dispatch_queue
#     await self.process_one()
#   File "/global/common/software/nersc/pm-2022q4/sw/pytorch/1.13.1/lib/python3.9/site-packages/ipykernel/kernelbase.py", line 499, in process_one
#     await dispatch(*args)
#   File "/global/common/software/nersc/pm-2022q4/sw/pytorch/1.13.1/lib/python3.9/site-packages/ipykernel/kernelbase.py", line 406, in dispatch_shell
#     await result
#   File "/global/common/software/nersc/pm-2022q4/sw/pytorch/1.13.1/lib/python3.9/site-packages/ipykernel/kernelbase.py", line 730, in execute_request
#     reply_content = await reply_content
#   File "/global/common/software/nersc/pm-2022q4/sw/pytorch/1.13.1/lib/python3.9/site-packages/ipykernel/ipkernel.py", line 383, in do_execute
#     res = shell.run_cell(
#   File "/global/common/software/nersc/pm-2022q4/sw/pytorch/1.13.1/lib/python3.9/site-packages/ipykernel/zmqshell.py", line 528, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/global/homes/s/sachdevk/.local/perlmutter/pytorch1.13.1/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3009, in run_cell
#     result = self._run_cell(
#   File "/global/homes/s/sachdevk/.local/perlmutter/pytorch1.13.1/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3064, in _run_cell
#     result = runner(coro)
#   File "/global/homes/s/sachdevk/.local/perlmutter/pytorch1.13.1/lib/python3.9/site-packages/IPython/core/async_helpers.py", line 129, in _pseudo_sync_runner
#     coro.send(None)
#   File "/global/homes/s/sachdevk/.local/perlmutter/pytorch1.13.1/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3269, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/global/homes/s/sachdevk/.local/perlmutter/pytorch1.13.1/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3448, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "/global/homes/s/sachdevk/.local/perlmutter/pytorch1.13.1/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3508, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_931654/2935425517.py", line 25, in <module>
#     logging.debug("num of classes: ", num_classes)
# Message: 'num of classes: '
# Arguments: (3,)
# DEBUG:root:torch.Size([128, 1, 224, 224])

# %%
class SimSiam(nn.Module):
    def __init__(self, backbone):
        super().__init__()
        self.backbone = backbone
        self.backbone[0] = nn.Conv2d(
            1, 64, kernel_size=7, stride=2, padding=3, bias=False
        )
        self.projection_head = SimSiamProjectionHead(2048, 512, 128)
        self.prediction_head = SimSiamPredictionHead(128, 64, 128)

    def forward(self, x):
        f = self.backbone(x).flatten(start_dim=1)
        z = self.projection_head(f)
        p = self.prediction_head(z)
        z = z.detach()
        return z, p

# %%
# # Create ResNet pretrain model
resnet = torchvision.models.resnet50() # -> [1] Model_III, "resnet34", (2)  Model_I, "resnet34", (3)  Model_I, "resnet50",
backbone = nn.Sequential(*list(resnet.children())[:-1])

num_ftrs_dict = {
    "resnet18": 512,
    "resnet34": 512,
    "resnet50": 2048,

}

model =  SimSiam(backbone)
device = "cuda" if torch.cuda.is_available() else "cpu"
model.to(device)

summary(model, input_size=(2, 1, 224, 224), device="cuda")
# Out:
# ===============================================================================================
# Layer (type:depth-idx)                        Output Shape              Param #
# ===============================================================================================
# SimSiam                                       [2, 128]                  --
# ├─Sequential: 1-1                             [2, 2048, 1, 1]           --
# │    └─Conv2d: 2-1                            [2, 64, 112, 112]         3,136
# │    └─BatchNorm2d: 2-2                       [2, 64, 112, 112]         128
# │    └─ReLU: 2-3                              [2, 64, 112, 112]         --
# │    └─MaxPool2d: 2-4                         [2, 64, 56, 56]           --
# │    └─Sequential: 2-5                        [2, 256, 56, 56]          --
# │    │    └─Bottleneck: 3-1                   [2, 256, 56, 56]          75,008
# │    │    └─Bottleneck: 3-2                   [2, 256, 56, 56]          70,400
# │    │    └─Bottleneck: 3-3                   [2, 256, 56, 56]          70,400
# │    └─Sequential: 2-6                        [2, 512, 28, 28]          --
# │    │    └─Bottleneck: 3-4                   [2, 512, 28, 28]          379,392
# │    │    └─Bottleneck: 3-5                   [2, 512, 28, 28]          280,064
# │    │    └─Bottleneck: 3-6                   [2, 512, 28, 28]          280,064
# │    │    └─Bottleneck: 3-7                   [2, 512, 28, 28]          280,064
# │    └─Sequential: 2-7                        [2, 1024, 14, 14]         --
# │    │    └─Bottleneck: 3-8                   [2, 1024, 14, 14]         1,512,448
# │    │    └─Bottleneck: 3-9                   [2, 1024, 14, 14]         1,117,184
# │    │    └─Bottleneck: 3-10                  [2, 1024, 14, 14]         1,117,184
# │    │    └─Bottleneck: 3-11                  [2, 1024, 14, 14]         1,117,184
# │    │    └─Bottleneck: 3-12                  [2, 1024, 14, 14]         1,117,184
# │    │    └─Bottleneck: 3-13                  [2, 1024, 14, 14]         1,117,184
# │    └─Sequential: 2-8                        [2, 2048, 7, 7]           --
# │    │    └─Bottleneck: 3-14                  [2, 2048, 7, 7]           6,039,552
# │    │    └─Bottleneck: 3-15                  [2, 2048, 7, 7]           4,462,592
# │    │    └─Bottleneck: 3-16                  [2, 2048, 7, 7]           4,462,592
# │    └─AdaptiveAvgPool2d: 2-9                 [2, 2048, 1, 1]           --
# ├─SimSiamProjectionHead: 1-2                  [2, 128]                  --
# │    └─Sequential: 2-10                       [2, 128]                  --
# │    │    └─Linear: 3-17                      [2, 512]                  1,048,576
# │    │    └─BatchNorm1d: 3-18                 [2, 512]                  1,024
# │    │    └─ReLU: 3-19                        [2, 512]                  --
# │    │    └─Linear: 3-20                      [2, 512]                  262,144
# │    │    └─BatchNorm1d: 3-21                 [2, 512]                  1,024
# │    │    └─ReLU: 3-22                        [2, 512]                  --
# │    │    └─Linear: 3-23                      [2, 128]                  65,536
# │    │    └─BatchNorm1d: 3-24                 [2, 128]                  --
# ├─SimSiamPredictionHead: 1-3                  [2, 128]                  --
# │    └─Sequential: 2-11                       [2, 128]                  --
# │    │    └─Linear: 3-25                      [2, 64]                   8,192
# │    │    └─BatchNorm1d: 3-26                 [2, 64]                   128
# │    │    └─ReLU: 3-27                        [2, 64]                   --
# │    │    └─Linear: 3-28                      [2, 128]                  8,320
# ===============================================================================================
# Total params: 24,896,704
# Trainable params: 24,896,704
# Non-trainable params: 0
# Total mult-adds (G): 8.02
# ===============================================================================================
# Input size (MB): 0.40
# Forward/backward pass size (MB): 355.69
# Params size (MB): 99.59
# Estimated Total Size (MB): 455.67
# ===============================================================================================

# %%
epochs_pretrain = 15
finetune_epochs = 20

# %%
#optimizer
optimizer_pretrain = optim.AdamW(model.parameters(), lr=1e-3, weight_decay = 1e-4)
warmup_epochs = 3
num_train_steps = math.ceil(len(train_loader))
num_warmup_steps= num_train_steps * warmup_epochs
num_training_steps=int(num_train_steps * epochs_pretrain)

#learning rate scheduler
cosine_scheduler = get_cosine_schedule_with_warmup(optimizer_pretrain,num_warmup_steps = num_warmup_steps,num_training_steps =num_training_steps)

# %%
criterion = NegativeCosineSimilarity()

# %%
logging.debug("Starting Training")
for epoch in range(epochs_pretrain):
    total_loss = 0    
    best_loss = float("inf")

    for batch_idx, batch in enumerate(train_loader):
        x0 = batch[0] 
        x1 = batch[1] 
        x0 = x0.to(device)
        x1 = x1.to(device)
        z0, p0 = model(x0)
        z1, p1 = model(x1)
        loss = 0.5 * (criterion(z0, p1) + criterion(z1, p0))
        total_loss += loss.detach()
        loss.backward()
        optimizer_pretrain.step()
        optimizer_pretrain.zero_grad()
        cosine_scheduler.step()

        if batch_idx % 10 == 0:
            logging.debug(f"Epoch [{epoch}/{epochs_pretrain}], Batch [{batch_idx}/{len(train_loader)}], Loss: {loss.item()}")

    if total_loss < best_loss:
        best_loss = total_loss
        torch.save(model.state_dict(), model_path_pretrained)

    avg_loss = total_loss / len(train_loader)
    logging.debug(f"epoch: {epoch:>02}, loss: {avg_loss:.5f}")
# Out:
# DEBUG:root:Starting Training
# DEBUG:root:Epoch [0/15], Batch [0/513], Loss: -0.006596988532692194
# DEBUG:root:Epoch [0/15], Batch [10/513], Loss: -0.005450536496937275
# DEBUG:root:Epoch [0/15], Batch [20/513], Loss: -0.02812296152114868
# DEBUG:root:Epoch [0/15], Batch [30/513], Loss: -0.04394757002592087
# DEBUG:root:Epoch [0/15], Batch [40/513], Loss: -0.04492758587002754
# DEBUG:root:Epoch [0/15], Batch [50/513], Loss: -0.0736430287361145
# DEBUG:root:Epoch [0/15], Batch [60/513], Loss: -0.09793750941753387
# DEBUG:root:Epoch [0/15], Batch [70/513], Loss: -0.13131669163703918
# DEBUG:root:Epoch [0/15], Batch [80/513], Loss: -0.18436892330646515
# DEBUG:root:Epoch [0/15], Batch [90/513], Loss: -0.18655094504356384
# DEBUG:root:Epoch [0/15], Batch [100/513], Loss: -0.2663574814796448
# DEBUG:root:Epoch [0/15], Batch [110/513], Loss: -0.35395801067352295
# DEBUG:root:Epoch [0/15], Batch [120/513], Loss: -0.36948931217193604
# DEBUG:root:Epoch [0/15], Batch [130/513], Loss: -0.45253536105155945
# DEBUG:root:Epoch [0/15], Batch [140/513], Loss: -0.5020808577537537
# DEBUG:root:Epoch [0/15], Batch [150/513], Loss: -0.5696351528167725
# DEBUG:root:Epoch [0/15], Batch [160/513], Loss: -0.5381700396537781
# DEBUG:root:Epoch [0/15], Batch [170/513], Loss: -0.6001525521278381
# DEBUG:root:Epoch [0/15], Batch [180/513], Loss: -0.6847265958786011
# DEBUG:root:Epoch [0/15], Batch [190/513], Loss: -0.6626010537147522
# DEBUG:root:Epoch [0/15], Batch [200/513], Loss: -0.770474910736084
# DEBUG:root:Epoch [0/15], Batch [210/513], Loss: -0.7179164886474609
# DEBUG:root:Epoch [0/15], Batch [220/513], Loss: -0.7324049472808838
# DEBUG:root:Epoch [0/15], Batch [230/513], Loss: -0.7621805667877197
# DEBUG:root:Epoch [0/15], Batch [240/513], Loss: -0.7952420711517334
# DEBUG:root:Epoch [0/15], Batch [250/513], Loss: -0.83167564868927
# DEBUG:root:Epoch [0/15], Batch [260/513], Loss: -0.8419796824455261
# DEBUG:root:Epoch [0/15], Batch [270/513], Loss: -0.838701069355011
# DEBUG:root:Epoch [0/15], Batch [280/513], Loss: -0.8189066648483276
# DEBUG:root:Epoch [0/15], Batch [290/513], Loss: -0.8431425094604492
# DEBUG:root:Epoch [0/15], Batch [300/513], Loss: -0.8861690163612366
# DEBUG:root:Epoch [0/15], Batch [310/513], Loss: -0.8607565760612488
# DEBUG:root:Epoch [0/15], Batch [320/513], Loss: -0.8699769973754883
# DEBUG:root:Epoch [0/15], Batch [330/513], Loss: -0.8858749866485596
# DEBUG:root:Epoch [0/15], Batch [340/513], Loss: -0.8920838832855225
# DEBUG:root:Epoch [0/15], Batch [350/513], Loss: -0.8487213850021362
# DEBUG:root:Epoch [0/15], Batch [360/513], Loss: -0.883507490158081
# DEBUG:root:Epoch [0/15], Batch [370/513], Loss: -0.8821728229522705
# DEBUG:root:Epoch [0/15], Batch [380/513], Loss: -0.8566921949386597
# DEBUG:root:Epoch [0/15], Batch [390/513], Loss: -0.912537157535553
# DEBUG:root:Epoch [0/15], Batch [400/513], Loss: -0.8678081035614014
# DEBUG:root:Epoch [0/15], Batch [410/513], Loss: -0.9306682348251343
# DEBUG:root:Epoch [0/15], Batch [420/513], Loss: -0.8950310349464417
# DEBUG:root:Epoch [0/15], Batch [430/513], Loss: -0.8991634845733643
# DEBUG:root:Epoch [0/15], Batch [440/513], Loss: -0.8923430442810059
# DEBUG:root:Epoch [0/15], Batch [450/513], Loss: -0.8803139925003052
# DEBUG:root:Epoch [0/15], Batch [460/513], Loss: -0.9066046476364136
# DEBUG:root:Epoch [0/15], Batch [470/513], Loss: -0.88718581199646
# DEBUG:root:Epoch [0/15], Batch [480/513], Loss: -0.8838750123977661
# DEBUG:root:Epoch [0/15], Batch [490/513], Loss: -0.891108512878418
# DEBUG:root:Epoch [0/15], Batch [500/513], Loss: -0.9256876707077026
# DEBUG:root:Epoch [0/15], Batch [510/513], Loss: -0.880065381526947
# DEBUG:root:epoch: 00, loss: -0.64710
# DEBUG:root:Epoch [1/15], Batch [0/513], Loss: -0.933436393737793
# DEBUG:root:Epoch [1/15], Batch [10/513], Loss: -0.9252626895904541
# DEBUG:root:Epoch [1/15], Batch [20/513], Loss: -0.9250795841217041
# DEBUG:root:Epoch [1/15], Batch [30/513], Loss: -0.8624681234359741
# DEBUG:root:Epoch [1/15], Batch [40/513], Loss: -0.9473552703857422
# DEBUG:root:Epoch [1/15], Batch [50/513], Loss: -0.8859608173370361
# DEBUG:root:Epoch [1/15], Batch [60/513], Loss: -0.9154525995254517
# DEBUG:root:Epoch [1/15], Batch [70/513], Loss: -0.9182736873626709
# DEBUG:root:Epoch [1/15], Batch [80/513], Loss: -0.9068729877471924
# DEBUG:root:Epoch [1/15], Batch [90/513], Loss: -0.8963401317596436
# DEBUG:root:Epoch [1/15], Batch [100/513], Loss: -0.937451183795929
# DEBUG:root:Epoch [1/15], Batch [110/513], Loss: -0.9329774379730225
# DEBUG:root:Epoch [1/15], Batch [120/513], Loss: -0.8834644556045532
# DEBUG:root:Epoch [1/15], Batch [130/513], Loss: -0.9288898706436157
# DEBUG:root:Epoch [1/15], Batch [140/513], Loss: -0.9252836108207703
# DEBUG:root:Epoch [1/15], Batch [150/513], Loss: -0.907286524772644
# DEBUG:root:Epoch [1/15], Batch [160/513], Loss: -0.899511456489563
# DEBUG:root:Epoch [1/15], Batch [170/513], Loss: -0.9159504175186157
# DEBUG:root:Epoch [1/15], Batch [180/513], Loss: -0.8721759915351868
# DEBUG:root:Epoch [1/15], Batch [190/513], Loss: -0.9264696836471558
# DEBUG:root:Epoch [1/15], Batch [200/513], Loss: -0.9250513911247253
# DEBUG:root:Epoch [1/15], Batch [210/513], Loss: -0.8974936008453369
# DEBUG:root:Epoch [1/15], Batch [220/513], Loss: -0.9137053489685059
# DEBUG:root:Epoch [1/15], Batch [230/513], Loss: -0.9149202108383179
# DEBUG:root:Epoch [1/15], Batch [240/513], Loss: -0.9184820652008057
# DEBUG:root:Epoch [1/15], Batch [250/513], Loss: -0.916420578956604
# DEBUG:root:Epoch [1/15], Batch [260/513], Loss: -0.8621484637260437
# DEBUG:root:Epoch [1/15], Batch [270/513], Loss: -0.8914756774902344
# DEBUG:root:Epoch [1/15], Batch [280/513], Loss: -0.9107820987701416
# DEBUG:root:Epoch [1/15], Batch [290/513], Loss: -0.9175456762313843
# DEBUG:root:Epoch [1/15], Batch [300/513], Loss: -0.9029215574264526
# DEBUG:root:Epoch [1/15], Batch [310/513], Loss: -0.9027879238128662
# DEBUG:root:Epoch [1/15], Batch [320/513], Loss: -0.9165244102478027
# DEBUG:root:Epoch [1/15], Batch [330/513], Loss: -0.9205559492111206
# DEBUG:root:Epoch [1/15], Batch [340/513], Loss: -0.888691782951355
# DEBUG:root:Epoch [1/15], Batch [350/513], Loss: -0.9050383567810059
# DEBUG:root:Epoch [1/15], Batch [360/513], Loss: -0.8947007656097412
# DEBUG:root:Epoch [1/15], Batch [370/513], Loss: -0.9206736087799072
# DEBUG:root:Epoch [1/15], Batch [380/513], Loss: -0.9011527299880981
# DEBUG:root:Epoch [1/15], Batch [390/513], Loss: -0.8331810235977173
# DEBUG:root:Epoch [1/15], Batch [400/513], Loss: -0.924636721611023
# DEBUG:root:Epoch [1/15], Batch [410/513], Loss: -0.913594126701355
# DEBUG:root:Epoch [1/15], Batch [420/513], Loss: -0.8982876539230347
# DEBUG:root:Epoch [1/15], Batch [430/513], Loss: -0.8984675407409668
# DEBUG:root:Epoch [1/15], Batch [440/513], Loss: -0.9202898740768433
# DEBUG:root:Epoch [1/15], Batch [450/513], Loss: -0.8662679195404053
# DEBUG:root:Epoch [1/15], Batch [460/513], Loss: -0.9109715819358826
# DEBUG:root:Epoch [1/15], Batch [470/513], Loss: -0.8801333904266357
# DEBUG:root:Epoch [1/15], Batch [480/513], Loss: -0.920694887638092
# DEBUG:root:Epoch [1/15], Batch [490/513], Loss: -0.9250257015228271
# DEBUG:root:Epoch [1/15], Batch [500/513], Loss: -0.9192527532577515
# DEBUG:root:Epoch [1/15], Batch [510/513], Loss: -0.9284188747406006
# DEBUG:root:epoch: 01, loss: -0.90696
# DEBUG:root:Epoch [2/15], Batch [0/513], Loss: -0.9088608026504517
# DEBUG:root:Epoch [2/15], Batch [10/513], Loss: -0.9490333795547485
# DEBUG:root:Epoch [2/15], Batch [20/513], Loss: -0.8944607973098755
# DEBUG:root:Epoch [2/15], Batch [30/513], Loss: -0.9047272801399231
# DEBUG:root:Epoch [2/15], Batch [40/513], Loss: -0.9207162857055664
# DEBUG:root:Epoch [2/15], Batch [50/513], Loss: -0.8722324967384338
# DEBUG:root:Epoch [2/15], Batch [60/513], Loss: -0.892535388469696
# DEBUG:root:Epoch [2/15], Batch [70/513], Loss: -0.9084949493408203
# DEBUG:root:Epoch [2/15], Batch [80/513], Loss: -0.8706042766571045
# DEBUG:root:Epoch [2/15], Batch [90/513], Loss: -0.8817882537841797
# DEBUG:root:Epoch [2/15], Batch [100/513], Loss: -0.9143801927566528
# DEBUG:root:Epoch [2/15], Batch [110/513], Loss: -0.9032570719718933
# DEBUG:root:Epoch [2/15], Batch [120/513], Loss: -0.802844762802124
# DEBUG:root:Epoch [2/15], Batch [130/513], Loss: -0.8652298450469971
# DEBUG:root:Epoch [2/15], Batch [140/513], Loss: -0.8547759056091309
# DEBUG:root:Epoch [2/15], Batch [150/513], Loss: -0.900795578956604
# DEBUG:root:Epoch [2/15], Batch [160/513], Loss: -0.8158419132232666
# DEBUG:root:Epoch [2/15], Batch [170/513], Loss: -0.7927671074867249
# DEBUG:root:Epoch [2/15], Batch [180/513], Loss: -0.8502390384674072
# DEBUG:root:Epoch [2/15], Batch [190/513], Loss: -0.7972904443740845
# DEBUG:root:Epoch [2/15], Batch [200/513], Loss: -0.8550900816917419
# DEBUG:root:Epoch [2/15], Batch [210/513], Loss: -0.8880258798599243
# DEBUG:root:Epoch [2/15], Batch [220/513], Loss: -0.8668086528778076
# DEBUG:root:Epoch [2/15], Batch [230/513], Loss: -0.8732895851135254
# DEBUG:root:Epoch [2/15], Batch [240/513], Loss: -0.8457428216934204
# DEBUG:root:Epoch [2/15], Batch [250/513], Loss: -0.8909673094749451
# DEBUG:root:Epoch [2/15], Batch [260/513], Loss: -0.8561734557151794
# DEBUG:root:Epoch [2/15], Batch [270/513], Loss: -0.8250424861907959
# DEBUG:root:Epoch [2/15], Batch [280/513], Loss: -0.8831532597541809
# DEBUG:root:Epoch [2/15], Batch [290/513], Loss: -0.8365876078605652
# DEBUG:root:Epoch [2/15], Batch [300/513], Loss: -0.8515802621841431
# DEBUG:root:Epoch [2/15], Batch [310/513], Loss: -0.8943189382553101
# DEBUG:root:Epoch [2/15], Batch [320/513], Loss: -0.8167421817779541
# DEBUG:root:Epoch [2/15], Batch [330/513], Loss: -0.8944054841995239
# DEBUG:root:Epoch [2/15], Batch [340/513], Loss: -0.8899233341217041
# DEBUG:root:Epoch [2/15], Batch [350/513], Loss: -0.8811889290809631
# DEBUG:root:Epoch [2/15], Batch [360/513], Loss: -0.8839341402053833
# DEBUG:root:Epoch [2/15], Batch [370/513], Loss: -0.907024085521698
# DEBUG:root:Epoch [2/15], Batch [380/513], Loss: -0.8745356798171997
# DEBUG:root:Epoch [2/15], Batch [390/513], Loss: -0.8808830976486206
# DEBUG:root:Epoch [2/15], Batch [400/513], Loss: -0.8800166845321655
# DEBUG:root:Epoch [2/15], Batch [410/513], Loss: -0.8496713638305664
# DEBUG:root:Epoch [2/15], Batch [420/513], Loss: -0.8936187028884888
# DEBUG:root:Epoch [2/15], Batch [430/513], Loss: -0.8725730776786804
# DEBUG:root:Epoch [2/15], Batch [440/513], Loss: -0.9096569418907166
# DEBUG:root:Epoch [2/15], Batch [450/513], Loss: -0.8433734178543091
# DEBUG:root:Epoch [2/15], Batch [460/513], Loss: -0.8632720112800598
# DEBUG:root:Epoch [2/15], Batch [470/513], Loss: -0.8654580116271973
# DEBUG:root:Epoch [2/15], Batch [480/513], Loss: -0.8446989059448242
# DEBUG:root:Epoch [2/15], Batch [490/513], Loss: -0.9023276567459106
# DEBUG:root:Epoch [2/15], Batch [500/513], Loss: -0.9252508878707886
# DEBUG:root:Epoch [2/15], Batch [510/513], Loss: -0.878074049949646
# DEBUG:root:epoch: 02, loss: -0.87675
# DEBUG:root:Epoch [3/15], Batch [0/513], Loss: -0.9156580567359924
# DEBUG:root:Epoch [3/15], Batch [10/513], Loss: -0.8863620758056641
# DEBUG:root:Epoch [3/15], Batch [20/513], Loss: -0.8751934766769409
# DEBUG:root:Epoch [3/15], Batch [30/513], Loss: -0.906284511089325
# DEBUG:root:Epoch [3/15], Batch [40/513], Loss: -0.8897665143013
# DEBUG:root:Epoch [3/15], Batch [50/513], Loss: -0.8835341930389404
# DEBUG:root:Epoch [3/15], Batch [60/513], Loss: -0.8410531878471375
# DEBUG:root:Epoch [3/15], Batch [70/513], Loss: -0.8169548511505127
# DEBUG:root:Epoch [3/15], Batch [80/513], Loss: -0.8848329782485962
# DEBUG:root:Epoch [3/15], Batch [90/513], Loss: -0.8808122873306274
# DEBUG:root:Epoch [3/15], Batch [100/513], Loss: -0.906143307685852
# DEBUG:root:Epoch [3/15], Batch [110/513], Loss: -0.8360029458999634
# DEBUG:root:Epoch [3/15], Batch [120/513], Loss: -0.8881791830062866
# DEBUG:root:Epoch [3/15], Batch [130/513], Loss: -0.8509819507598877
# DEBUG:root:Epoch [3/15], Batch [140/513], Loss: -0.8178073167800903
# DEBUG:root:Epoch [3/15], Batch [150/513], Loss: -0.8975738286972046
# DEBUG:root:Epoch [3/15], Batch [160/513], Loss: -0.894142746925354
# DEBUG:root:Epoch [3/15], Batch [170/513], Loss: -0.9190387725830078
# DEBUG:root:Epoch [3/15], Batch [180/513], Loss: -0.882362425327301
# DEBUG:root:Epoch [3/15], Batch [190/513], Loss: -0.8656014204025269
# DEBUG:root:Epoch [3/15], Batch [200/513], Loss: -0.874915361404419
# DEBUG:root:Epoch [3/15], Batch [210/513], Loss: -0.90058434009552
# DEBUG:root:Epoch [3/15], Batch [220/513], Loss: -0.8817551136016846
# DEBUG:root:Epoch [3/15], Batch [230/513], Loss: -0.8907355666160583
# DEBUG:root:Epoch [3/15], Batch [240/513], Loss: -0.9125128984451294
# DEBUG:root:Epoch [3/15], Batch [250/513], Loss: -0.8997220396995544
# DEBUG:root:Epoch [3/15], Batch [260/513], Loss: -0.8822742104530334
# DEBUG:root:Epoch [3/15], Batch [270/513], Loss: -0.8759162425994873
# DEBUG:root:Epoch [3/15], Batch [280/513], Loss: -0.9065946340560913
# DEBUG:root:Epoch [3/15], Batch [290/513], Loss: -0.8964364528656006
# DEBUG:root:Epoch [3/15], Batch [300/513], Loss: -0.8628880977630615
# DEBUG:root:Epoch [3/15], Batch [310/513], Loss: -0.8392105102539062
# DEBUG:root:Epoch [3/15], Batch [320/513], Loss: -0.8709403872489929
# DEBUG:root:Epoch [3/15], Batch [330/513], Loss: -0.8665766716003418
# DEBUG:root:Epoch [3/15], Batch [340/513], Loss: -0.8418956995010376
# DEBUG:root:Epoch [3/15], Batch [350/513], Loss: -0.8915114402770996
# DEBUG:root:Epoch [3/15], Batch [360/513], Loss: -0.8250813484191895
# DEBUG:root:Epoch [3/15], Batch [370/513], Loss: -0.8925638198852539
# DEBUG:root:Epoch [3/15], Batch [380/513], Loss: -0.8530967831611633
# DEBUG:root:Epoch [3/15], Batch [390/513], Loss: -0.8062463998794556
# DEBUG:root:Epoch [3/15], Batch [400/513], Loss: -0.8576647639274597
# DEBUG:root:Epoch [3/15], Batch [410/513], Loss: -0.8815585374832153
# DEBUG:root:Epoch [3/15], Batch [420/513], Loss: -0.8377344012260437
# DEBUG:root:Epoch [3/15], Batch [430/513], Loss: -0.867165207862854
# DEBUG:root:Epoch [3/15], Batch [440/513], Loss: -0.848906397819519
# DEBUG:root:Epoch [3/15], Batch [450/513], Loss: -0.8488785028457642
# DEBUG:root:Epoch [3/15], Batch [460/513], Loss: -0.8926589488983154
# DEBUG:root:Epoch [3/15], Batch [470/513], Loss: -0.899462103843689
# DEBUG:root:Epoch [3/15], Batch [480/513], Loss: -0.9112902879714966
# DEBUG:root:Epoch [3/15], Batch [490/513], Loss: -0.8987980484962463
# DEBUG:root:Epoch [3/15], Batch [500/513], Loss: -0.8637218475341797
# DEBUG:root:Epoch [3/15], Batch [510/513], Loss: -0.9172873497009277
# DEBUG:root:epoch: 03, loss: -0.88287
# DEBUG:root:Epoch [4/15], Batch [0/513], Loss: -0.9076651930809021
# DEBUG:root:Epoch [4/15], Batch [10/513], Loss: -0.8235254287719727
# DEBUG:root:Epoch [4/15], Batch [20/513], Loss: -0.8676506280899048
# DEBUG:root:Epoch [4/15], Batch [30/513], Loss: -0.8677150011062622
# DEBUG:root:Epoch [4/15], Batch [40/513], Loss: -0.8605283498764038
# DEBUG:root:Epoch [4/15], Batch [50/513], Loss: -0.8759186267852783
# DEBUG:root:Epoch [4/15], Batch [60/513], Loss: -0.8980216383934021
# DEBUG:root:Epoch [4/15], Batch [70/513], Loss: -0.8692476749420166
# DEBUG:root:Epoch [4/15], Batch [80/513], Loss: -0.8771487474441528
# DEBUG:root:Epoch [4/15], Batch [90/513], Loss: -0.8197815418243408
# DEBUG:root:Epoch [4/15], Batch [100/513], Loss: -0.8562358617782593
# DEBUG:root:Epoch [4/15], Batch [110/513], Loss: -0.9074236154556274
# DEBUG:root:Epoch [4/15], Batch [120/513], Loss: -0.8805443048477173
# DEBUG:root:Epoch [4/15], Batch [130/513], Loss: -0.886239767074585
# DEBUG:root:Epoch [4/15], Batch [140/513], Loss: -0.842728853225708
# DEBUG:root:Epoch [4/15], Batch [150/513], Loss: -0.8405174016952515
# DEBUG:root:Epoch [4/15], Batch [160/513], Loss: -0.8634090423583984
# DEBUG:root:Epoch [4/15], Batch [170/513], Loss: -0.8193535804748535
# DEBUG:root:Epoch [4/15], Batch [180/513], Loss: -0.8237932920455933
# DEBUG:root:Epoch [4/15], Batch [190/513], Loss: -0.851179838180542
# DEBUG:root:Epoch [4/15], Batch [200/513], Loss: -0.8901499509811401
# DEBUG:root:Epoch [4/15], Batch [210/513], Loss: -0.8544830083847046
# DEBUG:root:Epoch [4/15], Batch [220/513], Loss: -0.8525583148002625
# DEBUG:root:Epoch [4/15], Batch [230/513], Loss: -0.8824876546859741
# DEBUG:root:Epoch [4/15], Batch [240/513], Loss: -0.9101885557174683
# DEBUG:root:Epoch [4/15], Batch [250/513], Loss: -0.911683201789856
# DEBUG:root:Epoch [4/15], Batch [260/513], Loss: -0.8890275955200195
# DEBUG:root:Epoch [4/15], Batch [270/513], Loss: -0.9086142778396606
# DEBUG:root:Epoch [4/15], Batch [280/513], Loss: -0.9082164168357849
# DEBUG:root:Epoch [4/15], Batch [290/513], Loss: -0.930127739906311
# DEBUG:root:Epoch [4/15], Batch [300/513], Loss: -0.8987776041030884
# DEBUG:root:Epoch [4/15], Batch [310/513], Loss: -0.8702526092529297
# DEBUG:root:Epoch [4/15], Batch [320/513], Loss: -0.9140920639038086
# DEBUG:root:Epoch [4/15], Batch [330/513], Loss: -0.8994383811950684
# DEBUG:root:Epoch [4/15], Batch [340/513], Loss: -0.8549332618713379
# DEBUG:root:Epoch [4/15], Batch [350/513], Loss: -0.891919732093811
# DEBUG:root:Epoch [4/15], Batch [360/513], Loss: -0.880684494972229
# DEBUG:root:Epoch [4/15], Batch [370/513], Loss: -0.8942418098449707
# DEBUG:root:Epoch [4/15], Batch [380/513], Loss: -0.9112582802772522
# DEBUG:root:Epoch [4/15], Batch [390/513], Loss: -0.8940805792808533
# DEBUG:root:Epoch [4/15], Batch [400/513], Loss: -0.9134664535522461
# DEBUG:root:Epoch [4/15], Batch [410/513], Loss: -0.9081533551216125
# DEBUG:root:Epoch [4/15], Batch [420/513], Loss: -0.919475257396698
# DEBUG:root:Epoch [4/15], Batch [430/513], Loss: -0.8939123153686523
# DEBUG:root:Epoch [4/15], Batch [440/513], Loss: -0.899678111076355
# DEBUG:root:Epoch [4/15], Batch [450/513], Loss: -0.8726694583892822
# DEBUG:root:Epoch [4/15], Batch [460/513], Loss: -0.8395753502845764
# DEBUG:root:Epoch [4/15], Batch [470/513], Loss: -0.9094421863555908
# DEBUG:root:Epoch [4/15], Batch [480/513], Loss: -0.9082728028297424
# DEBUG:root:Epoch [4/15], Batch [490/513], Loss: -0.8783307671546936
# DEBUG:root:Epoch [4/15], Batch [500/513], Loss: -0.8727057576179504
# DEBUG:root:Epoch [4/15], Batch [510/513], Loss: -0.9178504347801208
# DEBUG:root:epoch: 04, loss: -0.88288
# DEBUG:root:Epoch [5/15], Batch [0/513], Loss: -0.9302682280540466
# DEBUG:root:Epoch [5/15], Batch [10/513], Loss: -0.9130469560623169
# DEBUG:root:Epoch [5/15], Batch [20/513], Loss: -0.8830700516700745
# DEBUG:root:Epoch [5/15], Batch [30/513], Loss: -0.8748035430908203
# DEBUG:root:Epoch [5/15], Batch [40/513], Loss: -0.9276173710823059
# DEBUG:root:Epoch [5/15], Batch [50/513], Loss: -0.920024573802948
# DEBUG:root:Epoch [5/15], Batch [60/513], Loss: -0.8893358111381531
# DEBUG:root:Epoch [5/15], Batch [70/513], Loss: -0.860348641872406
# DEBUG:root:Epoch [5/15], Batch [80/513], Loss: -0.9087752103805542
# DEBUG:root:Epoch [5/15], Batch [90/513], Loss: -0.9169381856918335
# DEBUG:root:Epoch [5/15], Batch [100/513], Loss: -0.9258711338043213
# DEBUG:root:Epoch [5/15], Batch [110/513], Loss: -0.9115841388702393
# DEBUG:root:Epoch [5/15], Batch [120/513], Loss: -0.8820040225982666
# DEBUG:root:Epoch [5/15], Batch [130/513], Loss: -0.9546360969543457
# DEBUG:root:Epoch [5/15], Batch [140/513], Loss: -0.9210422039031982
# DEBUG:root:Epoch [5/15], Batch [150/513], Loss: -0.9424245357513428
# DEBUG:root:Epoch [5/15], Batch [160/513], Loss: -0.8987243175506592
# DEBUG:root:Epoch [5/15], Batch [170/513], Loss: -0.9044219255447388
# DEBUG:root:Epoch [5/15], Batch [180/513], Loss: -0.9262754917144775
# DEBUG:root:Epoch [5/15], Batch [190/513], Loss: -0.8797442317008972
# DEBUG:root:Epoch [5/15], Batch [200/513], Loss: -0.8801971673965454
# DEBUG:root:Epoch [5/15], Batch [210/513], Loss: -0.8755970001220703
# DEBUG:root:Epoch [5/15], Batch [220/513], Loss: -0.894991934299469
# DEBUG:root:Epoch [5/15], Batch [230/513], Loss: -0.8738268613815308
# DEBUG:root:Epoch [5/15], Batch [240/513], Loss: -0.9218778014183044
# DEBUG:root:Epoch [5/15], Batch [250/513], Loss: -0.8965020179748535
# DEBUG:root:Epoch [5/15], Batch [260/513], Loss: -0.9142219424247742
# DEBUG:root:Epoch [5/15], Batch [270/513], Loss: -0.8428081274032593
# DEBUG:root:Epoch [5/15], Batch [280/513], Loss: -0.8971828818321228
# DEBUG:root:Epoch [5/15], Batch [290/513], Loss: -0.885606050491333
# DEBUG:root:Epoch [5/15], Batch [300/513], Loss: -0.9237669706344604
# DEBUG:root:Epoch [5/15], Batch [310/513], Loss: -0.9065223932266235
# DEBUG:root:Epoch [5/15], Batch [320/513], Loss: -0.9058659672737122
# DEBUG:root:Epoch [5/15], Batch [330/513], Loss: -0.9167673587799072
# DEBUG:root:Epoch [5/15], Batch [340/513], Loss: -0.8980509638786316
# DEBUG:root:Epoch [5/15], Batch [350/513], Loss: -0.9041088819503784
# DEBUG:root:Epoch [5/15], Batch [360/513], Loss: -0.8726049065589905
# DEBUG:root:Epoch [5/15], Batch [370/513], Loss: -0.8850104808807373
# DEBUG:root:Epoch [5/15], Batch [380/513], Loss: -0.8938959240913391
# DEBUG:root:Epoch [5/15], Batch [390/513], Loss: -0.8864664435386658
# DEBUG:root:Epoch [5/15], Batch [400/513], Loss: -0.9264838695526123
# DEBUG:root:Epoch [5/15], Batch [410/513], Loss: -0.9258708953857422
# DEBUG:root:Epoch [5/15], Batch [420/513], Loss: -0.8842592239379883
# DEBUG:root:Epoch [5/15], Batch [430/513], Loss: -0.8875441551208496
# DEBUG:root:Epoch [5/15], Batch [440/513], Loss: -0.914332926273346
# DEBUG:root:Epoch [5/15], Batch [450/513], Loss: -0.9208791255950928
# DEBUG:root:Epoch [5/15], Batch [460/513], Loss: -0.9039047956466675
# DEBUG:root:Epoch [5/15], Batch [470/513], Loss: -0.9061383605003357
# DEBUG:root:Epoch [5/15], Batch [480/513], Loss: -0.9017782211303711
# DEBUG:root:Epoch [5/15], Batch [490/513], Loss: -0.8635110855102539
# DEBUG:root:Epoch [5/15], Batch [500/513], Loss: -0.9003369808197021
# DEBUG:root:Epoch [5/15], Batch [510/513], Loss: -0.9178591370582581
# DEBUG:root:epoch: 05, loss: -0.90228
# DEBUG:root:Epoch [6/15], Batch [0/513], Loss: -0.9070429801940918
# DEBUG:root:Epoch [6/15], Batch [10/513], Loss: -0.8669896125793457
# DEBUG:root:Epoch [6/15], Batch [20/513], Loss: -0.9054474830627441
# DEBUG:root:Epoch [6/15], Batch [30/513], Loss: -0.9152915477752686
# DEBUG:root:Epoch [6/15], Batch [40/513], Loss: -0.9079482555389404
# DEBUG:root:Epoch [6/15], Batch [50/513], Loss: -0.8929553627967834
# DEBUG:root:Epoch [6/15], Batch [60/513], Loss: -0.870570182800293
# DEBUG:root:Epoch [6/15], Batch [70/513], Loss: -0.8980361223220825
# DEBUG:root:Epoch [6/15], Batch [80/513], Loss: -0.887050449848175
# DEBUG:root:Epoch [6/15], Batch [90/513], Loss: -0.9155060648918152
# DEBUG:root:Epoch [6/15], Batch [100/513], Loss: -0.8740746974945068
# DEBUG:root:Epoch [6/15], Batch [110/513], Loss: -0.9173800945281982
# DEBUG:root:Epoch [6/15], Batch [120/513], Loss: -0.918635368347168
# DEBUG:root:Epoch [6/15], Batch [130/513], Loss: -0.8714264631271362
# DEBUG:root:Epoch [6/15], Batch [140/513], Loss: -0.8903293609619141
# DEBUG:root:Epoch [6/15], Batch [150/513], Loss: -0.8251661062240601
# DEBUG:root:Epoch [6/15], Batch [160/513], Loss: -0.8544832468032837
# DEBUG:root:Epoch [6/15], Batch [170/513], Loss: -0.8683898448944092
# DEBUG:root:Epoch [6/15], Batch [180/513], Loss: -0.8660515546798706
# DEBUG:root:Epoch [6/15], Batch [190/513], Loss: -0.8860107064247131
# DEBUG:root:Epoch [6/15], Batch [200/513], Loss: -0.8563639521598816
# DEBUG:root:Epoch [6/15], Batch [210/513], Loss: -0.8667184710502625
# DEBUG:root:Epoch [6/15], Batch [220/513], Loss: -0.8893449902534485
# DEBUG:root:Epoch [6/15], Batch [230/513], Loss: -0.9244309067726135
# DEBUG:root:Epoch [6/15], Batch [240/513], Loss: -0.8671185970306396
# DEBUG:root:Epoch [6/15], Batch [250/513], Loss: -0.8818106651306152
# DEBUG:root:Epoch [6/15], Batch [260/513], Loss: -0.874282956123352
# DEBUG:root:Epoch [6/15], Batch [270/513], Loss: -0.9151337146759033
# DEBUG:root:Epoch [6/15], Batch [280/513], Loss: -0.8550474643707275
# DEBUG:root:Epoch [6/15], Batch [290/513], Loss: -0.9149265289306641
# DEBUG:root:Epoch [6/15], Batch [300/513], Loss: -0.8931053280830383
# DEBUG:root:Epoch [6/15], Batch [310/513], Loss: -0.8528332710266113
# DEBUG:root:Epoch [6/15], Batch [320/513], Loss: -0.8517563939094543
# DEBUG:root:Epoch [6/15], Batch [330/513], Loss: -0.9204778671264648
# DEBUG:root:Epoch [6/15], Batch [340/513], Loss: -0.8413709998130798
# DEBUG:root:Epoch [6/15], Batch [350/513], Loss: -0.9037500619888306
# DEBUG:root:Epoch [6/15], Batch [360/513], Loss: -0.9030845165252686
# DEBUG:root:Epoch [6/15], Batch [370/513], Loss: -0.8926034569740295
# DEBUG:root:Epoch [6/15], Batch [380/513], Loss: -0.929720938205719
# DEBUG:root:Epoch [6/15], Batch [390/513], Loss: -0.8773984313011169
# DEBUG:root:Epoch [6/15], Batch [400/513], Loss: -0.861177921295166
# DEBUG:root:Epoch [6/15], Batch [410/513], Loss: -0.8845100402832031
# DEBUG:root:Epoch [6/15], Batch [420/513], Loss: -0.9154703617095947
# DEBUG:root:Epoch [6/15], Batch [430/513], Loss: -0.8853039741516113
# DEBUG:root:Epoch [6/15], Batch [440/513], Loss: -0.9181857705116272
# DEBUG:root:Epoch [6/15], Batch [450/513], Loss: -0.8801107406616211
# DEBUG:root:Epoch [6/15], Batch [460/513], Loss: -0.8936218619346619
# DEBUG:root:Epoch [6/15], Batch [470/513], Loss: -0.9002516269683838
# DEBUG:root:Epoch [6/15], Batch [480/513], Loss: -0.89377361536026
# DEBUG:root:Epoch [6/15], Batch [490/513], Loss: -0.8486926555633545
# DEBUG:root:Epoch [6/15], Batch [500/513], Loss: -0.8915045261383057
# DEBUG:root:Epoch [6/15], Batch [510/513], Loss: -0.8359568119049072
# DEBUG:root:epoch: 06, loss: -0.88187
# DEBUG:root:Epoch [7/15], Batch [0/513], Loss: -0.8838476538658142
# DEBUG:root:Epoch [7/15], Batch [10/513], Loss: -0.8769823312759399
# DEBUG:root:Epoch [7/15], Batch [20/513], Loss: -0.8678088188171387
# DEBUG:root:Epoch [7/15], Batch [30/513], Loss: -0.8595230579376221
# DEBUG:root:Epoch [7/15], Batch [40/513], Loss: -0.932033121585846
# DEBUG:root:Epoch [7/15], Batch [50/513], Loss: -0.8968793749809265
# DEBUG:root:Epoch [7/15], Batch [60/513], Loss: -0.8878023624420166
# DEBUG:root:Epoch [7/15], Batch [70/513], Loss: -0.8655470609664917
# DEBUG:root:Epoch [7/15], Batch [80/513], Loss: -0.8717423677444458
# DEBUG:root:Epoch [7/15], Batch [90/513], Loss: -0.9017735123634338
# DEBUG:root:Epoch [7/15], Batch [100/513], Loss: -0.8444839119911194
# DEBUG:root:Epoch [7/15], Batch [110/513], Loss: -0.9243742823600769
# DEBUG:root:Epoch [7/15], Batch [120/513], Loss: -0.88319993019104
# DEBUG:root:Epoch [7/15], Batch [130/513], Loss: -0.9251788854598999
# DEBUG:root:Epoch [7/15], Batch [140/513], Loss: -0.8944481611251831
# DEBUG:root:Epoch [7/15], Batch [150/513], Loss: -0.9047620892524719
# DEBUG:root:Epoch [7/15], Batch [160/513], Loss: -0.8493860960006714
# DEBUG:root:Epoch [7/15], Batch [170/513], Loss: -0.8722976446151733
# DEBUG:root:Epoch [7/15], Batch [180/513], Loss: -0.8762012720108032
# DEBUG:root:Epoch [7/15], Batch [190/513], Loss: -0.8502498865127563
# DEBUG:root:Epoch [7/15], Batch [200/513], Loss: -0.8567884564399719
# DEBUG:root:Epoch [7/15], Batch [210/513], Loss: -0.8421549201011658
# DEBUG:root:Epoch [7/15], Batch [220/513], Loss: -0.8555831909179688
# DEBUG:root:Epoch [7/15], Batch [230/513], Loss: -0.8915565013885498
# DEBUG:root:Epoch [7/15], Batch [240/513], Loss: -0.9271306991577148
# DEBUG:root:Epoch [7/15], Batch [250/513], Loss: -0.8503157496452332
# DEBUG:root:Epoch [7/15], Batch [260/513], Loss: -0.9065447449684143
# DEBUG:root:Epoch [7/15], Batch [270/513], Loss: -0.90352463722229
# DEBUG:root:Epoch [7/15], Batch [280/513], Loss: -0.8679542541503906
# DEBUG:root:Epoch [7/15], Batch [290/513], Loss: -0.9390023946762085
# DEBUG:root:Epoch [7/15], Batch [300/513], Loss: -0.8831567764282227
# DEBUG:root:Epoch [7/15], Batch [310/513], Loss: -0.8988178372383118
# DEBUG:root:Epoch [7/15], Batch [320/513], Loss: -0.9147053956985474
# DEBUG:root:Epoch [7/15], Batch [330/513], Loss: -0.8691900968551636
# DEBUG:root:Epoch [7/15], Batch [340/513], Loss: -0.9145259857177734
# DEBUG:root:Epoch [7/15], Batch [350/513], Loss: -0.9269701242446899
# DEBUG:root:Epoch [7/15], Batch [360/513], Loss: -0.9326838850975037
# DEBUG:root:Epoch [7/15], Batch [370/513], Loss: -0.8812336325645447
# DEBUG:root:Epoch [7/15], Batch [380/513], Loss: -0.8771909475326538
# DEBUG:root:Epoch [7/15], Batch [390/513], Loss: -0.8763736486434937
# DEBUG:root:Epoch [7/15], Batch [400/513], Loss: -0.8729573488235474
# DEBUG:root:Epoch [7/15], Batch [410/513], Loss: -0.8656105995178223
# DEBUG:root:Epoch [7/15], Batch [420/513], Loss: -0.8915340900421143
# DEBUG:root:Epoch [7/15], Batch [430/513], Loss: -0.8219529390335083
# DEBUG:root:Epoch [7/15], Batch [440/513], Loss: -0.8796836733818054
# DEBUG:root:Epoch [7/15], Batch [450/513], Loss: -0.8651596307754517
# DEBUG:root:Epoch [7/15], Batch [460/513], Loss: -0.8971285820007324
# DEBUG:root:Epoch [7/15], Batch [470/513], Loss: -0.92458176612854
# DEBUG:root:Epoch [7/15], Batch [480/513], Loss: -0.9268909692764282
# DEBUG:root:Epoch [7/15], Batch [490/513], Loss: -0.9026191234588623
# DEBUG:root:Epoch [7/15], Batch [500/513], Loss: -0.8855486512184143
# DEBUG:root:Epoch [7/15], Batch [510/513], Loss: -0.886752724647522
# DEBUG:root:epoch: 07, loss: -0.88913
# DEBUG:root:Epoch [8/15], Batch [0/513], Loss: -0.9018928408622742
# DEBUG:root:Epoch [8/15], Batch [10/513], Loss: -0.8457044959068298
# DEBUG:root:Epoch [8/15], Batch [20/513], Loss: -0.8282223343849182
# DEBUG:root:Epoch [8/15], Batch [30/513], Loss: -0.8531918525695801
# DEBUG:root:Epoch [8/15], Batch [40/513], Loss: -0.8814728260040283
# DEBUG:root:Epoch [8/15], Batch [50/513], Loss: -0.8314515352249146
# DEBUG:root:Epoch [8/15], Batch [60/513], Loss: -0.8954312205314636
# DEBUG:root:Epoch [8/15], Batch [70/513], Loss: -0.9272406101226807
# DEBUG:root:Epoch [8/15], Batch [80/513], Loss: -0.8695094585418701
# DEBUG:root:Epoch [8/15], Batch [90/513], Loss: -0.922652542591095
# DEBUG:root:Epoch [8/15], Batch [100/513], Loss: -0.8876262307167053
# DEBUG:root:Epoch [8/15], Batch [110/513], Loss: -0.8848454356193542
# DEBUG:root:Epoch [8/15], Batch [120/513], Loss: -0.8890202641487122
# DEBUG:root:Epoch [8/15], Batch [130/513], Loss: -0.901831865310669
# DEBUG:root:Epoch [8/15], Batch [140/513], Loss: -0.9335055351257324
# DEBUG:root:Epoch [8/15], Batch [150/513], Loss: -0.8966604471206665
# DEBUG:root:Epoch [8/15], Batch [160/513], Loss: -0.9143091440200806
# DEBUG:root:Epoch [8/15], Batch [170/513], Loss: -0.910507082939148
# DEBUG:root:Epoch [8/15], Batch [180/513], Loss: -0.9245196580886841
# DEBUG:root:Epoch [8/15], Batch [190/513], Loss: -0.9035297632217407
# DEBUG:root:Epoch [8/15], Batch [200/513], Loss: -0.9282611608505249
# DEBUG:root:Epoch [8/15], Batch [210/513], Loss: -0.9286142587661743
# DEBUG:root:Epoch [8/15], Batch [220/513], Loss: -0.9157938957214355
# DEBUG:root:Epoch [8/15], Batch [230/513], Loss: -0.8934106826782227
# DEBUG:root:Epoch [8/15], Batch [240/513], Loss: -0.9102951884269714
# DEBUG:root:Epoch [8/15], Batch [250/513], Loss: -0.884797215461731
# DEBUG:root:Epoch [8/15], Batch [260/513], Loss: -0.8635958433151245
# DEBUG:root:Epoch [8/15], Batch [270/513], Loss: -0.8883493542671204
# DEBUG:root:Epoch [8/15], Batch [280/513], Loss: -0.895003080368042
# DEBUG:root:Epoch [8/15], Batch [290/513], Loss: -0.8586812019348145
# DEBUG:root:Epoch [8/15], Batch [300/513], Loss: -0.8662570714950562
# DEBUG:root:Epoch [8/15], Batch [310/513], Loss: -0.8886386156082153
# DEBUG:root:Epoch [8/15], Batch [320/513], Loss: -0.9258449673652649
# DEBUG:root:Epoch [8/15], Batch [330/513], Loss: -0.8694355487823486
# DEBUG:root:Epoch [8/15], Batch [340/513], Loss: -0.9096351861953735
# DEBUG:root:Epoch [8/15], Batch [350/513], Loss: -0.9147393703460693
# DEBUG:root:Epoch [8/15], Batch [360/513], Loss: -0.9207426309585571
# DEBUG:root:Epoch [8/15], Batch [370/513], Loss: -0.8870563507080078
# DEBUG:root:Epoch [8/15], Batch [380/513], Loss: -0.8746650218963623
# DEBUG:root:Epoch [8/15], Batch [390/513], Loss: -0.9098434448242188
# DEBUG:root:Epoch [8/15], Batch [400/513], Loss: -0.8981748819351196
# DEBUG:root:Epoch [8/15], Batch [410/513], Loss: -0.9421740770339966
# DEBUG:root:Epoch [8/15], Batch [420/513], Loss: -0.911224365234375
# DEBUG:root:Epoch [8/15], Batch [430/513], Loss: -0.9423773288726807
# DEBUG:root:Epoch [8/15], Batch [440/513], Loss: -0.9098745584487915
# DEBUG:root:Epoch [8/15], Batch [450/513], Loss: -0.9063622951507568
# DEBUG:root:Epoch [8/15], Batch [460/513], Loss: -0.8894500732421875
# DEBUG:root:Epoch [8/15], Batch [470/513], Loss: -0.9139614105224609
# DEBUG:root:Epoch [8/15], Batch [480/513], Loss: -0.9363709688186646
# DEBUG:root:Epoch [8/15], Batch [490/513], Loss: -0.910119891166687
# DEBUG:root:Epoch [8/15], Batch [500/513], Loss: -0.8951609134674072
# DEBUG:root:Epoch [8/15], Batch [510/513], Loss: -0.8768302202224731
# DEBUG:root:epoch: 08, loss: -0.90448
# DEBUG:root:Epoch [9/15], Batch [0/513], Loss: -0.9408663511276245
# DEBUG:root:Epoch [9/15], Batch [10/513], Loss: -0.9382331371307373
# DEBUG:root:Epoch [9/15], Batch [20/513], Loss: -0.9215636849403381
# DEBUG:root:Epoch [9/15], Batch [30/513], Loss: -0.9086278676986694
# DEBUG:root:Epoch [9/15], Batch [40/513], Loss: -0.923526406288147
# DEBUG:root:Epoch [9/15], Batch [50/513], Loss: -0.9391767382621765
# DEBUG:root:Epoch [9/15], Batch [60/513], Loss: -0.8936827182769775
# DEBUG:root:Epoch [9/15], Batch [70/513], Loss: -0.9240318536758423
# DEBUG:root:Epoch [9/15], Batch [80/513], Loss: -0.9446117877960205
# DEBUG:root:Epoch [9/15], Batch [90/513], Loss: -0.9221376776695251
# DEBUG:root:Epoch [9/15], Batch [100/513], Loss: -0.9111077785491943
# DEBUG:root:Epoch [9/15], Batch [110/513], Loss: -0.9134190678596497
# DEBUG:root:Epoch [9/15], Batch [120/513], Loss: -0.9295477867126465
# DEBUG:root:Epoch [9/15], Batch [130/513], Loss: -0.9116948843002319
# DEBUG:root:Epoch [9/15], Batch [140/513], Loss: -0.9027167558670044
# DEBUG:root:Epoch [9/15], Batch [150/513], Loss: -0.9151968955993652
# DEBUG:root:Epoch [9/15], Batch [160/513], Loss: -0.9066013097763062
# DEBUG:root:Epoch [9/15], Batch [170/513], Loss: -0.9129490256309509
# DEBUG:root:Epoch [9/15], Batch [180/513], Loss: -0.9339221119880676
# DEBUG:root:Epoch [9/15], Batch [190/513], Loss: -0.9485632181167603
# DEBUG:root:Epoch [9/15], Batch [200/513], Loss: -0.8895741105079651
# DEBUG:root:Epoch [9/15], Batch [210/513], Loss: -0.9087353944778442
# DEBUG:root:Epoch [9/15], Batch [220/513], Loss: -0.9439178705215454
# DEBUG:root:Epoch [9/15], Batch [230/513], Loss: -0.8920071721076965
# DEBUG:root:Epoch [9/15], Batch [240/513], Loss: -0.9049822092056274
# DEBUG:root:Epoch [9/15], Batch [250/513], Loss: -0.8457141518592834
# DEBUG:root:Epoch [9/15], Batch [260/513], Loss: -0.862861156463623
# DEBUG:root:Epoch [9/15], Batch [270/513], Loss: -0.9240990877151489
# DEBUG:root:Epoch [9/15], Batch [280/513], Loss: -0.9232128858566284
# DEBUG:root:Epoch [9/15], Batch [290/513], Loss: -0.9451408386230469
# DEBUG:root:Epoch [9/15], Batch [300/513], Loss: -0.8696768283843994
# DEBUG:root:Epoch [9/15], Batch [310/513], Loss: -0.9409544467926025
# DEBUG:root:Epoch [9/15], Batch [320/513], Loss: -0.9099332094192505
# DEBUG:root:Epoch [9/15], Batch [330/513], Loss: -0.9442739486694336
# DEBUG:root:Epoch [9/15], Batch [340/513], Loss: -0.8999365568161011
# DEBUG:root:Epoch [9/15], Batch [350/513], Loss: -0.9327692985534668
# DEBUG:root:Epoch [9/15], Batch [360/513], Loss: -0.9441853165626526
# DEBUG:root:Epoch [9/15], Batch [370/513], Loss: -0.9002386331558228
# DEBUG:root:Epoch [9/15], Batch [380/513], Loss: -0.9428359270095825
# DEBUG:root:Epoch [9/15], Batch [390/513], Loss: -0.9329623579978943
# DEBUG:root:Epoch [9/15], Batch [400/513], Loss: -0.8894909620285034
# DEBUG:root:Epoch [9/15], Batch [410/513], Loss: -0.9165786504745483
# DEBUG:root:Epoch [9/15], Batch [420/513], Loss: -0.9295182824134827
# DEBUG:root:Epoch [9/15], Batch [430/513], Loss: -0.9055534601211548
# DEBUG:root:Epoch [9/15], Batch [440/513], Loss: -0.8682571649551392
# DEBUG:root:Epoch [9/15], Batch [450/513], Loss: -0.9267874956130981
# DEBUG:root:Epoch [9/15], Batch [460/513], Loss: -0.9535017013549805
# DEBUG:root:Epoch [9/15], Batch [470/513], Loss: -0.912378191947937
# DEBUG:root:Epoch [9/15], Batch [480/513], Loss: -0.9279102087020874
# DEBUG:root:Epoch [9/15], Batch [490/513], Loss: -0.9276198148727417
# DEBUG:root:Epoch [9/15], Batch [500/513], Loss: -0.9216784238815308
# DEBUG:root:Epoch [9/15], Batch [510/513], Loss: -0.9153251647949219
# DEBUG:root:epoch: 09, loss: -0.91586
# DEBUG:root:Epoch [10/15], Batch [0/513], Loss: -0.9103744029998779
# DEBUG:root:Epoch [10/15], Batch [10/513], Loss: -0.9222990274429321
# DEBUG:root:Epoch [10/15], Batch [20/513], Loss: -0.9272014498710632
# DEBUG:root:Epoch [10/15], Batch [30/513], Loss: -0.9463260769844055
# DEBUG:root:Epoch [10/15], Batch [40/513], Loss: -0.901734471321106
# DEBUG:root:Epoch [10/15], Batch [50/513], Loss: -0.9125601649284363
# DEBUG:root:Epoch [10/15], Batch [60/513], Loss: -0.8899341821670532
# DEBUG:root:Epoch [10/15], Batch [70/513], Loss: -0.9411472082138062
# DEBUG:root:Epoch [10/15], Batch [80/513], Loss: -0.9357531666755676
# DEBUG:root:Epoch [10/15], Batch [90/513], Loss: -0.8939291834831238
# DEBUG:root:Epoch [10/15], Batch [100/513], Loss: -0.9228339195251465
# DEBUG:root:Epoch [10/15], Batch [110/513], Loss: -0.9440699815750122
# DEBUG:root:Epoch [10/15], Batch [120/513], Loss: -0.957850456237793
# DEBUG:root:Epoch [10/15], Batch [130/513], Loss: -0.9440293312072754
# DEBUG:root:Epoch [10/15], Batch [140/513], Loss: -0.9062625169754028
# DEBUG:root:Epoch [10/15], Batch [150/513], Loss: -0.9325279593467712
# DEBUG:root:Epoch [10/15], Batch [160/513], Loss: -0.9407933354377747
# DEBUG:root:Epoch [10/15], Batch [170/513], Loss: -0.9429111480712891
# DEBUG:root:Epoch [10/15], Batch [180/513], Loss: -0.9171968698501587
# DEBUG:root:Epoch [10/15], Batch [190/513], Loss: -0.9250327348709106
# DEBUG:root:Epoch [10/15], Batch [200/513], Loss: -0.9404711723327637
# DEBUG:root:Epoch [10/15], Batch [210/513], Loss: -0.9165672063827515
# DEBUG:root:Epoch [10/15], Batch [220/513], Loss: -0.9253114461898804
# DEBUG:root:Epoch [10/15], Batch [230/513], Loss: -0.9227696657180786
# DEBUG:root:Epoch [10/15], Batch [240/513], Loss: -0.9157538414001465
# DEBUG:root:Epoch [10/15], Batch [250/513], Loss: -0.9241012930870056
# DEBUG:root:Epoch [10/15], Batch [260/513], Loss: -0.9523358941078186
# DEBUG:root:Epoch [10/15], Batch [270/513], Loss: -0.8980956673622131
# DEBUG:root:Epoch [10/15], Batch [280/513], Loss: -0.9334083795547485
# DEBUG:root:Epoch [10/15], Batch [290/513], Loss: -0.9412590265274048
# DEBUG:root:Epoch [10/15], Batch [300/513], Loss: -0.9480058550834656
# DEBUG:root:Epoch [10/15], Batch [310/513], Loss: -0.9289203882217407
# DEBUG:root:Epoch [10/15], Batch [320/513], Loss: -0.928617537021637
# DEBUG:root:Epoch [10/15], Batch [330/513], Loss: -0.9338482618331909
# DEBUG:root:Epoch [10/15], Batch [340/513], Loss: -0.9451496601104736
# DEBUG:root:Epoch [10/15], Batch [350/513], Loss: -0.9321037530899048
# DEBUG:root:Epoch [10/15], Batch [360/513], Loss: -0.9477722644805908
# DEBUG:root:Epoch [10/15], Batch [370/513], Loss: -0.9402741193771362
# DEBUG:root:Epoch [10/15], Batch [380/513], Loss: -0.9219683408737183
# DEBUG:root:Epoch [10/15], Batch [390/513], Loss: -0.957442045211792
# DEBUG:root:Epoch [10/15], Batch [400/513], Loss: -0.946109414100647
# DEBUG:root:Epoch [10/15], Batch [410/513], Loss: -0.9534574747085571
# DEBUG:root:Epoch [10/15], Batch [420/513], Loss: -0.9170756936073303
# DEBUG:root:Epoch [10/15], Batch [430/513], Loss: -0.9387927055358887
# DEBUG:root:Epoch [10/15], Batch [440/513], Loss: -0.9134411811828613
# DEBUG:root:Epoch [10/15], Batch [450/513], Loss: -0.9130696058273315
# DEBUG:root:Epoch [10/15], Batch [460/513], Loss: -0.9172650575637817
# DEBUG:root:Epoch [10/15], Batch [470/513], Loss: -0.9332180023193359
# DEBUG:root:Epoch [10/15], Batch [480/513], Loss: -0.9312262535095215
# DEBUG:root:Epoch [10/15], Batch [490/513], Loss: -0.9521899223327637
# DEBUG:root:Epoch [10/15], Batch [500/513], Loss: -0.9155435562133789
# DEBUG:root:Epoch [10/15], Batch [510/513], Loss: -0.8983947038650513
# DEBUG:root:epoch: 10, loss: -0.92506
# DEBUG:root:Epoch [11/15], Batch [0/513], Loss: -0.9339752197265625
# DEBUG:root:Epoch [11/15], Batch [10/513], Loss: -0.9376885890960693
# DEBUG:root:Epoch [11/15], Batch [20/513], Loss: -0.9438043832778931
# DEBUG:root:Epoch [11/15], Batch [30/513], Loss: -0.9160066843032837
# DEBUG:root:Epoch [11/15], Batch [40/513], Loss: -0.9335818290710449
# DEBUG:root:Epoch [11/15], Batch [50/513], Loss: -0.9575720429420471
# DEBUG:root:Epoch [11/15], Batch [60/513], Loss: -0.9426113367080688
# DEBUG:root:Epoch [11/15], Batch [70/513], Loss: -0.9182027578353882
# DEBUG:root:Epoch [11/15], Batch [80/513], Loss: -0.9575999975204468
# DEBUG:root:Epoch [11/15], Batch [90/513], Loss: -0.8971502780914307
# DEBUG:root:Epoch [11/15], Batch [100/513], Loss: -0.9023861885070801
# DEBUG:root:Epoch [11/15], Batch [110/513], Loss: -0.9119330644607544
# DEBUG:root:Epoch [11/15], Batch [120/513], Loss: -0.93996262550354
# DEBUG:root:Epoch [11/15], Batch [130/513], Loss: -0.8751131296157837
# DEBUG:root:Epoch [11/15], Batch [140/513], Loss: -0.9268147945404053
# DEBUG:root:Epoch [11/15], Batch [150/513], Loss: -0.9333446621894836
# DEBUG:root:Epoch [11/15], Batch [160/513], Loss: -0.9466636180877686
# DEBUG:root:Epoch [11/15], Batch [170/513], Loss: -0.9385829567909241
# DEBUG:root:Epoch [11/15], Batch [180/513], Loss: -0.9424866437911987
# DEBUG:root:Epoch [11/15], Batch [190/513], Loss: -0.8994570970535278
# DEBUG:root:Epoch [11/15], Batch [200/513], Loss: -0.916749119758606
# DEBUG:root:Epoch [11/15], Batch [210/513], Loss: -0.9564117789268494
# DEBUG:root:Epoch [11/15], Batch [220/513], Loss: -0.945136547088623
# DEBUG:root:Epoch [11/15], Batch [230/513], Loss: -0.9503974318504333
# DEBUG:root:Epoch [11/15], Batch [240/513], Loss: -0.8786625266075134
# DEBUG:root:Epoch [11/15], Batch [250/513], Loss: -0.9213047027587891
# DEBUG:root:Epoch [11/15], Batch [260/513], Loss: -0.88978111743927
# DEBUG:root:Epoch [11/15], Batch [270/513], Loss: -0.9350122809410095
# DEBUG:root:Epoch [11/15], Batch [280/513], Loss: -0.890714168548584
# DEBUG:root:Epoch [11/15], Batch [290/513], Loss: -0.9222604036331177
# DEBUG:root:Epoch [11/15], Batch [300/513], Loss: -0.876840353012085
# DEBUG:root:Epoch [11/15], Batch [310/513], Loss: -0.9455000162124634
# DEBUG:root:Epoch [11/15], Batch [320/513], Loss: -0.8931049108505249
# DEBUG:root:Epoch [11/15], Batch [330/513], Loss: -0.9376724362373352
# DEBUG:root:Epoch [11/15], Batch [340/513], Loss: -0.9310394525527954
# DEBUG:root:Epoch [11/15], Batch [350/513], Loss: -0.906355619430542
# DEBUG:root:Epoch [11/15], Batch [360/513], Loss: -0.9245079755783081
# DEBUG:root:Epoch [11/15], Batch [370/513], Loss: -0.9449717402458191
# DEBUG:root:Epoch [11/15], Batch [380/513], Loss: -0.8915343284606934
# DEBUG:root:Epoch [11/15], Batch [390/513], Loss: -0.9075222015380859
# DEBUG:root:Epoch [11/15], Batch [400/513], Loss: -0.9242822527885437
# DEBUG:root:Epoch [11/15], Batch [410/513], Loss: -0.9011907577514648
# DEBUG:root:Epoch [11/15], Batch [420/513], Loss: -0.942603588104248
# DEBUG:root:Epoch [11/15], Batch [430/513], Loss: -0.923375129699707
# DEBUG:root:Epoch [11/15], Batch [440/513], Loss: -0.9474154710769653
# DEBUG:root:Epoch [11/15], Batch [450/513], Loss: -0.9346426129341125
# DEBUG:root:Epoch [11/15], Batch [460/513], Loss: -0.9169628620147705
# DEBUG:root:Epoch [11/15], Batch [470/513], Loss: -0.91193687915802
# DEBUG:root:Epoch [11/15], Batch [480/513], Loss: -0.9313043355941772
# DEBUG:root:Epoch [11/15], Batch [490/513], Loss: -0.9542200565338135
# DEBUG:root:Epoch [11/15], Batch [500/513], Loss: -0.9420449733734131
# DEBUG:root:Epoch [11/15], Batch [510/513], Loss: -0.9294159412384033
# DEBUG:root:epoch: 11, loss: -0.92659
# DEBUG:root:Epoch [12/15], Batch [0/513], Loss: -0.9169132709503174
# DEBUG:root:Epoch [12/15], Batch [10/513], Loss: -0.9306031465530396
# DEBUG:root:Epoch [12/15], Batch [20/513], Loss: -0.9365425705909729
# DEBUG:root:Epoch [12/15], Batch [30/513], Loss: -0.9031400680541992
# DEBUG:root:Epoch [12/15], Batch [40/513], Loss: -0.9408586025238037
# DEBUG:root:Epoch [12/15], Batch [50/513], Loss: -0.9413107633590698
# DEBUG:root:Epoch [12/15], Batch [60/513], Loss: -0.9097707271575928
# DEBUG:root:Epoch [12/15], Batch [70/513], Loss: -0.9211950898170471
# DEBUG:root:Epoch [12/15], Batch [80/513], Loss: -0.8985649347305298
# DEBUG:root:Epoch [12/15], Batch [90/513], Loss: -0.8969739079475403
# DEBUG:root:Epoch [12/15], Batch [100/513], Loss: -0.873488187789917
# DEBUG:root:Epoch [12/15], Batch [110/513], Loss: -0.8764748573303223
# DEBUG:root:Epoch [12/15], Batch [120/513], Loss: -0.8820423483848572
# DEBUG:root:Epoch [12/15], Batch [130/513], Loss: -0.903700590133667
# DEBUG:root:Epoch [12/15], Batch [140/513], Loss: -0.8717893958091736
# DEBUG:root:Epoch [12/15], Batch [150/513], Loss: -0.8956958651542664
# DEBUG:root:Epoch [12/15], Batch [160/513], Loss: -0.8944968581199646
# DEBUG:root:Epoch [12/15], Batch [170/513], Loss: -0.9047490358352661
# DEBUG:root:Epoch [12/15], Batch [180/513], Loss: -0.8606039881706238
# DEBUG:root:Epoch [12/15], Batch [190/513], Loss: -0.9103569984436035
# DEBUG:root:Epoch [12/15], Batch [200/513], Loss: -0.915987491607666
# DEBUG:root:Epoch [12/15], Batch [210/513], Loss: -0.8593895435333252
# DEBUG:root:Epoch [12/15], Batch [220/513], Loss: -0.9270726442337036
# DEBUG:root:Epoch [12/15], Batch [230/513], Loss: -0.8976678848266602
# DEBUG:root:Epoch [12/15], Batch [240/513], Loss: -0.930492639541626
# DEBUG:root:Epoch [12/15], Batch [250/513], Loss: -0.8708112239837646
# DEBUG:root:Epoch [12/15], Batch [260/513], Loss: -0.9254109859466553
# DEBUG:root:Epoch [12/15], Batch [270/513], Loss: -0.9302791357040405
# DEBUG:root:Epoch [12/15], Batch [280/513], Loss: -0.9256429672241211
# DEBUG:root:Epoch [12/15], Batch [290/513], Loss: -0.9089627861976624
# DEBUG:root:Epoch [12/15], Batch [300/513], Loss: -0.9329234957695007
# DEBUG:root:Epoch [12/15], Batch [310/513], Loss: -0.924407422542572
# DEBUG:root:Epoch [12/15], Batch [320/513], Loss: -0.9504003524780273
# DEBUG:root:Epoch [12/15], Batch [330/513], Loss: -0.9431706666946411
# DEBUG:root:Epoch [12/15], Batch [340/513], Loss: -0.9371151924133301
# DEBUG:root:Epoch [12/15], Batch [350/513], Loss: -0.932174563407898
# DEBUG:root:Epoch [12/15], Batch [360/513], Loss: -0.9078143835067749
# DEBUG:root:Epoch [12/15], Batch [370/513], Loss: -0.9141242504119873
# DEBUG:root:Epoch [12/15], Batch [380/513], Loss: -0.9347290992736816
# DEBUG:root:Epoch [12/15], Batch [390/513], Loss: -0.9309922456741333
# DEBUG:root:Epoch [12/15], Batch [400/513], Loss: -0.9327928423881531
# DEBUG:root:Epoch [12/15], Batch [410/513], Loss: -0.9079909920692444
# DEBUG:root:Epoch [12/15], Batch [420/513], Loss: -0.9376171231269836
# DEBUG:root:Epoch [12/15], Batch [430/513], Loss: -0.8742265701293945
# DEBUG:root:Epoch [12/15], Batch [440/513], Loss: -0.9016919136047363
# DEBUG:root:Epoch [12/15], Batch [450/513], Loss: -0.9337692856788635
# DEBUG:root:Epoch [12/15], Batch [460/513], Loss: -0.9202969074249268
# DEBUG:root:Epoch [12/15], Batch [470/513], Loss: -0.89599609375
# DEBUG:root:Epoch [12/15], Batch [480/513], Loss: -0.9171499013900757
# DEBUG:root:Epoch [12/15], Batch [490/513], Loss: -0.9366648197174072
# DEBUG:root:Epoch [12/15], Batch [500/513], Loss: -0.9273242950439453
# DEBUG:root:Epoch [12/15], Batch [510/513], Loss: -0.9378557205200195
# DEBUG:root:epoch: 12, loss: -0.91396
# DEBUG:root:Epoch [13/15], Batch [0/513], Loss: -0.9105214476585388
# DEBUG:root:Epoch [13/15], Batch [10/513], Loss: -0.9081714749336243
# DEBUG:root:Epoch [13/15], Batch [20/513], Loss: -0.9087188243865967
# DEBUG:root:Epoch [13/15], Batch [30/513], Loss: -0.9194797873497009
# DEBUG:root:Epoch [13/15], Batch [40/513], Loss: -0.9343944787979126
# DEBUG:root:Epoch [13/15], Batch [50/513], Loss: -0.8976994156837463
# DEBUG:root:Epoch [13/15], Batch [60/513], Loss: -0.9257203340530396
# DEBUG:root:Epoch [13/15], Batch [70/513], Loss: -0.9291564226150513
# DEBUG:root:Epoch [13/15], Batch [80/513], Loss: -0.8895764350891113
# DEBUG:root:Epoch [13/15], Batch [90/513], Loss: -0.8945850133895874
# DEBUG:root:Epoch [13/15], Batch [100/513], Loss: -0.9205542802810669
# DEBUG:root:Epoch [13/15], Batch [110/513], Loss: -0.9276258945465088
# DEBUG:root:Epoch [13/15], Batch [120/513], Loss: -0.9261036515235901
# DEBUG:root:Epoch [13/15], Batch [130/513], Loss: -0.9276261329650879
# DEBUG:root:Epoch [13/15], Batch [140/513], Loss: -0.9119614362716675
# DEBUG:root:Epoch [13/15], Batch [150/513], Loss: -0.9293931126594543
# DEBUG:root:Epoch [13/15], Batch [160/513], Loss: -0.915050208568573
# DEBUG:root:Epoch [13/15], Batch [170/513], Loss: -0.9504569172859192
# DEBUG:root:Epoch [13/15], Batch [180/513], Loss: -0.9243870377540588
# DEBUG:root:Epoch [13/15], Batch [190/513], Loss: -0.9417073130607605
# DEBUG:root:Epoch [13/15], Batch [200/513], Loss: -0.9148246049880981
# DEBUG:root:Epoch [13/15], Batch [210/513], Loss: -0.9398243427276611
# DEBUG:root:Epoch [13/15], Batch [220/513], Loss: -0.9304508566856384
# DEBUG:root:Epoch [13/15], Batch [230/513], Loss: -0.916519045829773
# DEBUG:root:Epoch [13/15], Batch [240/513], Loss: -0.9498668313026428
# DEBUG:root:Epoch [13/15], Batch [250/513], Loss: -0.9064030647277832
# DEBUG:root:Epoch [13/15], Batch [260/513], Loss: -0.9244277477264404
# DEBUG:root:Epoch [13/15], Batch [270/513], Loss: -0.9382346868515015
# DEBUG:root:Epoch [13/15], Batch [280/513], Loss: -0.9201639890670776
# DEBUG:root:Epoch [13/15], Batch [290/513], Loss: -0.9367043972015381
# DEBUG:root:Epoch [13/15], Batch [300/513], Loss: -0.9283511638641357
# DEBUG:root:Epoch [13/15], Batch [310/513], Loss: -0.8858861923217773
# DEBUG:root:Epoch [13/15], Batch [320/513], Loss: -0.9408316016197205
# DEBUG:root:Epoch [13/15], Batch [330/513], Loss: -0.9550740718841553
# DEBUG:root:Epoch [13/15], Batch [340/513], Loss: -0.9003281593322754
# DEBUG:root:Epoch [13/15], Batch [350/513], Loss: -0.9305278062820435
# DEBUG:root:Epoch [13/15], Batch [360/513], Loss: -0.9337260723114014
# DEBUG:root:Epoch [13/15], Batch [370/513], Loss: -0.9217454195022583
# DEBUG:root:Epoch [13/15], Batch [380/513], Loss: -0.9279847145080566
# DEBUG:root:Epoch [13/15], Batch [390/513], Loss: -0.9225060939788818
# DEBUG:root:Epoch [13/15], Batch [400/513], Loss: -0.9329515099525452
# DEBUG:root:Epoch [13/15], Batch [410/513], Loss: -0.9091264009475708
# DEBUG:root:Epoch [13/15], Batch [420/513], Loss: -0.9162665009498596
# DEBUG:root:Epoch [13/15], Batch [430/513], Loss: -0.934309720993042
# DEBUG:root:Epoch [13/15], Batch [440/513], Loss: -0.9296678900718689
# DEBUG:root:Epoch [13/15], Batch [450/513], Loss: -0.9459608793258667
# DEBUG:root:Epoch [13/15], Batch [460/513], Loss: -0.9111558198928833
# DEBUG:root:Epoch [13/15], Batch [470/513], Loss: -0.94361412525177
# DEBUG:root:Epoch [13/15], Batch [480/513], Loss: -0.9415969848632812
# DEBUG:root:Epoch [13/15], Batch [490/513], Loss: -0.9429316520690918
# DEBUG:root:Epoch [13/15], Batch [500/513], Loss: -0.924458384513855
# DEBUG:root:Epoch [13/15], Batch [510/513], Loss: -0.8694009780883789
# DEBUG:root:epoch: 13, loss: -0.92368
# DEBUG:root:Epoch [14/15], Batch [0/513], Loss: -0.8992542028427124
# DEBUG:root:Epoch [14/15], Batch [10/513], Loss: -0.9241180419921875
# DEBUG:root:Epoch [14/15], Batch [20/513], Loss: -0.9333701729774475
# DEBUG:root:Epoch [14/15], Batch [30/513], Loss: -0.9503396153450012
# DEBUG:root:Epoch [14/15], Batch [40/513], Loss: -0.931678295135498
# DEBUG:root:Epoch [14/15], Batch [50/513], Loss: -0.9125975370407104
# DEBUG:root:Epoch [14/15], Batch [60/513], Loss: -0.9579642415046692
# DEBUG:root:Epoch [14/15], Batch [70/513], Loss: -0.9073446989059448
# DEBUG:root:Epoch [14/15], Batch [80/513], Loss: -0.9245087504386902
# DEBUG:root:Epoch [14/15], Batch [90/513], Loss: -0.9266888499259949
# DEBUG:root:Epoch [14/15], Batch [100/513], Loss: -0.925262451171875
# DEBUG:root:Epoch [14/15], Batch [110/513], Loss: -0.9213775396347046
# DEBUG:root:Epoch [14/15], Batch [120/513], Loss: -0.9355940818786621
# DEBUG:root:Epoch [14/15], Batch [130/513], Loss: -0.9474790096282959
# DEBUG:root:Epoch [14/15], Batch [140/513], Loss: -0.867856502532959
# DEBUG:root:Epoch [14/15], Batch [150/513], Loss: -0.9233397245407104
# DEBUG:root:Epoch [14/15], Batch [160/513], Loss: -0.9210686683654785
# DEBUG:root:Epoch [14/15], Batch [170/513], Loss: -0.9339379072189331
# DEBUG:root:Epoch [14/15], Batch [180/513], Loss: -0.9598596692085266
# DEBUG:root:Epoch [14/15], Batch [190/513], Loss: -0.9295096397399902
# DEBUG:root:Epoch [14/15], Batch [200/513], Loss: -0.9156355857849121
# DEBUG:root:Epoch [14/15], Batch [210/513], Loss: -0.9195858836174011
# DEBUG:root:Epoch [14/15], Batch [220/513], Loss: -0.9656076431274414
# DEBUG:root:Epoch [14/15], Batch [230/513], Loss: -0.9363713264465332
# DEBUG:root:Epoch [14/15], Batch [240/513], Loss: -0.9134378433227539
# DEBUG:root:Epoch [14/15], Batch [250/513], Loss: -0.9474502801895142
# DEBUG:root:Epoch [14/15], Batch [260/513], Loss: -0.9218391180038452
# DEBUG:root:Epoch [14/15], Batch [270/513], Loss: -0.934935450553894
# DEBUG:root:Epoch [14/15], Batch [280/513], Loss: -0.9095943570137024
# DEBUG:root:Epoch [14/15], Batch [290/513], Loss: -0.9092234373092651
# DEBUG:root:Epoch [14/15], Batch [300/513], Loss: -0.914020299911499
# DEBUG:root:Epoch [14/15], Batch [310/513], Loss: -0.9440844058990479
# DEBUG:root:Epoch [14/15], Batch [320/513], Loss: -0.9610910415649414
# DEBUG:root:Epoch [14/15], Batch [330/513], Loss: -0.9095120429992676
# DEBUG:root:Epoch [14/15], Batch [340/513], Loss: -0.9290550947189331
# DEBUG:root:Epoch [14/15], Batch [350/513], Loss: -0.9538341760635376
# DEBUG:root:Epoch [14/15], Batch [360/513], Loss: -0.9254819750785828
# DEBUG:root:Epoch [14/15], Batch [370/513], Loss: -0.9572525024414062
# DEBUG:root:Epoch [14/15], Batch [380/513], Loss: -0.9438133239746094
# DEBUG:root:Epoch [14/15], Batch [390/513], Loss: -0.9349257946014404
# DEBUG:root:Epoch [14/15], Batch [400/513], Loss: -0.9249655604362488
# DEBUG:root:Epoch [14/15], Batch [410/513], Loss: -0.9482449293136597
# DEBUG:root:Epoch [14/15], Batch [420/513], Loss: -0.9458773136138916
# DEBUG:root:Epoch [14/15], Batch [430/513], Loss: -0.9280140399932861
# DEBUG:root:Epoch [14/15], Batch [440/513], Loss: -0.9133336544036865
# DEBUG:root:Epoch [14/15], Batch [450/513], Loss: -0.9242361783981323
# DEBUG:root:Epoch [14/15], Batch [460/513], Loss: -0.9118235111236572
# DEBUG:root:Epoch [14/15], Batch [470/513], Loss: -0.9454777240753174
# DEBUG:root:Epoch [14/15], Batch [480/513], Loss: -0.923815131187439
# DEBUG:root:Epoch [14/15], Batch [490/513], Loss: -0.9213821887969971
# DEBUG:root:Epoch [14/15], Batch [500/513], Loss: -0.9339561462402344
# DEBUG:root:Epoch [14/15], Batch [510/513], Loss: -0.9398050904273987
# DEBUG:root:epoch: 14, loss: -0.92845

# %%
class FinetuneClassifier(nn.Module):
    def __init__(self, backbone, head):
        super(FinetuneClassifier, self).__init__()
        self.backbone = backbone
        self.head = head

    def forward(self, x):
        z = self.backbone[0](x).flatten(start_dim=1)
        z = self.backbone[1](z)
        z = self.head(z)
        return z

# %%
# load model
backbone = nn.Sequential(model.backbone, model.projection_head)
classification_head = nn.Sequential(
    nn.Linear(128, 512), # num_ftrs_dict["resnet34"]
    nn.ReLU(),
    nn.BatchNorm1d(512),
    nn.Linear(512, num_classes),)

model =  FinetuneClassifier(backbone, classification_head) # num_ftrs_dict["resnet34"]
# model.load_state_dict(torch.load(model_path_pretrained))
summary(model, input_size=(2, 1, 224, 224), device="cuda")
# Out:
# ====================================================================================================
# Layer (type:depth-idx)                             Output Shape              Param #
# ====================================================================================================
# FinetuneClassifier                                 [2, 3]                    --
# ├─Sequential: 1-1                                  --                        --
# │    └─Sequential: 2-1                             [2, 2048, 1, 1]           --
# │    │    └─Conv2d: 3-1                            [2, 64, 112, 112]         3,136
# │    │    └─BatchNorm2d: 3-2                       [2, 64, 112, 112]         128
# │    │    └─ReLU: 3-3                              [2, 64, 112, 112]         --
# │    │    └─MaxPool2d: 3-4                         [2, 64, 56, 56]           --
# │    │    └─Sequential: 3-5                        [2, 256, 56, 56]          215,808
# │    │    └─Sequential: 3-6                        [2, 512, 28, 28]          1,219,584
# │    │    └─Sequential: 3-7                        [2, 1024, 14, 14]         7,098,368
# │    │    └─Sequential: 3-8                        [2, 2048, 7, 7]           14,964,736
# │    │    └─AdaptiveAvgPool2d: 3-9                 [2, 2048, 1, 1]           --
# │    └─SimSiamProjectionHead: 2-2                  [2, 128]                  --
# │    │    └─Sequential: 3-10                       [2, 128]                  1,378,304
# ├─Sequential: 1-2                                  [2, 3]                    --
# │    └─Linear: 2-3                                 [2, 512]                  66,048
# │    └─ReLU: 2-4                                   [2, 512]                  --
# │    └─BatchNorm1d: 2-5                            [2, 512]                  1,024
# │    └─Linear: 2-6                                 [2, 3]                    1,539
# ====================================================================================================
# Total params: 24,948,675
# Trainable params: 24,948,675
# Non-trainable params: 0
# Total mult-adds (G): 8.02
# ====================================================================================================
# Input size (MB): 0.40
# Forward/backward pass size (MB): 355.70
# Params size (MB): 99.79
# Estimated Total Size (MB): 455.89
# ====================================================================================================

# %%
import math
learning_rate = 3e-4 # 3e-4
weight_decay =  0.01

finetune_optimizer = optim.AdamW(
    model.parameters(),
    lr=learning_rate,
    weight_decay=weight_decay,
)



#optimizer
optimizer_finetune = optim.AdamW(model.parameters(), lr=learning_rate) #  weight_decay = 1e-4
warmup_epochs = 3
num_train_steps = math.ceil(len(train_loader))
num_warmup_steps= num_train_steps * warmup_epochs
num_training_steps=int(num_train_steps * finetune_epochs)

#learning rate scheduler
cosine_scheduler = get_cosine_schedule_with_warmup(optimizer_finetune,num_warmup_steps = num_warmup_steps,num_training_steps =num_training_steps)

# %%
finetune_criterion = nn.CrossEntropyLoss()

# %%
def finetune(
    epochs: int,
    model: nn.Module,
    device: Union[int, str],
    train_loader: Any,
    criterion: nn.Module,
    optimizer: nn.Module,
    saved_model_path: str,
    valid_loader: Any,
):
    best_loss = float("inf")
    best_accuracy = float("-inf")
    all_val_loss = []
    all_val_accuracy = []

    # Training loop
    for epoch in range(epochs):
        epoch_loss = 0.0
        model.train()

        for batch_idx, batch in enumerate(train_loader): # for batch_idx, batch in enumerate(train_loader):
            img1 = batch[0].to(device)
            label = batch[-1].to(device)
            optimizer.zero_grad()
            output = model(img1)

            loss = criterion(output, label)
            loss.backward()
            optimizer.step()
            # cosine_scheduler.step()
            epoch_loss += loss
             

            if batch_idx % 100 == 0:
                logging.debug(
                    f"Epoch [{epoch}/{epochs}], Batch [{batch_idx}/{len(train_loader)}], Loss: {loss.item()}"
                )

        epoch_loss = epoch_loss / len(train_loader)

        with torch.no_grad():
            logging.debug("====== Eval started ======")
            model.eval()
            epoch_val_accuracy = 0
            epoch_val_loss = 0
            for batch_idx, batch in enumerate(valid_loader): # for batch_idx, batch in enumerate(train_loader):
                data = batch[0].to(device)
                label = batch[-1].to(device)

                val_output = model(data)
                val_loss = criterion(val_output, label)

                acc = (val_output.argmax(dim=1) == label).float().mean()
                epoch_val_accuracy += acc
                epoch_val_loss += val_loss
                 

            epoch_val_accuracy = epoch_val_accuracy / len(valid_loader)
            
            if epoch_val_accuracy > best_accuracy:
                best_accuracy = epoch_val_accuracy
                torch.save(model.state_dict(), saved_model_path)
                logging.debug("====== Model saved ======")
            
            epoch_val_loss = epoch_val_loss / len(valid_loader)
            all_val_loss.append(epoch_val_loss)

        all_val_accuracy.append(epoch_val_accuracy.item() * 100)

        logging.debug(
            f"Epoch : {epoch+1} - loss : {epoch_loss:.4f} - val_loss : {epoch_val_loss:.4f} - val_acc: {epoch_val_accuracy:.4f} \n"
        )

# %%
# Training loop
finetune(
    finetune_epochs,
    model,
    device,
    train_loader,
    finetune_criterion,
    finetune_optimizer,
    finetuned_model_path,
    valid_loader=val_loader,
)
# Out:
# DEBUG:root:Epoch [0/20], Batch [0/513], Loss: 1.2652822732925415
# DEBUG:root:Epoch [0/20], Batch [100/513], Loss: 1.091691255569458
# DEBUG:root:Epoch [0/20], Batch [200/513], Loss: 1.102490782737732
# DEBUG:root:Epoch [0/20], Batch [300/513], Loss: 1.102827548980713
# DEBUG:root:Epoch [0/20], Batch [400/513], Loss: 1.0944465398788452
# DEBUG:root:Epoch [0/20], Batch [500/513], Loss: 1.109131097793579
# DEBUG:root:====== Eval started ======
# DEBUG:root:====== Model saved ======
# DEBUG:root:Epoch : 1 - loss : 1.1095 - val_loss : 1.1043 - val_acc: 0.3308
#
# DEBUG:root:Epoch [1/20], Batch [0/513], Loss: 1.0884543657302856
# DEBUG:root:Epoch [1/20], Batch [100/513], Loss: 1.1059849262237549
# DEBUG:root:Epoch [1/20], Batch [200/513], Loss: 1.1046380996704102
# DEBUG:root:Epoch [1/20], Batch [300/513], Loss: 1.0900661945343018
# DEBUG:root:Epoch [1/20], Batch [400/513], Loss: 1.118185043334961
# DEBUG:root:Epoch [1/20], Batch [500/513], Loss: 1.1024340391159058
# DEBUG:root:====== Eval started ======
# DEBUG:root:====== Model saved ======
# DEBUG:root:Epoch : 2 - loss : 1.1049 - val_loss : 1.1232 - val_acc: 0.3393
#
# DEBUG:root:Epoch [2/20], Batch [0/513], Loss: 1.1012845039367676
# DEBUG:root:Epoch [2/20], Batch [100/513], Loss: 1.0941914319992065
# DEBUG:root:Epoch [2/20], Batch [200/513], Loss: 1.106460690498352
# DEBUG:root:Epoch [2/20], Batch [300/513], Loss: 1.0899221897125244
# DEBUG:root:Epoch [2/20], Batch [400/513], Loss: 1.1032485961914062
# DEBUG:root:Epoch [2/20], Batch [500/513], Loss: 1.1138646602630615
# DEBUG:root:====== Eval started ======
# DEBUG:root:====== Model saved ======
# DEBUG:root:Epoch : 3 - loss : 1.1032 - val_loss : 1.0999 - val_acc: 0.3414
#
# DEBUG:root:Epoch [3/20], Batch [0/513], Loss: 1.0998448133468628
# DEBUG:root:Epoch [3/20], Batch [100/513], Loss: 1.0811396837234497
# DEBUG:root:Epoch [3/20], Batch [200/513], Loss: 1.102193832397461
# DEBUG:root:Epoch [3/20], Batch [300/513], Loss: 1.1001949310302734
# DEBUG:root:Epoch [3/20], Batch [400/513], Loss: 1.099029541015625
# DEBUG:root:Epoch [3/20], Batch [500/513], Loss: 1.1034057140350342
# DEBUG:root:====== Eval started ======
# DEBUG:root:====== Model saved ======
# DEBUG:root:Epoch : 4 - loss : 1.1024 - val_loss : 1.0990 - val_acc: 0.3423
#
# DEBUG:root:Epoch [4/20], Batch [0/513], Loss: 1.0932034254074097
# DEBUG:root:Epoch [4/20], Batch [100/513], Loss: 1.1227134466171265
# DEBUG:root:Epoch [4/20], Batch [200/513], Loss: 1.1005609035491943
# DEBUG:root:Epoch [4/20], Batch [300/513], Loss: 1.1009483337402344
# DEBUG:root:Epoch [4/20], Batch [400/513], Loss: 1.112043857574463
# DEBUG:root:Epoch [4/20], Batch [500/513], Loss: 1.1087522506713867
# DEBUG:root:====== Eval started ======
# DEBUG:root:Epoch : 5 - loss : 1.1030 - val_loss : 1.1013 - val_acc: 0.3315
#
# DEBUG:root:Epoch [5/20], Batch [0/513], Loss: 1.11235511302948
# DEBUG:root:Epoch [5/20], Batch [100/513], Loss: 1.1128685474395752
# DEBUG:root:Epoch [5/20], Batch [200/513], Loss: 1.0806583166122437
# DEBUG:root:Epoch [5/20], Batch [300/513], Loss: 1.0443146228790283
# DEBUG:root:Epoch [5/20], Batch [400/513], Loss: 1.0284302234649658
# DEBUG:root:Epoch [5/20], Batch [500/513], Loss: 1.023673176765442
# DEBUG:root:====== Eval started ======
# DEBUG:root:====== Model saved ======
# DEBUG:root:Epoch : 6 - loss : 1.0686 - val_loss : 1.0680 - val_acc: 0.4271
#
# DEBUG:root:Epoch [6/20], Batch [0/513], Loss: 1.0255813598632812
# DEBUG:root:Epoch [6/20], Batch [100/513], Loss: 1.0046210289001465
# DEBUG:root:Epoch [6/20], Batch [200/513], Loss: 0.94761723279953
# DEBUG:root:Epoch [6/20], Batch [300/513], Loss: 1.043684959411621
# DEBUG:root:Epoch [6/20], Batch [400/513], Loss: 0.9031084179878235
# DEBUG:root:Epoch [6/20], Batch [500/513], Loss: 0.9081203937530518
# DEBUG:root:====== Eval started ======
# DEBUG:root:Epoch : 7 - loss : 0.9470 - val_loss : 1.1066 - val_acc: 0.4176
#
# DEBUG:root:Epoch [7/20], Batch [0/513], Loss: 0.9389652013778687
# DEBUG:root:Epoch [7/20], Batch [100/513], Loss: 0.9628579616546631
# DEBUG:root:Epoch [7/20], Batch [200/513], Loss: 0.8993628621101379
# DEBUG:root:Epoch [7/20], Batch [300/513], Loss: 0.8776981830596924
# DEBUG:root:Epoch [7/20], Batch [400/513], Loss: 0.8732204437255859
# DEBUG:root:Epoch [7/20], Batch [500/513], Loss: 0.9269618391990662
# DEBUG:root:====== Eval started ======
# DEBUG:root:====== Model saved ======
# DEBUG:root:Epoch : 8 - loss : 0.9072 - val_loss : 0.9768 - val_acc: 0.4742
#
# DEBUG:root:Epoch [8/20], Batch [0/513], Loss: 0.8883129954338074
# DEBUG:root:Epoch [8/20], Batch [100/513], Loss: 0.9749394655227661
# DEBUG:root:Epoch [8/20], Batch [200/513], Loss: 0.9547126293182373
# DEBUG:root:Epoch [8/20], Batch [300/513], Loss: 0.9236966967582703
# DEBUG:root:Epoch [8/20], Batch [400/513], Loss: 0.8635168075561523
# DEBUG:root:Epoch [8/20], Batch [500/513], Loss: 0.8964594602584839
# DEBUG:root:====== Eval started ======
# DEBUG:root:====== Model saved ======
# DEBUG:root:Epoch : 9 - loss : 0.8918 - val_loss : 0.9067 - val_acc: 0.5264
#
# DEBUG:root:Epoch [9/20], Batch [0/513], Loss: 0.8204428553581238
# DEBUG:root:Epoch [9/20], Batch [100/513], Loss: 0.8753019571304321
# DEBUG:root:Epoch [9/20], Batch [200/513], Loss: 0.920640766620636
# DEBUG:root:Epoch [9/20], Batch [300/513], Loss: 0.9238593578338623
# DEBUG:root:Epoch [9/20], Batch [400/513], Loss: 0.8601259589195251
# DEBUG:root:Epoch [9/20], Batch [500/513], Loss: 0.8779632449150085
# DEBUG:root:====== Eval started ======
# DEBUG:root:Epoch : 10 - loss : 0.8772 - val_loss : 0.9433 - val_acc: 0.5006
#
# DEBUG:root:Epoch [10/20], Batch [0/513], Loss: 0.8405032157897949
# DEBUG:root:Epoch [10/20], Batch [100/513], Loss: 0.8608691692352295
# DEBUG:root:Epoch [10/20], Batch [200/513], Loss: 0.8488718271255493
# DEBUG:root:Epoch [10/20], Batch [300/513], Loss: 0.9213717579841614
# DEBUG:root:Epoch [10/20], Batch [400/513], Loss: 0.9181453585624695
# DEBUG:root:Epoch [10/20], Batch [500/513], Loss: 0.8482373952865601
# DEBUG:root:====== Eval started ======
# DEBUG:root:====== Model saved ======
# DEBUG:root:Epoch : 11 - loss : 0.8668 - val_loss : 0.8559 - val_acc: 0.5589
#
# DEBUG:root:Epoch [11/20], Batch [0/513], Loss: 0.7660650014877319
# DEBUG:root:Epoch [11/20], Batch [100/513], Loss: 0.8510064482688904
# DEBUG:root:Epoch [11/20], Batch [200/513], Loss: 0.8631834983825684
# DEBUG:root:Epoch [11/20], Batch [300/513], Loss: 0.9389880895614624
# DEBUG:root:Epoch [11/20], Batch [400/513], Loss: 0.8411129117012024
# DEBUG:root:Epoch [11/20], Batch [500/513], Loss: 0.8444503545761108
# DEBUG:root:====== Eval started ======
# DEBUG:root:Epoch : 12 - loss : 0.8600 - val_loss : 0.9760 - val_acc: 0.4873
#
# DEBUG:root:Epoch [12/20], Batch [0/513], Loss: 0.7695895433425903
# DEBUG:root:Epoch [12/20], Batch [100/513], Loss: 0.8946927785873413
# DEBUG:root:Epoch [12/20], Batch [200/513], Loss: 0.7928830981254578
# DEBUG:root:Epoch [12/20], Batch [300/513], Loss: 0.9014607667922974
# DEBUG:root:Epoch [12/20], Batch [400/513], Loss: 0.8374428153038025
# DEBUG:root:Epoch [12/20], Batch [500/513], Loss: 0.8507605791091919
# DEBUG:root:====== Eval started ======
# DEBUG:root:Epoch : 13 - loss : 0.8516 - val_loss : 1.2675 - val_acc: 0.4391
#
# DEBUG:root:Epoch [13/20], Batch [0/513], Loss: 0.8167485594749451
# DEBUG:root:Epoch [13/20], Batch [100/513], Loss: 0.7878783941268921
# DEBUG:root:Epoch [13/20], Batch [200/513], Loss: 0.7825192809104919
# DEBUG:root:Epoch [13/20], Batch [300/513], Loss: 0.8859061002731323
# DEBUG:root:Epoch [13/20], Batch [400/513], Loss: 0.8215710520744324
# DEBUG:root:Epoch [13/20], Batch [500/513], Loss: 0.8313924074172974
# DEBUG:root:====== Eval started ======
# DEBUG:root:====== Model saved ======
# DEBUG:root:Epoch : 14 - loss : 0.8402 - val_loss : 0.8681 - val_acc: 0.5628
#
# DEBUG:root:Epoch [14/20], Batch [0/513], Loss: 0.7316004037857056
# DEBUG:root:Epoch [14/20], Batch [100/513], Loss: 0.8030070066452026
# DEBUG:root:Epoch [14/20], Batch [200/513], Loss: 0.844195544719696
# DEBUG:root:Epoch [14/20], Batch [300/513], Loss: 0.8718374371528625
# DEBUG:root:Epoch [14/20], Batch [400/513], Loss: 0.8839315176010132
# DEBUG:root:Epoch [14/20], Batch [500/513], Loss: 0.7844445705413818
# DEBUG:root:====== Eval started ======
# DEBUG:root:====== Model saved ======
# DEBUG:root:Epoch : 15 - loss : 0.8333 - val_loss : 0.8454 - val_acc: 0.5739
#
# DEBUG:root:Epoch [15/20], Batch [0/513], Loss: 0.8340919017791748
# DEBUG:root:Epoch [15/20], Batch [100/513], Loss: 0.7783933877944946
# DEBUG:root:Epoch [15/20], Batch [200/513], Loss: 0.7750022411346436
# DEBUG:root:Epoch [15/20], Batch [300/513], Loss: 0.7810672521591187
# DEBUG:root:Epoch [15/20], Batch [400/513], Loss: 0.74769127368927
# DEBUG:root:Epoch [15/20], Batch [500/513], Loss: 0.7189750671386719
# DEBUG:root:====== Eval started ======
# DEBUG:root:====== Model saved ======
# DEBUG:root:Epoch : 16 - loss : 0.8086 - val_loss : 0.8687 - val_acc: 0.5880
#
# DEBUG:root:Epoch [16/20], Batch [0/513], Loss: 0.8319398164749146
# DEBUG:root:Epoch [16/20], Batch [100/513], Loss: 0.7005128860473633
# DEBUG:root:Epoch [16/20], Batch [200/513], Loss: 0.6817854046821594
# DEBUG:root:Epoch [16/20], Batch [300/513], Loss: 0.5917661786079407
# DEBUG:root:Epoch [16/20], Batch [400/513], Loss: 0.5968292355537415
# DEBUG:root:Epoch [16/20], Batch [500/513], Loss: 0.6777182221412659
# DEBUG:root:====== Eval started ======
# DEBUG:root:====== Model saved ======
# DEBUG:root:Epoch : 17 - loss : 0.6918 - val_loss : 0.6465 - val_acc: 0.7115
#
# DEBUG:root:Epoch [17/20], Batch [0/513], Loss: 0.6485003232955933
# DEBUG:root:Epoch [17/20], Batch [100/513], Loss: 0.5587235689163208
# DEBUG:root:Epoch [17/20], Batch [200/513], Loss: 0.5824211239814758
# DEBUG:root:Epoch [17/20], Batch [300/513], Loss: 0.6154521107673645
# DEBUG:root:Epoch [17/20], Batch [400/513], Loss: 0.6708598732948303
# DEBUG:root:Epoch [17/20], Batch [500/513], Loss: 0.6864644289016724
# DEBUG:root:====== Eval started ======
# DEBUG:root:====== Model saved ======
# DEBUG:root:Epoch : 18 - loss : 0.6300 - val_loss : 0.6195 - val_acc: 0.7298
#
# DEBUG:root:Epoch [18/20], Batch [0/513], Loss: 0.6860606670379639
# DEBUG:root:Epoch [18/20], Batch [100/513], Loss: 0.5944998264312744
# DEBUG:root:Epoch [18/20], Batch [200/513], Loss: 0.6343481540679932
# DEBUG:root:Epoch [18/20], Batch [300/513], Loss: 0.52580726146698
# DEBUG:root:Epoch [18/20], Batch [400/513], Loss: 0.4948035478591919
# DEBUG:root:Epoch [18/20], Batch [500/513], Loss: 0.6624441146850586
# DEBUG:root:====== Eval started ======
# DEBUG:root:Epoch : 19 - loss : 0.5971 - val_loss : 0.6428 - val_acc: 0.7199
#
# DEBUG:root:Epoch [19/20], Batch [0/513], Loss: 0.5469056367874146
# DEBUG:root:Epoch [19/20], Batch [100/513], Loss: 0.47835227847099304
# DEBUG:root:Epoch [19/20], Batch [200/513], Loss: 0.5639799237251282
# DEBUG:root:Epoch [19/20], Batch [300/513], Loss: 0.5200543403625488
# DEBUG:root:Epoch [19/20], Batch [400/513], Loss: 0.6429915428161621
# DEBUG:root:Epoch [19/20], Batch [500/513], Loss: 0.55122971534729
# DEBUG:root:====== Eval started ======
# DEBUG:root:====== Model saved ======
# DEBUG:root:Epoch : 20 - loss : 0.5750 - val_loss : 0.5888 - val_acc: 0.7447

# %%
test_dataset_dir = dataset_dir
test_dataset = DeepLenseDatasetSSL(destination_dir = test_dataset_dir, transforms = train_transforms, mode="test", dataset_name=dataset_name, download=True, channels=1)
test_loader = DataLoader(
    dataset=test_dataset,
    batch_size=batch_size,
    shuffle=True,
    num_workers=num_workers,
)
# Out:
# Model_I dataset already exists

# %%
channels = 1
infer_obj = InferenceSSL(
    model,
    test_loader,
    device,
    num_classes,
    test_dataset,
    dataset_name,
    labels_map=classes, # classes
    image_size=image_size,
    channels=channels,
    destination_dir="data",
    log_dir=log_dir,  # log_dir
)

infer_obj.infer_plot_roc()
infer_obj.generate_plot_confusion_matrix()
# Out:
# Inference started ...
# DEBUG:matplotlib.colorbar:locator: <matplotlib.ticker.AutoLocator object at 0x7f3a7c24c910>
# Confusion matrix, without normalization

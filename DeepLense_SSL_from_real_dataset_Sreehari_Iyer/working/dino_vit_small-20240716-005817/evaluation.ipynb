# %% [markdown]
# ## DINO with ViT-S architecture with patch size=16

# %%
import sys
sys.path.append("../../../ssl")

# %%
import numpy as np
import os
import torch
import torch.nn as nn
import torchvision.transforms as Transforms
import copy
import pickle
from augmentations.loader import get_dataloaders
from utils.eval import plot_cm_roc
from utils.eval import train
from utils.eval import test_
from models.classifier import Classifier
from utils import plot_history
from utils import set_seed
set_seed(12)

# %%
ckpt_path = "./dino_vit_small_models/checkpoint.pth"
state = torch.load(ckpt_path, mmap="cpu")

# %% [markdown]
# ### Plot for train loss vs epochs

# %%
plot_history(ckpt_path, "./train_history.png")

# %% [markdown]
# ### Train model over the train dataset

# %%
eval_transforms = Transforms.Compose([
                        # Transforms.ToTensor(), # npy loader returns torch.Tensor
                        Transforms.CenterCrop(64),
                        Transforms.Normalize(mean = [0.06814773380756378, 0.21582692861557007, 0.4182431399822235],\
                                                std = [0.16798585653305054, 0.5532506108283997, 1.1966736316680908]),
                    ])
dataloader, train_loader, val_loader, test_loader \
        = get_dataloaders(data_path="../../../input/real_lenses_dataset/", \
                          train_test_indices="../../../input/indices.pkl", \
                          state=state, eval_transforms=eval_transforms)

# %% [markdown]
# ### Finetune the pretrained model

# %%
set_seed(12)

student_network = torch.load("./representation_network.pth")
lp_network = Classifier(mode = "finetune", backbone = copy.deepcopy(student_network))
optimizer = torch.optim.Adam(lp_network.parameters(), lr=1e-4, weight_decay=1e-8)
num_epochs = 100
scheduler = torch.optim.lr_scheduler.CosineAnnealingWarmRestarts(optimizer, T_0=10, eta_min=1e-10)
# scheduler = None

# %%
set_seed(12)

lp_network, lp_network_best_loss = train(lp_network, train_loader, val_loader, nn.CrossEntropyLoss(), optimizer, num_epochs=num_epochs, scheduler=scheduler)
# Out:
# [1/100] Train Loss: 0.6094, Val Loss: 0.4169, Val Accuracy: 81.15%
#
# [2/100] Train Loss: 0.3285, Val Loss: 0.3624, Val Accuracy: 83.73%
#
# [3/100] Train Loss: 0.2798, Val Loss: 0.2730, Val Accuracy: 86.71%
#
# [4/100] Train Loss: 0.2710, Val Loss: 0.3888, Val Accuracy: 85.32%
#
# [5/100] Train Loss: 0.2646, Val Loss: 0.2920, Val Accuracy: 85.71%
#
# [6/100] Train Loss: 0.2207, Val Loss: 0.2605, Val Accuracy: 87.70%
#
# [7/100] Train Loss: 0.2079, Val Loss: 0.2424, Val Accuracy: 89.68%
#
# [8/100] Train Loss: 0.1908, Val Loss: 0.2504, Val Accuracy: 88.49%
#
# [9/100] Train Loss: 0.1697, Val Loss: 0.2473, Val Accuracy: 89.09%
#
# [10/100] Train Loss: 0.1580, Val Loss: 0.2369, Val Accuracy: 89.68%
#
# [11/100] Train Loss: 0.2200, Val Loss: 0.3104, Val Accuracy: 87.90%
#
# [12/100] Train Loss: 0.2107, Val Loss: 0.2434, Val Accuracy: 90.67%
#
# [13/100] Train Loss: 0.2299, Val Loss: 0.3160, Val Accuracy: 85.71%
#
# [14/100] Train Loss: 0.2387, Val Loss: 0.2394, Val Accuracy: 90.48%
#
# [15/100] Train Loss: 0.1984, Val Loss: 0.2655, Val Accuracy: 88.69%
#
# [16/100] Train Loss: 0.1531, Val Loss: 0.2225, Val Accuracy: 91.07%
#
# [17/100] Train Loss: 0.1359, Val Loss: 0.2440, Val Accuracy: 90.28%
#
# [18/100] Train Loss: 0.1163, Val Loss: 0.2238, Val Accuracy: 90.28%
#
# [19/100] Train Loss: 0.1044, Val Loss: 0.2248, Val Accuracy: 90.67%
#
# [20/100] Train Loss: 0.0922, Val Loss: 0.2276, Val Accuracy: 90.08%
#
# [21/100] Train Loss: 0.1444, Val Loss: 0.2324, Val Accuracy: 88.49%
#
# [22/100] Train Loss: 0.1662, Val Loss: 0.2170, Val Accuracy: 89.09%
#
# [23/100] Train Loss: 0.1230, Val Loss: 0.2935, Val Accuracy: 89.68%
#
# [24/100] Train Loss: 0.1000, Val Loss: 0.2615, Val Accuracy: 90.08%
#
# [25/100] Train Loss: 0.1095, Val Loss: 0.2708, Val Accuracy: 89.29%
#
# [26/100] Train Loss: 0.0755, Val Loss: 0.2304, Val Accuracy: 90.67%
#
# [27/100] Train Loss: 0.0568, Val Loss: 0.2431, Val Accuracy: 89.88%
#
# [28/100] Train Loss: 0.0480, Val Loss: 0.2735, Val Accuracy: 91.07%
#
# [29/100] Train Loss: 0.0310, Val Loss: 0.2683, Val Accuracy: 90.08%
#
# [30/100] Train Loss: 0.0314, Val Loss: 0.2718, Val Accuracy: 90.08%
#
# [31/100] Train Loss: 0.1129, Val Loss: 0.2322, Val Accuracy: 89.88%
#
# [32/100] Train Loss: 0.1132, Val Loss: 0.3232, Val Accuracy: 89.29%
#
# [33/100] Train Loss: 0.0832, Val Loss: 0.2889, Val Accuracy: 89.88%
#
# [34/100] Train Loss: 0.0960, Val Loss: 0.2608, Val Accuracy: 90.87%
#
# [35/100] Train Loss: 0.0521, Val Loss: 0.2892, Val Accuracy: 90.87%
#
# [36/100] Train Loss: 0.0398, Val Loss: 0.5243, Val Accuracy: 89.48%
#
# [37/100] Train Loss: 0.0450, Val Loss: 0.2741, Val Accuracy: 89.29%
#
# [38/100] Train Loss: 0.0245, Val Loss: 0.2803, Val Accuracy: 90.08%
#
# [39/100] Train Loss: 0.0142, Val Loss: 0.3113, Val Accuracy: 90.28%
#
# [40/100] Train Loss: 0.0135, Val Loss: 0.2978, Val Accuracy: 90.08%
#
# [41/100] Train Loss: 0.1332, Val Loss: 0.2314, Val Accuracy: 90.08%
#
# [42/100] Train Loss: 0.0827, Val Loss: 0.3918, Val Accuracy: 88.10%
#
# [43/100] Train Loss: 0.0760, Val Loss: 0.2018, Val Accuracy: 91.47%
#
# [44/100] Train Loss: 0.0382, Val Loss: 0.4148, Val Accuracy: 90.08%
#
# [45/100] Train Loss: 0.0422, Val Loss: 0.2783, Val Accuracy: 91.47%
#
# [46/100] Train Loss: 0.0310, Val Loss: 0.3338, Val Accuracy: 90.48%
#
# [47/100] Train Loss: 0.0190, Val Loss: 0.3729, Val Accuracy: 91.47%
#
# [48/100] Train Loss: 0.0126, Val Loss: 0.3625, Val Accuracy: 91.27%
#
# [49/100] Train Loss: 0.0098, Val Loss: 0.3536, Val Accuracy: 91.27%
#
# [50/100] Train Loss: 0.0065, Val Loss: 0.3669, Val Accuracy: 91.07%
#
# [51/100] Train Loss: 0.0487, Val Loss: 0.2929, Val Accuracy: 90.28%
#
# [52/100] Train Loss: 0.0996, Val Loss: 0.2461, Val Accuracy: 90.48%
#
# [53/100] Train Loss: 0.0729, Val Loss: 0.4096, Val Accuracy: 91.07%
#
# [54/100] Train Loss: 0.0500, Val Loss: 0.3112, Val Accuracy: 89.29%
#
# [55/100] Train Loss: 0.0406, Val Loss: 0.2890, Val Accuracy: 90.28%
#
# [56/100] Train Loss: 0.0227, Val Loss: 0.3657, Val Accuracy: 91.47%
#
# [57/100] Train Loss: 0.0200, Val Loss: 0.2986, Val Accuracy: 91.27%
#
# [58/100] Train Loss: 0.0076, Val Loss: 0.3023, Val Accuracy: 91.47%
#
# [59/100] Train Loss: 0.0055, Val Loss: 0.3064, Val Accuracy: 91.87%
#
# [60/100] Train Loss: 0.0055, Val Loss: 0.3088, Val Accuracy: 91.47%
#
# [61/100] Train Loss: 0.0541, Val Loss: 0.2878, Val Accuracy: 89.48%
#
# [62/100] Train Loss: 0.0556, Val Loss: 0.2548, Val Accuracy: 90.87%
#
# [63/100] Train Loss: 0.0589, Val Loss: 0.2644, Val Accuracy: 91.07%
#
# [64/100] Train Loss: 0.0425, Val Loss: 0.3376, Val Accuracy: 90.08%
#
# [65/100] Train Loss: 0.0306, Val Loss: 0.3720, Val Accuracy: 91.07%
#
# [66/100] Train Loss: 0.0121, Val Loss: 0.3364, Val Accuracy: 92.46%
#
# [67/100] Train Loss: 0.0059, Val Loss: 0.3513, Val Accuracy: 92.06%
#
# [68/100] Train Loss: 0.0044, Val Loss: 0.3679, Val Accuracy: 91.87%
#
# [69/100] Train Loss: 0.0030, Val Loss: 0.3799, Val Accuracy: 91.47%
#
# [70/100] Train Loss: 0.0025, Val Loss: 0.3728, Val Accuracy: 92.26%
#
# [71/100] Train Loss: 0.1006, Val Loss: 0.2296, Val Accuracy: 90.28%
#
# [72/100] Train Loss: 0.0711, Val Loss: 0.3364, Val Accuracy: 90.67%
#
# [73/100] Train Loss: 0.0376, Val Loss: 0.3534, Val Accuracy: 91.87%
#
# [74/100] Train Loss: 0.0517, Val Loss: 0.2539, Val Accuracy: 91.47%
#
# [75/100] Train Loss: 0.0192, Val Loss: 0.3259, Val Accuracy: 90.67%
#
# [76/100] Train Loss: 0.0193, Val Loss: 0.3166, Val Accuracy: 91.87%
#
# [77/100] Train Loss: 0.0100, Val Loss: 0.2893, Val Accuracy: 92.06%
#
# [78/100] Train Loss: 0.0058, Val Loss: 0.3143, Val Accuracy: 92.66%
#
# [79/100] Train Loss: 0.0052, Val Loss: 0.3173, Val Accuracy: 92.86%
#
# [80/100] Train Loss: 0.0020, Val Loss: 0.3201, Val Accuracy: 93.06%
#
# [81/100] Train Loss: 0.0127, Val Loss: 0.3953, Val Accuracy: 92.26%
#
# [82/100] Train Loss: 0.0905, Val Loss: 0.3330, Val Accuracy: 90.08%
#
# [83/100] Train Loss: 0.0440, Val Loss: 0.3330, Val Accuracy: 90.48%
#
# [84/100] Train Loss: 0.0332, Val Loss: 0.3127, Val Accuracy: 91.47%
#
# [85/100] Train Loss: 0.0153, Val Loss: 0.3479, Val Accuracy: 92.66%
#
# [86/100] Train Loss: 0.0113, Val Loss: 0.4097, Val Accuracy: 92.26%
#
# [87/100] Train Loss: 0.0100, Val Loss: 0.3526, Val Accuracy: 91.27%
#
# [88/100] Train Loss: 0.0057, Val Loss: 0.3565, Val Accuracy: 91.27%
#
# [89/100] Train Loss: 0.0032, Val Loss: 0.3645, Val Accuracy: 91.87%
#
# [90/100] Train Loss: 0.0027, Val Loss: 0.3612, Val Accuracy: 91.67%
#
# [91/100] Train Loss: 0.0437, Val Loss: 0.3778, Val Accuracy: 88.69%
#
# [92/100] Train Loss: 0.0630, Val Loss: 0.3276, Val Accuracy: 92.26%
#
# [93/100] Train Loss: 0.0387, Val Loss: 0.3555, Val Accuracy: 90.28%
#
# [94/100] Train Loss: 0.0268, Val Loss: 0.3482, Val Accuracy: 90.28%
#
# [95/100] Train Loss: 0.0138, Val Loss: 0.4170, Val Accuracy: 91.67%
#
# [96/100] Train Loss: 0.0160, Val Loss: 0.3816, Val Accuracy: 90.87%
#
# [97/100] Train Loss: 0.0044, Val Loss: 0.4182, Val Accuracy: 91.47%
#
# [98/100] Train Loss: 0.0030, Val Loss: 0.4253, Val Accuracy: 91.87%
#
# [99/100] Train Loss: 0.0023, Val Loss: 0.4242, Val Accuracy: 91.47%
#
# [100/100] Train Loss: 0.0021, Val Loss: 0.4255, Val Accuracy: 91.47%

# %% [markdown]
# ### Test scores when the model is run on the test dataset

# %%
from utils.eval import test_
output, y_true, acc, auc = test_(lp_network, test_loader, nn.CrossEntropyLoss())
# Out:
# Evaluation on held out test dataset
# Confusion Matrix
# +----------------+------------------+---------------------+
# |                | predicted lenses | predicted nonlenses |
# +----------------+------------------+---------------------+
# |  true lenses   |       268        |          25         |
# | true nonlenses |        11        |         289         |
# +----------------+------------------+---------------------+
# Test Metrics
# +-----------+----------+
# |  accuracy | 93.9292% |
# |    loss   |  0.0000  |
# | auc score |  0.9782  |
# +-----------+----------+
# +----------------+-----------+--------+---------+---------+
# |                | precision | recall | f-score | support |
# +----------------+-----------+--------+---------+---------+
# |     lenses     |   0.9606  | 0.9147 |  0.9371 |   293   |
# |   nonlenses    |   0.9204  | 0.9633 |  0.9414 |   300   |
# | macro averaged |   0.9405  | 0.9390 |  0.9392 |         |
# +----------------+-----------+--------+---------+---------+

# %%
plot_cm_roc(output, y_true)

# %% [markdown]
# ### Test scores when the model is run on the entire dataset

# %%
output, y_true, acc, auc = test_(lp_network, dataloader, nn.CrossEntropyLoss())
# Out:
# Evaluation on held out test dataset
# Confusion Matrix
# +----------------+------------------+---------------------+
# |                | predicted lenses | predicted nonlenses |
# +----------------+------------------+---------------------+
# |  true lenses   |       1899       |          50         |
# | true nonlenses |        31        |         1969        |
# +----------------+------------------+---------------------+
# Test Metrics
# +-----------+----------+
# |  accuracy | 97.9488% |
# |    loss   |  0.0008  |
# | auc score |  0.9960  |
# +-----------+----------+
# +----------------+-----------+--------+---------+---------+
# |                | precision | recall | f-score | support |
# +----------------+-----------+--------+---------+---------+
# |     lenses     |   0.9839  | 0.9743 |  0.9791 |   1949  |
# |   nonlenses    |   0.9752  | 0.9845 |  0.9798 |   2000  |
# | macro averaged |   0.9796  | 0.9794 |  0.9795 |         |
# +----------------+-----------+--------+---------+---------+

# %%
with open("./classifier_network.pth", "wb") as f:
    pickle.dump(lp_network, f)

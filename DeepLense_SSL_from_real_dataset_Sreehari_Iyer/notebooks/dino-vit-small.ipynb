# %% [markdown]
# ## Dino Pretrained ViT Small Backbone

# %% [markdown]
# ---

# %% [markdown]
# For classifying lenses from non-lenses, self-supervised learning (SSL), particularly with the transformer backbones could potentially outperform traditional supervised methods with abundant unlabelled dataset. The learned representations are then evaluated on the downstream task to classify lens and non-lens images. <br>
# The dataset contains 1949 lens images and 2000 non-lens images. Each image has 3 channels, g, r and i, corresponding to green, red and infrared filters respectively. The images are center cropped to 32 × 32 pixel as this empirically resulted in better prediction accuracy. <br>
# To understand how well SSL works with different fractions of labelled and unlabelled data, the model is pre-trained through self supervision on the entire data and then finetuned on the labelled fraction and compared with supervised baseline trained only on that labeled fraction. <br>
# The following table summarizes the results.

# %% [markdown]
# | # labelled data for <br> training/fine-tuning | Training | Accuracy | AUC |
# |:---:|:----------:|:----------:|:----------:|
# |300|Supervised | 86.0034% | 0.9235 |
# ||DINO | 88.1956% | 0.9382 |
# |600|Supervised | 88.0270% | 0.9210 |
# ||DINO | 89.5447% | 0.9361 |
# |1200|Supervised | 89.5447% | 0.9663 |
# ||DINO | 90.725% | 0.9657 |
# |3256 |Supervised | 93.7605% | 0.9786 |
# ||DINO | 92.4115% | 0.9806 |

# %% [markdown]
# ROC Curves for the SSL and supervised models are plotted below

# %% [markdown]
# ![](../assets/auc_supervised_dino_ssl_vit_small.png)

# %% [markdown]
# ---

# %%
import sys
sys.path.append("/kaggle/input/deeplense-ssl-sreehari-iyer/DeepLense_SSL_Sreehari_Iyer-1")
# !pip install GPUtil
# Out:
# Collecting GPUtil
#   Downloading GPUtil-1.4.0.tar.gz (5.5 kB)
# done
# Building wheels for collected packages: GPUtil
# done
#   Created wheel for GPUtil: filename=GPUtil-1.4.0-py3-none-any.whl size=7394 sha256=7a8cd84ab1c134b7103c8288546f13242af50fff676fc67e800373a100fb1fcd
#   Stored in directory: /root/.cache/pip/wheels/a9/8a/bd/81082387151853ab8b6b3ef33426e98f5cbfebc3c397a9d4d0
# Successfully built GPUtil
# Installing collected packages: GPUtil
# Successfully installed GPUtil-1.4.0

# %%
import numpy as np
import os
import torch
import torch.nn as nn
import torchvision.transforms as Transforms
from torch.utils.data import random_split, DataLoader, Dataset
from sklearn import metrics
import copy
import pickle
from utils import set_seed
from utils.eval import train
from models.backbone import Backbone
from augmentations.loader import npy_loader
from augmentations import ImageDataset
from models.classifier import Classifier
from utils.eval import test_
import matplotlib.pyplot as plt
set_seed(12)

# %%
def get_datasets(num_labelled_points):
    set_seed(12)

    eval_transforms = Transforms.Compose([
                    # Transforms.ToTensor(), # npy loader returns torch.Tensor
                    Transforms.CenterCrop(32),
                    Transforms.Normalize(mean = [0.17172211408615112, 0.5951611399650574, 1.205482840538025],\
                                         std = [0.2224876880645752, 0.8682928085327148, 2.003822088241577]),
                ])

    #--------------------------------------------------------------------------------------------------------

    train_test_indices = "../input/indices.pkl"
    data_path = "../input/real_lenses_dataset"
    
    train_indices_path = None
    indices = None
    with open(train_test_indices, "rb") as f:
        indices = pickle.load(f)
    train_indices = None
    
    if num_labelled_points == 300:
        train_indices_path = "../input/train_indices_300.pkl"
        with open(train_indices_path, "rb") as f:
            train_indices = pickle.load(f)
    elif num_labelled_points == 600:
        train_indices_path = "../input/train_indices_600.pkl"
        with open(train_indices_path, "rb") as f:
            train_indices = pickle.load(f)
    elif num_labelled_points == 1200:
        train_indices_path = "../input/train_indices_1200.pkl"
        with open(train_indices_path, "rb") as f:
            train_indices = pickle.load(f)
    elif num_labelled_points is None:
        train_indices_path = "../input/indices.pkl"
        with open(train_indices_path, "rb") as f:
            train_indices = pickle.load(f)
        train_indices = train_indices["train"]

    # train images and labels
    train_paths = [os.path.join(data_path, *["lenses", img]) for img in np.array(train_indices["lenses"])] +\
                    [os.path.join(data_path, *["nonlenses", img]) for img in np.array(train_indices["nonlenses"])]
    train_labels = [0]*len(train_indices["lenses"]) + [1]*len(train_indices["nonlenses"])

    # validation images and labels
    val_paths = [os.path.join(data_path, *["lenses", img]) for img in np.array(indices["val"]["lenses"])] +\
                    [os.path.join(data_path, *["nonlenses", img]) for img in np.array(indices["val"]["nonlenses"])]
    val_labels = [0]*len(indices["val"]["lenses"]) + [1]*len(indices["val"]["nonlenses"])

    # test images and labels
    test_paths = [os.path.join(data_path, *["lenses", img]) for img in np.array(indices["test"]["lenses"])] +\
                    [os.path.join(data_path, *["nonlenses", img]) for img in np.array(indices["test"]["nonlenses"])]
    test_labels = [0]*len(indices["test"]["lenses"]) + [1]*len(indices["test"]["nonlenses"])

    # sizes of the train, validation and test datasets
    train_size = len(train_paths)
    val_size = len(val_paths)
    test_size = len(test_paths)
    #--------------------------------------------------------------------------------------------------------

    dataset = ImageDataset(
        image_paths=train_paths+val_paths+test_paths,
        labels=train_labels+val_labels+test_labels,
        loader=npy_loader,
        transform=eval_transforms
    )
    train_dataset = ImageDataset(
        image_paths=train_paths,
        labels=train_labels,
        loader=npy_loader,
        transform=eval_transforms
    ) 
    val_dataset = ImageDataset(
        image_paths=val_paths,
        labels=val_labels,
        loader=npy_loader,
        transform=eval_transforms
    )
    test_dataset = ImageDataset(
        image_paths=test_paths,
        labels=test_labels,
        loader=npy_loader,
        transform=eval_transforms
    )
    data_loader = DataLoader(
        dataset,
        batch_size=64,
        num_workers=0,
        shuffle=False,
    )
    train_loader = DataLoader(
        train_dataset,
        batch_size=64,
        num_workers=0,
        shuffle=True,
    )
    val_loader = DataLoader(
        val_dataset,
        batch_size=64,
        num_workers=0,
        shuffle=False,
    )
    test_loader = DataLoader(
        test_dataset,
        batch_size=64,
        num_workers=0,
        shuffle=False,
    )
    return train_loader, val_loader, test_loader

def compute_auc(ft_network, test_loader):
    y = None
    scores = None
    ft_network.eval()
    ft_network = ft_network.cuda()
    for img, label in test_loader:
        img, label = img.cuda(), label.cuda()
        preds = ft_network(img)
        if y is None:
            y = label.detach().cpu().numpy()
        else:
            y = np.concatenate([y, label.detach().cpu().numpy()], axis=0)
        if scores is None:
            scores = preds.detach().cpu().numpy()
        else:
            scores = np.vstack((scores, preds.detach().cpu().numpy()))
    fpr, tpr, _ = metrics.roc_curve(y, scores[:,1])
    auc_score = metrics.auc(fpr, tpr)
    return fpr, tpr, auc_score

# %% [markdown]
# ### ViT Small Classifier trained on 300 labelled datapoints through supervised learning

# %%
set_seed(12)
train_loader, val_loader, test_loader = get_datasets(300)
ft_network = Classifier(mode = "finetune", backbone = Backbone(arch="vit_small", image_size=32, input_channels=3, patch_size=8))
optimizer = torch.optim.Adam(ft_network.parameters(), lr=1e-4, weight_decay=1e-5)
num_epochs = 100
scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, eta_min=1e-8, T_max=num_epochs)
ft_network, ft_network_best_loss = train(ft_network, train_loader, val_loader, nn.CrossEntropyLoss(), optimizer, num_epochs=num_epochs, scheduler=scheduler)

torch.save(ft_network, "../working/supervised_vit_small/supervised_300_ckpt.pth")
fpr_supervised_300, tpr_supervised_300, auc_score_300 = compute_auc(ft_network, test_loader)
# Out:
# [1/100] Train Loss: 4.4512, Val Loss: 3.8465, Val Accuracy: 50.00%
#
# [2/100] Train Loss: 2.1277, Val Loss: 0.8542, Val Accuracy: 60.00%
#
# [3/100] Train Loss: 1.1840, Val Loss: 0.7665, Val Accuracy: 59.00%
#
# [4/100] Train Loss: 0.7126, Val Loss: 1.0131, Val Accuracy: 50.00%
#
# [5/100] Train Loss: 0.7539, Val Loss: 0.5932, Val Accuracy: 60.00%
#
# [6/100] Train Loss: 0.6495, Val Loss: 0.6271, Val Accuracy: 61.00%
#
# [7/100] Train Loss: 0.6295, Val Loss: 0.6134, Val Accuracy: 75.00%
#
# [8/100] Train Loss: 0.6022, Val Loss: 0.6431, Val Accuracy: 71.00%
#
# [9/100] Train Loss: 0.5620, Val Loss: 0.5500, Val Accuracy: 62.00%
#
# [10/100] Train Loss: 0.5550, Val Loss: 0.5503, Val Accuracy: 60.00%
#
# [11/100] Train Loss: 0.5266, Val Loss: 0.5768, Val Accuracy: 75.00%
#
# [12/100] Train Loss: 0.5068, Val Loss: 0.5251, Val Accuracy: 66.00%
#
# [13/100] Train Loss: 0.5039, Val Loss: 0.5094, Val Accuracy: 68.00%
#
# [14/100] Train Loss: 0.4765, Val Loss: 0.5034, Val Accuracy: 79.00%
#
# [15/100] Train Loss: 0.4682, Val Loss: 0.4763, Val Accuracy: 83.00%
#
# [16/100] Train Loss: 0.4478, Val Loss: 0.4418, Val Accuracy: 83.00%
#
# [17/100] Train Loss: 0.4307, Val Loss: 0.4144, Val Accuracy: 84.00%
#
# [18/100] Train Loss: 0.4173, Val Loss: 0.4355, Val Accuracy: 85.00%
#
# [19/100] Train Loss: 0.3958, Val Loss: 0.3910, Val Accuracy: 83.00%
#
# [20/100] Train Loss: 0.3911, Val Loss: 0.3866, Val Accuracy: 83.00%
#
# [21/100] Train Loss: 0.3701, Val Loss: 0.3804, Val Accuracy: 83.00%
#
# [22/100] Train Loss: 0.3822, Val Loss: 0.3628, Val Accuracy: 84.00%
#
# [23/100] Train Loss: 0.3779, Val Loss: 0.3993, Val Accuracy: 84.00%
#
# [24/100] Train Loss: 0.3533, Val Loss: 0.3266, Val Accuracy: 84.00%
#
# [25/100] Train Loss: 0.3497, Val Loss: 0.3663, Val Accuracy: 85.00%
#
# [26/100] Train Loss: 0.3503, Val Loss: 0.3383, Val Accuracy: 84.00%
#
# [27/100] Train Loss: 0.3224, Val Loss: 0.3442, Val Accuracy: 84.00%
#
# [28/100] Train Loss: 0.3195, Val Loss: 0.3045, Val Accuracy: 82.00%
#
# [29/100] Train Loss: 0.3223, Val Loss: 0.3261, Val Accuracy: 86.00%
#
# [30/100] Train Loss: 0.3036, Val Loss: 0.3263, Val Accuracy: 85.00%
#
# [31/100] Train Loss: 0.2797, Val Loss: 0.3053, Val Accuracy: 81.00%
#
# [32/100] Train Loss: 0.2806, Val Loss: 0.3718, Val Accuracy: 88.00%
#
# [33/100] Train Loss: 0.2751, Val Loss: 0.3163, Val Accuracy: 84.00%
#
# [34/100] Train Loss: 0.2639, Val Loss: 0.3531, Val Accuracy: 85.00%
#
# [35/100] Train Loss: 0.2523, Val Loss: 0.3094, Val Accuracy: 87.00%
#
# [36/100] Train Loss: 0.2772, Val Loss: 0.3649, Val Accuracy: 85.00%
#
# [37/100] Train Loss: 0.2766, Val Loss: 0.3480, Val Accuracy: 84.00%
#
# [38/100] Train Loss: 0.2525, Val Loss: 0.3016, Val Accuracy: 86.00%
#
# [39/100] Train Loss: 0.2413, Val Loss: 0.3567, Val Accuracy: 86.00%
#
# [40/100] Train Loss: 0.2217, Val Loss: 0.2992, Val Accuracy: 84.00%
#
# [41/100] Train Loss: 0.2155, Val Loss: 0.3339, Val Accuracy: 85.00%
#
# [42/100] Train Loss: 0.1884, Val Loss: 0.3429, Val Accuracy: 85.00%
#
# [43/100] Train Loss: 0.1933, Val Loss: 0.3679, Val Accuracy: 85.00%
#
# [44/100] Train Loss: 0.2123, Val Loss: 0.3198, Val Accuracy: 85.00%
#
# [45/100] Train Loss: 0.1811, Val Loss: 0.3367, Val Accuracy: 85.00%
#
# [46/100] Train Loss: 0.1746, Val Loss: 0.3280, Val Accuracy: 86.00%
#
# [47/100] Train Loss: 0.1541, Val Loss: 0.3073, Val Accuracy: 89.00%
#
# [48/100] Train Loss: 0.1694, Val Loss: 0.3467, Val Accuracy: 87.00%
#
# [49/100] Train Loss: 0.1443, Val Loss: 0.3818, Val Accuracy: 84.00%
#
# [50/100] Train Loss: 0.1377, Val Loss: 0.3678, Val Accuracy: 87.00%
#
# [51/100] Train Loss: 0.1458, Val Loss: 0.3654, Val Accuracy: 87.00%
#
# [52/100] Train Loss: 0.1592, Val Loss: 0.4752, Val Accuracy: 84.00%
#
# [53/100] Train Loss: 0.1525, Val Loss: 0.4526, Val Accuracy: 85.00%
#
# [54/100] Train Loss: 0.1414, Val Loss: 0.3727, Val Accuracy: 87.00%
#
# [55/100] Train Loss: 0.1687, Val Loss: 0.4036, Val Accuracy: 82.00%
#
# [56/100] Train Loss: 0.1534, Val Loss: 0.4439, Val Accuracy: 84.00%
#
# [57/100] Train Loss: 0.1970, Val Loss: 0.3512, Val Accuracy: 82.00%
#
# [58/100] Train Loss: 0.1382, Val Loss: 0.3325, Val Accuracy: 84.00%
#
# [59/100] Train Loss: 0.1457, Val Loss: 0.3659, Val Accuracy: 86.00%
#
# [60/100] Train Loss: 0.1332, Val Loss: 0.3459, Val Accuracy: 86.00%
#
# [61/100] Train Loss: 0.1443, Val Loss: 0.3462, Val Accuracy: 87.00%
#
# [62/100] Train Loss: 0.1132, Val Loss: 0.3635, Val Accuracy: 86.00%
#
# [63/100] Train Loss: 0.0996, Val Loss: 0.3519, Val Accuracy: 85.00%
#
# [64/100] Train Loss: 0.1259, Val Loss: 0.3685, Val Accuracy: 87.00%
#
# [65/100] Train Loss: 0.1055, Val Loss: 0.3797, Val Accuracy: 86.00%
#
# [66/100] Train Loss: 0.0978, Val Loss: 0.3615, Val Accuracy: 86.00%
#
# [67/100] Train Loss: 0.0888, Val Loss: 0.3882, Val Accuracy: 87.00%
#
# [68/100] Train Loss: 0.1194, Val Loss: 0.3785, Val Accuracy: 89.00%
#
# [69/100] Train Loss: 0.1007, Val Loss: 0.3826, Val Accuracy: 89.00%
#
# [70/100] Train Loss: 0.0783, Val Loss: 0.4828, Val Accuracy: 83.00%
#
# [71/100] Train Loss: 0.0855, Val Loss: 0.3689, Val Accuracy: 89.00%
#
# [72/100] Train Loss: 0.0706, Val Loss: 0.3806, Val Accuracy: 89.00%
#
# [73/100] Train Loss: 0.0591, Val Loss: 0.4384, Val Accuracy: 87.00%
#
# [74/100] Train Loss: 0.0736, Val Loss: 0.4178, Val Accuracy: 88.00%
#
# [75/100] Train Loss: 0.0809, Val Loss: 0.3878, Val Accuracy: 89.00%
#
# [76/100] Train Loss: 0.0620, Val Loss: 0.4191, Val Accuracy: 89.00%
#
# [77/100] Train Loss: 0.0711, Val Loss: 0.3856, Val Accuracy: 89.00%
#
# [78/100] Train Loss: 0.0676, Val Loss: 0.3789, Val Accuracy: 88.00%
#
# [79/100] Train Loss: 0.0861, Val Loss: 0.3773, Val Accuracy: 88.00%
#
# [80/100] Train Loss: 0.0790, Val Loss: 0.3833, Val Accuracy: 89.00%
#
# [81/100] Train Loss: 0.0677, Val Loss: 0.4079, Val Accuracy: 87.00%
#
# [82/100] Train Loss: 0.0672, Val Loss: 0.4167, Val Accuracy: 87.00%
#
# [83/100] Train Loss: 0.0653, Val Loss: 0.4015, Val Accuracy: 88.00%
#
# [84/100] Train Loss: 0.0797, Val Loss: 0.4203, Val Accuracy: 87.00%
#
# [85/100] Train Loss: 0.0643, Val Loss: 0.3959, Val Accuracy: 88.00%
#
# [86/100] Train Loss: 0.0553, Val Loss: 0.3844, Val Accuracy: 89.00%
#
# [87/100] Train Loss: 0.0530, Val Loss: 0.3850, Val Accuracy: 89.00%
#
# [88/100] Train Loss: 0.0514, Val Loss: 0.3974, Val Accuracy: 88.00%
#
# [89/100] Train Loss: 0.0533, Val Loss: 0.4092, Val Accuracy: 89.00%
#
# [90/100] Train Loss: 0.0558, Val Loss: 0.4204, Val Accuracy: 87.00%
#
# [91/100] Train Loss: 0.0554, Val Loss: 0.4139, Val Accuracy: 88.00%
#
# [92/100] Train Loss: 0.0546, Val Loss: 0.4119, Val Accuracy: 88.00%
#
# [93/100] Train Loss: 0.0521, Val Loss: 0.4161, Val Accuracy: 88.00%
#
# [94/100] Train Loss: 0.0581, Val Loss: 0.4210, Val Accuracy: 88.00%
#
# [95/100] Train Loss: 0.0579, Val Loss: 0.4256, Val Accuracy: 88.00%
#
# [96/100] Train Loss: 0.0487, Val Loss: 0.4298, Val Accuracy: 87.00%
#
# [97/100] Train Loss: 0.0543, Val Loss: 0.4318, Val Accuracy: 87.00%
#
# [98/100] Train Loss: 0.0438, Val Loss: 0.4333, Val Accuracy: 87.00%
#
# [99/100] Train Loss: 0.0529, Val Loss: 0.4340, Val Accuracy: 87.00%
#
# [100/100] Train Loss: 0.0447, Val Loss: 0.4340, Val Accuracy: 87.00%

# %%
_, _, acc_supervised_300_val, auc_supervised_300_val = test_(ft_network, val_loader, nn.CrossEntropyLoss())
# Out:
# Evaluation on held out test dataset
# Confusion Matrix
# +----------------+------------------+---------------------+
# |                | predicted lenses | predicted nonlenses |
# +----------------+------------------+---------------------+
# |  true lenses   |        45        |          5          |
# | true nonlenses |        8         |          42         |
# +----------------+------------------+---------------------+
# Test Metrics
# +-----------+----------+
# |  accuracy | 87.0000% |
# |    loss   |  0.2470  |
# | auc score |  0.9560  |
# +-----------+----------+
# +----------------+-----------+--------+---------+---------+
# |                | precision | recall | f-score | support |
# +----------------+-----------+--------+---------+---------+
# |     lenses     |   0.8491  | 0.9000 |  0.8738 |    50   |
# |   nonlenses    |   0.8936  | 0.8400 |  0.8660 |    50   |
# | macro averaged |   0.8713  | 0.8700 |  0.8699 |         |
# +----------------+-----------+--------+---------+---------+

# %%
_, _, acc_supervised_300_test, auc_supervised_300_test = test_(ft_network, test_loader, nn.CrossEntropyLoss())
# Out:
# Evaluation on held out test dataset
# Confusion Matrix
# +----------------+------------------+---------------------+
# |                | predicted lenses | predicted nonlenses |
# +----------------+------------------+---------------------+
# |  true lenses   |       249        |          44         |
# | true nonlenses |        39        |         261         |
# +----------------+------------------+---------------------+
# Test Metrics
# +-----------+----------+
# |  accuracy | 86.0034% |
# |    loss   |  0.0221  |
# | auc score |  0.9235  |
# +-----------+----------+
# +----------------+-----------+--------+---------+---------+
# |                | precision | recall | f-score | support |
# +----------------+-----------+--------+---------+---------+
# |     lenses     |   0.8646  | 0.8498 |  0.8571 |   293   |
# |   nonlenses    |   0.8557  | 0.8700 |  0.8628 |   300   |
# | macro averaged |   0.8602  | 0.8599 |  0.8600 |         |
# +----------------+-----------+--------+---------+---------+

# %% [markdown]
# ### ViT Small Classifier trained on 600 labelled datapoints through supervised learning

# %%
set_seed(12)
train_loader, val_loader, test_loader = get_datasets(600)
ft_network = Classifier(mode = "finetune", backbone = Backbone(arch="vit_small", image_size=32, input_channels=3, patch_size=8))
optimizer = torch.optim.Adam(ft_network.parameters(), lr=1e-4, weight_decay=1e-5)
num_epochs = 100
scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, eta_min=1e-8, T_max=num_epochs)
ft_network, ft_network_best_loss = train(ft_network, train_loader, val_loader, nn.CrossEntropyLoss(), optimizer, num_epochs=num_epochs, scheduler=scheduler)

torch.save(ft_network, "../working/supervised_vit_small/supervised_600_ckpt.pth")
fpr_supervised_600, tpr_supervised_600, auc_score_600 = compute_auc(ft_network, test_loader)
# Out:
# [1/100] Train Loss: 2.7445, Val Loss: 0.8701, Val Accuracy: 61.00%
#
# [2/100] Train Loss: 0.7048, Val Loss: 0.5715, Val Accuracy: 62.00%
#
# [3/100] Train Loss: 0.5644, Val Loss: 0.5980, Val Accuracy: 74.00%
#
# [4/100] Train Loss: 0.5357, Val Loss: 0.5391, Val Accuracy: 69.00%
#
# [5/100] Train Loss: 0.4989, Val Loss: 0.4961, Val Accuracy: 64.00%
#
# [6/100] Train Loss: 0.4785, Val Loss: 0.4564, Val Accuracy: 83.00%
#
# [7/100] Train Loss: 0.4209, Val Loss: 0.4365, Val Accuracy: 83.00%
#
# [8/100] Train Loss: 0.3839, Val Loss: 0.4848, Val Accuracy: 85.00%
#
# [9/100] Train Loss: 0.3248, Val Loss: 0.3501, Val Accuracy: 81.00%
#
# [10/100] Train Loss: 0.3117, Val Loss: 0.3379, Val Accuracy: 81.00%
#
# [11/100] Train Loss: 0.3264, Val Loss: 0.3478, Val Accuracy: 79.00%
#
# [12/100] Train Loss: 0.2974, Val Loss: 0.3588, Val Accuracy: 85.00%
#
# [13/100] Train Loss: 0.2978, Val Loss: 0.4198, Val Accuracy: 85.00%
#
# [14/100] Train Loss: 0.2921, Val Loss: 0.4037, Val Accuracy: 82.00%
#
# [15/100] Train Loss: 0.2859, Val Loss: 0.3514, Val Accuracy: 84.00%
#
# [16/100] Train Loss: 0.2445, Val Loss: 0.3266, Val Accuracy: 84.00%
#
# [17/100] Train Loss: 0.2443, Val Loss: 0.3218, Val Accuracy: 90.00%
#
# [18/100] Train Loss: 0.2077, Val Loss: 0.3902, Val Accuracy: 88.00%
#
# [19/100] Train Loss: 0.2105, Val Loss: 0.4269, Val Accuracy: 83.00%
#
# [20/100] Train Loss: 0.2329, Val Loss: 0.3254, Val Accuracy: 89.00%
#
# [21/100] Train Loss: 0.2068, Val Loss: 0.5060, Val Accuracy: 86.00%
#
# [22/100] Train Loss: 0.2446, Val Loss: 0.4607, Val Accuracy: 87.00%
#
# [23/100] Train Loss: 0.1858, Val Loss: 0.3111, Val Accuracy: 89.00%
#
# [24/100] Train Loss: 0.1708, Val Loss: 0.3852, Val Accuracy: 86.00%
#
# [25/100] Train Loss: 0.1427, Val Loss: 0.3893, Val Accuracy: 90.00%
#
# [26/100] Train Loss: 0.1430, Val Loss: 0.4251, Val Accuracy: 87.00%
#
# [27/100] Train Loss: 0.1321, Val Loss: 0.3925, Val Accuracy: 88.00%
#
# [28/100] Train Loss: 0.1634, Val Loss: 0.4759, Val Accuracy: 86.00%
#
# [29/100] Train Loss: 0.1554, Val Loss: 0.3525, Val Accuracy: 87.00%
#
# [30/100] Train Loss: 0.1105, Val Loss: 0.4043, Val Accuracy: 89.00%
#
# [31/100] Train Loss: 0.1010, Val Loss: 0.3809, Val Accuracy: 89.00%
#
# [32/100] Train Loss: 0.1372, Val Loss: 0.6196, Val Accuracy: 87.00%
#
# [33/100] Train Loss: 0.1418, Val Loss: 0.4945, Val Accuracy: 88.00%
#
# [34/100] Train Loss: 0.1423, Val Loss: 0.3805, Val Accuracy: 82.00%
#
# [35/100] Train Loss: 0.1664, Val Loss: 0.3865, Val Accuracy: 88.00%
#
# [36/100] Train Loss: 0.1049, Val Loss: 0.5580, Val Accuracy: 90.00%
#
# [37/100] Train Loss: 0.0837, Val Loss: 0.4789, Val Accuracy: 91.00%
#
# [38/100] Train Loss: 0.0813, Val Loss: 0.5032, Val Accuracy: 90.00%
#
# [39/100] Train Loss: 0.0966, Val Loss: 0.6010, Val Accuracy: 88.00%
#
# [40/100] Train Loss: 0.0875, Val Loss: 0.6843, Val Accuracy: 88.00%
#
# [41/100] Train Loss: 0.0891, Val Loss: 0.7300, Val Accuracy: 90.00%
#
# [42/100] Train Loss: 0.0871, Val Loss: 0.8627, Val Accuracy: 89.00%
#
# [43/100] Train Loss: 0.0863, Val Loss: 0.8247, Val Accuracy: 91.00%
#
# [44/100] Train Loss: 0.0725, Val Loss: 0.8147, Val Accuracy: 88.00%
#
# [45/100] Train Loss: 0.0976, Val Loss: 0.8317, Val Accuracy: 88.00%
#
# [46/100] Train Loss: 0.0823, Val Loss: 0.7633, Val Accuracy: 90.00%
#
# [47/100] Train Loss: 0.0674, Val Loss: 0.6059, Val Accuracy: 86.00%
#
# [48/100] Train Loss: 0.0568, Val Loss: 0.7549, Val Accuracy: 88.00%
#
# [49/100] Train Loss: 0.0569, Val Loss: 0.8832, Val Accuracy: 89.00%
#
# [50/100] Train Loss: 0.0469, Val Loss: 0.8500, Val Accuracy: 88.00%
#
# [51/100] Train Loss: 0.0665, Val Loss: 0.7973, Val Accuracy: 90.00%
#
# [52/100] Train Loss: 0.0538, Val Loss: 0.8633, Val Accuracy: 90.00%
#
# [53/100] Train Loss: 0.0734, Val Loss: 0.9220, Val Accuracy: 90.00%
#
# [54/100] Train Loss: 0.0614, Val Loss: 0.9273, Val Accuracy: 89.00%
#
# [55/100] Train Loss: 0.0390, Val Loss: 0.9898, Val Accuracy: 89.00%
#
# [56/100] Train Loss: 0.0502, Val Loss: 1.0290, Val Accuracy: 87.00%
#
# [57/100] Train Loss: 0.0657, Val Loss: 1.1300, Val Accuracy: 89.00%
#
# [58/100] Train Loss: 0.0422, Val Loss: 1.0269, Val Accuracy: 89.00%
#
# [59/100] Train Loss: 0.0419, Val Loss: 1.1587, Val Accuracy: 87.00%
#
# [60/100] Train Loss: 0.0364, Val Loss: 1.1709, Val Accuracy: 88.00%
#
# [61/100] Train Loss: 0.0367, Val Loss: 1.2712, Val Accuracy: 88.00%
#
# [62/100] Train Loss: 0.0494, Val Loss: 1.1108, Val Accuracy: 93.00%
#
# [63/100] Train Loss: 0.0650, Val Loss: 0.9644, Val Accuracy: 89.00%
#
# [64/100] Train Loss: 0.0355, Val Loss: 0.8539, Val Accuracy: 91.00%
#
# [65/100] Train Loss: 0.0404, Val Loss: 0.8320, Val Accuracy: 89.00%
#
# [66/100] Train Loss: 0.0416, Val Loss: 1.0230, Val Accuracy: 90.00%
#
# [67/100] Train Loss: 0.0317, Val Loss: 1.0002, Val Accuracy: 90.00%
#
# [68/100] Train Loss: 0.0315, Val Loss: 1.0573, Val Accuracy: 90.00%
#
# [69/100] Train Loss: 0.0364, Val Loss: 1.0781, Val Accuracy: 90.00%
#
# [70/100] Train Loss: 0.0346, Val Loss: 1.0719, Val Accuracy: 89.00%
#
# [71/100] Train Loss: 0.0274, Val Loss: 1.0516, Val Accuracy: 90.00%
#
# [72/100] Train Loss: 0.0367, Val Loss: 1.0980, Val Accuracy: 90.00%
#
# [73/100] Train Loss: 0.0280, Val Loss: 1.1425, Val Accuracy: 88.00%
#
# [74/100] Train Loss: 0.0363, Val Loss: 1.1200, Val Accuracy: 88.00%
#
# [75/100] Train Loss: 0.0350, Val Loss: 1.0894, Val Accuracy: 89.00%
#
# [76/100] Train Loss: 0.0265, Val Loss: 1.0763, Val Accuracy: 90.00%
#
# [77/100] Train Loss: 0.0310, Val Loss: 1.0944, Val Accuracy: 89.00%
#
# [78/100] Train Loss: 0.0320, Val Loss: 1.1284, Val Accuracy: 89.00%
#
# [79/100] Train Loss: 0.0210, Val Loss: 1.1443, Val Accuracy: 90.00%
#
# [80/100] Train Loss: 0.0272, Val Loss: 1.1213, Val Accuracy: 90.00%
#
# [81/100] Train Loss: 0.0259, Val Loss: 1.1320, Val Accuracy: 89.00%
#
# [82/100] Train Loss: 0.0247, Val Loss: 1.1792, Val Accuracy: 90.00%
#
# [83/100] Train Loss: 0.0224, Val Loss: 1.1899, Val Accuracy: 90.00%
#
# [84/100] Train Loss: 0.0135, Val Loss: 1.2040, Val Accuracy: 89.00%
#
# [85/100] Train Loss: 0.0332, Val Loss: 1.2057, Val Accuracy: 89.00%
#
# [86/100] Train Loss: 0.0235, Val Loss: 1.2080, Val Accuracy: 89.00%
#
# [87/100] Train Loss: 0.0192, Val Loss: 1.1979, Val Accuracy: 89.00%
#
# [88/100] Train Loss: 0.0164, Val Loss: 1.1949, Val Accuracy: 89.00%
#
# [89/100] Train Loss: 0.0277, Val Loss: 1.2027, Val Accuracy: 90.00%
#
# [90/100] Train Loss: 0.0187, Val Loss: 1.2095, Val Accuracy: 89.00%
#
# [91/100] Train Loss: 0.0252, Val Loss: 1.2210, Val Accuracy: 89.00%
#
# [92/100] Train Loss: 0.0190, Val Loss: 1.2198, Val Accuracy: 89.00%
#
# [93/100] Train Loss: 0.0187, Val Loss: 1.2185, Val Accuracy: 89.00%
#
# [94/100] Train Loss: 0.0216, Val Loss: 1.2193, Val Accuracy: 89.00%
#
# [95/100] Train Loss: 0.0225, Val Loss: 1.2264, Val Accuracy: 89.00%
#
# [96/100] Train Loss: 0.0265, Val Loss: 1.2306, Val Accuracy: 89.00%
#
# [97/100] Train Loss: 0.0211, Val Loss: 1.2315, Val Accuracy: 89.00%
#
# [98/100] Train Loss: 0.0224, Val Loss: 1.2320, Val Accuracy: 89.00%
#
# [99/100] Train Loss: 0.0189, Val Loss: 1.2321, Val Accuracy: 89.00%
#
# [100/100] Train Loss: 0.0147, Val Loss: 1.2321, Val Accuracy: 89.00%

# %%
_, _, acc_supervised_600_val, auc_supervised_600_val = test_(ft_network, val_loader, nn.CrossEntropyLoss())
# Out:
# Evaluation on held out test dataset
# Confusion Matrix
# +----------------+------------------+---------------------+
# |                | predicted lenses | predicted nonlenses |
# +----------------+------------------+---------------------+
# |  true lenses   |        46        |          4          |
# | true nonlenses |        7         |          43         |
# +----------------+------------------+---------------------+
# Test Metrics
# +-----------+----------+
# |  accuracy | 89.0000% |
# |    loss   |  1.0400  |
# | auc score |  0.9216  |
# +-----------+----------+
# +----------------+-----------+--------+---------+---------+
# |                | precision | recall | f-score | support |
# +----------------+-----------+--------+---------+---------+
# |     lenses     |   0.8679  | 0.9200 |  0.8932 |    50   |
# |   nonlenses    |   0.9149  | 0.8600 |  0.8866 |    50   |
# | macro averaged |   0.8914  | 0.8900 |  0.8899 |         |
# +----------------+-----------+--------+---------+---------+

# %%
_, _, acc_supervised_600_test, auc_supervised_600_test = test_(ft_network, test_loader, nn.CrossEntropyLoss())
# Out:
# Evaluation on held out test dataset
# Confusion Matrix
# +----------------+------------------+---------------------+
# |                | predicted lenses | predicted nonlenses |
# +----------------+------------------+---------------------+
# |  true lenses   |       256        |          37         |
# | true nonlenses |        34        |         266         |
# +----------------+------------------+---------------------+
# Test Metrics
# +-----------+----------+
# |  accuracy | 88.0270% |
# |    loss   |  0.1331  |
# | auc score |  0.9210  |
# +-----------+----------+
# +----------------+-----------+--------+---------+---------+
# |                | precision | recall | f-score | support |
# +----------------+-----------+--------+---------+---------+
# |     lenses     |   0.8828  | 0.8737 |  0.8782 |   293   |
# |   nonlenses    |   0.8779  | 0.8867 |  0.8823 |   300   |
# | macro averaged |   0.8803  | 0.8802 |  0.8802 |         |
# +----------------+-----------+--------+---------+---------+

# %% [markdown]
# ### ViT Small Classifier trained on 1200 labelled datapoints through supervised learning

# %%
set_seed(12)
train_loader, val_loader, test_loader = get_datasets(1200)
ft_network = Classifier(mode = "finetune", backbone = Backbone(arch="vit_small", image_size=32, input_channels=3, patch_size=8))
optimizer = torch.optim.Adam(ft_network.parameters(), lr=1e-4, weight_decay=1e-5)
num_epochs = 100
scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, eta_min=1e-8, T_max=num_epochs)
ft_network, ft_network_best_loss = train(ft_network, train_loader, val_loader, nn.CrossEntropyLoss(), optimizer, num_epochs=num_epochs, scheduler=scheduler)

torch.save(ft_network, "../working/supervised_vit_small/supervised_1200_ckpt.pth")
fpr_supervised_1200, tpr_supervised_1200, auc_score_1200 = compute_auc(ft_network, test_loader)
# Out:
# [1/100] Train Loss: 1.8420, Val Loss: 0.9086, Val Accuracy: 50.00%
#
# [2/100] Train Loss: 0.6123, Val Loss: 0.5541, Val Accuracy: 60.00%
#
# [3/100] Train Loss: 0.5341, Val Loss: 0.5646, Val Accuracy: 84.00%
#
# [4/100] Train Loss: 0.4691, Val Loss: 0.4238, Val Accuracy: 84.00%
#
# [5/100] Train Loss: 0.3940, Val Loss: 0.3494, Val Accuracy: 83.00%
#
# [6/100] Train Loss: 0.3690, Val Loss: 0.3708, Val Accuracy: 80.00%
#
# [7/100] Train Loss: 0.3619, Val Loss: 0.3402, Val Accuracy: 83.00%
#
# [8/100] Train Loss: 0.3284, Val Loss: 0.3160, Val Accuracy: 86.00%
#
# [9/100] Train Loss: 0.2930, Val Loss: 0.3086, Val Accuracy: 85.00%
#
# [10/100] Train Loss: 0.2878, Val Loss: 0.3155, Val Accuracy: 84.00%
#
# [11/100] Train Loss: 0.2633, Val Loss: 0.3311, Val Accuracy: 86.00%
#
# [12/100] Train Loss: 0.2389, Val Loss: 0.2426, Val Accuracy: 85.00%
#
# [13/100] Train Loss: 0.2446, Val Loss: 0.2223, Val Accuracy: 89.00%
#
# [14/100] Train Loss: 0.2437, Val Loss: 0.3083, Val Accuracy: 85.00%
#
# [15/100] Train Loss: 0.2440, Val Loss: 0.2416, Val Accuracy: 89.00%
#
# [16/100] Train Loss: 0.2156, Val Loss: 0.2077, Val Accuracy: 91.00%
#
# [17/100] Train Loss: 0.1908, Val Loss: 0.2046, Val Accuracy: 91.00%
#
# [18/100] Train Loss: 0.1985, Val Loss: 0.2536, Val Accuracy: 92.00%
#
# [19/100] Train Loss: 0.1723, Val Loss: 0.2978, Val Accuracy: 85.00%
#
# [20/100] Train Loss: 0.1620, Val Loss: 0.2741, Val Accuracy: 90.00%
#
# [21/100] Train Loss: 0.1822, Val Loss: 0.2471, Val Accuracy: 88.00%
#
# [22/100] Train Loss: 0.1797, Val Loss: 0.2643, Val Accuracy: 90.00%
#
# [23/100] Train Loss: 0.1753, Val Loss: 0.2503, Val Accuracy: 89.00%
#
# [24/100] Train Loss: 0.1479, Val Loss: 0.2390, Val Accuracy: 90.00%
#
# [25/100] Train Loss: 0.1634, Val Loss: 0.3711, Val Accuracy: 87.00%
#
# [26/100] Train Loss: 0.1255, Val Loss: 0.5147, Val Accuracy: 86.00%
#
# [27/100] Train Loss: 0.1096, Val Loss: 0.3234, Val Accuracy: 91.00%
#
# [28/100] Train Loss: 0.1194, Val Loss: 0.3875, Val Accuracy: 89.00%
#
# [29/100] Train Loss: 0.1320, Val Loss: 0.2343, Val Accuracy: 90.00%
#
# [30/100] Train Loss: 0.1200, Val Loss: 0.3223, Val Accuracy: 91.00%
#
# [31/100] Train Loss: 0.1045, Val Loss: 0.4382, Val Accuracy: 87.00%
#
# [32/100] Train Loss: 0.1031, Val Loss: 0.4974, Val Accuracy: 85.00%
#
# [33/100] Train Loss: 0.1098, Val Loss: 0.3862, Val Accuracy: 90.00%
#
# [34/100] Train Loss: 0.0804, Val Loss: 0.3864, Val Accuracy: 90.00%
#
# [35/100] Train Loss: 0.0623, Val Loss: 0.3420, Val Accuracy: 89.00%
#
# [36/100] Train Loss: 0.0623, Val Loss: 0.3889, Val Accuracy: 88.00%
#
# [37/100] Train Loss: 0.0814, Val Loss: 0.2797, Val Accuracy: 91.00%
#
# [38/100] Train Loss: 0.0519, Val Loss: 0.3643, Val Accuracy: 89.00%
#
# [39/100] Train Loss: 0.0878, Val Loss: 0.3698, Val Accuracy: 90.00%
#
# [40/100] Train Loss: 0.0579, Val Loss: 0.7668, Val Accuracy: 88.00%
#
# [41/100] Train Loss: 0.1017, Val Loss: 0.4283, Val Accuracy: 88.00%
#
# [42/100] Train Loss: 0.0662, Val Loss: 0.4848, Val Accuracy: 91.00%
#
# [43/100] Train Loss: 0.0394, Val Loss: 0.5819, Val Accuracy: 88.00%
#
# [44/100] Train Loss: 0.0267, Val Loss: 0.7597, Val Accuracy: 89.00%
#
# [45/100] Train Loss: 0.0253, Val Loss: 0.8071, Val Accuracy: 90.00%
#
# [46/100] Train Loss: 0.0282, Val Loss: 1.1244, Val Accuracy: 88.00%
#
# [47/100] Train Loss: 0.0402, Val Loss: 0.6970, Val Accuracy: 89.00%
#
# [48/100] Train Loss: 0.0281, Val Loss: 0.5197, Val Accuracy: 89.00%
#
# [49/100] Train Loss: 0.0329, Val Loss: 0.5966, Val Accuracy: 90.00%
#
# [50/100] Train Loss: 0.0558, Val Loss: 0.5855, Val Accuracy: 90.00%
#
# [51/100] Train Loss: 0.0274, Val Loss: 0.4234, Val Accuracy: 90.00%
#
# [52/100] Train Loss: 0.0274, Val Loss: 0.6091, Val Accuracy: 90.00%
#
# [53/100] Train Loss: 0.0315, Val Loss: 0.9177, Val Accuracy: 88.00%
#
# [54/100] Train Loss: 0.0491, Val Loss: 0.3953, Val Accuracy: 92.00%
#
# [55/100] Train Loss: 0.0314, Val Loss: 0.3742, Val Accuracy: 92.00%
#
# [56/100] Train Loss: 0.0135, Val Loss: 0.6413, Val Accuracy: 90.00%
#
# [57/100] Train Loss: 0.0156, Val Loss: 0.6972, Val Accuracy: 90.00%
#
# [58/100] Train Loss: 0.0105, Val Loss: 0.8226, Val Accuracy: 90.00%
#
# [59/100] Train Loss: 0.0143, Val Loss: 0.8181, Val Accuracy: 91.00%
#
# [60/100] Train Loss: 0.0069, Val Loss: 1.0404, Val Accuracy: 90.00%
#
# [61/100] Train Loss: 0.0084, Val Loss: 0.8633, Val Accuracy: 90.00%
#
# [62/100] Train Loss: 0.0209, Val Loss: 0.8201, Val Accuracy: 90.00%
#
# [63/100] Train Loss: 0.0116, Val Loss: 0.9496, Val Accuracy: 91.00%
#
# [64/100] Train Loss: 0.0327, Val Loss: 1.1715, Val Accuracy: 90.00%
#
# [65/100] Train Loss: 0.0218, Val Loss: 0.5591, Val Accuracy: 90.00%
#
# [66/100] Train Loss: 0.0152, Val Loss: 0.5382, Val Accuracy: 91.00%
#
# [67/100] Train Loss: 0.0067, Val Loss: 0.4508, Val Accuracy: 92.00%
#
# [68/100] Train Loss: 0.0083, Val Loss: 0.4768, Val Accuracy: 92.00%
#
# [69/100] Train Loss: 0.0108, Val Loss: 0.6988, Val Accuracy: 92.00%
#
# [70/100] Train Loss: 0.0072, Val Loss: 0.6625, Val Accuracy: 93.00%
#
# [71/100] Train Loss: 0.0040, Val Loss: 0.7282, Val Accuracy: 93.00%
#
# [72/100] Train Loss: 0.0035, Val Loss: 0.6687, Val Accuracy: 91.00%
#
# [73/100] Train Loss: 0.0046, Val Loss: 0.7014, Val Accuracy: 93.00%
#
# [74/100] Train Loss: 0.0032, Val Loss: 0.5800, Val Accuracy: 92.00%
#
# [75/100] Train Loss: 0.0087, Val Loss: 0.6379, Val Accuracy: 92.00%
#
# [76/100] Train Loss: 0.0021, Val Loss: 0.6932, Val Accuracy: 93.00%
#
# [77/100] Train Loss: 0.0063, Val Loss: 0.6581, Val Accuracy: 93.00%
#
# [78/100] Train Loss: 0.0043, Val Loss: 0.6922, Val Accuracy: 93.00%
#
# [79/100] Train Loss: 0.0012, Val Loss: 0.7519, Val Accuracy: 93.00%
#
# [80/100] Train Loss: 0.0057, Val Loss: 0.7440, Val Accuracy: 93.00%
#
# [81/100] Train Loss: 0.0019, Val Loss: 0.7111, Val Accuracy: 93.00%
#
# [82/100] Train Loss: 0.0035, Val Loss: 0.7743, Val Accuracy: 93.00%
#
# [83/100] Train Loss: 0.0060, Val Loss: 0.7792, Val Accuracy: 92.00%
#
# [84/100] Train Loss: 0.0091, Val Loss: 0.7305, Val Accuracy: 93.00%
#
# [85/100] Train Loss: 0.0013, Val Loss: 0.7551, Val Accuracy: 93.00%
#
# [86/100] Train Loss: 0.0013, Val Loss: 0.7484, Val Accuracy: 93.00%
#
# [87/100] Train Loss: 0.0034, Val Loss: 0.7573, Val Accuracy: 93.00%
#
# [88/100] Train Loss: 0.0009, Val Loss: 0.7474, Val Accuracy: 93.00%
#
# [89/100] Train Loss: 0.0022, Val Loss: 0.7141, Val Accuracy: 93.00%
#
# [90/100] Train Loss: 0.0010, Val Loss: 0.6947, Val Accuracy: 93.00%
#
# [91/100] Train Loss: 0.0014, Val Loss: 0.6987, Val Accuracy: 93.00%
#
# [92/100] Train Loss: 0.0041, Val Loss: 0.7169, Val Accuracy: 93.00%
#
# [93/100] Train Loss: 0.0008, Val Loss: 0.7392, Val Accuracy: 93.00%
#
# [94/100] Train Loss: 0.0007, Val Loss: 0.7405, Val Accuracy: 93.00%
#
# [95/100] Train Loss: 0.0009, Val Loss: 0.7368, Val Accuracy: 93.00%
#
# [96/100] Train Loss: 0.0022, Val Loss: 0.7368, Val Accuracy: 93.00%
#
# [97/100] Train Loss: 0.0033, Val Loss: 0.7392, Val Accuracy: 93.00%
#
# [98/100] Train Loss: 0.0011, Val Loss: 0.7404, Val Accuracy: 93.00%
#
# [99/100] Train Loss: 0.0031, Val Loss: 0.7411, Val Accuracy: 93.00%
#
# [100/100] Train Loss: 0.0006, Val Loss: 0.7411, Val Accuracy: 93.00%

# %%
_, _, acc_supervised_1200_val, auc_supervised_1200_val = test_(ft_network, val_loader, nn.CrossEntropyLoss())
# Out:
# Evaluation on held out test dataset
# Confusion Matrix
# +----------------+------------------+---------------------+
# |                | predicted lenses | predicted nonlenses |
# +----------------+------------------+---------------------+
# |  true lenses   |        49        |          1          |
# | true nonlenses |        6         |          44         |
# +----------------+------------------+---------------------+
# Test Metrics
# +-----------+----------+
# |  accuracy | 93.0000% |
# |    loss   |  0.6627  |
# | auc score |  0.9760  |
# +-----------+----------+
# +----------------+-----------+--------+---------+---------+
# |                | precision | recall | f-score | support |
# +----------------+-----------+--------+---------+---------+
# |     lenses     |   0.8909  | 0.9800 |  0.9333 |    50   |
# |   nonlenses    |   0.9778  | 0.8800 |  0.9263 |    50   |
# | macro averaged |   0.9343  | 0.9300 |  0.9298 |         |
# +----------------+-----------+--------+---------+---------+

# %%
_, _, acc_supervised_1200_test, auc_supervised_1200_test = test_(ft_network, test_loader, nn.CrossEntropyLoss())
# Out:
# Evaluation on held out test dataset
# Confusion Matrix
# +----------------+------------------+---------------------+
# |                | predicted lenses | predicted nonlenses |
# +----------------+------------------+---------------------+
# |  true lenses   |       257        |          36         |
# | true nonlenses |        26        |         274         |
# +----------------+------------------+---------------------+
# Test Metrics
# +-----------+----------+
# |  accuracy | 89.5447% |
# |    loss   |  0.0446  |
# | auc score |  0.9663  |
# +-----------+----------+
# +----------------+-----------+--------+---------+---------+
# |                | precision | recall | f-score | support |
# +----------------+-----------+--------+---------+---------+
# |     lenses     |   0.9081  | 0.8771 |  0.8924 |   293   |
# |   nonlenses    |   0.8839  | 0.9133 |  0.8984 |   300   |
# | macro averaged |   0.8960  | 0.8952 |  0.8954 |         |
# +----------------+-----------+--------+---------+---------+

# %% [markdown]
# ### ViT Small Classifier trained on all labelled datapoints through supervised learning

# %%
set_seed(12)
train_loader, val_loader, test_loader = get_datasets(None)
ft_network = Classifier(mode = "finetune", backbone = Backbone(arch="vit_small", image_size=32, input_channels=3, patch_size=8))
optimizer = torch.optim.Adam(ft_network.parameters(), lr=1e-4, weight_decay=1e-3)
num_epochs = 100
scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, eta_min=1e-8, T_max=num_epochs)
ft_network, ft_network_best_loss = train(ft_network, train_loader, val_loader, nn.CrossEntropyLoss(), optimizer, num_epochs=num_epochs, scheduler=scheduler)

torch.save(ft_network, "../working/supervised_vit_small/supervised_all_ckpt.pth")
fpr_supervised_all, tpr_supervised_all, auc_score_all = compute_auc(ft_network, test_loader)
# Out:
# [1/100] Train Loss: 0.9528, Val Loss: 0.5426, Val Accuracy: 83.00%
#
# [2/100] Train Loss: 0.3964, Val Loss: 0.3410, Val Accuracy: 86.00%
#
# [3/100] Train Loss: 0.3345, Val Loss: 0.3129, Val Accuracy: 84.00%
#
# [4/100] Train Loss: 0.2919, Val Loss: 0.2643, Val Accuracy: 85.00%
#
# [5/100] Train Loss: 0.2629, Val Loss: 0.3523, Val Accuracy: 87.00%
#
# [6/100] Train Loss: 0.2620, Val Loss: 0.2249, Val Accuracy: 90.00%
#
# [7/100] Train Loss: 0.2338, Val Loss: 0.3313, Val Accuracy: 90.00%
#
# [8/100] Train Loss: 0.2270, Val Loss: 0.2143, Val Accuracy: 92.00%
#
# [9/100] Train Loss: 0.2203, Val Loss: 0.1711, Val Accuracy: 91.00%
#
# [10/100] Train Loss: 0.2055, Val Loss: 0.1663, Val Accuracy: 95.00%
#
# [11/100] Train Loss: 0.1985, Val Loss: 0.1576, Val Accuracy: 90.00%
#
# [12/100] Train Loss: 0.1846, Val Loss: 0.1545, Val Accuracy: 93.00%
#
# [13/100] Train Loss: 0.1845, Val Loss: 0.2209, Val Accuracy: 92.00%
#
# [14/100] Train Loss: 0.1762, Val Loss: 0.1685, Val Accuracy: 95.00%
#
# [15/100] Train Loss: 0.1634, Val Loss: 0.1310, Val Accuracy: 95.00%
#
# [16/100] Train Loss: 0.1484, Val Loss: 0.2082, Val Accuracy: 93.00%
#
# [17/100] Train Loss: 0.1515, Val Loss: 0.1372, Val Accuracy: 97.00%
#
# [18/100] Train Loss: 0.1686, Val Loss: 0.1293, Val Accuracy: 96.00%
#
# [19/100] Train Loss: 0.1493, Val Loss: 0.2817, Val Accuracy: 88.00%
#
# [20/100] Train Loss: 0.1443, Val Loss: 0.1567, Val Accuracy: 93.00%
#
# [21/100] Train Loss: 0.1238, Val Loss: 0.0999, Val Accuracy: 96.00%
#
# [22/100] Train Loss: 0.1282, Val Loss: 0.3184, Val Accuracy: 88.00%
#
# [23/100] Train Loss: 0.1312, Val Loss: 0.1203, Val Accuracy: 97.00%
#
# [24/100] Train Loss: 0.1265, Val Loss: 0.1861, Val Accuracy: 95.00%
#
# [25/100] Train Loss: 0.1180, Val Loss: 0.2866, Val Accuracy: 90.00%
#
# [26/100] Train Loss: 0.1035, Val Loss: 0.1597, Val Accuracy: 96.00%
#
# [27/100] Train Loss: 0.1124, Val Loss: 0.1020, Val Accuracy: 95.00%
#
# [28/100] Train Loss: 0.1034, Val Loss: 0.1269, Val Accuracy: 95.00%
#
# [29/100] Train Loss: 0.1068, Val Loss: 0.2724, Val Accuracy: 89.00%
#
# [30/100] Train Loss: 0.0975, Val Loss: 0.1131, Val Accuracy: 96.00%
#
# [31/100] Train Loss: 0.0816, Val Loss: 0.0878, Val Accuracy: 96.00%
#
# [32/100] Train Loss: 0.0787, Val Loss: 0.2101, Val Accuracy: 94.00%
#
# [33/100] Train Loss: 0.1033, Val Loss: 0.1105, Val Accuracy: 97.00%
#
# [34/100] Train Loss: 0.0789, Val Loss: 0.1475, Val Accuracy: 94.00%
#
# [35/100] Train Loss: 0.0642, Val Loss: 0.0889, Val Accuracy: 97.00%
#
# [36/100] Train Loss: 0.0781, Val Loss: 0.1468, Val Accuracy: 95.00%
#
# [37/100] Train Loss: 0.0732, Val Loss: 0.1275, Val Accuracy: 96.00%
#
# [38/100] Train Loss: 0.0639, Val Loss: 0.1397, Val Accuracy: 96.00%
#
# [39/100] Train Loss: 0.0537, Val Loss: 0.2360, Val Accuracy: 93.00%
#
# [40/100] Train Loss: 0.0505, Val Loss: 0.1179, Val Accuracy: 94.00%
#
# [41/100] Train Loss: 0.0607, Val Loss: 0.4315, Val Accuracy: 88.00%
#
# [42/100] Train Loss: 0.0680, Val Loss: 0.1755, Val Accuracy: 93.00%
#
# [43/100] Train Loss: 0.0459, Val Loss: 0.1069, Val Accuracy: 95.00%
#
# [44/100] Train Loss: 0.0469, Val Loss: 0.1460, Val Accuracy: 95.00%
#
# [45/100] Train Loss: 0.0486, Val Loss: 0.1328, Val Accuracy: 95.00%
#
# [46/100] Train Loss: 0.0418, Val Loss: 0.1360, Val Accuracy: 97.00%
#
# [47/100] Train Loss: 0.0347, Val Loss: 0.1270, Val Accuracy: 97.00%
#
# [48/100] Train Loss: 0.0338, Val Loss: 0.1430, Val Accuracy: 95.00%
#
# [49/100] Train Loss: 0.0403, Val Loss: 0.2251, Val Accuracy: 92.00%
#
# [50/100] Train Loss: 0.0378, Val Loss: 0.1239, Val Accuracy: 96.00%
#
# [51/100] Train Loss: 0.0572, Val Loss: 0.1871, Val Accuracy: 93.00%
#
# [52/100] Train Loss: 0.0261, Val Loss: 0.1222, Val Accuracy: 96.00%
#
# [53/100] Train Loss: 0.0222, Val Loss: 0.0934, Val Accuracy: 97.00%
#
# [54/100] Train Loss: 0.0287, Val Loss: 0.1283, Val Accuracy: 95.00%
#
# [55/100] Train Loss: 0.0278, Val Loss: 0.0899, Val Accuracy: 97.00%
#
# [56/100] Train Loss: 0.0260, Val Loss: 0.2045, Val Accuracy: 93.00%
#
# [57/100] Train Loss: 0.0287, Val Loss: 0.1373, Val Accuracy: 95.00%
#
# [58/100] Train Loss: 0.0271, Val Loss: 0.1566, Val Accuracy: 95.00%
#
# [59/100] Train Loss: 0.0169, Val Loss: 0.1522, Val Accuracy: 94.00%
#
# [60/100] Train Loss: 0.0190, Val Loss: 0.1976, Val Accuracy: 95.00%
#
# [61/100] Train Loss: 0.0214, Val Loss: 0.2005, Val Accuracy: 93.00%
#
# [62/100] Train Loss: 0.0146, Val Loss: 0.1546, Val Accuracy: 95.00%
#
# [63/100] Train Loss: 0.0108, Val Loss: 0.1021, Val Accuracy: 96.00%
#
# [64/100] Train Loss: 0.0157, Val Loss: 0.1992, Val Accuracy: 94.00%
#
# [65/100] Train Loss: 0.0280, Val Loss: 0.1491, Val Accuracy: 96.00%
#
# [66/100] Train Loss: 0.0108, Val Loss: 0.2144, Val Accuracy: 94.00%
#
# [67/100] Train Loss: 0.0111, Val Loss: 0.2016, Val Accuracy: 95.00%
#
# [68/100] Train Loss: 0.0100, Val Loss: 0.2057, Val Accuracy: 95.00%
#
# [69/100] Train Loss: 0.0143, Val Loss: 0.1998, Val Accuracy: 94.00%
#
# [70/100] Train Loss: 0.0094, Val Loss: 0.1784, Val Accuracy: 98.00%
#
# [71/100] Train Loss: 0.0052, Val Loss: 0.2046, Val Accuracy: 95.00%
#
# [72/100] Train Loss: 0.0089, Val Loss: 0.0976, Val Accuracy: 97.00%
#
# [73/100] Train Loss: 0.0080, Val Loss: 0.1703, Val Accuracy: 96.00%
#
# [74/100] Train Loss: 0.0058, Val Loss: 0.2025, Val Accuracy: 96.00%
#
# [75/100] Train Loss: 0.0058, Val Loss: 0.2104, Val Accuracy: 96.00%
#
# [76/100] Train Loss: 0.0057, Val Loss: 0.2287, Val Accuracy: 96.00%
#
# [77/100] Train Loss: 0.0062, Val Loss: 0.2029, Val Accuracy: 97.00%
#
# [78/100] Train Loss: 0.0036, Val Loss: 0.1541, Val Accuracy: 97.00%
#
# [79/100] Train Loss: 0.0045, Val Loss: 0.1631, Val Accuracy: 96.00%
#
# [80/100] Train Loss: 0.0055, Val Loss: 0.1550, Val Accuracy: 97.00%
#
# [81/100] Train Loss: 0.0041, Val Loss: 0.1605, Val Accuracy: 98.00%
#
# [82/100] Train Loss: 0.0064, Val Loss: 0.1402, Val Accuracy: 97.00%
#
# [83/100] Train Loss: 0.0038, Val Loss: 0.2163, Val Accuracy: 96.00%
#
# [84/100] Train Loss: 0.0027, Val Loss: 0.1883, Val Accuracy: 96.00%
#
# [85/100] Train Loss: 0.0041, Val Loss: 0.2016, Val Accuracy: 97.00%
#
# [86/100] Train Loss: 0.0026, Val Loss: 0.2078, Val Accuracy: 97.00%
#
# [87/100] Train Loss: 0.0041, Val Loss: 0.2127, Val Accuracy: 96.00%
#
# [88/100] Train Loss: 0.0030, Val Loss: 0.1837, Val Accuracy: 96.00%
#
# [89/100] Train Loss: 0.0029, Val Loss: 0.1664, Val Accuracy: 97.00%
#
# [90/100] Train Loss: 0.0032, Val Loss: 0.1898, Val Accuracy: 98.00%
#
# [91/100] Train Loss: 0.0019, Val Loss: 0.1963, Val Accuracy: 98.00%
#
# [92/100] Train Loss: 0.0031, Val Loss: 0.1931, Val Accuracy: 96.00%
#
# [93/100] Train Loss: 0.0038, Val Loss: 0.2008, Val Accuracy: 97.00%
#
# [94/100] Train Loss: 0.0011, Val Loss: 0.1983, Val Accuracy: 97.00%
#
# [95/100] Train Loss: 0.0060, Val Loss: 0.2035, Val Accuracy: 96.00%
#
# [96/100] Train Loss: 0.0036, Val Loss: 0.2085, Val Accuracy: 96.00%
#
# [97/100] Train Loss: 0.0047, Val Loss: 0.2105, Val Accuracy: 96.00%
#
# [98/100] Train Loss: 0.0047, Val Loss: 0.2138, Val Accuracy: 97.00%
#
# [99/100] Train Loss: 0.0025, Val Loss: 0.2140, Val Accuracy: 97.00%
#
# [100/100] Train Loss: 0.0034, Val Loss: 0.2136, Val Accuracy: 97.00%

# %%
_, _, acc_supervised_all_val, auc_supervised_all_val = test_(ft_network, val_loader, nn.CrossEntropyLoss())
# Out:
# Evaluation on held out test dataset
# Confusion Matrix
# +----------------+------------------+---------------------+
# |                | predicted lenses | predicted nonlenses |
# +----------------+------------------+---------------------+
# |  true lenses   |        48        |          2          |
# | true nonlenses |        1         |          49         |
# +----------------+------------------+---------------------+
# Test Metrics
# +-----------+----------+
# |  accuracy | 97.0000% |
# |    loss   |  0.1440  |
# | auc score |  0.9944  |
# +-----------+----------+
# +----------------+-----------+--------+---------+---------+
# |                | precision | recall | f-score | support |
# +----------------+-----------+--------+---------+---------+
# |     lenses     |   0.9796  | 0.9600 |  0.9697 |    50   |
# |   nonlenses    |   0.9608  | 0.9800 |  0.9703 |    50   |
# | macro averaged |   0.9702  | 0.9700 |  0.9700 |         |
# +----------------+-----------+--------+---------+---------+

# %%
_, _, acc_supervised_all_test, auc_supervised_all_test = test_(ft_network, test_loader, nn.CrossEntropyLoss())
# Out:
# Evaluation on held out test dataset
# Confusion Matrix
# +----------------+------------------+---------------------+
# |                | predicted lenses | predicted nonlenses |
# +----------------+------------------+---------------------+
# |  true lenses   |       273        |          20         |
# | true nonlenses |        17        |         283         |
# +----------------+------------------+---------------------+
# Test Metrics
# +-----------+----------+
# |  accuracy | 93.7605% |
# |    loss   |  0.0007  |
# | auc score |  0.9786  |
# +-----------+----------+
# +----------------+-----------+--------+---------+---------+
# |                | precision | recall | f-score | support |
# +----------------+-----------+--------+---------+---------+
# |     lenses     |   0.9414  | 0.9317 |  0.9365 |   293   |
# |   nonlenses    |   0.9340  | 0.9433 |  0.9386 |   300   |
# | macro averaged |   0.9377  | 0.9375 |  0.9376 |         |
# +----------------+-----------+--------+---------+---------+

# %% [markdown]
# ### ROC Curves for the supervised models are plotted below

# %%
plt.figure(figsize=(15, 15))
plt.title('ROC')
plt.plot(fpr_supervised_300, tpr_supervised_300, 'r', label = 'AUC (trained on 300 labelled data, supervised) = %0.4f' % auc_score_300)
plt.plot(fpr_supervised_600, tpr_supervised_600, 'm', label = 'AUC (trained on 600 labelled data, supervised) = %0.4f' % auc_score_600)
plt.plot(fpr_supervised_1200, tpr_supervised_1200, 'g', label = 'AUC (trained on 1200 labelled data, supervised) = %0.4f' % auc_score_1200)
plt.plot(fpr_supervised_all, tpr_supervised_all, 'b', label = 'AUC (trained on all labelled data, supervised) = %0.4f' % auc_score_all)

plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.savefig("auc_supervised.png")
plt.show()

# %% [markdown]
# ### ViT Small backbone pretrained with DINO

# %%
state = torch.load(# path to vit small backbone pretrained with dino)

# %% [markdown]
# ### ViT Small pretrained backbone finetuned on 300 labelled datapoints

# %%
set_seed(12)
train_loader, val_loader, test_loader = get_datasets(300)
ft_network = Classifier(mode = "finetune", backbone = copy.deepcopy(state["student"].backbone))
optimizer = torch.optim.Adam(ft_network.parameters(), lr=1e-4, weight_decay=1e-0)
num_epochs = 100
scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, eta_min=1e-8, T_max=num_epochs)
ft_network, ft_network_best_loss = train(ft_network, train_loader, val_loader, nn.CrossEntropyLoss(), optimizer, num_epochs=num_epochs, scheduler=scheduler)

torch.save(ft_network, "../working/dino_vit_small/dino_finetuned_300_ckpt.pth")
fpr_dino_finetuned_300, tpr_dino_finetuned_300, auc_score_dino_finetuned_300 = compute_auc(ft_network, test_loader)
# Out:
# [1/100] Train Loss: 0.7204, Val Loss: 0.5835, Val Accuracy: 62.00%
#
# [2/100] Train Loss: 0.5837, Val Loss: 0.5557, Val Accuracy: 63.00%
#
# [3/100] Train Loss: 0.5639, Val Loss: 0.5630, Val Accuracy: 71.00%
#
# [4/100] Train Loss: 0.5612, Val Loss: 0.5371, Val Accuracy: 66.00%
#
# [5/100] Train Loss: 0.5408, Val Loss: 0.5309, Val Accuracy: 69.00%
#
# [6/100] Train Loss: 0.5283, Val Loss: 0.5368, Val Accuracy: 73.00%
#
# [7/100] Train Loss: 0.5238, Val Loss: 0.4983, Val Accuracy: 80.00%
#
# [8/100] Train Loss: 0.5105, Val Loss: 0.4957, Val Accuracy: 81.00%
#
# [9/100] Train Loss: 0.5008, Val Loss: 0.5569, Val Accuracy: 74.00%
#
# [10/100] Train Loss: 0.5946, Val Loss: 0.5891, Val Accuracy: 69.00%
#
# [11/100] Train Loss: 0.5863, Val Loss: 0.5984, Val Accuracy: 79.00%
#
# [12/100] Train Loss: 0.5698, Val Loss: 0.5662, Val Accuracy: 63.00%
#
# [13/100] Train Loss: 0.5650, Val Loss: 0.6190, Val Accuracy: 74.00%
#
# [14/100] Train Loss: 0.5397, Val Loss: 0.5414, Val Accuracy: 62.00%
#
# [15/100] Train Loss: 0.5679, Val Loss: 0.6024, Val Accuracy: 76.00%
#
# [16/100] Train Loss: 0.5196, Val Loss: 0.5037, Val Accuracy: 69.00%
#
# [17/100] Train Loss: 0.5064, Val Loss: 0.5947, Val Accuracy: 76.00%
#
# [18/100] Train Loss: 0.5216, Val Loss: 0.4812, Val Accuracy: 68.00%
#
# [19/100] Train Loss: 0.4941, Val Loss: 0.4839, Val Accuracy: 80.00%
#
# [20/100] Train Loss: 0.4647, Val Loss: 0.4555, Val Accuracy: 82.00%
#
# [21/100] Train Loss: 0.4309, Val Loss: 0.4481, Val Accuracy: 82.00%
#
# [22/100] Train Loss: 0.4128, Val Loss: 0.4371, Val Accuracy: 83.00%
#
# [23/100] Train Loss: 0.4034, Val Loss: 0.4200, Val Accuracy: 82.00%
#
# [24/100] Train Loss: 0.3739, Val Loss: 0.4065, Val Accuracy: 84.00%
#
# [25/100] Train Loss: 0.3684, Val Loss: 0.4747, Val Accuracy: 78.00%
#
# [26/100] Train Loss: 0.4046, Val Loss: 0.3994, Val Accuracy: 83.00%
#
# [27/100] Train Loss: 0.4106, Val Loss: 0.4820, Val Accuracy: 85.00%
#
# [28/100] Train Loss: 0.4557, Val Loss: 0.3479, Val Accuracy: 82.00%
#
# [29/100] Train Loss: 0.4689, Val Loss: 0.4513, Val Accuracy: 69.00%
#
# [30/100] Train Loss: 0.4787, Val Loss: 0.6061, Val Accuracy: 72.00%
#
# [31/100] Train Loss: 0.4700, Val Loss: 0.4443, Val Accuracy: 81.00%
#
# [32/100] Train Loss: 0.4128, Val Loss: 0.4159, Val Accuracy: 76.00%
#
# [33/100] Train Loss: 0.4099, Val Loss: 0.5693, Val Accuracy: 80.00%
#
# [34/100] Train Loss: 0.3629, Val Loss: 0.3257, Val Accuracy: 84.00%
#
# [35/100] Train Loss: 0.3449, Val Loss: 0.2965, Val Accuracy: 87.00%
#
# [36/100] Train Loss: 0.3399, Val Loss: 0.3393, Val Accuracy: 89.00%
#
# [37/100] Train Loss: 0.3386, Val Loss: 0.3768, Val Accuracy: 81.00%
#
# [38/100] Train Loss: 0.3428, Val Loss: 0.3679, Val Accuracy: 88.00%
#
# [39/100] Train Loss: 0.3536, Val Loss: 0.4258, Val Accuracy: 82.00%
#
# [40/100] Train Loss: 0.4612, Val Loss: 0.4958, Val Accuracy: 74.00%
#
# [41/100] Train Loss: 0.5209, Val Loss: 0.5285, Val Accuracy: 78.00%
#
# [42/100] Train Loss: 0.5135, Val Loss: 0.4878, Val Accuracy: 72.00%
#
# [43/100] Train Loss: 0.4804, Val Loss: 0.5080, Val Accuracy: 79.00%
#
# [44/100] Train Loss: 0.4923, Val Loss: 0.4601, Val Accuracy: 71.00%
#
# [45/100] Train Loss: 0.4748, Val Loss: 0.5084, Val Accuracy: 84.00%
#
# [46/100] Train Loss: 0.4517, Val Loss: 0.4294, Val Accuracy: 77.00%
#
# [47/100] Train Loss: 0.4411, Val Loss: 0.4484, Val Accuracy: 86.00%
#
# [48/100] Train Loss: 0.4360, Val Loss: 0.3929, Val Accuracy: 78.00%
#
# [49/100] Train Loss: 0.4172, Val Loss: 0.4059, Val Accuracy: 87.00%
#
# [50/100] Train Loss: 0.4056, Val Loss: 0.3565, Val Accuracy: 83.00%
#
# [51/100] Train Loss: 0.3799, Val Loss: 0.3868, Val Accuracy: 87.00%
#
# [52/100] Train Loss: 0.3809, Val Loss: 0.3285, Val Accuracy: 87.00%
#
# [53/100] Train Loss: 0.3444, Val Loss: 0.3157, Val Accuracy: 87.00%
#
# [54/100] Train Loss: 0.3176, Val Loss: 0.3275, Val Accuracy: 88.00%
#
# [55/100] Train Loss: 0.3106, Val Loss: 0.3231, Val Accuracy: 87.00%
#
# [56/100] Train Loss: 0.3312, Val Loss: 0.2812, Val Accuracy: 87.00%
#
# [57/100] Train Loss: 0.3125, Val Loss: 0.2942, Val Accuracy: 85.00%
#
# [58/100] Train Loss: 0.2994, Val Loss: 0.3052, Val Accuracy: 88.00%
#
# [59/100] Train Loss: 0.2989, Val Loss: 0.2791, Val Accuracy: 86.00%
#
# [60/100] Train Loss: 0.3128, Val Loss: 0.3908, Val Accuracy: 82.00%
#
# [61/100] Train Loss: 0.2954, Val Loss: 0.2626, Val Accuracy: 88.00%
#
# [62/100] Train Loss: 0.2808, Val Loss: 0.3014, Val Accuracy: 88.00%
#
# [63/100] Train Loss: 0.2594, Val Loss: 0.2591, Val Accuracy: 88.00%
#
# [64/100] Train Loss: 0.2524, Val Loss: 0.2500, Val Accuracy: 90.00%
#
# [65/100] Train Loss: 0.2860, Val Loss: 0.2369, Val Accuracy: 87.00%
#
# [66/100] Train Loss: 0.2631, Val Loss: 0.2586, Val Accuracy: 88.00%
#
# [67/100] Train Loss: 0.2231, Val Loss: 0.2375, Val Accuracy: 87.00%
#
# [68/100] Train Loss: 0.2415, Val Loss: 0.2629, Val Accuracy: 89.00%
#
# [69/100] Train Loss: 0.2462, Val Loss: 0.2749, Val Accuracy: 85.00%
#
# [70/100] Train Loss: 0.2764, Val Loss: 0.2432, Val Accuracy: 87.00%
#
# [71/100] Train Loss: 0.2516, Val Loss: 0.2495, Val Accuracy: 86.00%
#
# [72/100] Train Loss: 0.2605, Val Loss: 0.2513, Val Accuracy: 86.00%
#
# [73/100] Train Loss: 0.2553, Val Loss: 0.2749, Val Accuracy: 88.00%
#
# [74/100] Train Loss: 0.2338, Val Loss: 0.2444, Val Accuracy: 86.00%
#
# [75/100] Train Loss: 0.2039, Val Loss: 0.2444, Val Accuracy: 86.00%
#
# [76/100] Train Loss: 0.2084, Val Loss: 0.2473, Val Accuracy: 87.00%
#
# [77/100] Train Loss: 0.2132, Val Loss: 0.2419, Val Accuracy: 88.00%
#
# [78/100] Train Loss: 0.2011, Val Loss: 0.2439, Val Accuracy: 87.00%
#
# [79/100] Train Loss: 0.1939, Val Loss: 0.4364, Val Accuracy: 83.00%
#
# [80/100] Train Loss: 0.2562, Val Loss: 0.3446, Val Accuracy: 85.00%
#
# [81/100] Train Loss: 0.2704, Val Loss: 0.3415, Val Accuracy: 85.00%
#
# [82/100] Train Loss: 0.1824, Val Loss: 0.2585, Val Accuracy: 87.00%
#
# [83/100] Train Loss: 0.1950, Val Loss: 0.2788, Val Accuracy: 84.00%
#
# [84/100] Train Loss: 0.2021, Val Loss: 0.2624, Val Accuracy: 86.00%
#
# [85/100] Train Loss: 0.1819, Val Loss: 0.2651, Val Accuracy: 87.00%
#
# [86/100] Train Loss: 0.1648, Val Loss: 0.2693, Val Accuracy: 88.00%
#
# [87/100] Train Loss: 0.1671, Val Loss: 0.2634, Val Accuracy: 85.00%
#
# [88/100] Train Loss: 0.1745, Val Loss: 0.3012, Val Accuracy: 85.00%
#
# [89/100] Train Loss: 0.1565, Val Loss: 0.2577, Val Accuracy: 88.00%
#
# [90/100] Train Loss: 0.2176, Val Loss: 0.2737, Val Accuracy: 87.00%
#
# [91/100] Train Loss: 0.1935, Val Loss: 0.2939, Val Accuracy: 85.00%
#
# [92/100] Train Loss: 0.1724, Val Loss: 0.2598, Val Accuracy: 85.00%
#
# [93/100] Train Loss: 0.1639, Val Loss: 0.2617, Val Accuracy: 87.00%
#
# [94/100] Train Loss: 0.1835, Val Loss: 0.2657, Val Accuracy: 84.00%
#
# [95/100] Train Loss: 0.1573, Val Loss: 0.2724, Val Accuracy: 83.00%
#
# [96/100] Train Loss: 0.1711, Val Loss: 0.2667, Val Accuracy: 83.00%
#
# [97/100] Train Loss: 0.1706, Val Loss: 0.2637, Val Accuracy: 84.00%
#
# [98/100] Train Loss: 0.1735, Val Loss: 0.2627, Val Accuracy: 84.00%
#
# [99/100] Train Loss: 0.1657, Val Loss: 0.2618, Val Accuracy: 84.00%
#
# [100/100] Train Loss: 0.1442, Val Loss: 0.2616, Val Accuracy: 85.00%

# %%
_, _, acc_dino_finetuned_300, auc_dino_finetuned_300 = test_(ft_network, val_loader, nn.CrossEntropyLoss())
# Out:
# Evaluation on held out test dataset
# Confusion Matrix
# +----------------+------------------+---------------------+
# |                | predicted lenses | predicted nonlenses |
# +----------------+------------------+---------------------+
# |  true lenses   |        42        |          8          |
# | true nonlenses |        7         |          43         |
# +----------------+------------------+---------------------+
# Test Metrics
# +-----------+----------+
# |  accuracy | 85.0000% |
# |    loss   |  0.1311  |
# | auc score |  0.9540  |
# +-----------+----------+
# +----------------+-----------+--------+---------+---------+
# |                | precision | recall | f-score | support |
# +----------------+-----------+--------+---------+---------+
# |     lenses     |   0.8571  | 0.8400 |  0.8485 |    50   |
# |   nonlenses    |   0.8431  | 0.8600 |  0.8515 |    50   |
# | macro averaged |   0.8501  | 0.8500 |  0.8500 |         |
# +----------------+-----------+--------+---------+---------+

# %%
_, _, acc_dino_finetuned_300, auc_dino_finetuned_300 = test_(ft_network, test_loader, nn.CrossEntropyLoss())
# Out:
# Evaluation on held out test dataset
# Confusion Matrix
# +----------------+------------------+---------------------+
# |                | predicted lenses | predicted nonlenses |
# +----------------+------------------+---------------------+
# |  true lenses   |       258        |          35         |
# | true nonlenses |        35        |         265         |
# +----------------+------------------+---------------------+
# Test Metrics
# +-----------+----------+
# |  accuracy | 88.1956% |
# |    loss   |  0.0372  |
# | auc score |  0.9382  |
# +-----------+----------+
# +----------------+-----------+--------+---------+---------+
# |                | precision | recall | f-score | support |
# +----------------+-----------+--------+---------+---------+
# |     lenses     |   0.8805  | 0.8805 |  0.8805 |   293   |
# |   nonlenses    |   0.8833  | 0.8833 |  0.8833 |   300   |
# | macro averaged |   0.8819  | 0.8819 |  0.8819 |         |
# +----------------+-----------+--------+---------+---------+

# %% [markdown]
# ### ViT Small pretrained backbone finetuned on 600 labelled datapoints

# %%
set_seed(12)
train_loader, val_loader, test_loader = get_datasets(600)
ft_network = Classifier(mode = "finetune", backbone = copy.deepcopy(state["student"].backbone))
optimizer = torch.optim.Adam(ft_network.parameters(), lr=1e-4, weight_decay=1e-8)
num_epochs = 100
scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, eta_min=1e-8, T_max=num_epochs)
ft_network, ft_network_best_loss = train(ft_network, train_loader, val_loader, nn.CrossEntropyLoss(), optimizer, num_epochs=num_epochs, scheduler=scheduler)

torch.save(ft_network, "../working/dino_vit_small/dino_finetuned_600_ckpt.pth")
fpr_dino_finetuned_600, tpr_dino_finetuned_600, auc_score_dino_finetuned_600 = compute_auc(ft_network, test_loader)
# Out:
# [1/100] Train Loss: 0.7506, Val Loss: 0.5367, Val Accuracy: 60.00%
#
# [2/100] Train Loss: 0.5153, Val Loss: 0.4799, Val Accuracy: 79.00%
#
# [3/100] Train Loss: 0.3984, Val Loss: 0.5082, Val Accuracy: 84.00%
#
# [4/100] Train Loss: 0.3290, Val Loss: 0.3967, Val Accuracy: 82.00%
#
# [5/100] Train Loss: 0.2766, Val Loss: 0.2888, Val Accuracy: 84.00%
#
# [6/100] Train Loss: 0.2440, Val Loss: 0.2942, Val Accuracy: 83.00%
#
# [7/100] Train Loss: 0.2634, Val Loss: 0.2878, Val Accuracy: 84.00%
#
# [8/100] Train Loss: 0.2359, Val Loss: 0.2716, Val Accuracy: 89.00%
#
# [9/100] Train Loss: 0.1846, Val Loss: 0.3870, Val Accuracy: 87.00%
#
# [10/100] Train Loss: 0.1995, Val Loss: 0.4671, Val Accuracy: 86.00%
#
# [11/100] Train Loss: 0.1917, Val Loss: 0.4570, Val Accuracy: 84.00%
#
# [12/100] Train Loss: 0.1681, Val Loss: 0.2892, Val Accuracy: 90.00%
#
# [13/100] Train Loss: 0.2028, Val Loss: 0.3232, Val Accuracy: 87.00%
#
# [14/100] Train Loss: 0.1687, Val Loss: 0.3659, Val Accuracy: 88.00%
#
# [15/100] Train Loss: 0.1423, Val Loss: 0.3539, Val Accuracy: 90.00%
#
# [16/100] Train Loss: 0.1201, Val Loss: 0.4740, Val Accuracy: 87.00%
#
# [17/100] Train Loss: 0.1192, Val Loss: 0.3636, Val Accuracy: 89.00%
#
# [18/100] Train Loss: 0.1444, Val Loss: 0.7073, Val Accuracy: 81.00%
#
# [19/100] Train Loss: 0.1948, Val Loss: 0.2786, Val Accuracy: 90.00%
#
# [20/100] Train Loss: 0.1286, Val Loss: 0.2805, Val Accuracy: 91.00%
#
# [21/100] Train Loss: 0.0957, Val Loss: 0.4271, Val Accuracy: 88.00%
#
# [22/100] Train Loss: 0.0784, Val Loss: 0.4774, Val Accuracy: 88.00%
#
# [23/100] Train Loss: 0.0677, Val Loss: 0.7484, Val Accuracy: 86.00%
#
# [24/100] Train Loss: 0.0687, Val Loss: 0.5971, Val Accuracy: 89.00%
#
# [25/100] Train Loss: 0.0808, Val Loss: 0.5837, Val Accuracy: 89.00%
#
# [26/100] Train Loss: 0.1867, Val Loss: 0.2834, Val Accuracy: 90.00%
#
# [27/100] Train Loss: 0.1366, Val Loss: 0.3866, Val Accuracy: 89.00%
#
# [28/100] Train Loss: 0.1157, Val Loss: 0.4228, Val Accuracy: 88.00%
#
# [29/100] Train Loss: 0.1352, Val Loss: 0.3539, Val Accuracy: 91.00%
#
# [30/100] Train Loss: 0.0796, Val Loss: 0.3410, Val Accuracy: 91.00%
#
# [31/100] Train Loss: 0.0629, Val Loss: 0.5875, Val Accuracy: 87.00%
#
# [32/100] Train Loss: 0.0400, Val Loss: 0.5314, Val Accuracy: 90.00%
#
# [33/100] Train Loss: 0.0277, Val Loss: 0.6556, Val Accuracy: 89.00%
#
# [34/100] Train Loss: 0.0167, Val Loss: 0.7462, Val Accuracy: 88.00%
#
# [35/100] Train Loss: 0.0197, Val Loss: 1.3688, Val Accuracy: 87.00%
#
# [36/100] Train Loss: 0.0240, Val Loss: 1.1517, Val Accuracy: 88.00%
#
# [37/100] Train Loss: 0.0558, Val Loss: 1.3759, Val Accuracy: 83.00%
#
# [38/100] Train Loss: 0.0637, Val Loss: 0.9854, Val Accuracy: 87.00%
#
# [39/100] Train Loss: 0.0666, Val Loss: 0.6836, Val Accuracy: 88.00%
#
# [40/100] Train Loss: 0.0291, Val Loss: 0.5045, Val Accuracy: 89.00%
#
# [41/100] Train Loss: 0.0241, Val Loss: 0.6224, Val Accuracy: 88.00%
#
# [42/100] Train Loss: 0.0182, Val Loss: 0.7519, Val Accuracy: 90.00%
#
# [43/100] Train Loss: 0.0136, Val Loss: 0.5627, Val Accuracy: 89.00%
#
# [44/100] Train Loss: 0.0191, Val Loss: 0.6872, Val Accuracy: 89.00%
#
# [45/100] Train Loss: 0.0294, Val Loss: 0.4869, Val Accuracy: 90.00%
#
# [46/100] Train Loss: 0.0230, Val Loss: 0.6996, Val Accuracy: 89.00%
#
# [47/100] Train Loss: 0.0089, Val Loss: 0.8825, Val Accuracy: 89.00%
#
# [48/100] Train Loss: 0.0064, Val Loss: 0.8682, Val Accuracy: 88.00%
#
# [49/100] Train Loss: 0.0057, Val Loss: 1.1740, Val Accuracy: 88.00%
#
# [50/100] Train Loss: 0.0027, Val Loss: 1.1867, Val Accuracy: 88.00%
#
# [51/100] Train Loss: 0.0030, Val Loss: 1.6166, Val Accuracy: 88.00%
#
# [52/100] Train Loss: 0.0045, Val Loss: 0.8385, Val Accuracy: 89.00%
#
# [53/100] Train Loss: 0.0150, Val Loss: 2.0182, Val Accuracy: 88.00%
#
# [54/100] Train Loss: 0.0087, Val Loss: 1.5804, Val Accuracy: 87.00%
#
# [55/100] Train Loss: 0.0210, Val Loss: 1.6034, Val Accuracy: 88.00%
#
# [56/100] Train Loss: 0.0195, Val Loss: 0.7749, Val Accuracy: 89.00%
#
# [57/100] Train Loss: 0.0444, Val Loss: 1.6235, Val Accuracy: 89.00%
#
# [58/100] Train Loss: 0.0051, Val Loss: 0.9752, Val Accuracy: 89.00%
#
# [59/100] Train Loss: 0.0032, Val Loss: 0.9544, Val Accuracy: 89.00%
#
# [60/100] Train Loss: 0.0032, Val Loss: 1.3050, Val Accuracy: 88.00%
#
# [61/100] Train Loss: 0.0033, Val Loss: 1.5033, Val Accuracy: 88.00%
#
# [62/100] Train Loss: 0.0029, Val Loss: 1.1914, Val Accuracy: 88.00%
#
# [63/100] Train Loss: 0.0024, Val Loss: 1.2264, Val Accuracy: 88.00%
#
# [64/100] Train Loss: 0.0016, Val Loss: 1.4266, Val Accuracy: 88.00%
#
# [65/100] Train Loss: 0.0011, Val Loss: 1.5698, Val Accuracy: 87.00%
#
# [66/100] Train Loss: 0.0046, Val Loss: 1.4640, Val Accuracy: 87.00%
#
# [67/100] Train Loss: 0.0012, Val Loss: 1.5166, Val Accuracy: 87.00%
#
# [68/100] Train Loss: 0.0048, Val Loss: 1.8119, Val Accuracy: 88.00%
#
# [69/100] Train Loss: 0.0014, Val Loss: 1.7156, Val Accuracy: 88.00%
#
# [70/100] Train Loss: 0.0018, Val Loss: 1.5461, Val Accuracy: 89.00%
#
# [71/100] Train Loss: 0.0002, Val Loss: 1.3797, Val Accuracy: 88.00%
#
# [72/100] Train Loss: 0.0013, Val Loss: 1.3499, Val Accuracy: 88.00%
#
# [73/100] Train Loss: 0.0010, Val Loss: 1.5648, Val Accuracy: 90.00%
#
# [74/100] Train Loss: 0.0052, Val Loss: 1.7446, Val Accuracy: 88.00%
#
# [75/100] Train Loss: 0.0005, Val Loss: 1.8091, Val Accuracy: 88.00%
#
# [76/100] Train Loss: 0.0009, Val Loss: 1.7267, Val Accuracy: 88.00%
#
# [77/100] Train Loss: 0.0003, Val Loss: 1.6540, Val Accuracy: 90.00%
#
# [78/100] Train Loss: 0.0004, Val Loss: 1.6271, Val Accuracy: 90.00%
#
# [79/100] Train Loss: 0.0015, Val Loss: 1.6413, Val Accuracy: 90.00%
#
# [80/100] Train Loss: 0.0005, Val Loss: 1.7018, Val Accuracy: 89.00%
#
# [81/100] Train Loss: 0.0003, Val Loss: 1.6984, Val Accuracy: 89.00%
#
# [82/100] Train Loss: 0.0013, Val Loss: 1.5332, Val Accuracy: 90.00%
#
# [83/100] Train Loss: 0.0059, Val Loss: 1.5087, Val Accuracy: 89.00%
#
# [84/100] Train Loss: 0.0027, Val Loss: 1.5533, Val Accuracy: 90.00%
#
# [85/100] Train Loss: 0.0003, Val Loss: 1.6398, Val Accuracy: 90.00%
#
# [86/100] Train Loss: 0.0003, Val Loss: 1.6612, Val Accuracy: 90.00%
#
# [87/100] Train Loss: 0.0010, Val Loss: 1.6399, Val Accuracy: 90.00%
#
# [88/100] Train Loss: 0.0005, Val Loss: 1.6262, Val Accuracy: 90.00%
#
# [89/100] Train Loss: 0.0003, Val Loss: 1.6178, Val Accuracy: 90.00%
#
# [90/100] Train Loss: 0.0002, Val Loss: 1.6126, Val Accuracy: 90.00%
#
# [91/100] Train Loss: 0.0026, Val Loss: 1.5890, Val Accuracy: 90.00%
#
# [92/100] Train Loss: 0.0055, Val Loss: 1.5843, Val Accuracy: 90.00%
#
# [93/100] Train Loss: 0.0003, Val Loss: 1.5917, Val Accuracy: 90.00%
#
# [94/100] Train Loss: 0.0002, Val Loss: 1.5928, Val Accuracy: 90.00%
#
# [95/100] Train Loss: 0.0003, Val Loss: 1.5920, Val Accuracy: 90.00%
#
# [96/100] Train Loss: 0.0025, Val Loss: 1.5966, Val Accuracy: 90.00%
#
# [97/100] Train Loss: 0.0003, Val Loss: 1.5962, Val Accuracy: 90.00%
#
# [98/100] Train Loss: 0.0003, Val Loss: 1.5960, Val Accuracy: 90.00%
#
# [99/100] Train Loss: 0.0039, Val Loss: 1.5970, Val Accuracy: 90.00%
#
# [100/100] Train Loss: 0.0004, Val Loss: 1.5971, Val Accuracy: 90.00%

# %%
_, _, acc_dino_finetuned_600, auc_dino_finetuned_600 = test_(ft_network, val_loader, nn.CrossEntropyLoss())
# Out:
# Evaluation on held out test dataset
# Confusion Matrix
# +----------------+------------------+---------------------+
# |                | predicted lenses | predicted nonlenses |
# +----------------+------------------+---------------------+
# |  true lenses   |        47        |          3          |
# | true nonlenses |        7         |          43         |
# +----------------+------------------+---------------------+
# Test Metrics
# +-----------+----------+
# |  accuracy | 90.0000% |
# |    loss   |  1.3109  |
# | auc score |  0.9328  |
# +-----------+----------+
# +----------------+-----------+--------+---------+---------+
# |                | precision | recall | f-score | support |
# +----------------+-----------+--------+---------+---------+
# |     lenses     |   0.8704  | 0.9400 |  0.9038 |    50   |
# |   nonlenses    |   0.9348  | 0.8600 |  0.8958 |    50   |
# | macro averaged |   0.9026  | 0.9000 |  0.8998 |         |
# +----------------+-----------+--------+---------+---------+

# %%
_, _, acc_dino_finetuned_600, auc_dino_finetuned_600 = test_(ft_network, test_loader, nn.CrossEntropyLoss())
# Out:
# Evaluation on held out test dataset
# Confusion Matrix
# +----------------+------------------+---------------------+
# |                | predicted lenses | predicted nonlenses |
# +----------------+------------------+---------------------+
# |  true lenses   |       262        |          31         |
# | true nonlenses |        31        |         269         |
# +----------------+------------------+---------------------+
# Test Metrics
# +-----------+----------+
# |  accuracy | 89.5447% |
# |    loss   |  0.3524  |
# | auc score |  0.9361  |
# +-----------+----------+
# +----------------+-----------+--------+---------+---------+
# |                | precision | recall | f-score | support |
# +----------------+-----------+--------+---------+---------+
# |     lenses     |   0.8942  | 0.8942 |  0.8942 |   293   |
# |   nonlenses    |   0.8967  | 0.8967 |  0.8967 |   300   |
# | macro averaged |   0.8954  | 0.8954 |  0.8954 |         |
# +----------------+-----------+--------+---------+---------+

# %% [markdown]
# ### ViT Small pretrained backbone finetuned on 1200 labelled datapoints

# %%
set_seed(12)
train_loader, val_loader, test_loader = get_datasets(1200)
ft_network = Classifier(mode = "finetune", backbone = copy.deepcopy(state["student"].backbone))
optimizer = torch.optim.Adam(ft_network.parameters(), lr=1e-4, weight_decay=1e-8)
num_epochs = 100
scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, eta_min=1e-8, T_max=num_epochs)
ft_network, ft_network_best_loss = train(ft_network, train_loader, val_loader, nn.CrossEntropyLoss(), optimizer, num_epochs=num_epochs, scheduler=scheduler)

torch.save(ft_network, "../working/dino_vit_small/dino_finetuned_1200_ckpt.pth")
fpr_dino_finetuned_1200, tpr_dino_finetuned_1200, auc_score_dino_finetuned_1200 = compute_auc(ft_network, test_loader)
# Out:
# [1/100] Train Loss: 0.6942, Val Loss: 0.5957, Val Accuracy: 73.00%
#
# [2/100] Train Loss: 0.4470, Val Loss: 0.3983, Val Accuracy: 83.00%
#
# [3/100] Train Loss: 0.3100, Val Loss: 0.2477, Val Accuracy: 90.00%
#
# [4/100] Train Loss: 0.2523, Val Loss: 0.2916, Val Accuracy: 87.00%
#
# [5/100] Train Loss: 0.2389, Val Loss: 0.1997, Val Accuracy: 91.00%
#
# [6/100] Train Loss: 0.2414, Val Loss: 0.3170, Val Accuracy: 87.00%
#
# [7/100] Train Loss: 0.2341, Val Loss: 0.1992, Val Accuracy: 90.00%
#
# [8/100] Train Loss: 0.2047, Val Loss: 0.1849, Val Accuracy: 90.00%
#
# [9/100] Train Loss: 0.2226, Val Loss: 0.2960, Val Accuracy: 86.00%
#
# [10/100] Train Loss: 0.1766, Val Loss: 0.2136, Val Accuracy: 92.00%
#
# [11/100] Train Loss: 0.1670, Val Loss: 0.1633, Val Accuracy: 94.00%
#
# [12/100] Train Loss: 0.1490, Val Loss: 0.2591, Val Accuracy: 88.00%
#
# [13/100] Train Loss: 0.1340, Val Loss: 0.2586, Val Accuracy: 88.00%
#
# [14/100] Train Loss: 0.1509, Val Loss: 0.1481, Val Accuracy: 95.00%
#
# [15/100] Train Loss: 0.1333, Val Loss: 0.2178, Val Accuracy: 87.00%
#
# [16/100] Train Loss: 0.1259, Val Loss: 0.2612, Val Accuracy: 86.00%
#
# [17/100] Train Loss: 0.1039, Val Loss: 0.1414, Val Accuracy: 93.00%
#
# [18/100] Train Loss: 0.0810, Val Loss: 0.1246, Val Accuracy: 93.00%
#
# [19/100] Train Loss: 0.0628, Val Loss: 0.3448, Val Accuracy: 87.00%
#
# [20/100] Train Loss: 0.0742, Val Loss: 0.1667, Val Accuracy: 93.00%
#
# [21/100] Train Loss: 0.1126, Val Loss: 0.3128, Val Accuracy: 91.00%
#
# [22/100] Train Loss: 0.1040, Val Loss: 0.2386, Val Accuracy: 90.00%
#
# [23/100] Train Loss: 0.0942, Val Loss: 0.1199, Val Accuracy: 95.00%
#
# [24/100] Train Loss: 0.0496, Val Loss: 0.1777, Val Accuracy: 95.00%
#
# [25/100] Train Loss: 0.0226, Val Loss: 0.2403, Val Accuracy: 95.00%
#
# [26/100] Train Loss: 0.0327, Val Loss: 0.6538, Val Accuracy: 89.00%
#
# [27/100] Train Loss: 0.1116, Val Loss: 0.3421, Val Accuracy: 91.00%
#
# [28/100] Train Loss: 0.1007, Val Loss: 0.1249, Val Accuracy: 94.00%
#
# [29/100] Train Loss: 0.0395, Val Loss: 0.1937, Val Accuracy: 93.00%
#
# [30/100] Train Loss: 0.0209, Val Loss: 0.1526, Val Accuracy: 95.00%
#
# [31/100] Train Loss: 0.0299, Val Loss: 0.2992, Val Accuracy: 92.00%
#
# [32/100] Train Loss: 0.0136, Val Loss: 0.1742, Val Accuracy: 94.00%
#
# [33/100] Train Loss: 0.0228, Val Loss: 0.2017, Val Accuracy: 95.00%
#
# [34/100] Train Loss: 0.0358, Val Loss: 0.2846, Val Accuracy: 91.00%
#
# [35/100] Train Loss: 0.0320, Val Loss: 0.3297, Val Accuracy: 91.00%
#
# [36/100] Train Loss: 0.0302, Val Loss: 0.4463, Val Accuracy: 90.00%
#
# [37/100] Train Loss: 0.0291, Val Loss: 0.2897, Val Accuracy: 93.00%
#
# [38/100] Train Loss: 0.0170, Val Loss: 0.4799, Val Accuracy: 89.00%
#
# [39/100] Train Loss: 0.0101, Val Loss: 0.5021, Val Accuracy: 91.00%
#
# [40/100] Train Loss: 0.0264, Val Loss: 0.2979, Val Accuracy: 90.00%
#
# [41/100] Train Loss: 0.0202, Val Loss: 0.4731, Val Accuracy: 90.00%
#
# [42/100] Train Loss: 0.0136, Val Loss: 0.8108, Val Accuracy: 89.00%
#
# [43/100] Train Loss: 0.0105, Val Loss: 0.4211, Val Accuracy: 92.00%
#
# [44/100] Train Loss: 0.0267, Val Loss: 0.6981, Val Accuracy: 88.00%
#
# [45/100] Train Loss: 0.0334, Val Loss: 0.5548, Val Accuracy: 94.00%
#
# [46/100] Train Loss: 0.0296, Val Loss: 0.3031, Val Accuracy: 92.00%
#
# [47/100] Train Loss: 0.0120, Val Loss: 0.3680, Val Accuracy: 92.00%
#
# [48/100] Train Loss: 0.0069, Val Loss: 0.2567, Val Accuracy: 94.00%
#
# [49/100] Train Loss: 0.0033, Val Loss: 0.1846, Val Accuracy: 96.00%
#
# [50/100] Train Loss: 0.0050, Val Loss: 0.4615, Val Accuracy: 94.00%
#
# [51/100] Train Loss: 0.0071, Val Loss: 0.1803, Val Accuracy: 92.00%
#
# [52/100] Train Loss: 0.0044, Val Loss: 0.3036, Val Accuracy: 95.00%
#
# [53/100] Train Loss: 0.0052, Val Loss: 0.3102, Val Accuracy: 94.00%
#
# [54/100] Train Loss: 0.0070, Val Loss: 0.5405, Val Accuracy: 91.00%
#
# [55/100] Train Loss: 0.0012, Val Loss: 0.3685, Val Accuracy: 93.00%
#
# [56/100] Train Loss: 0.0019, Val Loss: 0.3763, Val Accuracy: 92.00%
#
# [57/100] Train Loss: 0.0004, Val Loss: 0.3706, Val Accuracy: 95.00%
#
# [58/100] Train Loss: 0.0005, Val Loss: 0.4058, Val Accuracy: 96.00%
#
# [59/100] Train Loss: 0.0032, Val Loss: 0.4634, Val Accuracy: 94.00%
#
# [60/100] Train Loss: 0.0016, Val Loss: 0.3732, Val Accuracy: 93.00%
#
# [61/100] Train Loss: 0.0044, Val Loss: 0.7078, Val Accuracy: 91.00%
#
# [62/100] Train Loss: 0.0006, Val Loss: 0.6207, Val Accuracy: 91.00%
#
# [63/100] Train Loss: 0.0003, Val Loss: 0.4534, Val Accuracy: 94.00%
#
# [64/100] Train Loss: 0.0004, Val Loss: 0.4388, Val Accuracy: 95.00%
#
# [65/100] Train Loss: 0.0007, Val Loss: 0.4667, Val Accuracy: 93.00%
#
# [66/100] Train Loss: 0.0067, Val Loss: 0.5812, Val Accuracy: 92.00%
#
# [67/100] Train Loss: 0.0024, Val Loss: 0.2971, Val Accuracy: 96.00%
#
# [68/100] Train Loss: 0.0062, Val Loss: 0.8909, Val Accuracy: 90.00%
#
# [69/100] Train Loss: 0.0048, Val Loss: 0.2878, Val Accuracy: 93.00%
#
# [70/100] Train Loss: 0.0036, Val Loss: 0.3171, Val Accuracy: 92.00%
#
# [71/100] Train Loss: 0.0084, Val Loss: 0.8956, Val Accuracy: 89.00%
#
# [72/100] Train Loss: 0.0007, Val Loss: 0.3610, Val Accuracy: 93.00%
#
# [73/100] Train Loss: 0.0010, Val Loss: 0.4646, Val Accuracy: 92.00%
#
# [74/100] Train Loss: 0.0002, Val Loss: 0.5754, Val Accuracy: 92.00%
#
# [75/100] Train Loss: 0.0002, Val Loss: 0.5718, Val Accuracy: 92.00%
#
# [76/100] Train Loss: 0.0002, Val Loss: 0.5466, Val Accuracy: 92.00%
#
# [77/100] Train Loss: 0.0012, Val Loss: 0.5300, Val Accuracy: 92.00%
#
# [78/100] Train Loss: 0.0001, Val Loss: 0.2684, Val Accuracy: 93.00%
#
# [79/100] Train Loss: 0.0011, Val Loss: 0.2303, Val Accuracy: 93.00%
#
# [80/100] Train Loss: 0.0004, Val Loss: 0.2479, Val Accuracy: 94.00%
#
# [81/100] Train Loss: 0.0012, Val Loss: 0.3377, Val Accuracy: 93.00%
#
# [82/100] Train Loss: 0.0014, Val Loss: 0.3576, Val Accuracy: 93.00%
#
# [83/100] Train Loss: 0.0002, Val Loss: 0.3389, Val Accuracy: 94.00%
#
# [84/100] Train Loss: 0.0021, Val Loss: 0.4129, Val Accuracy: 93.00%
#
# [85/100] Train Loss: 0.0013, Val Loss: 0.5200, Val Accuracy: 91.00%
#
# [86/100] Train Loss: 0.0003, Val Loss: 0.5123, Val Accuracy: 91.00%
#
# [87/100] Train Loss: 0.0020, Val Loss: 0.5391, Val Accuracy: 91.00%
#
# [88/100] Train Loss: 0.0001, Val Loss: 0.5530, Val Accuracy: 91.00%
#
# [89/100] Train Loss: 0.0001, Val Loss: 0.5475, Val Accuracy: 91.00%
#
# [90/100] Train Loss: 0.0001, Val Loss: 0.5439, Val Accuracy: 91.00%
#
# [91/100] Train Loss: 0.0001, Val Loss: 0.5418, Val Accuracy: 91.00%
#
# [92/100] Train Loss: 0.0005, Val Loss: 0.5589, Val Accuracy: 91.00%
#
# [93/100] Train Loss: 0.0007, Val Loss: 0.5722, Val Accuracy: 90.00%
#
# [94/100] Train Loss: 0.0012, Val Loss: 0.5919, Val Accuracy: 90.00%
#
# [95/100] Train Loss: 0.0001, Val Loss: 0.5925, Val Accuracy: 90.00%
#
# [96/100] Train Loss: 0.0002, Val Loss: 0.5912, Val Accuracy: 90.00%
#
# [97/100] Train Loss: 0.0001, Val Loss: 0.5912, Val Accuracy: 90.00%
#
# [98/100] Train Loss: 0.0011, Val Loss: 0.5894, Val Accuracy: 90.00%
#
# [99/100] Train Loss: 0.0006, Val Loss: 0.5876, Val Accuracy: 90.00%
#
# [100/100] Train Loss: 0.0001, Val Loss: 0.5875, Val Accuracy: 90.00%

# %%
_, _, acc_dino_finetuned_1200, auc_dino_finetuned_1200 = test_(ft_network, val_loader, nn.CrossEntropyLoss())
# Out:
# Evaluation on held out test dataset
# Confusion Matrix
# +----------------+------------------+---------------------+
# |                | predicted lenses | predicted nonlenses |
# +----------------+------------------+---------------------+
# |  true lenses   |        48        |          2          |
# | true nonlenses |        8         |          42         |
# +----------------+------------------+---------------------+
# Test Metrics
# +-----------+----------+
# |  accuracy | 90.0000% |
# |    loss   |  0.5308  |
# | auc score |  0.9868  |
# +-----------+----------+
# +----------------+-----------+--------+---------+---------+
# |                | precision | recall | f-score | support |
# +----------------+-----------+--------+---------+---------+
# |     lenses     |   0.8571  | 0.9600 |  0.9057 |    50   |
# |   nonlenses    |   0.9545  | 0.8400 |  0.8936 |    50   |
# | macro averaged |   0.9058  | 0.9000 |  0.8996 |         |
# +----------------+-----------+--------+---------+---------+

# %%
_, _, acc_dino_finetuned_1200, auc_dino_finetuned_1200 = test_(ft_network, test_loader, nn.CrossEntropyLoss())
# Out:
# Evaluation on held out test dataset
# Confusion Matrix
# +----------------+------------------+---------------------+
# |                | predicted lenses | predicted nonlenses |
# +----------------+------------------+---------------------+
# |  true lenses   |       264        |          29         |
# | true nonlenses |        26        |         274         |
# +----------------+------------------+---------------------+
# Test Metrics
# +-----------+----------+
# |  accuracy | 90.7251% |
# |    loss   |  0.1110  |
# | auc score |  0.9657  |
# +-----------+----------+
# +----------------+-----------+--------+---------+---------+
# |                | precision | recall | f-score | support |
# +----------------+-----------+--------+---------+---------+
# |     lenses     |   0.9103  | 0.9010 |  0.9057 |   293   |
# |   nonlenses    |   0.9043  | 0.9133 |  0.9088 |   300   |
# | macro averaged |   0.9073  | 0.9072 |  0.9072 |         |
# +----------------+-----------+--------+---------+---------+

# %% [markdown]
# ### ViT Small pretrained backbone finetuned on all datapoints

# %%
set_seed(12)
train_loader, val_loader, test_loader = get_datasets(None)
ft_network = Classifier(mode = "finetune", backbone = copy.deepcopy(state["student"].backbone))
optimizer = torch.optim.Adam(ft_network.parameters(), lr=1e-4, weight_decay=1e-8)
num_epochs = 100
scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, eta_min=1e-8, T_max=num_epochs)
ft_network, ft_network_best_loss = train(ft_network, train_loader, val_loader, nn.CrossEntropyLoss(), optimizer, num_epochs=num_epochs, scheduler=scheduler)

torch.save(ft_network, "../working/dino_vit_small/dino_finetuned_all_ckpt.pth")
fpr_dino_finetuned_all, tpr_dino_finetuned_all, auc_score_dino_finetuned_all = compute_auc(ft_network, test_loader)
# Out:
# [1/100] Train Loss: 0.4268, Val Loss: 0.2434, Val Accuracy: 89.00%
#
# [2/100] Train Loss: 0.2936, Val Loss: 0.1884, Val Accuracy: 92.00%
#
# [3/100] Train Loss: 0.3620, Val Loss: 0.3113, Val Accuracy: 86.00%
#
# [4/100] Train Loss: 0.2514, Val Loss: 0.2249, Val Accuracy: 91.00%
#
# [5/100] Train Loss: 0.2265, Val Loss: 0.2019, Val Accuracy: 92.00%
#
# [6/100] Train Loss: 0.2245, Val Loss: 0.1786, Val Accuracy: 92.00%
#
# [7/100] Train Loss: 0.2049, Val Loss: 0.1758, Val Accuracy: 93.00%
#
# [8/100] Train Loss: 0.1870, Val Loss: 0.1839, Val Accuracy: 93.00%
#
# [9/100] Train Loss: 0.1843, Val Loss: 0.1429, Val Accuracy: 93.00%
#
# [10/100] Train Loss: 0.2106, Val Loss: 0.3256, Val Accuracy: 85.00%
#
# [11/100] Train Loss: 0.2329, Val Loss: 0.2107, Val Accuracy: 93.00%
#
# [12/100] Train Loss: 0.2396, Val Loss: 0.2301, Val Accuracy: 89.00%
#
# [13/100] Train Loss: 0.2188, Val Loss: 0.1906, Val Accuracy: 91.00%
#
# [14/100] Train Loss: 0.1837, Val Loss: 0.1634, Val Accuracy: 93.00%
#
# [15/100] Train Loss: 0.1858, Val Loss: 0.1925, Val Accuracy: 95.00%
#
# [16/100] Train Loss: 0.3475, Val Loss: 0.8165, Val Accuracy: 51.00%
#
# [17/100] Train Loss: 0.3627, Val Loss: 0.2694, Val Accuracy: 85.00%
#
# [18/100] Train Loss: 0.2531, Val Loss: 0.2761, Val Accuracy: 89.00%
#
# [19/100] Train Loss: 0.3140, Val Loss: 0.2604, Val Accuracy: 88.00%
#
# [20/100] Train Loss: 0.2642, Val Loss: 0.2411, Val Accuracy: 88.00%
#
# [21/100] Train Loss: 0.2592, Val Loss: 0.2167, Val Accuracy: 90.00%
#
# [22/100] Train Loss: 0.2288, Val Loss: 0.2231, Val Accuracy: 89.00%
#
# [23/100] Train Loss: 0.2072, Val Loss: 0.2349, Val Accuracy: 89.00%
#
# [24/100] Train Loss: 0.2008, Val Loss: 0.2053, Val Accuracy: 88.00%
#
# [25/100] Train Loss: 0.1964, Val Loss: 0.2113, Val Accuracy: 90.00%
#
# [26/100] Train Loss: 0.1891, Val Loss: 0.1936, Val Accuracy: 89.00%
#
# [27/100] Train Loss: 0.1821, Val Loss: 0.1810, Val Accuracy: 90.00%
#
# [28/100] Train Loss: 0.1777, Val Loss: 0.1755, Val Accuracy: 90.00%
#
# [29/100] Train Loss: 0.1631, Val Loss: 0.1986, Val Accuracy: 92.00%
#
# [30/100] Train Loss: 0.1651, Val Loss: 0.1569, Val Accuracy: 91.00%
#
# [31/100] Train Loss: 0.1617, Val Loss: 0.1459, Val Accuracy: 91.00%
#
# [32/100] Train Loss: 0.1514, Val Loss: 0.1493, Val Accuracy: 94.00%
#
# [33/100] Train Loss: 0.1519, Val Loss: 0.1679, Val Accuracy: 92.00%
#
# [34/100] Train Loss: 0.1356, Val Loss: 0.2597, Val Accuracy: 89.00%
#
# [35/100] Train Loss: 0.1225, Val Loss: 0.2568, Val Accuracy: 92.00%
#
# [36/100] Train Loss: 0.1358, Val Loss: 0.1279, Val Accuracy: 95.00%
#
# [37/100] Train Loss: 0.1197, Val Loss: 0.1945, Val Accuracy: 93.00%
#
# [38/100] Train Loss: 0.1154, Val Loss: 0.1873, Val Accuracy: 94.00%
#
# [39/100] Train Loss: 0.1004, Val Loss: 0.1322, Val Accuracy: 94.00%
#
# [40/100] Train Loss: 0.0932, Val Loss: 0.1065, Val Accuracy: 94.00%
#
# [41/100] Train Loss: 0.1035, Val Loss: 0.2799, Val Accuracy: 92.00%
#
# [42/100] Train Loss: 0.1131, Val Loss: 0.1239, Val Accuracy: 95.00%
#
# [43/100] Train Loss: 0.1030, Val Loss: 0.1482, Val Accuracy: 94.00%
#
# [44/100] Train Loss: 0.1949, Val Loss: 0.1933, Val Accuracy: 93.00%
#
# [45/100] Train Loss: 0.1713, Val Loss: 0.1659, Val Accuracy: 92.00%
#
# [46/100] Train Loss: 0.1562, Val Loss: 0.2727, Val Accuracy: 89.00%
#
# [47/100] Train Loss: 0.3178, Val Loss: 0.3500, Val Accuracy: 83.00%
#
# [48/100] Train Loss: 0.3129, Val Loss: 0.2255, Val Accuracy: 89.00%
#
# [49/100] Train Loss: 0.2029, Val Loss: 0.2051, Val Accuracy: 93.00%
#
# [50/100] Train Loss: 0.1812, Val Loss: 0.1699, Val Accuracy: 96.00%
#
# [51/100] Train Loss: 0.1545, Val Loss: 0.2378, Val Accuracy: 90.00%
#
# [52/100] Train Loss: 0.1301, Val Loss: 0.1776, Val Accuracy: 94.00%
#
# [53/100] Train Loss: 0.1367, Val Loss: 0.1760, Val Accuracy: 92.00%
#
# [54/100] Train Loss: 0.1186, Val Loss: 0.1441, Val Accuracy: 93.00%
#
# [55/100] Train Loss: 0.1171, Val Loss: 0.1404, Val Accuracy: 93.00%
#
# [56/100] Train Loss: 0.0992, Val Loss: 0.1746, Val Accuracy: 93.00%
#
# [57/100] Train Loss: 0.1108, Val Loss: 0.1640, Val Accuracy: 93.00%
#
# [58/100] Train Loss: 0.0982, Val Loss: 0.1272, Val Accuracy: 95.00%
#
# [59/100] Train Loss: 0.0907, Val Loss: 0.1645, Val Accuracy: 93.00%
#
# [60/100] Train Loss: 0.0847, Val Loss: 0.1294, Val Accuracy: 94.00%
#
# [61/100] Train Loss: 0.0774, Val Loss: 0.1288, Val Accuracy: 93.00%
#
# [62/100] Train Loss: 0.0747, Val Loss: 0.1250, Val Accuracy: 93.00%
#
# [63/100] Train Loss: 0.0732, Val Loss: 0.1022, Val Accuracy: 97.00%
#
# [64/100] Train Loss: 0.0677, Val Loss: 0.1186, Val Accuracy: 96.00%
#
# [65/100] Train Loss: 0.0598, Val Loss: 0.0970, Val Accuracy: 96.00%
#
# [66/100] Train Loss: 0.0654, Val Loss: 0.1621, Val Accuracy: 93.00%
#
# [67/100] Train Loss: 0.0625, Val Loss: 0.1614, Val Accuracy: 93.00%
#
# [68/100] Train Loss: 0.0764, Val Loss: 0.1226, Val Accuracy: 93.00%
#
# [69/100] Train Loss: 0.0518, Val Loss: 0.2100, Val Accuracy: 95.00%
#
# [70/100] Train Loss: 0.0516, Val Loss: 0.1850, Val Accuracy: 94.00%
#
# [71/100] Train Loss: 0.0463, Val Loss: 0.1046, Val Accuracy: 96.00%
#
# [72/100] Train Loss: 0.0519, Val Loss: 0.1299, Val Accuracy: 96.00%
#
# [73/100] Train Loss: 0.0338, Val Loss: 0.1165, Val Accuracy: 97.00%
#
# [74/100] Train Loss: 0.0446, Val Loss: 0.0929, Val Accuracy: 98.00%
#
# [75/100] Train Loss: 0.0439, Val Loss: 0.1844, Val Accuracy: 95.00%
#
# [76/100] Train Loss: 0.0399, Val Loss: 0.2139, Val Accuracy: 94.00%
#
# [77/100] Train Loss: 0.0443, Val Loss: 0.2014, Val Accuracy: 97.00%
#
# [78/100] Train Loss: 0.0321, Val Loss: 0.1132, Val Accuracy: 96.00%
#
# [79/100] Train Loss: 0.0370, Val Loss: 0.1713, Val Accuracy: 97.00%
#
# [80/100] Train Loss: 0.0270, Val Loss: 0.1322, Val Accuracy: 96.00%
#
# [81/100] Train Loss: 0.0370, Val Loss: 0.1041, Val Accuracy: 96.00%
#
# [82/100] Train Loss: 0.0320, Val Loss: 0.1672, Val Accuracy: 96.00%
#
# [83/100] Train Loss: 0.0316, Val Loss: 0.1197, Val Accuracy: 97.00%
#
# [84/100] Train Loss: 0.0363, Val Loss: 0.1522, Val Accuracy: 96.00%
#
# [85/100] Train Loss: 0.0249, Val Loss: 0.1903, Val Accuracy: 97.00%
#
# [86/100] Train Loss: 0.0259, Val Loss: 0.1670, Val Accuracy: 96.00%
#
# [87/100] Train Loss: 0.0270, Val Loss: 0.1651, Val Accuracy: 96.00%
#
# [88/100] Train Loss: 0.0290, Val Loss: 0.1931, Val Accuracy: 96.00%
#
# [89/100] Train Loss: 0.0281, Val Loss: 0.2353, Val Accuracy: 96.00%
#
# [90/100] Train Loss: 0.0284, Val Loss: 0.2285, Val Accuracy: 96.00%
#
# [91/100] Train Loss: 0.0243, Val Loss: 0.1299, Val Accuracy: 96.00%
#
# [92/100] Train Loss: 0.0262, Val Loss: 0.1731, Val Accuracy: 96.00%
#
# [93/100] Train Loss: 0.0304, Val Loss: 0.1710, Val Accuracy: 96.00%
#
# [94/100] Train Loss: 0.0214, Val Loss: 0.1754, Val Accuracy: 96.00%
#
# [95/100] Train Loss: 0.0205, Val Loss: 0.1795, Val Accuracy: 96.00%
#
# [96/100] Train Loss: 0.0187, Val Loss: 0.1647, Val Accuracy: 96.00%
#
# [97/100] Train Loss: 0.0207, Val Loss: 0.1704, Val Accuracy: 96.00%
#
# [98/100] Train Loss: 0.0243, Val Loss: 0.1648, Val Accuracy: 96.00%
#
# [99/100] Train Loss: 0.0216, Val Loss: 0.1670, Val Accuracy: 96.00%
#
# [100/100] Train Loss: 0.0207, Val Loss: 0.1675, Val Accuracy: 96.00%

# %%
_, _, acc_dino_finetuned_all, auc_dino_finetuned_all = test_(ft_network, val_loader, nn.CrossEntropyLoss())
# Out:
# Evaluation on held out test dataset
# Confusion Matrix
# +----------------+------------------+---------------------+
# |                | predicted lenses | predicted nonlenses |
# +----------------+------------------+---------------------+
# |  true lenses   |        48        |          2          |
# | true nonlenses |        2         |          48         |
# +----------------+------------------+---------------------+
# Test Metrics
# +-----------+----------+
# |  accuracy | 96.0000% |
# |    loss   |  0.1063  |
# | auc score |  0.9916  |
# +-----------+----------+
# +----------------+-----------+--------+---------+---------+
# |                | precision | recall | f-score | support |
# +----------------+-----------+--------+---------+---------+
# |     lenses     |   0.9600  | 0.9600 |  0.9600 |    50   |
# |   nonlenses    |   0.9600  | 0.9600 |  0.9600 |    50   |
# | macro averaged |   0.9600  | 0.9600 |  0.9600 |         |
# +----------------+-----------+--------+---------+---------+

# %%
_, _, acc_dino_finetuned_all, auc_dino_finetuned_all = test_(ft_network, test_loader, nn.CrossEntropyLoss())
# Out:
# Evaluation on held out test dataset
# Confusion Matrix
# +----------------+------------------+---------------------+
# |                | predicted lenses | predicted nonlenses |
# +----------------+------------------+---------------------+
# |  true lenses   |       262        |          31         |
# | true nonlenses |        14        |         286         |
# +----------------+------------------+---------------------+
# Test Metrics
# +-----------+----------+
# |  accuracy | 92.4115% |
# |    loss   |  0.0017  |
# | auc score |  0.9806  |
# +-----------+----------+
# +----------------+-----------+--------+---------+---------+
# |                | precision | recall | f-score | support |
# +----------------+-----------+--------+---------+---------+
# |     lenses     |   0.9493  | 0.8942 |  0.9209 |   293   |
# |   nonlenses    |   0.9022  | 0.9533 |  0.9271 |   300   |
# | macro averaged |   0.9257  | 0.9238 |  0.9240 |         |
# +----------------+-----------+--------+---------+---------+

# %% [markdown]
# ### ROC Curves for the SSL model finetuning are plotted below

# %%
plt.figure(figsize=(15, 15))
plt.title('ROC')
plt.plot(fpr_dino_finetuned_300, tpr_dino_finetuned_300, 'r', label = 'AUC (finetuned on 300 labelled data, DINO pretrained) = %0.4f' % auc_dino_finetuned_300)
plt.plot(fpr_dino_finetuned_600, tpr_dino_finetuned_600, 'm', label = 'AUC (finetuned on 600 labelled data, DINO pretrained) = %0.4f' % auc_dino_finetuned_600)
plt.plot(fpr_dino_finetuned_1200, tpr_dino_finetuned_1200, 'g', label = 'AUC (finetuned on 1200 labelled data, DINO pretrained) = %0.4f' % auc_dino_finetuned_1200)
plt.plot(fpr_dino_finetuned_all, tpr_dino_finetuned_all, 'b', label = 'AUC (finetuned on all labelled data, DINO pretrained) = %0.4f' % auc_dino_finetuned_all)

plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.savefig("auc_ssl_dino.png")
plt.show()

# %% [markdown]
# ### ROC Curves for the SSL and supervised models are plotted below

# %%
plt.figure(figsize=(15, 15))
plt.title('ROC')
plt.plot(fpr_dino_finetuned_300, tpr_dino_finetuned_300, 'r', label = 'AUC (finetuned on 300 labelled data, DINO pretrained) = %0.4f' % auc_dino_finetuned_300)
plt.plot(fpr_dino_finetuned_600, tpr_dino_finetuned_600, 'm', label = 'AUC (finetuned on 600 labelled data, DINO pretrained) = %0.4f' % auc_dino_finetuned_600)
plt.plot(fpr_dino_finetuned_1200, tpr_dino_finetuned_1200, 'g', label = 'AUC (finetuned on 1200 labelled data, DINO pretrained) = %0.4f' % auc_dino_finetuned_1200)
plt.plot(fpr_dino_finetuned_all, tpr_dino_finetuned_all, 'b', label = 'AUC (finetuned on all labelled data, DINO pretrained) = %0.4f' % auc_dino_finetuned_all)

plt.plot(fpr_supervised_300, tpr_supervised_300, 'r:', label = 'AUC (trained on 300 labelled data, supervised) = %0.4f' % auc_score_300)
plt.plot(fpr_supervised_600, tpr_supervised_600, 'm:', label = 'AUC (trained on 600 labelled data, supervised) = %0.4f' % auc_score_600)
plt.plot(fpr_supervised_1200, tpr_supervised_1200, 'g:', label = 'AUC (trained on 1200 labelled data, supervised) = %0.4f' % auc_score_1200)
plt.plot(fpr_supervised_all, tpr_supervised_all, 'b:', label = 'AUC (trained on all labelled data, supervised) = %0.4f' % auc_score_all)

plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.savefig("auc_supervised_ssl_dino.png")
plt.show()

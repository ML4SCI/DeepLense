# %% [markdown]
# ## Simsiam Pretrained ViT Small Backbone

# %% [markdown]
# ---

# %% [markdown]
# For classifying lenses from non-lenses, self-supervised learning (SSL), particularly with the transformer backbones could potentially outperform traditional supervised methods with abundant unlabelled dataset. The learned representations are then evaluated on the downstream task to classify lens and non-lens images. <br>
# The train dataset contains 2333 lens images and 1530 non-lens images. The validation dataset contains 259 lens images and 170 non-lens images. The test dataset contains 458 lens images and 300 non-lens images. Each image has 3 channels, g, r and i, corresponding to green, red and infrared filters respectively. The images are center cropped to 32 × 32 pixel as this empirically resulted in better downstream prediction accuracy. <br>
# To understand how well SSL works with different fractions of labelled and unlabelled data, the model is pre-trained through self supervision on the entire train data and then finetuned on the labelled fraction of the train data and compared with supervised baseline trained only on that labeled fraction. This simulates the real world scenario where only a fraction of dataset may have associated labels. <br>
# The following table summarizes the results on the held out test dataset.

# %% [markdown]
# | # labelled data for <br> training/fine-tuning | Training | Accuracy | AUC |
# |:---:|:----------:|:----------:|:----------:|
# |300|Supervised | 89.7098% | 0.9547 |
# ||Simsiam | 89.8417% | 0.9540 |
# |600|Supervised | 92.2164% | 0.9445 |
# ||Simsiam | 92.2164% | 0.9691 |
# |1200|Supervised | 93.1398% | 0.9780 |
# ||Simsiam | 94.9868% | 0.9843 |
# |3863 |Supervised | 94.9868% | 0.9861 |
# ||Simsiam | 95.1187% | 0.9864 |

# %% [markdown]
# ROC Curves for the SSL and supervised models are plotted below

# %% [markdown]
# ![](../assets/auc_supervised_simsiam_ssl_vit_small.png)

# %% [markdown]
# ---

# %%
import sys
sys.path.append("/kaggle/input/deeplense-git/DeepLense_SSL_from_real_dataset_Sreehari_Iyer")
sys.path.append("/kaggle/input/deeplense-git/DeepLense_SSL_from_real_dataset_Sreehari_Iyer/selfsupervised")
# !pip install GPUtil
# Out:
# Collecting GPUtil
#   Downloading GPUtil-1.4.0.tar.gz (5.5 kB)
# done
# Building wheels for collected packages: GPUtil
# done
#   Created wheel for GPUtil: filename=GPUtil-1.4.0-py3-none-any.whl size=7394 sha256=a779a3ff2b551bc79f5ea28a3896572a6e782d0109992dc43c9dd6923911082e
#   Stored in directory: /root/.cache/pip/wheels/a9/8a/bd/81082387151853ab8b6b3ef33426e98f5cbfebc3c397a9d4d0
# Successfully built GPUtil
# Installing collected packages: GPUtil
# Successfully installed GPUtil-1.4.0

# %%
import numpy as np
import os
import torch
import torch.nn as nn
import torchvision.transforms as Transforms
from torch.utils.data import random_split, DataLoader, Dataset
from sklearn import metrics
import copy
import pickle
from utils import set_seed
from utils.eval import train
from models.backbone import Backbone
from augmentations.loader import npy_loader
from augmentations import ImageDataset
from models.classifier import Classifier
from utils.eval import test_
import matplotlib.pyplot as plt
set_seed(12)

# %%
def get_datasets(num_labelled_points):
    set_seed(12)

    eval_transforms = Transforms.Compose([
                    # Transforms.ToTensor(), # npy loader returns torch.Tensor
                    Transforms.CenterCrop(32),
                    Transforms.Normalize(mean = [0.19948305189609528, 0.6667526960372925, 1.2940289974212646],\
                                     std = [0.2700458765029907, 0.9860594868659973, 2.1648175716400146]),
                ])

    #--------------------------------------------------------------------------------------------------------

    train_test_indices = "/kaggle/input/reallenses-traintestindices/indices.pkl"
    data_path = "/kaggle/input/reallensdataset/real_lenses_dataset"
    
    train_indices_path = None
    indices = None
    with open(train_test_indices, "rb") as f:
        indices = pickle.load(f)
    train_indices = None
    
    if num_labelled_points == 300:
        train_indices_path = "/kaggle/input/reallenses-traintestindices/train_indices_300.pkl"
        with open(train_indices_path, "rb") as f:
            train_indices = pickle.load(f)
    elif num_labelled_points == 600:
        train_indices_path = "/kaggle/input/reallenses-traintestindices/train_indices_600.pkl"
        with open(train_indices_path, "rb") as f:
            train_indices = pickle.load(f)
    elif num_labelled_points == 1200:
        train_indices_path = "/kaggle/input/reallenses-traintestindices/train_indices_1200.pkl"
        with open(train_indices_path, "rb") as f:
            train_indices = pickle.load(f)
    elif num_labelled_points is None:
        train_indices_path = "/kaggle/input/reallenses-traintestindices/indices.pkl"
        with open(train_indices_path, "rb") as f:
            train_indices = pickle.load(f)
        train_indices = train_indices["train"]

    # train images and labels
    train_paths = [os.path.join(data_path, *["lenses", img]) for img in np.array(train_indices["lenses"])] +\
                    [os.path.join(data_path, *["nonlenses", img]) for img in np.array(train_indices["nonlenses"])]
    train_labels = [0]*len(train_indices["lenses"]) + [1]*len(train_indices["nonlenses"])

    # validation images and labels
    val_paths = [os.path.join(data_path, *["lenses", img]) for img in np.array(indices["val"]["lenses"])] +\
                    [os.path.join(data_path, *["nonlenses", img]) for img in np.array(indices["val"]["nonlenses"])]
    val_labels = [0]*len(indices["val"]["lenses"]) + [1]*len(indices["val"]["nonlenses"])

    # test images and labels
    test_paths = [os.path.join(data_path, *["lenses", img]) for img in np.array(indices["test"]["lenses"])] +\
                    [os.path.join(data_path, *["nonlenses", img]) for img in np.array(indices["test"]["nonlenses"])]
    test_labels = [0]*len(indices["test"]["lenses"]) + [1]*len(indices["test"]["nonlenses"])

    # sizes of the train, validation and test datasets
    train_size = len(train_paths)
    val_size = len(val_paths)
    test_size = len(test_paths)
    #--------------------------------------------------------------------------------------------------------

    dataset = ImageDataset(
        image_paths=train_paths+val_paths+test_paths,
        labels=train_labels+val_labels+test_labels,
        loader=npy_loader,
        transform=eval_transforms
    )
    train_dataset = ImageDataset(
        image_paths=train_paths,
        labels=train_labels,
        loader=npy_loader,
        transform=eval_transforms
    ) 
    val_dataset = ImageDataset(
        image_paths=val_paths,
        labels=val_labels,
        loader=npy_loader,
        transform=eval_transforms
    )
    test_dataset = ImageDataset(
        image_paths=test_paths,
        labels=test_labels,
        loader=npy_loader,
        transform=eval_transforms
    )
    data_loader = DataLoader(
        dataset,
        batch_size=64,
        num_workers=0,
        shuffle=False,
    )
    train_loader = DataLoader(
        train_dataset,
        batch_size=64,
        num_workers=0,
        shuffle=True,
    )
    val_loader = DataLoader(
        val_dataset,
        batch_size=64,
        num_workers=0,
        shuffle=False,
    )
    test_loader = DataLoader(
        test_dataset,
        batch_size=64,
        num_workers=0,
        shuffle=False,
    )
    return train_loader, val_loader, test_loader

def compute_auc(ft_network, test_loader):
    y = None
    scores = None
    ft_network.eval()
    ft_network = ft_network.cuda()
    for img, label in test_loader:
        img, label = img.cuda(), label.cuda()
        preds = ft_network(img)
        if y is None:
            y = label.detach().cpu().numpy()
        else:
            y = np.concatenate([y, label.detach().cpu().numpy()], axis=0)
        if scores is None:
            scores = preds.detach().cpu().numpy()
        else:
            scores = np.vstack((scores, preds.detach().cpu().numpy()))
    fpr, tpr, _ = metrics.roc_curve(y, scores[:,1])
    auc_score = metrics.auc(fpr, tpr)
    return fpr, tpr, auc_score

# %% [markdown]
# ### ViT Small Classifier trained on 300 labelled datapoints through supervised learning

# %%
set_seed(12)
train_loader, val_loader, test_loader = get_datasets(300)
ft_network = Classifier(mode = "finetune", backbone = Backbone(arch="vit_small", image_size=32, input_channels=3, patch_size=8))
optimizer = torch.optim.Adam(ft_network.parameters(), lr=1e-4, weight_decay=1e-5)
num_epochs = 100
scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, eta_min=1e-8, T_max=num_epochs)
ft_network, ft_network_best_loss = train(ft_network, train_loader, val_loader, nn.CrossEntropyLoss(), optimizer, num_epochs=num_epochs, scheduler=scheduler)

torch.save(ft_network, "/kaggle/working/supervised_300_ckpt.pth")

fpr_supervised_300, tpr_supervised_300, auc_score_300 = compute_auc(ft_network, test_loader)
# Out:
# [1/100] Train Loss: 4.6106, Val Loss: 2.8412, Val Accuracy: 60.37%
#
# [2/100] Train Loss: 2.2302, Val Loss: 1.0176, Val Accuracy: 57.11%
#
# [3/100] Train Loss: 1.1907, Val Loss: 0.9279, Val Accuracy: 55.48%
#
# [4/100] Train Loss: 0.7267, Val Loss: 0.7603, Val Accuracy: 60.37%
#
# [5/100] Train Loss: 0.7707, Val Loss: 0.5548, Val Accuracy: 69.46%
#
# [6/100] Train Loss: 0.6653, Val Loss: 0.7246, Val Accuracy: 56.64%
#
# [7/100] Train Loss: 0.6466, Val Loss: 0.5443, Val Accuracy: 78.32%
#
# [8/100] Train Loss: 0.6219, Val Loss: 0.5483, Val Accuracy: 62.24%
#
# [9/100] Train Loss: 0.5837, Val Loss: 0.5702, Val Accuracy: 62.94%
#
# [10/100] Train Loss: 0.5818, Val Loss: 0.5255, Val Accuracy: 67.60%
#
# [11/100] Train Loss: 0.5545, Val Loss: 0.5095, Val Accuracy: 79.25%
#
# [12/100] Train Loss: 0.5365, Val Loss: 0.5012, Val Accuracy: 70.16%
#
# [13/100] Train Loss: 0.5360, Val Loss: 0.4862, Val Accuracy: 71.33%
#
# [14/100] Train Loss: 0.5104, Val Loss: 0.4635, Val Accuracy: 79.25%
#
# [15/100] Train Loss: 0.5061, Val Loss: 0.4441, Val Accuracy: 81.12%
#
# [16/100] Train Loss: 0.4855, Val Loss: 0.4232, Val Accuracy: 82.28%
#
# [17/100] Train Loss: 0.4676, Val Loss: 0.4012, Val Accuracy: 84.15%
#
# [18/100] Train Loss: 0.4552, Val Loss: 0.3785, Val Accuracy: 87.41%
#
# [19/100] Train Loss: 0.4289, Val Loss: 0.3571, Val Accuracy: 86.48%
#
# [20/100] Train Loss: 0.4235, Val Loss: 0.3442, Val Accuracy: 87.41%
#
# [21/100] Train Loss: 0.3950, Val Loss: 0.3309, Val Accuracy: 87.88%
#
# [22/100] Train Loss: 0.4009, Val Loss: 0.3253, Val Accuracy: 88.11%
#
# [23/100] Train Loss: 0.4097, Val Loss: 0.3241, Val Accuracy: 87.65%
#
# [24/100] Train Loss: 0.3806, Val Loss: 0.3130, Val Accuracy: 87.65%
#
# [25/100] Train Loss: 0.3737, Val Loss: 0.3029, Val Accuracy: 87.41%
#
# [26/100] Train Loss: 0.3930, Val Loss: 0.3035, Val Accuracy: 87.65%
#
# [27/100] Train Loss: 0.3555, Val Loss: 0.2887, Val Accuracy: 87.41%
#
# [28/100] Train Loss: 0.3596, Val Loss: 0.2846, Val Accuracy: 87.65%
#
# [29/100] Train Loss: 0.3543, Val Loss: 0.2916, Val Accuracy: 87.88%
#
# [30/100] Train Loss: 0.3418, Val Loss: 0.2896, Val Accuracy: 87.65%
#
# [31/100] Train Loss: 0.3277, Val Loss: 0.2771, Val Accuracy: 88.81%
#
# [32/100] Train Loss: 0.3214, Val Loss: 0.2764, Val Accuracy: 88.58%
#
# [33/100] Train Loss: 0.3149, Val Loss: 0.2806, Val Accuracy: 88.34%
#
# [34/100] Train Loss: 0.3081, Val Loss: 0.2908, Val Accuracy: 88.34%
#
# [35/100] Train Loss: 0.2996, Val Loss: 0.2758, Val Accuracy: 89.28%
#
# [36/100] Train Loss: 0.3346, Val Loss: 0.2749, Val Accuracy: 89.51%
#
# [37/100] Train Loss: 0.3287, Val Loss: 0.2727, Val Accuracy: 89.04%
#
# [38/100] Train Loss: 0.3138, Val Loss: 0.2754, Val Accuracy: 88.81%
#
# [39/100] Train Loss: 0.2975, Val Loss: 0.2898, Val Accuracy: 89.04%
#
# [40/100] Train Loss: 0.2828, Val Loss: 0.2853, Val Accuracy: 89.04%
#
# [41/100] Train Loss: 0.2639, Val Loss: 0.3123, Val Accuracy: 88.58%
#
# [42/100] Train Loss: 0.2480, Val Loss: 0.3087, Val Accuracy: 88.11%
#
# [43/100] Train Loss: 0.2725, Val Loss: 0.3033, Val Accuracy: 88.81%
#
# [44/100] Train Loss: 0.2970, Val Loss: 0.2886, Val Accuracy: 88.34%
#
# [45/100] Train Loss: 0.2464, Val Loss: 0.2917, Val Accuracy: 89.28%
#
# [46/100] Train Loss: 0.2293, Val Loss: 0.2788, Val Accuracy: 88.34%
#
# [47/100] Train Loss: 0.2254, Val Loss: 0.3037, Val Accuracy: 89.04%
#
# [48/100] Train Loss: 0.2281, Val Loss: 0.3065, Val Accuracy: 89.04%
#
# [49/100] Train Loss: 0.1766, Val Loss: 0.3261, Val Accuracy: 88.81%
#
# [50/100] Train Loss: 0.1877, Val Loss: 0.3508, Val Accuracy: 89.74%
#
# [51/100] Train Loss: 0.1825, Val Loss: 0.3515, Val Accuracy: 89.04%
#
# [52/100] Train Loss: 0.2102, Val Loss: 0.3476, Val Accuracy: 89.51%
#
# [53/100] Train Loss: 0.1885, Val Loss: 0.3493, Val Accuracy: 89.28%
#
# [54/100] Train Loss: 0.2032, Val Loss: 0.3657, Val Accuracy: 88.81%
#
# [55/100] Train Loss: 0.2109, Val Loss: 0.3046, Val Accuracy: 88.58%
#
# [56/100] Train Loss: 0.2086, Val Loss: 0.3496, Val Accuracy: 88.11%
#
# [57/100] Train Loss: 0.2271, Val Loss: 0.3095, Val Accuracy: 88.34%
#
# [58/100] Train Loss: 0.1666, Val Loss: 0.3123, Val Accuracy: 89.28%
#
# [59/100] Train Loss: 0.1648, Val Loss: 0.3413, Val Accuracy: 88.58%
#
# [60/100] Train Loss: 0.1568, Val Loss: 0.3839, Val Accuracy: 89.74%
#
# [61/100] Train Loss: 0.2207, Val Loss: 0.3403, Val Accuracy: 89.74%
#
# [62/100] Train Loss: 0.1685, Val Loss: 0.3351, Val Accuracy: 88.58%
#
# [63/100] Train Loss: 0.1467, Val Loss: 0.3256, Val Accuracy: 89.04%
#
# [64/100] Train Loss: 0.1723, Val Loss: 0.3257, Val Accuracy: 88.81%
#
# [65/100] Train Loss: 0.1618, Val Loss: 0.3365, Val Accuracy: 88.34%
#
# [66/100] Train Loss: 0.1631, Val Loss: 0.3465, Val Accuracy: 88.58%
#
# [67/100] Train Loss: 0.1329, Val Loss: 0.3318, Val Accuracy: 89.28%
#
# [68/100] Train Loss: 0.1854, Val Loss: 0.3311, Val Accuracy: 88.81%
#
# [69/100] Train Loss: 0.1310, Val Loss: 0.3371, Val Accuracy: 89.04%
#
# [70/100] Train Loss: 0.1101, Val Loss: 0.3361, Val Accuracy: 89.04%
#
# [71/100] Train Loss: 0.1267, Val Loss: 0.3397, Val Accuracy: 89.28%
#
# [72/100] Train Loss: 0.1073, Val Loss: 0.3531, Val Accuracy: 88.34%
#
# [73/100] Train Loss: 0.1022, Val Loss: 0.3549, Val Accuracy: 89.74%
#
# [74/100] Train Loss: 0.1039, Val Loss: 0.3635, Val Accuracy: 89.51%
#
# [75/100] Train Loss: 0.1360, Val Loss: 0.3696, Val Accuracy: 89.04%
#
# [76/100] Train Loss: 0.1116, Val Loss: 0.3715, Val Accuracy: 89.51%
#
# [77/100] Train Loss: 0.1110, Val Loss: 0.3629, Val Accuracy: 88.81%
#
# [78/100] Train Loss: 0.0912, Val Loss: 0.3666, Val Accuracy: 88.81%
#
# [79/100] Train Loss: 0.1343, Val Loss: 0.3668, Val Accuracy: 88.58%
#
# [80/100] Train Loss: 0.1165, Val Loss: 0.3673, Val Accuracy: 88.58%
#
# [81/100] Train Loss: 0.1089, Val Loss: 0.3655, Val Accuracy: 88.11%
#
# [82/100] Train Loss: 0.1006, Val Loss: 0.3646, Val Accuracy: 88.11%
#
# [83/100] Train Loss: 0.0936, Val Loss: 0.3645, Val Accuracy: 88.81%
#
# [84/100] Train Loss: 0.1018, Val Loss: 0.3679, Val Accuracy: 89.28%
#
# [85/100] Train Loss: 0.1166, Val Loss: 0.3712, Val Accuracy: 88.58%
#
# [86/100] Train Loss: 0.1138, Val Loss: 0.3719, Val Accuracy: 89.04%
#
# [87/100] Train Loss: 0.0942, Val Loss: 0.3721, Val Accuracy: 88.81%
#
# [88/100] Train Loss: 0.1118, Val Loss: 0.3752, Val Accuracy: 89.04%
#
# [89/100] Train Loss: 0.0974, Val Loss: 0.3781, Val Accuracy: 89.28%
#
# [90/100] Train Loss: 0.0902, Val Loss: 0.3785, Val Accuracy: 89.04%
#
# [91/100] Train Loss: 0.0768, Val Loss: 0.3786, Val Accuracy: 88.58%
#
# [92/100] Train Loss: 0.0930, Val Loss: 0.3788, Val Accuracy: 88.34%
#
# [93/100] Train Loss: 0.0849, Val Loss: 0.3795, Val Accuracy: 88.81%
#
# [94/100] Train Loss: 0.0880, Val Loss: 0.3800, Val Accuracy: 89.04%
#
# [95/100] Train Loss: 0.0911, Val Loss: 0.3806, Val Accuracy: 88.58%
#
# [96/100] Train Loss: 0.0638, Val Loss: 0.3809, Val Accuracy: 88.81%
#
# [97/100] Train Loss: 0.0996, Val Loss: 0.3813, Val Accuracy: 88.81%
#
# [98/100] Train Loss: 0.0925, Val Loss: 0.3814, Val Accuracy: 88.81%
#
# [99/100] Train Loss: 0.0781, Val Loss: 0.3815, Val Accuracy: 88.81%
#
# [100/100] Train Loss: 0.0846, Val Loss: 0.3815, Val Accuracy: 88.81%

# %%
_, _, acc_supervised_300_val, auc_supervised_300_val = test_(ft_network, val_loader, nn.CrossEntropyLoss())
# Out:
# Evaluation on held out test dataset
# Confusion Matrix
# +----------------+------------------+---------------------+
# |                | predicted lenses | predicted nonlenses |
# +----------------+------------------+---------------------+
# |  true lenses   |       235        |          24         |
# | true nonlenses |        24        |         146         |
# +----------------+------------------+---------------------+
# Test Metrics
# +-----------+----------+
# |  accuracy | 88.8112% |
# |    loss   |  0.0676  |
# | auc score |  0.9504  |
# +-----------+----------+
# +----------------+-----------+--------+---------+---------+
# |                | precision | recall | f-score | support |
# +----------------+-----------+--------+---------+---------+
# |     lenses     |   0.9073  | 0.9073 |  0.9073 |   259   |
# |   nonlenses    |   0.8588  | 0.8588 |  0.8588 |   170   |
# | macro averaged |   0.8831  | 0.8831 |  0.8831 |         |
# +----------------+-----------+--------+---------+---------+

# %%
_, _, acc_supervised_300_test, auc_supervised_300_test = test_(ft_network, test_loader, nn.CrossEntropyLoss())
# Out:
# Evaluation on held out test dataset
# Confusion Matrix
# +----------------+------------------+---------------------+
# |                | predicted lenses | predicted nonlenses |
# +----------------+------------------+---------------------+
# |  true lenses   |       412        |          46         |
# | true nonlenses |        32        |         268         |
# +----------------+------------------+---------------------+
# Test Metrics
# +-----------+----------+
# |  accuracy | 89.7098% |
# |    loss   |  0.0302  |
# | auc score |  0.9547  |
# +-----------+----------+
# +----------------+-----------+--------+---------+---------+
# |                | precision | recall | f-score | support |
# +----------------+-----------+--------+---------+---------+
# |     lenses     |   0.9279  | 0.8996 |  0.9135 |   458   |
# |   nonlenses    |   0.8535  | 0.8933 |  0.8730 |   300   |
# | macro averaged |   0.8907  | 0.8964 |  0.8932 |         |
# +----------------+-----------+--------+---------+---------+

# %% [markdown]
# ### ViT Small Classifier trained on 600 labelled datapoints through supervised learning

# %%
set_seed(12)
train_loader, val_loader, test_loader = get_datasets(600)
ft_network = Classifier(mode = "finetune", backbone = Backbone(arch="vit_small", image_size=32, input_channels=3, patch_size=8))
optimizer = torch.optim.Adam(ft_network.parameters(), lr=1e-4, weight_decay=1e-3)
num_epochs = 100
scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, eta_min=1e-8, T_max=num_epochs)
ft_network, ft_network_best_loss = train(ft_network, train_loader, val_loader, nn.CrossEntropyLoss(), optimizer, num_epochs=num_epochs, scheduler=scheduler)

torch.save(ft_network, "/kaggle/working/supervised_600_ckpt.pth")
fpr_supervised_600, tpr_supervised_600, auc_score_600 = compute_auc(ft_network, test_loader)
# Out:
# [1/100] Train Loss: 2.8194, Val Loss: 1.1126, Val Accuracy: 55.01%
#
# [2/100] Train Loss: 0.7521, Val Loss: 0.5458, Val Accuracy: 69.23%
#
# [3/100] Train Loss: 0.5807, Val Loss: 0.5201, Val Accuracy: 77.39%
#
# [4/100] Train Loss: 0.5636, Val Loss: 0.4894, Val Accuracy: 71.56%
#
# [5/100] Train Loss: 0.5190, Val Loss: 0.4724, Val Accuracy: 71.33%
#
# [6/100] Train Loss: 0.4946, Val Loss: 0.3841, Val Accuracy: 85.08%
#
# [7/100] Train Loss: 0.4404, Val Loss: 0.3452, Val Accuracy: 88.11%
#
# [8/100] Train Loss: 0.4014, Val Loss: 0.3613, Val Accuracy: 87.18%
#
# [9/100] Train Loss: 0.3458, Val Loss: 0.3148, Val Accuracy: 86.48%
#
# [10/100] Train Loss: 0.3200, Val Loss: 0.3340, Val Accuracy: 85.78%
#
# [11/100] Train Loss: 0.3374, Val Loss: 0.3279, Val Accuracy: 86.48%
#
# [12/100] Train Loss: 0.3083, Val Loss: 0.3006, Val Accuracy: 88.34%
#
# [13/100] Train Loss: 0.3046, Val Loss: 0.3256, Val Accuracy: 89.28%
#
# [14/100] Train Loss: 0.3089, Val Loss: 0.3079, Val Accuracy: 89.28%
#
# [15/100] Train Loss: 0.2868, Val Loss: 0.3645, Val Accuracy: 87.18%
#
# [16/100] Train Loss: 0.2530, Val Loss: 0.2965, Val Accuracy: 88.11%
#
# [17/100] Train Loss: 0.2386, Val Loss: 0.2899, Val Accuracy: 88.34%
#
# [18/100] Train Loss: 0.2120, Val Loss: 0.2944, Val Accuracy: 89.51%
#
# [19/100] Train Loss: 0.2182, Val Loss: 0.3661, Val Accuracy: 88.11%
#
# [20/100] Train Loss: 0.2454, Val Loss: 0.3006, Val Accuracy: 89.51%
#
# [21/100] Train Loss: 0.2215, Val Loss: 0.3518, Val Accuracy: 89.28%
#
# [22/100] Train Loss: 0.2956, Val Loss: 0.3146, Val Accuracy: 89.74%
#
# [23/100] Train Loss: 0.2208, Val Loss: 0.3041, Val Accuracy: 88.34%
#
# [24/100] Train Loss: 0.1820, Val Loss: 0.2997, Val Accuracy: 90.91%
#
# [25/100] Train Loss: 0.1526, Val Loss: 0.2816, Val Accuracy: 90.44%
#
# [26/100] Train Loss: 0.1576, Val Loss: 0.3273, Val Accuracy: 89.51%
#
# [27/100] Train Loss: 0.1469, Val Loss: 0.3359, Val Accuracy: 90.21%
#
# [28/100] Train Loss: 0.1725, Val Loss: 0.3505, Val Accuracy: 89.04%
#
# [29/100] Train Loss: 0.1616, Val Loss: 0.2868, Val Accuracy: 90.44%
#
# [30/100] Train Loss: 0.1206, Val Loss: 0.3590, Val Accuracy: 90.21%
#
# [31/100] Train Loss: 0.1111, Val Loss: 0.3283, Val Accuracy: 89.51%
#
# [32/100] Train Loss: 0.1400, Val Loss: 0.3387, Val Accuracy: 90.68%
#
# [33/100] Train Loss: 0.1211, Val Loss: 0.2792, Val Accuracy: 91.14%
#
# [34/100] Train Loss: 0.1147, Val Loss: 0.3526, Val Accuracy: 89.98%
#
# [35/100] Train Loss: 0.1374, Val Loss: 0.3138, Val Accuracy: 91.61%
#
# [36/100] Train Loss: 0.1117, Val Loss: 0.3391, Val Accuracy: 91.14%
#
# [37/100] Train Loss: 0.0873, Val Loss: 0.3340, Val Accuracy: 91.14%
#
# [38/100] Train Loss: 0.0844, Val Loss: 0.2966, Val Accuracy: 92.07%
#
# [39/100] Train Loss: 0.0900, Val Loss: 0.4078, Val Accuracy: 91.61%
#
# [40/100] Train Loss: 0.0710, Val Loss: 0.4480, Val Accuracy: 91.38%
#
# [41/100] Train Loss: 0.0760, Val Loss: 0.5994, Val Accuracy: 90.21%
#
# [42/100] Train Loss: 0.1029, Val Loss: 0.3359, Val Accuracy: 92.07%
#
# [43/100] Train Loss: 0.0970, Val Loss: 0.3719, Val Accuracy: 90.68%
#
# [44/100] Train Loss: 0.0741, Val Loss: 0.4449, Val Accuracy: 89.98%
#
# [45/100] Train Loss: 0.2153, Val Loss: 0.4586, Val Accuracy: 87.18%
#
# [46/100] Train Loss: 0.1511, Val Loss: 0.2797, Val Accuracy: 91.84%
#
# [47/100] Train Loss: 0.1253, Val Loss: 0.3497, Val Accuracy: 91.38%
#
# [48/100] Train Loss: 0.0897, Val Loss: 0.3856, Val Accuracy: 90.44%
#
# [49/100] Train Loss: 0.0756, Val Loss: 0.3944, Val Accuracy: 90.91%
#
# [50/100] Train Loss: 0.0713, Val Loss: 0.4301, Val Accuracy: 92.07%
#
# [51/100] Train Loss: 0.1001, Val Loss: 0.4044, Val Accuracy: 91.38%
#
# [52/100] Train Loss: 0.0857, Val Loss: 0.3494, Val Accuracy: 91.84%
#
# [53/100] Train Loss: 0.1049, Val Loss: 0.4866, Val Accuracy: 89.98%
#
# [54/100] Train Loss: 0.0910, Val Loss: 0.3906, Val Accuracy: 90.91%
#
# [55/100] Train Loss: 0.0606, Val Loss: 0.3783, Val Accuracy: 92.31%
#
# [56/100] Train Loss: 0.0551, Val Loss: 0.4373, Val Accuracy: 91.38%
#
# [57/100] Train Loss: 0.0540, Val Loss: 0.4642, Val Accuracy: 91.84%
#
# [58/100] Train Loss: 0.0468, Val Loss: 0.4544, Val Accuracy: 92.07%
#
# [59/100] Train Loss: 0.0536, Val Loss: 0.4973, Val Accuracy: 91.84%
#
# [60/100] Train Loss: 0.0422, Val Loss: 0.5131, Val Accuracy: 92.07%
#
# [61/100] Train Loss: 0.0341, Val Loss: 0.5564, Val Accuracy: 92.07%
#
# [62/100] Train Loss: 0.0384, Val Loss: 0.4948, Val Accuracy: 92.54%
#
# [63/100] Train Loss: 0.0473, Val Loss: 0.5414, Val Accuracy: 92.31%
#
# [64/100] Train Loss: 0.0428, Val Loss: 0.5064, Val Accuracy: 91.84%
#
# [65/100] Train Loss: 0.0525, Val Loss: 0.4257, Val Accuracy: 92.54%
#
# [66/100] Train Loss: 0.0590, Val Loss: 0.4821, Val Accuracy: 91.14%
#
# [67/100] Train Loss: 0.0373, Val Loss: 0.5136, Val Accuracy: 91.14%
#
# [68/100] Train Loss: 0.0295, Val Loss: 0.5149, Val Accuracy: 90.91%
#
# [69/100] Train Loss: 0.0386, Val Loss: 0.4948, Val Accuracy: 91.38%
#
# [70/100] Train Loss: 0.0411, Val Loss: 0.4902, Val Accuracy: 92.54%
#
# [71/100] Train Loss: 0.0394, Val Loss: 0.4580, Val Accuracy: 92.77%
#
# [72/100] Train Loss: 0.0535, Val Loss: 0.5191, Val Accuracy: 91.38%
#
# [73/100] Train Loss: 0.0266, Val Loss: 0.5454, Val Accuracy: 91.84%
#
# [74/100] Train Loss: 0.0343, Val Loss: 0.5374, Val Accuracy: 91.84%
#
# [75/100] Train Loss: 0.0370, Val Loss: 0.5118, Val Accuracy: 92.31%
#
# [76/100] Train Loss: 0.0293, Val Loss: 0.4855, Val Accuracy: 92.54%
#
# [77/100] Train Loss: 0.0379, Val Loss: 0.5042, Val Accuracy: 92.77%
#
# [78/100] Train Loss: 0.0306, Val Loss: 0.5353, Val Accuracy: 93.01%
#
# [79/100] Train Loss: 0.0379, Val Loss: 0.5029, Val Accuracy: 92.07%
#
# [80/100] Train Loss: 0.0397, Val Loss: 0.4969, Val Accuracy: 91.84%
#
# [81/100] Train Loss: 0.0338, Val Loss: 0.4885, Val Accuracy: 92.77%
#
# [82/100] Train Loss: 0.0308, Val Loss: 0.4813, Val Accuracy: 92.77%
#
# [83/100] Train Loss: 0.0271, Val Loss: 0.4933, Val Accuracy: 92.54%
#
# [84/100] Train Loss: 0.0213, Val Loss: 0.5056, Val Accuracy: 92.07%
#
# [85/100] Train Loss: 0.0406, Val Loss: 0.5094, Val Accuracy: 92.07%
#
# [86/100] Train Loss: 0.0323, Val Loss: 0.5159, Val Accuracy: 91.61%
#
# [87/100] Train Loss: 0.0210, Val Loss: 0.5178, Val Accuracy: 91.84%
#
# [88/100] Train Loss: 0.0176, Val Loss: 0.5215, Val Accuracy: 91.84%
#
# [89/100] Train Loss: 0.0271, Val Loss: 0.5274, Val Accuracy: 92.07%
#
# [90/100] Train Loss: 0.0196, Val Loss: 0.5320, Val Accuracy: 92.31%
#
# [91/100] Train Loss: 0.0242, Val Loss: 0.5377, Val Accuracy: 92.31%
#
# [92/100] Train Loss: 0.0228, Val Loss: 0.5351, Val Accuracy: 92.31%
#
# [93/100] Train Loss: 0.0231, Val Loss: 0.5332, Val Accuracy: 92.54%
#
# [94/100] Train Loss: 0.0310, Val Loss: 0.5322, Val Accuracy: 92.54%
#
# [95/100] Train Loss: 0.0238, Val Loss: 0.5271, Val Accuracy: 92.77%
#
# [96/100] Train Loss: 0.0281, Val Loss: 0.5280, Val Accuracy: 92.77%
#
# [97/100] Train Loss: 0.0263, Val Loss: 0.5291, Val Accuracy: 92.77%
#
# [98/100] Train Loss: 0.0259, Val Loss: 0.5293, Val Accuracy: 92.77%
#
# [99/100] Train Loss: 0.0222, Val Loss: 0.5295, Val Accuracy: 92.77%
#
# [100/100] Train Loss: 0.0265, Val Loss: 0.5295, Val Accuracy: 92.77%

# %%
_, _, acc_supervised_600_val, auc_supervised_600_val = test_(ft_network, val_loader, nn.CrossEntropyLoss())
# Out:
# Evaluation on held out test dataset
# Confusion Matrix
# +----------------+------------------+---------------------+
# |                | predicted lenses | predicted nonlenses |
# +----------------+------------------+---------------------+
# |  true lenses   |       242        |          17         |
# | true nonlenses |        14        |         156         |
# +----------------+------------------+---------------------+
# Test Metrics
# +-----------+----------+
# |  accuracy | 92.7739% |
# |    loss   |  0.0996  |
# | auc score |  0.9497  |
# +-----------+----------+
# +----------------+-----------+--------+---------+---------+
# |                | precision | recall | f-score | support |
# +----------------+-----------+--------+---------+---------+
# |     lenses     |   0.9453  | 0.9344 |  0.9398 |   259   |
# |   nonlenses    |   0.9017  | 0.9176 |  0.9096 |   170   |
# | macro averaged |   0.9235  | 0.9260 |  0.9247 |         |
# +----------------+-----------+--------+---------+---------+

# %%
_, _, acc_supervised_600_test, auc_supervised_600_test = test_(ft_network, test_loader, nn.CrossEntropyLoss())
# Out:
# Evaluation on held out test dataset
# Confusion Matrix
# +----------------+------------------+---------------------+
# |                | predicted lenses | predicted nonlenses |
# +----------------+------------------+---------------------+
# |  true lenses   |       424        |          34         |
# | true nonlenses |        25        |         275         |
# +----------------+------------------+---------------------+
# Test Metrics
# +-----------+----------+
# |  accuracy | 92.2164% |
# |    loss   |  0.0634  |
# | auc score |  0.9445  |
# +-----------+----------+
# +----------------+-----------+--------+---------+---------+
# |                | precision | recall | f-score | support |
# +----------------+-----------+--------+---------+---------+
# |     lenses     |   0.9443  | 0.9258 |  0.9350 |   458   |
# |   nonlenses    |   0.8900  | 0.9167 |  0.9031 |   300   |
# | macro averaged |   0.9171  | 0.9212 |  0.9190 |         |
# +----------------+-----------+--------+---------+---------+

# %% [markdown]
# ### ViT Small Classifier trained on 1200 labelled datapoints through supervised learning

# %%
set_seed(12)
train_loader, val_loader, test_loader = get_datasets(1200)
ft_network = Classifier(mode = "finetune", backbone = Backbone(arch="vit_small", image_size=32, input_channels=3, patch_size=8))
optimizer = torch.optim.Adam(ft_network.parameters(), lr=1e-4, weight_decay=1e-3)
num_epochs = 100
scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, eta_min=1e-8, T_max=num_epochs)
ft_network, ft_network_best_loss = train(ft_network, train_loader, val_loader, nn.CrossEntropyLoss(), optimizer, num_epochs=num_epochs, scheduler=scheduler)

torch.save(ft_network, "/kaggle/working/supervised_1200_ckpt.pth")
fpr_supervised_1200, tpr_supervised_1200, auc_score_1200 = compute_auc(ft_network, test_loader)
# Out:
# [1/100] Train Loss: 1.8651, Val Loss: 0.7149, Val Accuracy: 60.37%
#
# [2/100] Train Loss: 0.6199, Val Loss: 0.5262, Val Accuracy: 66.43%
#
# [3/100] Train Loss: 0.5347, Val Loss: 0.4509, Val Accuracy: 85.08%
#
# [4/100] Train Loss: 0.4633, Val Loss: 0.3575, Val Accuracy: 86.25%
#
# [5/100] Train Loss: 0.3916, Val Loss: 0.3190, Val Accuracy: 87.65%
#
# [6/100] Train Loss: 0.3755, Val Loss: 0.3118, Val Accuracy: 86.01%
#
# [7/100] Train Loss: 0.3674, Val Loss: 0.2915, Val Accuracy: 87.65%
#
# [8/100] Train Loss: 0.3413, Val Loss: 0.2944, Val Accuracy: 88.34%
#
# [9/100] Train Loss: 0.2976, Val Loss: 0.2754, Val Accuracy: 89.04%
#
# [10/100] Train Loss: 0.2930, Val Loss: 0.2773, Val Accuracy: 88.11%
#
# [11/100] Train Loss: 0.2744, Val Loss: 0.2640, Val Accuracy: 89.28%
#
# [12/100] Train Loss: 0.2471, Val Loss: 0.2790, Val Accuracy: 88.81%
#
# [13/100] Train Loss: 0.2461, Val Loss: 0.2821, Val Accuracy: 88.58%
#
# [14/100] Train Loss: 0.2494, Val Loss: 0.4170, Val Accuracy: 85.08%
#
# [15/100] Train Loss: 0.2565, Val Loss: 0.2398, Val Accuracy: 91.14%
#
# [16/100] Train Loss: 0.2219, Val Loss: 0.2505, Val Accuracy: 91.61%
#
# [17/100] Train Loss: 0.1915, Val Loss: 0.2523, Val Accuracy: 89.28%
#
# [18/100] Train Loss: 0.1907, Val Loss: 0.2342, Val Accuracy: 90.91%
#
# [19/100] Train Loss: 0.1623, Val Loss: 0.2528, Val Accuracy: 90.21%
#
# [20/100] Train Loss: 0.1671, Val Loss: 0.2743, Val Accuracy: 91.14%
#
# [21/100] Train Loss: 0.1785, Val Loss: 0.2958, Val Accuracy: 89.74%
#
# [22/100] Train Loss: 0.1892, Val Loss: 0.2665, Val Accuracy: 90.91%
#
# [23/100] Train Loss: 0.1905, Val Loss: 0.2473, Val Accuracy: 91.61%
#
# [24/100] Train Loss: 0.1444, Val Loss: 0.2741, Val Accuracy: 91.61%
#
# [25/100] Train Loss: 0.1671, Val Loss: 0.2389, Val Accuracy: 90.68%
#
# [26/100] Train Loss: 0.1379, Val Loss: 0.2763, Val Accuracy: 91.61%
#
# [27/100] Train Loss: 0.1323, Val Loss: 0.2641, Val Accuracy: 89.74%
#
# [28/100] Train Loss: 0.1401, Val Loss: 0.2936, Val Accuracy: 91.38%
#
# [29/100] Train Loss: 0.1476, Val Loss: 0.3204, Val Accuracy: 89.98%
#
# [30/100] Train Loss: 0.1427, Val Loss: 0.2231, Val Accuracy: 92.07%
#
# [31/100] Train Loss: 0.1411, Val Loss: 0.2553, Val Accuracy: 91.14%
#
# [32/100] Train Loss: 0.1165, Val Loss: 0.2967, Val Accuracy: 90.44%
#
# [33/100] Train Loss: 0.1042, Val Loss: 0.2675, Val Accuracy: 92.07%
#
# [34/100] Train Loss: 0.1019, Val Loss: 0.2414, Val Accuracy: 92.54%
#
# [35/100] Train Loss: 0.0780, Val Loss: 0.2637, Val Accuracy: 92.54%
#
# [36/100] Train Loss: 0.0827, Val Loss: 0.2667, Val Accuracy: 92.07%
#
# [37/100] Train Loss: 0.0991, Val Loss: 0.2634, Val Accuracy: 92.77%
#
# [38/100] Train Loss: 0.1030, Val Loss: 0.2891, Val Accuracy: 92.07%
#
# [39/100] Train Loss: 0.0930, Val Loss: 0.3677, Val Accuracy: 91.61%
#
# [40/100] Train Loss: 0.0862, Val Loss: 0.2504, Val Accuracy: 92.31%
#
# [41/100] Train Loss: 0.0867, Val Loss: 0.2760, Val Accuracy: 93.47%
#
# [42/100] Train Loss: 0.0724, Val Loss: 0.2869, Val Accuracy: 92.77%
#
# [43/100] Train Loss: 0.0477, Val Loss: 0.4064, Val Accuracy: 92.07%
#
# [44/100] Train Loss: 0.0753, Val Loss: 0.3785, Val Accuracy: 91.61%
#
# [45/100] Train Loss: 0.0828, Val Loss: 0.2875, Val Accuracy: 93.01%
#
# [46/100] Train Loss: 0.0563, Val Loss: 0.3494, Val Accuracy: 92.77%
#
# [47/100] Train Loss: 0.0574, Val Loss: 0.2758, Val Accuracy: 92.07%
#
# [48/100] Train Loss: 0.0811, Val Loss: 0.3393, Val Accuracy: 93.01%
#
# [49/100] Train Loss: 0.0603, Val Loss: 0.3787, Val Accuracy: 90.21%
#
# [50/100] Train Loss: 0.0369, Val Loss: 0.4285, Val Accuracy: 92.31%
#
# [51/100] Train Loss: 0.0457, Val Loss: 0.3376, Val Accuracy: 92.54%
#
# [52/100] Train Loss: 0.0537, Val Loss: 0.4643, Val Accuracy: 90.68%
#
# [53/100] Train Loss: 0.0746, Val Loss: 0.3636, Val Accuracy: 93.24%
#
# [54/100] Train Loss: 0.0585, Val Loss: 0.3635, Val Accuracy: 92.77%
#
# [55/100] Train Loss: 0.0349, Val Loss: 0.3740, Val Accuracy: 92.77%
#
# [56/100] Train Loss: 0.0352, Val Loss: 0.4974, Val Accuracy: 92.31%
#
# [57/100] Train Loss: 0.0413, Val Loss: 0.3636, Val Accuracy: 93.24%
#
# [58/100] Train Loss: 0.0308, Val Loss: 0.4437, Val Accuracy: 93.01%
#
# [59/100] Train Loss: 0.0294, Val Loss: 0.3752, Val Accuracy: 92.77%
#
# [60/100] Train Loss: 0.0330, Val Loss: 0.3727, Val Accuracy: 92.54%
#
# [61/100] Train Loss: 0.0383, Val Loss: 0.3256, Val Accuracy: 93.24%
#
# [62/100] Train Loss: 0.0386, Val Loss: 0.3345, Val Accuracy: 93.47%
#
# [63/100] Train Loss: 0.0157, Val Loss: 0.4137, Val Accuracy: 92.07%
#
# [64/100] Train Loss: 0.0360, Val Loss: 0.3708, Val Accuracy: 92.31%
#
# [65/100] Train Loss: 0.0303, Val Loss: 0.4226, Val Accuracy: 93.24%
#
# [66/100] Train Loss: 0.0119, Val Loss: 0.4230, Val Accuracy: 92.77%
#
# [67/100] Train Loss: 0.0267, Val Loss: 0.3658, Val Accuracy: 93.01%
#
# [68/100] Train Loss: 0.0237, Val Loss: 0.4493, Val Accuracy: 92.54%
#
# [69/100] Train Loss: 0.0228, Val Loss: 0.3864, Val Accuracy: 93.24%
#
# [70/100] Train Loss: 0.0237, Val Loss: 0.4147, Val Accuracy: 93.24%
#
# [71/100] Train Loss: 0.0177, Val Loss: 0.3702, Val Accuracy: 93.94%
#
# [72/100] Train Loss: 0.0139, Val Loss: 0.3910, Val Accuracy: 93.47%
#
# [73/100] Train Loss: 0.0147, Val Loss: 0.3920, Val Accuracy: 93.71%
#
# [74/100] Train Loss: 0.0099, Val Loss: 0.3878, Val Accuracy: 93.71%
#
# [75/100] Train Loss: 0.0159, Val Loss: 0.4185, Val Accuracy: 93.01%
#
# [76/100] Train Loss: 0.0100, Val Loss: 0.3884, Val Accuracy: 93.71%
#
# [77/100] Train Loss: 0.0207, Val Loss: 0.4538, Val Accuracy: 93.24%
#
# [78/100] Train Loss: 0.0108, Val Loss: 0.4459, Val Accuracy: 93.24%
#
# [79/100] Train Loss: 0.0079, Val Loss: 0.4497, Val Accuracy: 93.71%
#
# [80/100] Train Loss: 0.0092, Val Loss: 0.4502, Val Accuracy: 93.71%
#
# [81/100] Train Loss: 0.0128, Val Loss: 0.4852, Val Accuracy: 93.24%
#
# [82/100] Train Loss: 0.0132, Val Loss: 0.4747, Val Accuracy: 93.71%
#
# [83/100] Train Loss: 0.0125, Val Loss: 0.4552, Val Accuracy: 93.24%
#
# [84/100] Train Loss: 0.0166, Val Loss: 0.4676, Val Accuracy: 93.47%
#
# [85/100] Train Loss: 0.0089, Val Loss: 0.5087, Val Accuracy: 93.01%
#
# [86/100] Train Loss: 0.0130, Val Loss: 0.4739, Val Accuracy: 93.71%
#
# [87/100] Train Loss: 0.0037, Val Loss: 0.4668, Val Accuracy: 93.71%
#
# [88/100] Train Loss: 0.0060, Val Loss: 0.4572, Val Accuracy: 93.47%
#
# [89/100] Train Loss: 0.0072, Val Loss: 0.4845, Val Accuracy: 93.71%
#
# [90/100] Train Loss: 0.0067, Val Loss: 0.4850, Val Accuracy: 93.71%
#
# [91/100] Train Loss: 0.0064, Val Loss: 0.4863, Val Accuracy: 93.71%
#
# [92/100] Train Loss: 0.0086, Val Loss: 0.4881, Val Accuracy: 93.71%
#
# [93/100] Train Loss: 0.0083, Val Loss: 0.4921, Val Accuracy: 93.71%
#
# [94/100] Train Loss: 0.0064, Val Loss: 0.4881, Val Accuracy: 93.71%
#
# [95/100] Train Loss: 0.0090, Val Loss: 0.4876, Val Accuracy: 93.71%
#
# [96/100] Train Loss: 0.0057, Val Loss: 0.4883, Val Accuracy: 93.71%
#
# [97/100] Train Loss: 0.0064, Val Loss: 0.4892, Val Accuracy: 93.71%
#
# [98/100] Train Loss: 0.0064, Val Loss: 0.4890, Val Accuracy: 93.71%
#
# [99/100] Train Loss: 0.0068, Val Loss: 0.4892, Val Accuracy: 93.71%
#
# [100/100] Train Loss: 0.0062, Val Loss: 0.4892, Val Accuracy: 93.71%

# %%
_, _, acc_supervised_1200_val, auc_supervised_1200_val = test_(ft_network, val_loader, nn.CrossEntropyLoss())
# Out:
# Evaluation on held out test dataset
# Confusion Matrix
# +----------------+------------------+---------------------+
# |                | predicted lenses | predicted nonlenses |
# +----------------+------------------+---------------------+
# |  true lenses   |       250        |          9          |
# | true nonlenses |        18        |         152         |
# +----------------+------------------+---------------------+
# Test Metrics
# +-----------+----------+
# |  accuracy | 93.7063% |
# |    loss   |  0.1369  |
# | auc score |  0.9762  |
# +-----------+----------+
# +----------------+-----------+--------+---------+---------+
# |                | precision | recall | f-score | support |
# +----------------+-----------+--------+---------+---------+
# |     lenses     |   0.9328  | 0.9653 |  0.9488 |   259   |
# |   nonlenses    |   0.9441  | 0.8941 |  0.9184 |   170   |
# | macro averaged |   0.9385  | 0.9297 |  0.9336 |         |
# +----------------+-----------+--------+---------+---------+

# %%
_, _, acc_supervised_1200_test, auc_supervised_1200_test = test_(ft_network, test_loader, nn.CrossEntropyLoss())
# Out:
# Evaluation on held out test dataset
# Confusion Matrix
# +----------------+------------------+---------------------+
# |                | predicted lenses | predicted nonlenses |
# +----------------+------------------+---------------------+
# |  true lenses   |       428        |          30         |
# | true nonlenses |        22        |         278         |
# +----------------+------------------+---------------------+
# Test Metrics
# +-----------+----------+
# |  accuracy | 93.1398% |
# |    loss   |  0.0335  |
# | auc score |  0.9780  |
# +-----------+----------+
# +----------------+-----------+--------+---------+---------+
# |                | precision | recall | f-score | support |
# +----------------+-----------+--------+---------+---------+
# |     lenses     |   0.9511  | 0.9345 |  0.9427 |   458   |
# |   nonlenses    |   0.9026  | 0.9267 |  0.9145 |   300   |
# | macro averaged |   0.9269  | 0.9306 |  0.9286 |         |
# +----------------+-----------+--------+---------+---------+

# %% [markdown]
# ### ViT Small Classifier trained on all labelled datapoints through supervised learning

# %%
set_seed(12)
train_loader, val_loader, test_loader = get_datasets(None)
ft_network = Classifier(mode = "finetune", backbone = Backbone(arch="vit_small", image_size=32, input_channels=3, patch_size=8))
optimizer = torch.optim.Adam(ft_network.parameters(), lr=1e-4, weight_decay=1e-8)
num_epochs = 100
scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, eta_min=1e-8, T_max=num_epochs)
ft_network, ft_network_best_loss = train(ft_network, train_loader, val_loader, nn.CrossEntropyLoss(), optimizer, num_epochs=num_epochs, scheduler=scheduler)

torch.save(ft_network, "/kaggle/working/supervised_all_ckpt.pth")
fpr_supervised_all, tpr_supervised_all, auc_score_all = compute_auc(ft_network, test_loader)
# Out:
# [1/100] Train Loss: 0.9361, Val Loss: 0.3746, Val Accuracy: 86.48%
#
# [2/100] Train Loss: 0.3511, Val Loss: 0.3079, Val Accuracy: 87.65%
#
# [3/100] Train Loss: 0.3067, Val Loss: 0.2474, Val Accuracy: 89.74%
#
# [4/100] Train Loss: 0.2789, Val Loss: 0.2365, Val Accuracy: 90.44%
#
# [5/100] Train Loss: 0.2437, Val Loss: 0.2294, Val Accuracy: 90.91%
#
# [6/100] Train Loss: 0.2293, Val Loss: 0.2937, Val Accuracy: 89.28%
#
# [7/100] Train Loss: 0.2212, Val Loss: 0.2055, Val Accuracy: 90.91%
#
# [8/100] Train Loss: 0.2014, Val Loss: 0.2256, Val Accuracy: 91.14%
#
# [9/100] Train Loss: 0.1827, Val Loss: 0.1777, Val Accuracy: 93.47%
#
# [10/100] Train Loss: 0.1744, Val Loss: 0.1920, Val Accuracy: 92.07%
#
# [11/100] Train Loss: 0.1600, Val Loss: 0.4441, Val Accuracy: 89.04%
#
# [12/100] Train Loss: 0.1736, Val Loss: 0.1638, Val Accuracy: 93.71%
#
# [13/100] Train Loss: 0.1426, Val Loss: 0.1798, Val Accuracy: 93.01%
#
# [14/100] Train Loss: 0.1589, Val Loss: 0.1544, Val Accuracy: 94.17%
#
# [15/100] Train Loss: 0.1241, Val Loss: 0.1708, Val Accuracy: 93.94%
#
# [16/100] Train Loss: 0.1188, Val Loss: 0.1809, Val Accuracy: 93.94%
#
# [17/100] Train Loss: 0.1092, Val Loss: 0.1488, Val Accuracy: 94.64%
#
# [18/100] Train Loss: 0.1340, Val Loss: 0.1680, Val Accuracy: 93.94%
#
# [19/100] Train Loss: 0.1126, Val Loss: 0.1859, Val Accuracy: 93.94%
#
# [20/100] Train Loss: 0.1117, Val Loss: 0.2015, Val Accuracy: 93.24%
#
# [21/100] Train Loss: 0.1003, Val Loss: 0.1544, Val Accuracy: 94.41%
#
# [22/100] Train Loss: 0.0951, Val Loss: 0.1503, Val Accuracy: 94.17%
#
# [23/100] Train Loss: 0.0809, Val Loss: 0.2211, Val Accuracy: 93.94%
#
# [24/100] Train Loss: 0.0894, Val Loss: 0.1848, Val Accuracy: 94.17%
#
# [25/100] Train Loss: 0.0844, Val Loss: 0.1660, Val Accuracy: 95.10%
#
# [26/100] Train Loss: 0.0919, Val Loss: 0.1579, Val Accuracy: 95.57%
#
# [27/100] Train Loss: 0.0820, Val Loss: 0.1712, Val Accuracy: 93.94%
#
# [28/100] Train Loss: 0.0700, Val Loss: 0.1716, Val Accuracy: 95.34%
#
# [29/100] Train Loss: 0.0665, Val Loss: 0.1705, Val Accuracy: 94.64%
#
# [30/100] Train Loss: 0.0813, Val Loss: 0.2414, Val Accuracy: 94.17%
#
# [31/100] Train Loss: 0.0649, Val Loss: 0.2188, Val Accuracy: 94.64%
#
# [32/100] Train Loss: 0.0516, Val Loss: 0.2242, Val Accuracy: 94.64%
#
# [33/100] Train Loss: 0.0665, Val Loss: 0.2066, Val Accuracy: 95.34%
#
# [34/100] Train Loss: 0.0577, Val Loss: 0.1602, Val Accuracy: 94.64%
#
# [35/100] Train Loss: 0.0578, Val Loss: 0.2665, Val Accuracy: 93.94%
#
# [36/100] Train Loss: 0.0490, Val Loss: 0.4032, Val Accuracy: 93.47%
#
# [37/100] Train Loss: 0.0523, Val Loss: 0.2775, Val Accuracy: 94.87%
#
# [38/100] Train Loss: 0.0463, Val Loss: 0.3263, Val Accuracy: 93.01%
#
# [39/100] Train Loss: 0.0612, Val Loss: 0.2149, Val Accuracy: 95.57%
#
# [40/100] Train Loss: 0.0324, Val Loss: 0.2229, Val Accuracy: 95.10%
#
# [41/100] Train Loss: 0.0296, Val Loss: 0.1914, Val Accuracy: 95.34%
#
# [42/100] Train Loss: 0.0414, Val Loss: 0.1807, Val Accuracy: 95.10%
#
# [43/100] Train Loss: 0.0394, Val Loss: 0.2142, Val Accuracy: 95.80%
#
# [44/100] Train Loss: 0.0364, Val Loss: 0.2364, Val Accuracy: 95.57%
#
# [45/100] Train Loss: 0.0247, Val Loss: 0.2287, Val Accuracy: 95.34%
#
# [46/100] Train Loss: 0.0335, Val Loss: 0.2418, Val Accuracy: 94.87%
#
# [47/100] Train Loss: 0.0225, Val Loss: 0.2053, Val Accuracy: 95.34%
#
# [48/100] Train Loss: 0.0143, Val Loss: 0.2733, Val Accuracy: 95.34%
#
# [49/100] Train Loss: 0.0284, Val Loss: 0.2016, Val Accuracy: 95.34%
#
# [50/100] Train Loss: 0.0247, Val Loss: 0.2581, Val Accuracy: 95.10%
#
# [51/100] Train Loss: 0.0204, Val Loss: 0.2561, Val Accuracy: 96.04%
#
# [52/100] Train Loss: 0.0136, Val Loss: 0.2655, Val Accuracy: 95.34%
#
# [53/100] Train Loss: 0.0145, Val Loss: 0.2617, Val Accuracy: 94.87%
#
# [54/100] Train Loss: 0.0109, Val Loss: 0.3307, Val Accuracy: 95.34%
#
# [55/100] Train Loss: 0.0172, Val Loss: 0.3469, Val Accuracy: 94.87%
#
# [56/100] Train Loss: 0.0297, Val Loss: 0.1859, Val Accuracy: 95.57%
#
# [57/100] Train Loss: 0.0150, Val Loss: 0.3122, Val Accuracy: 94.87%
#
# [58/100] Train Loss: 0.0107, Val Loss: 0.2982, Val Accuracy: 94.87%
#
# [59/100] Train Loss: 0.0157, Val Loss: 0.2649, Val Accuracy: 94.87%
#
# [60/100] Train Loss: 0.0141, Val Loss: 0.2999, Val Accuracy: 95.34%
#
# [61/100] Train Loss: 0.0096, Val Loss: 0.3687, Val Accuracy: 94.64%
#
# [62/100] Train Loss: 0.0090, Val Loss: 0.4152, Val Accuracy: 93.47%
#
# [63/100] Train Loss: 0.0090, Val Loss: 0.3516, Val Accuracy: 95.10%
#
# [64/100] Train Loss: 0.0079, Val Loss: 0.3104, Val Accuracy: 95.34%
#
# [65/100] Train Loss: 0.0071, Val Loss: 0.4438, Val Accuracy: 94.64%
#
# [66/100] Train Loss: 0.0106, Val Loss: 0.3795, Val Accuracy: 94.87%
#
# [67/100] Train Loss: 0.0048, Val Loss: 0.4095, Val Accuracy: 94.87%
#
# [68/100] Train Loss: 0.0066, Val Loss: 0.3700, Val Accuracy: 95.10%
#
# [69/100] Train Loss: 0.0047, Val Loss: 0.3362, Val Accuracy: 95.34%
#
# [70/100] Train Loss: 0.0025, Val Loss: 0.4219, Val Accuracy: 95.10%
#
# [71/100] Train Loss: 0.0071, Val Loss: 0.3031, Val Accuracy: 95.10%
#
# [72/100] Train Loss: 0.0067, Val Loss: 0.3151, Val Accuracy: 95.34%
#
# [73/100] Train Loss: 0.0058, Val Loss: 0.3121, Val Accuracy: 95.34%
#
# [74/100] Train Loss: 0.0055, Val Loss: 0.2879, Val Accuracy: 95.57%
#
# [75/100] Train Loss: 0.0036, Val Loss: 0.3191, Val Accuracy: 96.04%
#
# [76/100] Train Loss: 0.0023, Val Loss: 0.3365, Val Accuracy: 95.80%
#
# [77/100] Train Loss: 0.0031, Val Loss: 0.3669, Val Accuracy: 95.34%
#
# [78/100] Train Loss: 0.0027, Val Loss: 0.3372, Val Accuracy: 95.34%
#
# [79/100] Train Loss: 0.0041, Val Loss: 0.4151, Val Accuracy: 94.17%
#
# [80/100] Train Loss: 0.0033, Val Loss: 0.3629, Val Accuracy: 94.87%
#
# [81/100] Train Loss: 0.0049, Val Loss: 0.3445, Val Accuracy: 95.57%
#
# [82/100] Train Loss: 0.0029, Val Loss: 0.4277, Val Accuracy: 95.34%
#
# [83/100] Train Loss: 0.0026, Val Loss: 0.3657, Val Accuracy: 95.57%
#
# [84/100] Train Loss: 0.0028, Val Loss: 0.3869, Val Accuracy: 95.57%
#
# [85/100] Train Loss: 0.0029, Val Loss: 0.3850, Val Accuracy: 95.10%
#
# [86/100] Train Loss: 0.0013, Val Loss: 0.4103, Val Accuracy: 95.34%
#
# [87/100] Train Loss: 0.0032, Val Loss: 0.4114, Val Accuracy: 95.10%
#
# [88/100] Train Loss: 0.0023, Val Loss: 0.4332, Val Accuracy: 95.34%
#
# [89/100] Train Loss: 0.0015, Val Loss: 0.4162, Val Accuracy: 95.57%
#
# [90/100] Train Loss: 0.0021, Val Loss: 0.4496, Val Accuracy: 95.34%
#
# [91/100] Train Loss: 0.0025, Val Loss: 0.4201, Val Accuracy: 95.34%
#
# [92/100] Train Loss: 0.0021, Val Loss: 0.4303, Val Accuracy: 95.34%
#
# [93/100] Train Loss: 0.0020, Val Loss: 0.4139, Val Accuracy: 95.10%
#
# [94/100] Train Loss: 0.0017, Val Loss: 0.4217, Val Accuracy: 95.34%
#
# [95/100] Train Loss: 0.0016, Val Loss: 0.4181, Val Accuracy: 95.10%
#
# [96/100] Train Loss: 0.0018, Val Loss: 0.4254, Val Accuracy: 95.34%
#
# [97/100] Train Loss: 0.0021, Val Loss: 0.4311, Val Accuracy: 95.34%
#
# [98/100] Train Loss: 0.0025, Val Loss: 0.4313, Val Accuracy: 95.34%
#
# [99/100] Train Loss: 0.0018, Val Loss: 0.4320, Val Accuracy: 95.34%
#
# [100/100] Train Loss: 0.0020, Val Loss: 0.4326, Val Accuracy: 95.34%

# %%
_, _, acc_supervised_all_val, auc_supervised_all_val = test_(ft_network, val_loader, nn.CrossEntropyLoss())
# Out:
# Evaluation on held out test dataset
# Confusion Matrix
# +----------------+------------------+---------------------+
# |                | predicted lenses | predicted nonlenses |
# +----------------+------------------+---------------------+
# |  true lenses   |       253        |          6          |
# | true nonlenses |        14        |         156         |
# +----------------+------------------+---------------------+
# Test Metrics
# +-----------+----------+
# |  accuracy | 95.3380% |
# |    loss   |  0.1202  |
# | auc score |  0.9892  |
# +-----------+----------+
# +----------------+-----------+--------+---------+---------+
# |                | precision | recall | f-score | support |
# +----------------+-----------+--------+---------+---------+
# |     lenses     |   0.9476  | 0.9768 |  0.9620 |   259   |
# |   nonlenses    |   0.9630  | 0.9176 |  0.9398 |   170   |
# | macro averaged |   0.9553  | 0.9472 |  0.9509 |         |
# +----------------+-----------+--------+---------+---------+

# %%
_, _, acc_supervised_all_test, auc_supervised_all_test = test_(ft_network, test_loader, nn.CrossEntropyLoss())
# Out:
# Evaluation on held out test dataset
# Confusion Matrix
# +----------------+------------------+---------------------+
# |                | predicted lenses | predicted nonlenses |
# +----------------+------------------+---------------------+
# |  true lenses   |       439        |          19         |
# | true nonlenses |        19        |         281         |
# +----------------+------------------+---------------------+
# Test Metrics
# +-----------+----------+
# |  accuracy | 94.9868% |
# |    loss   |  0.0185  |
# | auc score |  0.9861  |
# +-----------+----------+
# +----------------+-----------+--------+---------+---------+
# |                | precision | recall | f-score | support |
# +----------------+-----------+--------+---------+---------+
# |     lenses     |   0.9585  | 0.9585 |  0.9585 |   458   |
# |   nonlenses    |   0.9367  | 0.9367 |  0.9367 |   300   |
# | macro averaged |   0.9476  | 0.9476 |  0.9476 |         |
# +----------------+-----------+--------+---------+---------+

# %% [markdown]
# ### ROC Curves for the supervised models are plotted below

# %%
plt.figure(figsize=(15, 15))
plt.title('ROC')
plt.plot(fpr_supervised_300, tpr_supervised_300, 'r', label = 'AUC (trained on 300 labelled data, supervised) = %0.4f' % auc_score_300)
plt.plot(fpr_supervised_600, tpr_supervised_600, 'm', label = 'AUC (trained on 600 labelled data, supervised) = %0.4f' % auc_score_600)
plt.plot(fpr_supervised_1200, tpr_supervised_1200, 'g', label = 'AUC (trained on 1200 labelled data, supervised) = %0.4f' % auc_score_1200)
plt.plot(fpr_supervised_all, tpr_supervised_all, 'b', label = 'AUC (trained on all labelled data, supervised) = %0.4f' % auc_score_all)

plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.savefig("auc_supervised.png")
plt.show()

# %% [markdown]
# ### ViT Small backbone pretrained with Simsiam

# %%
state = torch.load("/kaggle/input/deeplense-git/simsiam-vit-small-ckpt.pth")
# Out:
# /tmp/ipykernel_24/2468157085.py:1: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state = torch.load("/kaggle/input/deeplense-git/simsiam-vit-small-ckpt.pth")

# %% [markdown]
# ### ViT Small pretrained backbone finetuned on 300 labelled datapoints

# %%
set_seed(12)
train_loader, val_loader, test_loader = get_datasets(300)
ft_network = Classifier(mode = "finetune", backbone = copy.deepcopy(state["student"].backbone))
optimizer = torch.optim.Adam(ft_network.parameters(), lr=1e-4, weight_decay=0)
num_epochs = 100
scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, eta_min=1e-8, T_max=num_epochs)
ft_network, ft_network_best_loss = train(ft_network, train_loader, val_loader, nn.CrossEntropyLoss(), optimizer, num_epochs=num_epochs, scheduler=scheduler)

torch.save(ft_network, "/kaggle/working/simsiam_finetuned_300_ckpt.pth")
fpr_simsiam_finetuned_300, tpr_simsiam_finetuned_300, auc_score_simsiam_finetuned_300 = compute_auc(ft_network, test_loader)
# Out:
# [1/100] Train Loss: 1.9863, Val Loss: 1.2210, Val Accuracy: 60.14%
#
# [2/100] Train Loss: 0.9658, Val Loss: 1.0172, Val Accuracy: 49.65%
#
# [3/100] Train Loss: 0.8754, Val Loss: 0.5903, Val Accuracy: 66.20%
#
# [4/100] Train Loss: 0.6869, Val Loss: 0.5954, Val Accuracy: 60.37%
#
# [5/100] Train Loss: 0.6240, Val Loss: 0.6621, Val Accuracy: 56.18%
#
# [6/100] Train Loss: 0.6097, Val Loss: 0.5393, Val Accuracy: 72.26%
#
# [7/100] Train Loss: 0.5817, Val Loss: 0.5252, Val Accuracy: 67.13%
#
# [8/100] Train Loss: 0.5635, Val Loss: 0.5222, Val Accuracy: 64.34%
#
# [9/100] Train Loss: 0.5491, Val Loss: 0.4696, Val Accuracy: 83.92%
#
# [10/100] Train Loss: 0.5063, Val Loss: 0.4523, Val Accuracy: 73.19%
#
# [11/100] Train Loss: 0.4693, Val Loss: 0.3674, Val Accuracy: 87.41%
#
# [12/100] Train Loss: 0.4094, Val Loss: 0.3371, Val Accuracy: 84.62%
#
# [13/100] Train Loss: 0.4165, Val Loss: 0.3215, Val Accuracy: 86.71%
#
# [14/100] Train Loss: 0.3676, Val Loss: 0.2949, Val Accuracy: 87.18%
#
# [15/100] Train Loss: 0.3656, Val Loss: 0.3052, Val Accuracy: 89.51%
#
# [16/100] Train Loss: 0.3425, Val Loss: 0.2752, Val Accuracy: 87.41%
#
# [17/100] Train Loss: 0.3027, Val Loss: 0.2788, Val Accuracy: 88.81%
#
# [18/100] Train Loss: 0.3031, Val Loss: 0.2777, Val Accuracy: 87.88%
#
# [19/100] Train Loss: 0.3269, Val Loss: 0.2719, Val Accuracy: 89.04%
#
# [20/100] Train Loss: 0.3370, Val Loss: 0.2638, Val Accuracy: 89.28%
#
# [21/100] Train Loss: 0.3105, Val Loss: 0.2746, Val Accuracy: 89.04%
#
# [22/100] Train Loss: 0.3028, Val Loss: 0.2746, Val Accuracy: 89.04%
#
# [23/100] Train Loss: 0.2923, Val Loss: 0.2709, Val Accuracy: 88.81%
#
# [24/100] Train Loss: 0.2890, Val Loss: 0.2738, Val Accuracy: 88.81%
#
# [25/100] Train Loss: 0.2680, Val Loss: 0.3356, Val Accuracy: 87.18%
#
# [26/100] Train Loss: 0.2405, Val Loss: 0.2601, Val Accuracy: 88.34%
#
# [27/100] Train Loss: 0.2533, Val Loss: 0.2644, Val Accuracy: 88.58%
#
# [28/100] Train Loss: 0.2456, Val Loss: 0.2749, Val Accuracy: 87.88%
#
# [29/100] Train Loss: 0.2332, Val Loss: 0.2742, Val Accuracy: 88.81%
#
# [30/100] Train Loss: 0.2050, Val Loss: 0.2899, Val Accuracy: 89.04%
#
# [31/100] Train Loss: 0.1746, Val Loss: 0.2934, Val Accuracy: 89.04%
#
# [32/100] Train Loss: 0.1787, Val Loss: 0.2941, Val Accuracy: 89.04%
#
# [33/100] Train Loss: 0.1917, Val Loss: 0.2986, Val Accuracy: 89.98%
#
# [34/100] Train Loss: 0.2021, Val Loss: 0.3087, Val Accuracy: 89.51%
#
# [35/100] Train Loss: 0.1562, Val Loss: 0.2949, Val Accuracy: 89.28%
#
# [36/100] Train Loss: 0.1875, Val Loss: 0.3018, Val Accuracy: 89.51%
#
# [37/100] Train Loss: 0.1194, Val Loss: 0.2954, Val Accuracy: 88.81%
#
# [38/100] Train Loss: 0.1130, Val Loss: 0.2979, Val Accuracy: 88.58%
#
# [39/100] Train Loss: 0.0989, Val Loss: 0.3263, Val Accuracy: 89.04%
#
# [40/100] Train Loss: 0.0807, Val Loss: 0.3473, Val Accuracy: 89.28%
#
# [41/100] Train Loss: 0.0726, Val Loss: 0.4733, Val Accuracy: 87.88%
#
# [42/100] Train Loss: 0.0840, Val Loss: 0.3807, Val Accuracy: 89.28%
#
# [43/100] Train Loss: 0.0616, Val Loss: 0.3699, Val Accuracy: 89.28%
#
# [44/100] Train Loss: 0.0446, Val Loss: 0.5661, Val Accuracy: 87.18%
#
# [45/100] Train Loss: 0.0703, Val Loss: 0.4325, Val Accuracy: 89.74%
#
# [46/100] Train Loss: 0.0649, Val Loss: 0.4947, Val Accuracy: 89.51%
#
# [47/100] Train Loss: 0.1517, Val Loss: 0.5755, Val Accuracy: 86.71%
#
# [48/100] Train Loss: 0.1021, Val Loss: 0.3245, Val Accuracy: 89.51%
#
# [49/100] Train Loss: 0.0974, Val Loss: 0.3429, Val Accuracy: 88.81%
#
# [50/100] Train Loss: 0.0687, Val Loss: 0.3866, Val Accuracy: 88.34%
#
# [51/100] Train Loss: 0.0674, Val Loss: 0.3907, Val Accuracy: 88.11%
#
# [52/100] Train Loss: 0.0463, Val Loss: 0.4707, Val Accuracy: 88.34%
#
# [53/100] Train Loss: 0.0367, Val Loss: 0.4368, Val Accuracy: 88.34%
#
# [54/100] Train Loss: 0.0262, Val Loss: 0.4159, Val Accuracy: 89.98%
#
# [55/100] Train Loss: 0.0323, Val Loss: 0.4805, Val Accuracy: 89.51%
#
# [56/100] Train Loss: 0.0193, Val Loss: 0.5075, Val Accuracy: 89.28%
#
# [57/100] Train Loss: 0.0153, Val Loss: 0.5160, Val Accuracy: 89.51%
#
# [58/100] Train Loss: 0.0386, Val Loss: 0.5071, Val Accuracy: 89.51%
#
# [59/100] Train Loss: 0.0408, Val Loss: 0.4819, Val Accuracy: 89.51%
#
# [60/100] Train Loss: 0.0288, Val Loss: 0.5263, Val Accuracy: 89.04%
#
# [61/100] Train Loss: 0.0213, Val Loss: 0.6268, Val Accuracy: 89.28%
#
# [62/100] Train Loss: 0.0190, Val Loss: 0.5907, Val Accuracy: 89.74%
#
# [63/100] Train Loss: 0.0138, Val Loss: 0.6060, Val Accuracy: 89.04%
#
# [64/100] Train Loss: 0.0135, Val Loss: 0.6571, Val Accuracy: 89.51%
#
# [65/100] Train Loss: 0.0069, Val Loss: 0.6463, Val Accuracy: 89.28%
#
# [66/100] Train Loss: 0.0069, Val Loss: 0.6210, Val Accuracy: 89.98%
#
# [67/100] Train Loss: 0.0044, Val Loss: 0.6016, Val Accuracy: 89.74%
#
# [68/100] Train Loss: 0.0069, Val Loss: 0.6435, Val Accuracy: 89.98%
#
# [69/100] Train Loss: 0.0065, Val Loss: 0.6399, Val Accuracy: 89.51%
#
# [70/100] Train Loss: 0.0030, Val Loss: 0.6337, Val Accuracy: 89.51%
#
# [71/100] Train Loss: 0.0036, Val Loss: 0.6377, Val Accuracy: 89.74%
#
# [72/100] Train Loss: 0.0039, Val Loss: 0.6798, Val Accuracy: 89.74%
#
# [73/100] Train Loss: 0.0117, Val Loss: 0.6989, Val Accuracy: 89.51%
#
# [74/100] Train Loss: 0.0020, Val Loss: 0.6876, Val Accuracy: 89.28%
#
# [75/100] Train Loss: 0.0018, Val Loss: 0.6713, Val Accuracy: 89.28%
#
# [76/100] Train Loss: 0.0026, Val Loss: 0.6694, Val Accuracy: 89.28%
#
# [77/100] Train Loss: 0.0080, Val Loss: 0.7005, Val Accuracy: 89.04%
#
# [78/100] Train Loss: 0.0039, Val Loss: 0.7151, Val Accuracy: 89.04%
#
# [79/100] Train Loss: 0.0019, Val Loss: 0.7001, Val Accuracy: 89.28%
#
# [80/100] Train Loss: 0.0055, Val Loss: 0.6755, Val Accuracy: 89.74%
#
# [81/100] Train Loss: 0.0008, Val Loss: 0.6645, Val Accuracy: 89.74%
#
# [82/100] Train Loss: 0.0029, Val Loss: 0.6666, Val Accuracy: 89.74%
#
# [83/100] Train Loss: 0.0021, Val Loss: 0.6714, Val Accuracy: 89.74%
#
# [84/100] Train Loss: 0.0018, Val Loss: 0.6774, Val Accuracy: 89.98%
#
# [85/100] Train Loss: 0.0008, Val Loss: 0.6844, Val Accuracy: 89.98%
#
# [86/100] Train Loss: 0.0011, Val Loss: 0.6882, Val Accuracy: 89.98%
#
# [87/100] Train Loss: 0.0057, Val Loss: 0.6893, Val Accuracy: 89.98%
#
# [88/100] Train Loss: 0.0013, Val Loss: 0.6861, Val Accuracy: 89.98%
#
# [89/100] Train Loss: 0.0016, Val Loss: 0.6844, Val Accuracy: 89.74%
#
# [90/100] Train Loss: 0.0015, Val Loss: 0.6837, Val Accuracy: 89.74%
#
# [91/100] Train Loss: 0.0037, Val Loss: 0.6885, Val Accuracy: 89.98%
#
# [92/100] Train Loss: 0.0109, Val Loss: 0.6980, Val Accuracy: 89.98%
#
# [93/100] Train Loss: 0.0013, Val Loss: 0.7037, Val Accuracy: 89.74%
#
# [94/100] Train Loss: 0.0013, Val Loss: 0.7060, Val Accuracy: 89.74%
#
# [95/100] Train Loss: 0.0011, Val Loss: 0.7068, Val Accuracy: 89.74%
#
# [96/100] Train Loss: 0.0023, Val Loss: 0.7072, Val Accuracy: 89.74%
#
# [97/100] Train Loss: 0.0008, Val Loss: 0.7073, Val Accuracy: 89.74%
#
# [98/100] Train Loss: 0.0011, Val Loss: 0.7074, Val Accuracy: 89.74%
#
# [99/100] Train Loss: 0.0016, Val Loss: 0.7074, Val Accuracy: 89.74%
#
# [100/100] Train Loss: 0.0007, Val Loss: 0.7074, Val Accuracy: 89.74%

# %%
_, _, acc_simsiam_finetuned_300, auc_simsiam_finetuned_300 = test_(ft_network, val_loader, nn.CrossEntropyLoss())
# Out:
# Evaluation on held out test dataset
# Confusion Matrix
# +----------------+------------------+---------------------+
# |                | predicted lenses | predicted nonlenses |
# +----------------+------------------+---------------------+
# |  true lenses   |       241        |          18         |
# | true nonlenses |        26        |         144         |
# +----------------+------------------+---------------------+
# Test Metrics
# +-----------+----------+
# |  accuracy | 89.7436% |
# |    loss   |  0.1354  |
# | auc score |  0.9571  |
# +-----------+----------+
# +----------------+-----------+--------+---------+---------+
# |                | precision | recall | f-score | support |
# +----------------+-----------+--------+---------+---------+
# |     lenses     |   0.9026  | 0.9305 |  0.9163 |   259   |
# |   nonlenses    |   0.8889  | 0.8471 |  0.8675 |   170   |
# | macro averaged |   0.8958  | 0.8888 |  0.8919 |         |
# +----------------+-----------+--------+---------+---------+

# %%
_, _, acc_simsiam_finetuned_300, auc_simsiam_finetuned_300 = test_(ft_network, test_loader, nn.CrossEntropyLoss())
# Out:
# Evaluation on held out test dataset
# Confusion Matrix
# +----------------+------------------+---------------------+
# |                | predicted lenses | predicted nonlenses |
# +----------------+------------------+---------------------+
# |  true lenses   |       421        |          37         |
# | true nonlenses |        40        |         260         |
# +----------------+------------------+---------------------+
# Test Metrics
# +-----------+----------+
# |  accuracy | 89.8417% |
# |    loss   |  0.0703  |
# | auc score |  0.9540  |
# +-----------+----------+
# +----------------+-----------+--------+---------+---------+
# |                | precision | recall | f-score | support |
# +----------------+-----------+--------+---------+---------+
# |     lenses     |   0.9132  | 0.9192 |  0.9162 |   458   |
# |   nonlenses    |   0.8754  | 0.8667 |  0.8710 |   300   |
# | macro averaged |   0.8943  | 0.8929 |  0.8936 |         |
# +----------------+-----------+--------+---------+---------+

# %% [markdown]
# ### ViT Small pretrained backbone finetuned on 600 labelled datapoints

# %%
set_seed(12)
train_loader, val_loader, test_loader = get_datasets(600)
ft_network = Classifier(mode = "finetune", backbone = copy.deepcopy(state["student"].backbone))
optimizer = torch.optim.Adam(ft_network.parameters(), lr=1e-4, weight_decay=1e-5)
num_epochs = 100
scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, eta_min=1e-8, T_max=num_epochs)
ft_network, ft_network_best_loss = train(ft_network, train_loader, val_loader, nn.CrossEntropyLoss(), optimizer, num_epochs=num_epochs, scheduler=scheduler)

torch.save(ft_network, "/kaggle/working/simsiam_finetuned_600_ckpt.pth")
fpr_simsiam_finetuned_600, tpr_simsiam_finetuned_600, auc_score_simsiam_finetuned_600 = compute_auc(ft_network, test_loader)
# Out:
# [1/100] Train Loss: 1.7346, Val Loss: 0.6281, Val Accuracy: 57.58%
#
# [2/100] Train Loss: 0.7265, Val Loss: 0.6662, Val Accuracy: 60.37%
#
# [3/100] Train Loss: 0.6634, Val Loss: 0.6297, Val Accuracy: 57.81%
#
# [4/100] Train Loss: 0.5919, Val Loss: 0.5513, Val Accuracy: 65.27%
#
# [5/100] Train Loss: 0.5743, Val Loss: 0.5077, Val Accuracy: 79.72%
#
# [6/100] Train Loss: 0.5292, Val Loss: 0.4834, Val Accuracy: 67.13%
#
# [7/100] Train Loss: 0.4898, Val Loss: 0.3699, Val Accuracy: 85.08%
#
# [8/100] Train Loss: 0.4248, Val Loss: 0.3332, Val Accuracy: 87.41%
#
# [9/100] Train Loss: 0.3880, Val Loss: 0.3424, Val Accuracy: 86.48%
#
# [10/100] Train Loss: 0.3441, Val Loss: 0.3154, Val Accuracy: 88.34%
#
# [11/100] Train Loss: 0.3496, Val Loss: 0.3005, Val Accuracy: 89.28%
#
# [12/100] Train Loss: 0.3068, Val Loss: 0.2886, Val Accuracy: 88.34%
#
# [13/100] Train Loss: 0.3036, Val Loss: 0.2911, Val Accuracy: 88.34%
#
# [14/100] Train Loss: 0.2901, Val Loss: 0.2729, Val Accuracy: 90.21%
#
# [15/100] Train Loss: 0.2648, Val Loss: 0.2864, Val Accuracy: 88.58%
#
# [16/100] Train Loss: 0.2350, Val Loss: 0.2662, Val Accuracy: 89.28%
#
# [17/100] Train Loss: 0.2052, Val Loss: 0.2851, Val Accuracy: 89.51%
#
# [18/100] Train Loss: 0.2062, Val Loss: 0.2625, Val Accuracy: 90.21%
#
# [19/100] Train Loss: 0.1737, Val Loss: 0.3210, Val Accuracy: 88.11%
#
# [20/100] Train Loss: 0.2075, Val Loss: 0.2579, Val Accuracy: 89.51%
#
# [21/100] Train Loss: 0.1847, Val Loss: 0.2799, Val Accuracy: 89.51%
#
# [22/100] Train Loss: 0.1663, Val Loss: 0.2830, Val Accuracy: 89.74%
#
# [23/100] Train Loss: 0.1598, Val Loss: 0.2868, Val Accuracy: 90.21%
#
# [24/100] Train Loss: 0.1548, Val Loss: 0.2960, Val Accuracy: 90.21%
#
# [25/100] Train Loss: 0.1329, Val Loss: 0.3186, Val Accuracy: 89.74%
#
# [26/100] Train Loss: 0.1541, Val Loss: 0.3037, Val Accuracy: 89.98%
#
# [27/100] Train Loss: 0.1654, Val Loss: 0.2954, Val Accuracy: 89.74%
#
# [28/100] Train Loss: 0.0995, Val Loss: 0.2999, Val Accuracy: 90.44%
#
# [29/100] Train Loss: 0.0827, Val Loss: 0.3041, Val Accuracy: 91.38%
#
# [30/100] Train Loss: 0.0796, Val Loss: 0.3042, Val Accuracy: 92.07%
#
# [31/100] Train Loss: 0.0818, Val Loss: 0.4394, Val Accuracy: 88.34%
#
# [32/100] Train Loss: 0.0933, Val Loss: 0.3982, Val Accuracy: 90.21%
#
# [33/100] Train Loss: 0.0820, Val Loss: 0.3338, Val Accuracy: 90.21%
#
# [34/100] Train Loss: 0.0848, Val Loss: 0.3266, Val Accuracy: 89.74%
#
# [35/100] Train Loss: 0.0797, Val Loss: 0.2662, Val Accuracy: 91.14%
#
# [36/100] Train Loss: 0.0943, Val Loss: 0.2705, Val Accuracy: 92.54%
#
# [37/100] Train Loss: 0.0665, Val Loss: 0.3441, Val Accuracy: 91.84%
#
# [38/100] Train Loss: 0.0696, Val Loss: 0.3773, Val Accuracy: 90.68%
#
# [39/100] Train Loss: 0.0511, Val Loss: 0.3790, Val Accuracy: 91.84%
#
# [40/100] Train Loss: 0.0659, Val Loss: 0.3571, Val Accuracy: 92.07%
#
# [41/100] Train Loss: 0.0574, Val Loss: 0.3575, Val Accuracy: 91.61%
#
# [42/100] Train Loss: 0.0889, Val Loss: 0.3709, Val Accuracy: 93.01%
#
# [43/100] Train Loss: 0.0589, Val Loss: 0.3414, Val Accuracy: 92.77%
#
# [44/100] Train Loss: 0.0254, Val Loss: 0.4184, Val Accuracy: 91.14%
#
# [45/100] Train Loss: 0.0224, Val Loss: 0.4776, Val Accuracy: 92.54%
#
# [46/100] Train Loss: 0.0296, Val Loss: 0.4046, Val Accuracy: 91.61%
#
# [47/100] Train Loss: 0.0136, Val Loss: 0.3872, Val Accuracy: 92.54%
#
# [48/100] Train Loss: 0.0124, Val Loss: 0.4395, Val Accuracy: 91.61%
#
# [49/100] Train Loss: 0.0063, Val Loss: 0.4883, Val Accuracy: 92.31%
#
# [50/100] Train Loss: 0.0064, Val Loss: 0.5620, Val Accuracy: 91.84%
#
# [51/100] Train Loss: 0.0029, Val Loss: 0.6131, Val Accuracy: 91.84%
#
# [52/100] Train Loss: 0.0121, Val Loss: 0.5555, Val Accuracy: 92.54%
#
# [53/100] Train Loss: 0.0027, Val Loss: 0.5501, Val Accuracy: 92.31%
#
# [54/100] Train Loss: 0.0041, Val Loss: 0.5881, Val Accuracy: 92.31%
#
# [55/100] Train Loss: 0.0018, Val Loss: 0.6033, Val Accuracy: 92.31%
#
# [56/100] Train Loss: 0.0010, Val Loss: 0.6087, Val Accuracy: 92.07%
#
# [57/100] Train Loss: 0.0009, Val Loss: 0.6264, Val Accuracy: 92.07%
#
# [58/100] Train Loss: 0.0008, Val Loss: 0.6430, Val Accuracy: 92.54%
#
# [59/100] Train Loss: 0.0017, Val Loss: 0.6640, Val Accuracy: 91.61%
#
# [60/100] Train Loss: 0.0044, Val Loss: 0.6798, Val Accuracy: 91.38%
#
# [61/100] Train Loss: 0.0026, Val Loss: 0.6622, Val Accuracy: 92.07%
#
# [62/100] Train Loss: 0.0017, Val Loss: 0.6414, Val Accuracy: 92.54%
#
# [63/100] Train Loss: 0.0004, Val Loss: 0.6397, Val Accuracy: 92.77%
#
# [64/100] Train Loss: 0.0006, Val Loss: 0.6443, Val Accuracy: 92.77%
#
# [65/100] Train Loss: 0.0177, Val Loss: 0.6420, Val Accuracy: 92.54%
#
# [66/100] Train Loss: 0.0087, Val Loss: 0.5884, Val Accuracy: 92.31%
#
# [67/100] Train Loss: 0.0104, Val Loss: 0.6169, Val Accuracy: 92.54%
#
# [68/100] Train Loss: 0.0028, Val Loss: 0.6160, Val Accuracy: 93.01%
#
# [69/100] Train Loss: 0.0023, Val Loss: 0.6606, Val Accuracy: 92.07%
#
# [70/100] Train Loss: 0.0175, Val Loss: 0.6505, Val Accuracy: 91.61%
#
# [71/100] Train Loss: 0.0020, Val Loss: 0.6474, Val Accuracy: 91.84%
#
# [72/100] Train Loss: 0.0064, Val Loss: 0.6579, Val Accuracy: 91.61%
#
# [73/100] Train Loss: 0.0023, Val Loss: 0.6448, Val Accuracy: 92.54%
#
# [74/100] Train Loss: 0.0055, Val Loss: 0.6367, Val Accuracy: 92.54%
#
# [75/100] Train Loss: 0.0004, Val Loss: 0.6312, Val Accuracy: 92.77%
#
# [76/100] Train Loss: 0.0006, Val Loss: 0.6287, Val Accuracy: 92.77%
#
# [77/100] Train Loss: 0.0005, Val Loss: 0.6275, Val Accuracy: 92.54%
#
# [78/100] Train Loss: 0.0003, Val Loss: 0.6278, Val Accuracy: 92.54%
#
# [79/100] Train Loss: 0.0005, Val Loss: 0.6296, Val Accuracy: 92.54%
#
# [80/100] Train Loss: 0.0008, Val Loss: 0.6321, Val Accuracy: 92.77%
#
# [81/100] Train Loss: 0.0007, Val Loss: 0.6343, Val Accuracy: 92.77%
#
# [82/100] Train Loss: 0.0003, Val Loss: 0.6382, Val Accuracy: 92.31%
#
# [83/100] Train Loss: 0.0007, Val Loss: 0.6416, Val Accuracy: 92.07%
#
# [84/100] Train Loss: 0.0003, Val Loss: 0.6439, Val Accuracy: 92.07%
#
# [85/100] Train Loss: 0.0002, Val Loss: 0.6453, Val Accuracy: 92.07%
#
# [86/100] Train Loss: 0.0003, Val Loss: 0.6462, Val Accuracy: 92.07%
#
# [87/100] Train Loss: 0.0003, Val Loss: 0.6466, Val Accuracy: 92.07%
#
# [88/100] Train Loss: 0.0004, Val Loss: 0.6472, Val Accuracy: 92.07%
#
# [89/100] Train Loss: 0.0004, Val Loss: 0.6488, Val Accuracy: 92.07%
#
# [90/100] Train Loss: 0.0004, Val Loss: 0.6502, Val Accuracy: 92.07%
#
# [91/100] Train Loss: 0.0005, Val Loss: 0.6507, Val Accuracy: 92.07%
#
# [92/100] Train Loss: 0.0002, Val Loss: 0.6511, Val Accuracy: 92.07%
#
# [93/100] Train Loss: 0.0005, Val Loss: 0.6514, Val Accuracy: 92.07%
#
# [94/100] Train Loss: 0.0007, Val Loss: 0.6518, Val Accuracy: 92.07%
#
# [95/100] Train Loss: 0.0004, Val Loss: 0.6520, Val Accuracy: 91.84%
#
# [96/100] Train Loss: 0.0009, Val Loss: 0.6521, Val Accuracy: 91.84%
#
# [97/100] Train Loss: 0.0005, Val Loss: 0.6521, Val Accuracy: 91.84%
#
# [98/100] Train Loss: 0.0003, Val Loss: 0.6521, Val Accuracy: 91.84%
#
# [99/100] Train Loss: 0.0089, Val Loss: 0.6521, Val Accuracy: 91.84%
#
# [100/100] Train Loss: 0.0004, Val Loss: 0.6521, Val Accuracy: 91.84%

# %%
_, _, acc_simsiam_finetuned_600, auc_simsiam_finetuned_600 = test_(ft_network, val_loader, nn.CrossEntropyLoss())
# Out:
# Evaluation on held out test dataset
# Confusion Matrix
# +----------------+------------------+---------------------+
# |                | predicted lenses | predicted nonlenses |
# +----------------+------------------+---------------------+
# |  true lenses   |       242        |          17         |
# | true nonlenses |        18        |         152         |
# +----------------+------------------+---------------------+
# Test Metrics
# +-----------+----------+
# |  accuracy | 91.8415% |
# |    loss   |  0.1191  |
# | auc score |  0.9635  |
# +-----------+----------+
# +----------------+-----------+--------+---------+---------+
# |                | precision | recall | f-score | support |
# +----------------+-----------+--------+---------+---------+
# |     lenses     |   0.9308  | 0.9344 |  0.9326 |   259   |
# |   nonlenses    |   0.8994  | 0.8941 |  0.8968 |   170   |
# | macro averaged |   0.9151  | 0.9142 |  0.9147 |         |
# +----------------+-----------+--------+---------+---------+

# %%
_, _, acc_simsiam_finetuned_600, auc_simsiam_finetuned_600 = test_(ft_network, test_loader, nn.CrossEntropyLoss())
# Out:
# Evaluation on held out test dataset
# Confusion Matrix
# +----------------+------------------+---------------------+
# |                | predicted lenses | predicted nonlenses |
# +----------------+------------------+---------------------+
# |  true lenses   |       430        |          28         |
# | true nonlenses |        31        |         269         |
# +----------------+------------------+---------------------+
# Test Metrics
# +-----------+----------+
# |  accuracy | 92.2164% |
# |    loss   |  0.0640  |
# | auc score |  0.9691  |
# +-----------+----------+
# +----------------+-----------+--------+---------+---------+
# |                | precision | recall | f-score | support |
# +----------------+-----------+--------+---------+---------+
# |     lenses     |   0.9328  | 0.9389 |  0.9358 |   458   |
# |   nonlenses    |   0.9057  | 0.8967 |  0.9012 |   300   |
# | macro averaged |   0.9192  | 0.9178 |  0.9185 |         |
# +----------------+-----------+--------+---------+---------+

# %% [markdown]
# ### ViT Small pretrained backbone finetuned on 1200 labelled datapoints

# %%
set_seed(12)
train_loader, val_loader, test_loader = get_datasets(1200)
ft_network = Classifier(mode = "finetune", backbone = copy.deepcopy(state["student"].backbone))
optimizer = torch.optim.Adam(ft_network.parameters(), lr=1e-4, weight_decay=1e-5)
num_epochs = 100
scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, eta_min=1e-8, T_max=num_epochs)
ft_network, ft_network_best_loss = train(ft_network, train_loader, val_loader, nn.CrossEntropyLoss(), optimizer, num_epochs=num_epochs, scheduler=scheduler)

torch.save(ft_network, "/kaggle/working/simsiam_finetuned_1200_ckpt.pth")
fpr_simsiam_finetuned_1200, tpr_simsiam_finetuned_1200, auc_score_simsiam_finetuned_1200 = compute_auc(ft_network, test_loader)
# Out:
# [1/100] Train Loss: 1.0972, Val Loss: 0.6235, Val Accuracy: 60.37%
#
# [2/100] Train Loss: 0.6095, Val Loss: 0.5278, Val Accuracy: 66.43%
#
# [3/100] Train Loss: 0.5184, Val Loss: 0.4246, Val Accuracy: 80.42%
#
# [4/100] Train Loss: 0.4138, Val Loss: 0.2933, Val Accuracy: 87.41%
#
# [5/100] Train Loss: 0.3642, Val Loss: 0.3554, Val Accuracy: 83.68%
#
# [6/100] Train Loss: 0.3421, Val Loss: 0.2775, Val Accuracy: 87.88%
#
# [7/100] Train Loss: 0.3022, Val Loss: 0.3531, Val Accuracy: 84.38%
#
# [8/100] Train Loss: 0.3064, Val Loss: 0.2993, Val Accuracy: 87.18%
#
# [9/100] Train Loss: 0.2775, Val Loss: 0.2401, Val Accuracy: 89.04%
#
# [10/100] Train Loss: 0.2159, Val Loss: 0.2348, Val Accuracy: 90.68%
#
# [11/100] Train Loss: 0.2182, Val Loss: 0.2413, Val Accuracy: 89.98%
#
# [12/100] Train Loss: 0.1889, Val Loss: 0.2122, Val Accuracy: 91.38%
#
# [13/100] Train Loss: 0.1849, Val Loss: 0.2383, Val Accuracy: 90.44%
#
# [14/100] Train Loss: 0.1687, Val Loss: 0.2078, Val Accuracy: 92.07%
#
# [15/100] Train Loss: 0.1564, Val Loss: 0.2461, Val Accuracy: 91.14%
#
# [16/100] Train Loss: 0.1590, Val Loss: 0.1942, Val Accuracy: 91.38%
#
# [17/100] Train Loss: 0.1498, Val Loss: 0.2584, Val Accuracy: 91.38%
#
# [18/100] Train Loss: 0.1493, Val Loss: 0.1849, Val Accuracy: 91.14%
#
# [19/100] Train Loss: 0.1117, Val Loss: 0.2717, Val Accuracy: 92.31%
#
# [20/100] Train Loss: 0.1233, Val Loss: 0.1915, Val Accuracy: 93.24%
#
# [21/100] Train Loss: 0.0846, Val Loss: 0.2211, Val Accuracy: 93.24%
#
# [22/100] Train Loss: 0.0930, Val Loss: 0.2154, Val Accuracy: 93.01%
#
# [23/100] Train Loss: 0.0800, Val Loss: 0.2419, Val Accuracy: 93.01%
#
# [24/100] Train Loss: 0.0786, Val Loss: 0.2411, Val Accuracy: 93.94%
#
# [25/100] Train Loss: 0.0735, Val Loss: 0.3622, Val Accuracy: 93.24%
#
# [26/100] Train Loss: 0.0674, Val Loss: 0.2741, Val Accuracy: 93.47%
#
# [27/100] Train Loss: 0.0900, Val Loss: 0.2478, Val Accuracy: 93.01%
#
# [28/100] Train Loss: 0.0608, Val Loss: 0.2943, Val Accuracy: 92.77%
#
# [29/100] Train Loss: 0.0643, Val Loss: 0.2350, Val Accuracy: 94.41%
#
# [30/100] Train Loss: 0.0437, Val Loss: 0.3226, Val Accuracy: 92.77%
#
# [31/100] Train Loss: 0.0716, Val Loss: 0.2610, Val Accuracy: 94.17%
#
# [32/100] Train Loss: 0.0434, Val Loss: 0.2358, Val Accuracy: 94.64%
#
# [33/100] Train Loss: 0.0550, Val Loss: 0.3222, Val Accuracy: 93.71%
#
# [34/100] Train Loss: 0.0341, Val Loss: 0.2245, Val Accuracy: 95.10%
#
# [35/100] Train Loss: 0.0329, Val Loss: 0.4093, Val Accuracy: 93.71%
#
# [36/100] Train Loss: 0.0341, Val Loss: 0.2599, Val Accuracy: 93.47%
#
# [37/100] Train Loss: 0.0603, Val Loss: 0.2959, Val Accuracy: 93.94%
#
# [38/100] Train Loss: 0.0486, Val Loss: 0.2397, Val Accuracy: 93.94%
#
# [39/100] Train Loss: 0.0194, Val Loss: 0.2973, Val Accuracy: 94.17%
#
# [40/100] Train Loss: 0.0079, Val Loss: 0.3576, Val Accuracy: 94.17%
#
# [41/100] Train Loss: 0.0053, Val Loss: 0.3749, Val Accuracy: 93.94%
#
# [42/100] Train Loss: 0.0058, Val Loss: 0.4985, Val Accuracy: 93.71%
#
# [43/100] Train Loss: 0.0244, Val Loss: 0.8402, Val Accuracy: 91.14%
#
# [44/100] Train Loss: 0.0670, Val Loss: 0.3192, Val Accuracy: 93.94%
#
# [45/100] Train Loss: 0.0286, Val Loss: 0.2732, Val Accuracy: 93.94%
#
# [46/100] Train Loss: 0.0152, Val Loss: 0.3060, Val Accuracy: 94.41%
#
# [47/100] Train Loss: 0.0043, Val Loss: 0.3463, Val Accuracy: 94.64%
#
# [48/100] Train Loss: 0.0046, Val Loss: 0.3493, Val Accuracy: 94.64%
#
# [49/100] Train Loss: 0.0073, Val Loss: 0.3837, Val Accuracy: 94.64%
#
# [50/100] Train Loss: 0.0210, Val Loss: 0.3557, Val Accuracy: 94.17%
#
# [51/100] Train Loss: 0.0068, Val Loss: 0.3398, Val Accuracy: 94.64%
#
# [52/100] Train Loss: 0.0096, Val Loss: 0.4419, Val Accuracy: 93.71%
#
# [53/100] Train Loss: 0.0138, Val Loss: 0.4344, Val Accuracy: 94.64%
#
# [54/100] Train Loss: 0.0092, Val Loss: 0.3663, Val Accuracy: 95.10%
#
# [55/100] Train Loss: 0.0021, Val Loss: 0.3457, Val Accuracy: 94.87%
#
# [56/100] Train Loss: 0.0044, Val Loss: 0.3036, Val Accuracy: 94.41%
#
# [57/100] Train Loss: 0.0088, Val Loss: 0.3765, Val Accuracy: 94.41%
#
# [58/100] Train Loss: 0.0033, Val Loss: 0.4022, Val Accuracy: 93.71%
#
# [59/100] Train Loss: 0.0054, Val Loss: 0.3856, Val Accuracy: 94.41%
#
# [60/100] Train Loss: 0.0054, Val Loss: 0.3839, Val Accuracy: 94.64%
#
# [61/100] Train Loss: 0.0040, Val Loss: 0.4449, Val Accuracy: 94.41%
#
# [62/100] Train Loss: 0.0012, Val Loss: 0.3952, Val Accuracy: 94.87%
#
# [63/100] Train Loss: 0.0006, Val Loss: 0.4253, Val Accuracy: 95.10%
#
# [64/100] Train Loss: 0.0006, Val Loss: 0.4331, Val Accuracy: 95.10%
#
# [65/100] Train Loss: 0.0002, Val Loss: 0.4225, Val Accuracy: 95.10%
#
# [66/100] Train Loss: 0.0002, Val Loss: 0.4400, Val Accuracy: 95.10%
#
# [67/100] Train Loss: 0.0002, Val Loss: 0.4404, Val Accuracy: 95.10%
#
# [68/100] Train Loss: 0.0002, Val Loss: 0.4293, Val Accuracy: 94.87%
#
# [69/100] Train Loss: 0.0003, Val Loss: 0.4192, Val Accuracy: 94.87%
#
# [70/100] Train Loss: 0.0003, Val Loss: 0.4340, Val Accuracy: 94.87%
#
# [71/100] Train Loss: 0.0001, Val Loss: 0.4465, Val Accuracy: 95.10%
#
# [72/100] Train Loss: 0.0038, Val Loss: 0.4574, Val Accuracy: 95.34%
#
# [73/100] Train Loss: 0.0005, Val Loss: 0.4651, Val Accuracy: 94.64%
#
# [74/100] Train Loss: 0.0002, Val Loss: 0.4502, Val Accuracy: 94.64%
#
# [75/100] Train Loss: 0.0003, Val Loss: 0.4462, Val Accuracy: 94.87%
#
# [76/100] Train Loss: 0.0002, Val Loss: 0.4408, Val Accuracy: 94.87%
#
# [77/100] Train Loss: 0.0003, Val Loss: 0.4384, Val Accuracy: 95.10%
#
# [78/100] Train Loss: 0.0001, Val Loss: 0.4389, Val Accuracy: 95.10%
#
# [79/100] Train Loss: 0.0001, Val Loss: 0.4399, Val Accuracy: 95.10%
#
# [80/100] Train Loss: 0.0001, Val Loss: 0.4388, Val Accuracy: 95.10%
#
# [81/100] Train Loss: 0.0001, Val Loss: 0.4407, Val Accuracy: 95.10%
#
# [82/100] Train Loss: 0.0002, Val Loss: 0.4372, Val Accuracy: 95.10%
#
# [83/100] Train Loss: 0.0004, Val Loss: 0.4454, Val Accuracy: 95.10%
#
# [84/100] Train Loss: 0.0003, Val Loss: 0.4512, Val Accuracy: 95.10%
#
# [85/100] Train Loss: 0.0002, Val Loss: 0.4518, Val Accuracy: 95.10%
#
# [86/100] Train Loss: 0.0001, Val Loss: 0.4513, Val Accuracy: 94.87%
#
# [87/100] Train Loss: 0.0001, Val Loss: 0.4490, Val Accuracy: 94.87%
#
# [88/100] Train Loss: 0.0006, Val Loss: 0.4481, Val Accuracy: 94.87%
#
# [89/100] Train Loss: 0.0001, Val Loss: 0.4442, Val Accuracy: 94.87%
#
# [90/100] Train Loss: 0.0001, Val Loss: 0.4440, Val Accuracy: 94.87%
#
# [91/100] Train Loss: 0.0004, Val Loss: 0.4456, Val Accuracy: 94.87%
#
# [92/100] Train Loss: 0.0001, Val Loss: 0.4494, Val Accuracy: 95.10%
#
# [93/100] Train Loss: 0.0009, Val Loss: 0.4563, Val Accuracy: 95.10%
#
# [94/100] Train Loss: 0.0005, Val Loss: 0.4588, Val Accuracy: 95.10%
#
# [95/100] Train Loss: 0.0002, Val Loss: 0.4582, Val Accuracy: 95.10%
#
# [96/100] Train Loss: 0.0001, Val Loss: 0.4580, Val Accuracy: 95.10%
#
# [97/100] Train Loss: 0.0001, Val Loss: 0.4582, Val Accuracy: 95.10%
#
# [98/100] Train Loss: 0.0001, Val Loss: 0.4582, Val Accuracy: 95.10%
#
# [99/100] Train Loss: 0.0001, Val Loss: 0.4582, Val Accuracy: 95.10%
#
# [100/100] Train Loss: 0.0001, Val Loss: 0.4582, Val Accuracy: 95.10%

# %%
_, _, acc_simsiam_finetuned_1200, auc_simsiam_finetuned_1200 = test_(ft_network, val_loader, nn.CrossEntropyLoss())
# Out:
# Evaluation on held out test dataset
# Confusion Matrix
# +----------------+------------------+---------------------+
# |                | predicted lenses | predicted nonlenses |
# +----------------+------------------+---------------------+
# |  true lenses   |       250        |          9          |
# | true nonlenses |        12        |         158         |
# +----------------+------------------+---------------------+
# Test Metrics
# +-----------+----------+
# |  accuracy | 95.1049% |
# |    loss   |  0.1264  |
# | auc score |  0.9866  |
# +-----------+----------+
# +----------------+-----------+--------+---------+---------+
# |                | precision | recall | f-score | support |
# +----------------+-----------+--------+---------+---------+
# |     lenses     |   0.9542  | 0.9653 |  0.9597 |   259   |
# |   nonlenses    |   0.9461  | 0.9294 |  0.9377 |   170   |
# | macro averaged |   0.9502  | 0.9473 |  0.9487 |         |
# +----------------+-----------+--------+---------+---------+

# %%
_, _, acc_simsiam_finetuned_1200, auc_simsiam_finetuned_1200 = test_(ft_network, test_loader, nn.CrossEntropyLoss())
# Out:
# Evaluation on held out test dataset
# Confusion Matrix
# +----------------+------------------+---------------------+
# |                | predicted lenses | predicted nonlenses |
# +----------------+------------------+---------------------+
# |  true lenses   |       436        |          22         |
# | true nonlenses |        16        |         284         |
# +----------------+------------------+---------------------+
# Test Metrics
# +-----------+----------+
# |  accuracy | 94.9868% |
# |    loss   |  0.0242  |
# | auc score |  0.9843  |
# +-----------+----------+
# +----------------+-----------+--------+---------+---------+
# |                | precision | recall | f-score | support |
# +----------------+-----------+--------+---------+---------+
# |     lenses     |   0.9646  | 0.9520 |  0.9582 |   458   |
# |   nonlenses    |   0.9281  | 0.9467 |  0.9373 |   300   |
# | macro averaged |   0.9464  | 0.9493 |  0.9478 |         |
# +----------------+-----------+--------+---------+---------+

# %% [markdown]
# ### ViT Small pretrained backbone finetuned on all datapoints

# %%
set_seed(12)
train_loader, val_loader, test_loader = get_datasets(None)
ft_network = Classifier(mode = "finetune", backbone = copy.deepcopy(state["student"].backbone))
optimizer = torch.optim.Adam(ft_network.parameters(), lr=1e-4, weight_decay=1e-5)
num_epochs = 100
scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, eta_min=1e-8, T_max=num_epochs)
ft_network, ft_network_best_loss = train(ft_network, train_loader, val_loader, nn.CrossEntropyLoss(), optimizer, num_epochs=num_epochs, scheduler=scheduler)

torch.save(ft_network, "/kaggle/working/simsiam_finetuned_all_ckpt.pth")
fpr_simsiam_finetuned_all, tpr_simsiam_finetuned_all, auc_score_simsiam_finetuned_all = compute_auc(ft_network, test_loader)
# Out:
# [1/100] Train Loss: 0.7390, Val Loss: 0.4150, Val Accuracy: 87.41%
#
# [2/100] Train Loss: 0.3297, Val Loss: 0.2870, Val Accuracy: 87.88%
#
# [3/100] Train Loss: 0.2651, Val Loss: 0.2333, Val Accuracy: 90.91%
#
# [4/100] Train Loss: 0.2307, Val Loss: 0.2216, Val Accuracy: 90.91%
#
# [5/100] Train Loss: 0.2076, Val Loss: 0.1848, Val Accuracy: 93.24%
#
# [6/100] Train Loss: 0.1837, Val Loss: 0.1904, Val Accuracy: 92.77%
#
# [7/100] Train Loss: 0.1682, Val Loss: 0.1712, Val Accuracy: 94.41%
#
# [8/100] Train Loss: 0.1525, Val Loss: 0.2019, Val Accuracy: 91.84%
#
# [9/100] Train Loss: 0.1415, Val Loss: 0.1737, Val Accuracy: 92.77%
#
# [10/100] Train Loss: 0.1528, Val Loss: 0.2226, Val Accuracy: 91.38%
#
# [11/100] Train Loss: 0.1585, Val Loss: 0.1822, Val Accuracy: 92.77%
#
# [12/100] Train Loss: 0.1270, Val Loss: 0.1980, Val Accuracy: 94.41%
#
# [13/100] Train Loss: 0.1169, Val Loss: 0.2135, Val Accuracy: 93.71%
#
# [14/100] Train Loss: 0.1150, Val Loss: 0.1434, Val Accuracy: 94.64%
#
# [15/100] Train Loss: 0.1026, Val Loss: 0.1576, Val Accuracy: 94.87%
#
# [16/100] Train Loss: 0.0992, Val Loss: 0.1883, Val Accuracy: 94.64%
#
# [17/100] Train Loss: 0.0877, Val Loss: 0.1513, Val Accuracy: 95.34%
#
# [18/100] Train Loss: 0.0972, Val Loss: 0.1408, Val Accuracy: 94.17%
#
# [19/100] Train Loss: 0.0900, Val Loss: 0.1756, Val Accuracy: 95.57%
#
# [20/100] Train Loss: 0.0867, Val Loss: 0.1584, Val Accuracy: 95.80%
#
# [21/100] Train Loss: 0.0790, Val Loss: 0.1766, Val Accuracy: 93.94%
#
# [22/100] Train Loss: 0.0845, Val Loss: 0.1637, Val Accuracy: 96.04%
#
# [23/100] Train Loss: 0.0653, Val Loss: 0.1685, Val Accuracy: 95.10%
#
# [24/100] Train Loss: 0.0739, Val Loss: 0.1343, Val Accuracy: 95.80%
#
# [25/100] Train Loss: 0.0616, Val Loss: 0.1497, Val Accuracy: 96.04%
#
# [26/100] Train Loss: 0.0474, Val Loss: 0.2110, Val Accuracy: 95.10%
#
# [27/100] Train Loss: 0.0437, Val Loss: 0.2267, Val Accuracy: 95.34%
#
# [28/100] Train Loss: 0.0511, Val Loss: 0.2715, Val Accuracy: 94.87%
#
# [29/100] Train Loss: 0.0504, Val Loss: 0.2115, Val Accuracy: 94.64%
#
# [30/100] Train Loss: 0.0500, Val Loss: 0.2614, Val Accuracy: 94.87%
#
# [31/100] Train Loss: 0.0461, Val Loss: 0.2030, Val Accuracy: 95.57%
#
# [32/100] Train Loss: 0.0376, Val Loss: 0.2609, Val Accuracy: 94.64%
#
# [33/100] Train Loss: 0.0369, Val Loss: 0.2591, Val Accuracy: 94.17%
#
# [34/100] Train Loss: 0.0380, Val Loss: 0.2247, Val Accuracy: 95.57%
#
# [35/100] Train Loss: 0.0377, Val Loss: 0.1738, Val Accuracy: 96.27%
#
# [36/100] Train Loss: 0.0191, Val Loss: 0.3123, Val Accuracy: 95.34%
#
# [37/100] Train Loss: 0.0260, Val Loss: 0.2365, Val Accuracy: 96.04%
#
# [38/100] Train Loss: 0.0352, Val Loss: 0.1992, Val Accuracy: 95.57%
#
# [39/100] Train Loss: 0.0238, Val Loss: 0.2871, Val Accuracy: 95.10%
#
# [40/100] Train Loss: 0.0152, Val Loss: 0.2781, Val Accuracy: 95.10%
#
# [41/100] Train Loss: 0.0151, Val Loss: 0.3223, Val Accuracy: 95.34%
#
# [42/100] Train Loss: 0.0119, Val Loss: 0.2201, Val Accuracy: 95.80%
#
# [43/100] Train Loss: 0.0208, Val Loss: 0.2200, Val Accuracy: 96.04%
#
# [44/100] Train Loss: 0.0205, Val Loss: 0.2548, Val Accuracy: 95.57%
#
# [45/100] Train Loss: 0.0455, Val Loss: 0.1844, Val Accuracy: 95.34%
#
# [46/100] Train Loss: 0.0161, Val Loss: 0.3538, Val Accuracy: 95.10%
#
# [47/100] Train Loss: 0.0159, Val Loss: 0.2463, Val Accuracy: 95.57%
#
# [48/100] Train Loss: 0.0107, Val Loss: 0.3618, Val Accuracy: 96.04%
#
# [49/100] Train Loss: 0.0081, Val Loss: 0.3533, Val Accuracy: 95.57%
#
# [50/100] Train Loss: 0.0175, Val Loss: 0.3688, Val Accuracy: 94.64%
#
# [51/100] Train Loss: 0.0278, Val Loss: 0.2615, Val Accuracy: 95.80%
#
# [52/100] Train Loss: 0.0098, Val Loss: 0.3866, Val Accuracy: 95.57%
#
# [53/100] Train Loss: 0.0117, Val Loss: 0.3444, Val Accuracy: 95.80%
#
# [54/100] Train Loss: 0.0089, Val Loss: 0.3040, Val Accuracy: 96.04%
#
# [55/100] Train Loss: 0.0057, Val Loss: 0.3377, Val Accuracy: 96.04%
#
# [56/100] Train Loss: 0.0131, Val Loss: 0.4144, Val Accuracy: 94.87%
#
# [57/100] Train Loss: 0.0051, Val Loss: 0.3456, Val Accuracy: 95.57%
#
# [58/100] Train Loss: 0.0049, Val Loss: 0.3692, Val Accuracy: 96.27%
#
# [59/100] Train Loss: 0.0047, Val Loss: 0.3645, Val Accuracy: 96.50%
#
# [60/100] Train Loss: 0.0058, Val Loss: 0.3777, Val Accuracy: 95.80%
#
# [61/100] Train Loss: 0.0037, Val Loss: 0.4558, Val Accuracy: 95.57%
#
# [62/100] Train Loss: 0.0039, Val Loss: 0.4297, Val Accuracy: 95.80%
#
# [63/100] Train Loss: 0.0030, Val Loss: 0.4275, Val Accuracy: 95.80%
#
# [64/100] Train Loss: 0.0037, Val Loss: 0.4509, Val Accuracy: 95.57%
#
# [65/100] Train Loss: 0.0051, Val Loss: 0.3818, Val Accuracy: 95.80%
#
# [66/100] Train Loss: 0.0033, Val Loss: 0.4175, Val Accuracy: 95.80%
#
# [67/100] Train Loss: 0.0034, Val Loss: 0.4205, Val Accuracy: 95.80%
#
# [68/100] Train Loss: 0.0018, Val Loss: 0.4601, Val Accuracy: 95.57%
#
# [69/100] Train Loss: 0.0029, Val Loss: 0.4342, Val Accuracy: 96.04%
#
# [70/100] Train Loss: 0.0017, Val Loss: 0.4957, Val Accuracy: 95.34%
#
# [71/100] Train Loss: 0.0023, Val Loss: 0.4345, Val Accuracy: 96.27%
#
# [72/100] Train Loss: 0.0039, Val Loss: 0.4759, Val Accuracy: 96.04%
#
# [73/100] Train Loss: 0.0015, Val Loss: 0.4737, Val Accuracy: 96.04%
#
# [74/100] Train Loss: 0.0018, Val Loss: 0.4685, Val Accuracy: 96.27%
#
# [75/100] Train Loss: 0.0056, Val Loss: 0.4556, Val Accuracy: 95.57%
#
# [76/100] Train Loss: 0.0024, Val Loss: 0.4309, Val Accuracy: 95.80%
#
# [77/100] Train Loss: 0.0022, Val Loss: 0.4207, Val Accuracy: 96.04%
#
# [78/100] Train Loss: 0.0020, Val Loss: 0.4302, Val Accuracy: 95.80%
#
# [79/100] Train Loss: 0.0014, Val Loss: 0.4279, Val Accuracy: 96.27%
#
# [80/100] Train Loss: 0.0015, Val Loss: 0.4380, Val Accuracy: 96.04%
#
# [81/100] Train Loss: 0.0012, Val Loss: 0.4413, Val Accuracy: 95.80%
#
# [82/100] Train Loss: 0.0018, Val Loss: 0.4558, Val Accuracy: 95.80%
#
# [83/100] Train Loss: 0.0020, Val Loss: 0.4484, Val Accuracy: 95.80%
#
# [84/100] Train Loss: 0.0019, Val Loss: 0.4423, Val Accuracy: 96.04%
#
# [85/100] Train Loss: 0.0018, Val Loss: 0.4574, Val Accuracy: 96.04%
#
# [86/100] Train Loss: 0.0013, Val Loss: 0.4518, Val Accuracy: 96.04%
#
# [87/100] Train Loss: 0.0018, Val Loss: 0.4789, Val Accuracy: 96.04%
#
# [88/100] Train Loss: 0.0017, Val Loss: 0.4687, Val Accuracy: 96.04%
#
# [89/100] Train Loss: 0.0009, Val Loss: 0.4664, Val Accuracy: 96.04%
#
# [90/100] Train Loss: 0.0016, Val Loss: 0.4658, Val Accuracy: 96.27%
#
# [91/100] Train Loss: 0.0016, Val Loss: 0.4712, Val Accuracy: 96.04%
#
# [92/100] Train Loss: 0.0011, Val Loss: 0.4715, Val Accuracy: 96.04%
#
# [93/100] Train Loss: 0.0013, Val Loss: 0.4701, Val Accuracy: 96.04%
#
# [94/100] Train Loss: 0.0014, Val Loss: 0.4703, Val Accuracy: 96.04%
#
# [95/100] Train Loss: 0.0015, Val Loss: 0.4654, Val Accuracy: 96.27%
#
# [96/100] Train Loss: 0.0014, Val Loss: 0.4656, Val Accuracy: 96.27%
#
# [97/100] Train Loss: 0.0018, Val Loss: 0.4656, Val Accuracy: 96.27%
#
# [98/100] Train Loss: 0.0015, Val Loss: 0.4668, Val Accuracy: 96.27%
#
# [99/100] Train Loss: 0.0015, Val Loss: 0.4666, Val Accuracy: 96.27%
#
# [100/100] Train Loss: 0.0010, Val Loss: 0.4667, Val Accuracy: 96.27%

# %%
_, _, acc_simsiam_finetuned_all, auc_simsiam_finetuned_all = test_(ft_network, val_loader, nn.CrossEntropyLoss())
# Out:
# Evaluation on held out test dataset
# Confusion Matrix
# +----------------+------------------+---------------------+
# |                | predicted lenses | predicted nonlenses |
# +----------------+------------------+---------------------+
# |  true lenses   |       252        |          7          |
# | true nonlenses |        9         |         161         |
# +----------------+------------------+---------------------+
# Test Metrics
# +-----------+----------+
# |  accuracy | 96.2704% |
# |    loss   |  0.1022  |
# | auc score |  0.9785  |
# +-----------+----------+
# +----------------+-----------+--------+---------+---------+
# |                | precision | recall | f-score | support |
# +----------------+-----------+--------+---------+---------+
# |     lenses     |   0.9655  | 0.9730 |  0.9692 |   259   |
# |   nonlenses    |   0.9583  | 0.9471 |  0.9527 |   170   |
# | macro averaged |   0.9619  | 0.9600 |  0.9609 |         |
# +----------------+-----------+--------+---------+---------+

# %%
_, _, acc_simsiam_finetuned_all, auc_simsiam_finetuned_all = test_(ft_network, test_loader, nn.CrossEntropyLoss())
# Out:
# Evaluation on held out test dataset
# Confusion Matrix
# +----------------+------------------+---------------------+
# |                | predicted lenses | predicted nonlenses |
# +----------------+------------------+---------------------+
# |  true lenses   |       439        |          19         |
# | true nonlenses |        18        |         282         |
# +----------------+------------------+---------------------+
# Test Metrics
# +-----------+----------+
# |  accuracy | 95.1187% |
# |    loss   |  0.0507  |
# | auc score |  0.9864  |
# +-----------+----------+
# +----------------+-----------+--------+---------+---------+
# |                | precision | recall | f-score | support |
# +----------------+-----------+--------+---------+---------+
# |     lenses     |   0.9606  | 0.9585 |  0.9596 |   458   |
# |   nonlenses    |   0.9369  | 0.9400 |  0.9384 |   300   |
# | macro averaged |   0.9487  | 0.9493 |  0.9490 |         |
# +----------------+-----------+--------+---------+---------+

# %% [markdown]
# ### ROC Curves for the SSL model finetuning are plotted below

# %%
plt.figure(figsize=(15, 15))
plt.title('ROC')
plt.plot(fpr_simsiam_finetuned_300, tpr_simsiam_finetuned_300, 'r', label = 'AUC (finetuned on 300 labelled data, simsiam pretrained) = %0.4f' % auc_simsiam_finetuned_300)
plt.plot(fpr_simsiam_finetuned_600, tpr_simsiam_finetuned_600, 'm', label = 'AUC (finetuned on 600 labelled data, simsiam pretrained) = %0.4f' % auc_simsiam_finetuned_600)
plt.plot(fpr_simsiam_finetuned_1200, tpr_simsiam_finetuned_1200, 'g', label = 'AUC (finetuned on 1200 labelled data, simsiam pretrained) = %0.4f' % auc_simsiam_finetuned_1200)
plt.plot(fpr_simsiam_finetuned_all, tpr_simsiam_finetuned_all, 'b', label = 'AUC (finetuned on all labelled data, simsiam pretrained) = %0.4f' % auc_simsiam_finetuned_all)

plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.savefig("auc_ssl_simsiam.png")
plt.show()

# %% [markdown]
# ### ROC Curves for the SSL and supervised models are plotted below

# %%
plt.figure(figsize=(15, 15))
plt.title('ROC')
plt.plot(fpr_simsiam_finetuned_300, tpr_simsiam_finetuned_300, 'r', label = 'AUC (finetuned on 300 labelled data, simsiam pretrained) = %0.4f' % auc_simsiam_finetuned_300)
plt.plot(fpr_simsiam_finetuned_600, tpr_simsiam_finetuned_600, 'm', label = 'AUC (finetuned on 600 labelled data, simsiam pretrained) = %0.4f' % auc_simsiam_finetuned_600)
plt.plot(fpr_simsiam_finetuned_1200, tpr_simsiam_finetuned_1200, 'g', label = 'AUC (finetuned on 1200 labelled data, simsiam pretrained) = %0.4f' % auc_simsiam_finetuned_1200)
plt.plot(fpr_simsiam_finetuned_all, tpr_simsiam_finetuned_all, 'b', label = 'AUC (finetuned on all labelled data, simsiam pretrained) = %0.4f' % auc_simsiam_finetuned_all)

plt.plot(fpr_supervised_300, tpr_supervised_300, 'r:', label = 'AUC (trained on 300 labelled data, supervised) = %0.4f' % auc_score_300)
plt.plot(fpr_supervised_600, tpr_supervised_600, 'm:', label = 'AUC (trained on 600 labelled data, supervised) = %0.4f' % auc_score_600)
plt.plot(fpr_supervised_1200, tpr_supervised_1200, 'g:', label = 'AUC (trained on 1200 labelled data, supervised) = %0.4f' % auc_score_1200)
plt.plot(fpr_supervised_all, tpr_supervised_all, 'b:', label = 'AUC (trained on all labelled data, supervised) = %0.4f' % auc_score_all)

plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.savefig("auc_supervised_ssl_simsiam.png")
plt.show()

# %% [markdown]
# ## Dino Pretrained ViT Base Backbone

# %% [markdown]
# ---

# %% [markdown]
# For classifying lenses from non-lenses, self-supervised learning (SSL), particularly with the transformer backbones could potentially outperform traditional supervised methods with abundant unlabelled dataset. The learned representations are then evaluated on the downstream task to classify lens and non-lens images. <br>
# The dataset contains 1949 lens images and 2000 non-lens images. Each image has 3 channels, g, r and i, corresponding to green, red and infrared filters respectively. The images are center cropped to 32 × 32 pixel as this empirically resulted in better prediction accuracy. <br>
# To understand how well SSL works with different fractions of labelled and unlabelled data, the model is pre-trained through self supervision on the entire data and then finetuned on the labelled fraction and compared with supervised baseline trained only on that labeled fraction. <br>
# The following table summarizes the results.

# %% [markdown]
# | # labelled data for <br> training/fine-tuning | Training | Accuracy | AUC |
# |:---:|:----------:|:----------:|:----------:|
# |300|Supervised | 86.6779% | 0.9339 |
# ||DINO | 89.5447% | 0.9487 |
# |600|Supervised | 88.3642% | 0.9371 |
# ||DINO | 89.5447% | 0.9376 |
# |1200|Supervised | 90.7251% | 0.9698 |
# ||DINO | 92.5801% | 0.9768 |
# |3256 |Supervised | 93.0860% | 0.9786 |
# ||DINO | 94.6037% | 0.9810 |

# %% [markdown]
# ROC Curves for the SSL and supervised models are plotted below

# %% [markdown]
# ![](../assets/auc_supervised_dino_ssl_vit_base.png)

# %% [markdown]
# ---

# %%
import sys
sys.path.append("/kaggle/input/deeplense-ssl-sreehari-iyer/DeepLense_SSL_Sreehari_Iyer-1")
# !pip install GPUtil

# %%
import numpy as np
import os
import torch
import torch.nn as nn
import torchvision.transforms as Transforms
from torch.utils.data import random_split, DataLoader, Dataset
from sklearn import metrics
import copy
import pickle
from utils import set_seed
from utils.eval import train
from models.backbone import Backbone
from augmentations.loader import npy_loader
from augmentations import ImageDataset
from models.classifier import Classifier
from utils.eval import test_
import matplotlib.pyplot as plt
set_seed(12)

# %%
def get_datasets(num_labelled_points):
    set_seed(12)

    eval_transforms = Transforms.Compose([
                    # Transforms.ToTensor(), # npy loader returns torch.Tensor
                    Transforms.CenterCrop(32),
                    Transforms.Normalize(mean = [0.17172211408615112, 0.5951611399650574, 1.205482840538025],\
                                         std = [0.2224876880645752, 0.8682928085327148, 2.003822088241577]),
                ])

    #--------------------------------------------------------------------------------------------------------

    train_test_indices = "/kaggle/input/reallenses-traintestindices/indices.pkl"
    data_path = "/kaggle/input/reallensdataset/real_lenses_dataset"
    
    train_indices_path = None
    indices = None
    with open(train_test_indices, "rb") as f:
        indices = pickle.load(f)
    train_indices = None
    
    if num_labelled_points == 300:
        train_indices_path = "/kaggle/input/reallenses-traintestindices/train_indices_300.pkl"
        with open(train_indices_path, "rb") as f:
            train_indices = pickle.load(f)
    elif num_labelled_points == 600:
        train_indices_path = "/kaggle/input/reallenses-traintestindices/train_indices_600.pkl"
        with open(train_indices_path, "rb") as f:
            train_indices = pickle.load(f)
    elif num_labelled_points == 1200:
        train_indices_path = "/kaggle/input/reallenses-traintestindices/train_indices_1200.pkl"
        with open(train_indices_path, "rb") as f:
            train_indices = pickle.load(f)
    elif num_labelled_points is None:
        train_indices_path = "/kaggle/input/reallenses-traintestindices/indices.pkl"
        with open(train_indices_path, "rb") as f:
            train_indices = pickle.load(f)
        train_indices = train_indices["train"]

    # train images and labels
    train_paths = [os.path.join(data_path, *["lenses", img]) for img in np.array(train_indices["lenses"])] +\
                    [os.path.join(data_path, *["nonlenses", img]) for img in np.array(train_indices["nonlenses"])]
    train_labels = [0]*len(train_indices["lenses"]) + [1]*len(train_indices["nonlenses"])

    # validation images and labels
    val_paths = [os.path.join(data_path, *["lenses", img]) for img in np.array(indices["val"]["lenses"])] +\
                    [os.path.join(data_path, *["nonlenses", img]) for img in np.array(indices["val"]["nonlenses"])]
    val_labels = [0]*len(indices["val"]["lenses"]) + [1]*len(indices["val"]["nonlenses"])

    # test images and labels
    test_paths = [os.path.join(data_path, *["lenses", img]) for img in np.array(indices["test"]["lenses"])] +\
                    [os.path.join(data_path, *["nonlenses", img]) for img in np.array(indices["test"]["nonlenses"])]
    test_labels = [0]*len(indices["test"]["lenses"]) + [1]*len(indices["test"]["nonlenses"])

    # sizes of the train, validation and test datasets
    train_size = len(train_paths)
    val_size = len(val_paths)
    test_size = len(test_paths)
    #--------------------------------------------------------------------------------------------------------

    dataset = ImageDataset(
        image_paths=train_paths+val_paths+test_paths,
        labels=train_labels+val_labels+test_labels,
        loader=npy_loader,
        transform=eval_transforms
    )
    train_dataset = ImageDataset(
        image_paths=train_paths,
        labels=train_labels,
        loader=npy_loader,
        transform=eval_transforms
    ) 
    val_dataset = ImageDataset(
        image_paths=val_paths,
        labels=val_labels,
        loader=npy_loader,
        transform=eval_transforms
    )
    test_dataset = ImageDataset(
        image_paths=test_paths,
        labels=test_labels,
        loader=npy_loader,
        transform=eval_transforms
    )
    data_loader = DataLoader(
        dataset,
        batch_size=64,
        num_workers=0,
        shuffle=False,
    )
    train_loader = DataLoader(
        train_dataset,
        batch_size=64,
        num_workers=0,
        shuffle=True,
    )
    val_loader = DataLoader(
        val_dataset,
        batch_size=64,
        num_workers=0,
        shuffle=False,
    )
    test_loader = DataLoader(
        test_dataset,
        batch_size=64,
        num_workers=0,
        shuffle=False,
    )
    return train_loader, val_loader, test_loader

def compute_auc(ft_network, test_loader):
    y = None
    scores = None
    ft_network.eval()
    ft_network = ft_network.cuda()
    for img, label in test_loader:
        img, label = img.cuda(), label.cuda()
        preds = ft_network(img)
        if y is None:
            y = label.detach().cpu().numpy()
        else:
            y = np.concatenate([y, label.detach().cpu().numpy()], axis=0)
        if scores is None:
            scores = preds.detach().cpu().numpy()
        else:
            scores = np.vstack((scores, preds.detach().cpu().numpy()))
    fpr, tpr, _ = metrics.roc_curve(y, scores[:,1])
    auc_score = metrics.auc(fpr, tpr)
    return fpr, tpr, auc_score

# %% [markdown]
# ### ViT Base Classifier trained on 300 labelled datapoints through supervised learning

# %%
set_seed(12)
train_loader, val_loader, test_loader = get_datasets(300)
ft_network = Classifier(mode = "finetune", backbone = Backbone(arch="vit_base", image_size=32, input_channels=3, patch_size=8))
optimizer = torch.optim.Adam(ft_network.parameters(), lr=1e-4, weight_decay=1e-3)
num_epochs = 100
scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, eta_min=1e-8, T_max=num_epochs)
ft_network, ft_network_best_loss = train(ft_network, train_loader, val_loader, nn.CrossEntropyLoss(), optimizer, num_epochs=num_epochs, scheduler=scheduler)

torch.save(ft_network, "/kaggle/working/supervised-300-ckpt.pth")
fpr_supervised_300, tpr_supervised_300, auc_score_300 = compute_auc(ft_network, test_loader)
# Out:
# [1/100] Train Loss: 4.7637, Val Loss: 0.8888, Val Accuracy: 60.00%
#
# [2/100] Train Loss: 1.1171, Val Loss: 1.2593, Val Accuracy: 50.00%
#
# [3/100] Train Loss: 0.8151, Val Loss: 0.6786, Val Accuracy: 61.00%
#
# [4/100] Train Loss: 0.6749, Val Loss: 0.6885, Val Accuracy: 83.00%
#
# [5/100] Train Loss: 0.6424, Val Loss: 0.5154, Val Accuracy: 64.00%
#
# [6/100] Train Loss: 0.5864, Val Loss: 0.5209, Val Accuracy: 70.00%
#
# [7/100] Train Loss: 0.5440, Val Loss: 0.5583, Val Accuracy: 81.00%
#
# [8/100] Train Loss: 0.4747, Val Loss: 0.4462, Val Accuracy: 67.00%
#
# [9/100] Train Loss: 0.4266, Val Loss: 0.5275, Val Accuracy: 85.00%
#
# [10/100] Train Loss: 0.4195, Val Loss: 0.3800, Val Accuracy: 82.00%
#
# [11/100] Train Loss: 0.4104, Val Loss: 0.3917, Val Accuracy: 83.00%
#
# [12/100] Train Loss: 0.3951, Val Loss: 0.3835, Val Accuracy: 85.00%
#
# [13/100] Train Loss: 0.3524, Val Loss: 0.3336, Val Accuracy: 85.00%
#
# [14/100] Train Loss: 0.3453, Val Loss: 0.3574, Val Accuracy: 83.00%
#
# [15/100] Train Loss: 0.3509, Val Loss: 0.3010, Val Accuracy: 83.00%
#
# [16/100] Train Loss: 0.3325, Val Loss: 0.3768, Val Accuracy: 86.00%
#
# [17/100] Train Loss: 0.3206, Val Loss: 0.2935, Val Accuracy: 83.00%
#
# [18/100] Train Loss: 0.3181, Val Loss: 0.4817, Val Accuracy: 85.00%
#
# [19/100] Train Loss: 0.3019, Val Loss: 0.2992, Val Accuracy: 85.00%
#
# [20/100] Train Loss: 0.3142, Val Loss: 0.3900, Val Accuracy: 87.00%
#
# [21/100] Train Loss: 0.2648, Val Loss: 0.2979, Val Accuracy: 84.00%
#
# [22/100] Train Loss: 0.2393, Val Loss: 0.2907, Val Accuracy: 86.00%
#
# [23/100] Train Loss: 0.2358, Val Loss: 0.4451, Val Accuracy: 87.00%
#
# [24/100] Train Loss: 0.2459, Val Loss: 0.3306, Val Accuracy: 84.00%
#
# [25/100] Train Loss: 0.2664, Val Loss: 0.4293, Val Accuracy: 87.00%
#
# [26/100] Train Loss: 0.2136, Val Loss: 0.2736, Val Accuracy: 86.00%
#
# [27/100] Train Loss: 0.2012, Val Loss: 0.3981, Val Accuracy: 85.00%
#
# [28/100] Train Loss: 0.1962, Val Loss: 0.6208, Val Accuracy: 87.00%
#
# [29/100] Train Loss: 0.2859, Val Loss: 0.4188, Val Accuracy: 81.00%
#
# [30/100] Train Loss: 0.3779, Val Loss: 0.3492, Val Accuracy: 86.00%
#
# [31/100] Train Loss: 0.2572, Val Loss: 0.3806, Val Accuracy: 86.00%
#
# [32/100] Train Loss: 0.2729, Val Loss: 0.3299, Val Accuracy: 85.00%
#
# [33/100] Train Loss: 0.2256, Val Loss: 0.3264, Val Accuracy: 86.00%
#
# [34/100] Train Loss: 0.2226, Val Loss: 0.5112, Val Accuracy: 85.00%
#
# [35/100] Train Loss: 0.2246, Val Loss: 0.3565, Val Accuracy: 84.00%
#
# [36/100] Train Loss: 0.1918, Val Loss: 0.4391, Val Accuracy: 87.00%
#
# [37/100] Train Loss: 0.1803, Val Loss: 0.3382, Val Accuracy: 86.00%
#
# [38/100] Train Loss: 0.1763, Val Loss: 0.4288, Val Accuracy: 86.00%
#
# [39/100] Train Loss: 0.1636, Val Loss: 0.3809, Val Accuracy: 86.00%
#
# [40/100] Train Loss: 0.1381, Val Loss: 0.4420, Val Accuracy: 88.00%
#
# [41/100] Train Loss: 0.1120, Val Loss: 0.5360, Val Accuracy: 89.00%
#
# [42/100] Train Loss: 0.1035, Val Loss: 0.4392, Val Accuracy: 85.00%
#
# [43/100] Train Loss: 0.0976, Val Loss: 0.4782, Val Accuracy: 87.00%
#
# [44/100] Train Loss: 0.0859, Val Loss: 0.4590, Val Accuracy: 89.00%
#
# [45/100] Train Loss: 0.0754, Val Loss: 0.5291, Val Accuracy: 87.00%
#
# [46/100] Train Loss: 0.0978, Val Loss: 0.5074, Val Accuracy: 88.00%
#
# [47/100] Train Loss: 0.1063, Val Loss: 0.4950, Val Accuracy: 87.00%
#
# [48/100] Train Loss: 0.0943, Val Loss: 0.5926, Val Accuracy: 88.00%
#
# [49/100] Train Loss: 0.0939, Val Loss: 0.4940, Val Accuracy: 87.00%
#
# [50/100] Train Loss: 0.0998, Val Loss: 0.5889, Val Accuracy: 89.00%
#
# [51/100] Train Loss: 0.0871, Val Loss: 0.5288, Val Accuracy: 89.00%
#
# [52/100] Train Loss: 0.0998, Val Loss: 0.4985, Val Accuracy: 87.00%
#
# [53/100] Train Loss: 0.0924, Val Loss: 0.5205, Val Accuracy: 87.00%
#
# [54/100] Train Loss: 0.0738, Val Loss: 0.4813, Val Accuracy: 87.00%
#
# [55/100] Train Loss: 0.0705, Val Loss: 0.6898, Val Accuracy: 87.00%
#
# [56/100] Train Loss: 0.0546, Val Loss: 0.5700, Val Accuracy: 90.00%
#
# [57/100] Train Loss: 0.0699, Val Loss: 0.6725, Val Accuracy: 88.00%
#
# [58/100] Train Loss: 0.0923, Val Loss: 0.6296, Val Accuracy: 89.00%
#
# [59/100] Train Loss: 0.0547, Val Loss: 0.5031, Val Accuracy: 88.00%
#
# [60/100] Train Loss: 0.0593, Val Loss: 0.5342, Val Accuracy: 89.00%
#
# [61/100] Train Loss: 0.0628, Val Loss: 0.5424, Val Accuracy: 89.00%
#
# [62/100] Train Loss: 0.0418, Val Loss: 0.5268, Val Accuracy: 89.00%
#
# [63/100] Train Loss: 0.0328, Val Loss: 0.5693, Val Accuracy: 87.00%
#
# [64/100] Train Loss: 0.0775, Val Loss: 0.5513, Val Accuracy: 89.00%
#
# [65/100] Train Loss: 0.0317, Val Loss: 0.5600, Val Accuracy: 89.00%
#
# [66/100] Train Loss: 0.0414, Val Loss: 0.6028, Val Accuracy: 89.00%
#
# [67/100] Train Loss: 0.0388, Val Loss: 0.5945, Val Accuracy: 90.00%
#
# [68/100] Train Loss: 0.0272, Val Loss: 0.5834, Val Accuracy: 89.00%
#
# [69/100] Train Loss: 0.0308, Val Loss: 0.6428, Val Accuracy: 90.00%
#
# [70/100] Train Loss: 0.0285, Val Loss: 0.6102, Val Accuracy: 90.00%
#
# [71/100] Train Loss: 0.0118, Val Loss: 0.6274, Val Accuracy: 89.00%
#
# [72/100] Train Loss: 0.0518, Val Loss: 0.6528, Val Accuracy: 89.00%
#
# [73/100] Train Loss: 0.0248, Val Loss: 0.6563, Val Accuracy: 89.00%
#
# [74/100] Train Loss: 0.0199, Val Loss: 0.6477, Val Accuracy: 88.00%
#
# [75/100] Train Loss: 0.0168, Val Loss: 0.6727, Val Accuracy: 88.00%
#
# [76/100] Train Loss: 0.0119, Val Loss: 0.6817, Val Accuracy: 88.00%
#
# [77/100] Train Loss: 0.0254, Val Loss: 0.6539, Val Accuracy: 89.00%
#
# [78/100] Train Loss: 0.0257, Val Loss: 0.6472, Val Accuracy: 89.00%
#
# [79/100] Train Loss: 0.0184, Val Loss: 0.6613, Val Accuracy: 89.00%
#
# [80/100] Train Loss: 0.0208, Val Loss: 0.6604, Val Accuracy: 89.00%
#
# [81/100] Train Loss: 0.0100, Val Loss: 0.6725, Val Accuracy: 88.00%
#
# [82/100] Train Loss: 0.0271, Val Loss: 0.6892, Val Accuracy: 88.00%
#
# [83/100] Train Loss: 0.0164, Val Loss: 0.7107, Val Accuracy: 88.00%
#
# [84/100] Train Loss: 0.0175, Val Loss: 0.7096, Val Accuracy: 88.00%
#
# [85/100] Train Loss: 0.0102, Val Loss: 0.6942, Val Accuracy: 89.00%
#
# [86/100] Train Loss: 0.0176, Val Loss: 0.6852, Val Accuracy: 88.00%
#
# [87/100] Train Loss: 0.0196, Val Loss: 0.6739, Val Accuracy: 89.00%
#
# [88/100] Train Loss: 0.0136, Val Loss: 0.6765, Val Accuracy: 88.00%
#
# [89/100] Train Loss: 0.0244, Val Loss: 0.6833, Val Accuracy: 88.00%
#
# [90/100] Train Loss: 0.0158, Val Loss: 0.6907, Val Accuracy: 88.00%
#
# [91/100] Train Loss: 0.0370, Val Loss: 0.7015, Val Accuracy: 88.00%
#
# [92/100] Train Loss: 0.0462, Val Loss: 0.7029, Val Accuracy: 88.00%
#
# [93/100] Train Loss: 0.0113, Val Loss: 0.7012, Val Accuracy: 88.00%
#
# [94/100] Train Loss: 0.0177, Val Loss: 0.6994, Val Accuracy: 88.00%
#
# [95/100] Train Loss: 0.0402, Val Loss: 0.6999, Val Accuracy: 88.00%
#
# [96/100] Train Loss: 0.0233, Val Loss: 0.7001, Val Accuracy: 88.00%
#
# [97/100] Train Loss: 0.0148, Val Loss: 0.7008, Val Accuracy: 88.00%
#
# [98/100] Train Loss: 0.0193, Val Loss: 0.7010, Val Accuracy: 88.00%
#
# [99/100] Train Loss: 0.0243, Val Loss: 0.7014, Val Accuracy: 88.00%
#
# [100/100] Train Loss: 0.0234, Val Loss: 0.7016, Val Accuracy: 88.00%

# %%
_, _, acc_supervised_300_val, auc_supervised_300_val = test_(ft_network, val_loader, nn.CrossEntropyLoss())
# Out:
# Evaluation on held out test dataset
# Confusion Matrix
# +----------------+------------------+---------------------+
# |                | predicted lenses | predicted nonlenses |
# +----------------+------------------+---------------------+
# |  true lenses   |        46        |          4          |
# | true nonlenses |        8         |          42         |
# +----------------+------------------+---------------------+
# Test Metrics
# +-----------+----------+
# |  accuracy | 88.0000% |
# |    loss   |  0.4174  |
# | auc score |  0.9412  |
# +-----------+----------+
# +----------------+-----------+--------+---------+---------+
# |                | precision | recall | f-score | support |
# +----------------+-----------+--------+---------+---------+
# |     lenses     |   0.8519  | 0.9200 |  0.8846 |    50   |
# |   nonlenses    |   0.9130  | 0.8400 |  0.8750 |    50   |
# | macro averaged |   0.8824  | 0.8800 |  0.8798 |         |
# +----------------+-----------+--------+---------+---------+

# %%
_, _, acc_supervised_300_test, auc_supervised_300_test = test_(ft_network, test_loader, nn.CrossEntropyLoss())
# Out:
# Evaluation on held out test dataset
# Confusion Matrix
# +----------------+------------------+---------------------+
# |                | predicted lenses | predicted nonlenses |
# +----------------+------------------+---------------------+
# |  true lenses   |       256        |          37         |
# | true nonlenses |        42        |         258         |
# +----------------+------------------+---------------------+
# Test Metrics
# +-----------+----------+
# |  accuracy | 86.6779% |
# |    loss   |  0.0689  |
# | auc score |  0.9339  |
# +-----------+----------+
# +----------------+-----------+--------+---------+---------+
# |                | precision | recall | f-score | support |
# +----------------+-----------+--------+---------+---------+
# |     lenses     |   0.8591  | 0.8737 |  0.8663 |   293   |
# |   nonlenses    |   0.8746  | 0.8600 |  0.8672 |   300   |
# | macro averaged |   0.8668  | 0.8669 |  0.8668 |         |
# +----------------+-----------+--------+---------+---------+

# %% [markdown]
# ### ViT Base Classifier trained on 600 labelled datapoints through supervised learning

# %%
set_seed(12)
train_loader, val_loader, test_loader = get_datasets(600)
ft_network = Classifier(mode = "finetune", backbone = Backbone(arch="vit_base", image_size=32, input_channels=3, patch_size=8))
optimizer = torch.optim.Adam(ft_network.parameters(), lr=1e-4, weight_decay=1e-3)
num_epochs = 100
scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, eta_min=1e-8, T_max=num_epochs)
ft_network, ft_network_best_loss = train(ft_network, train_loader, val_loader, nn.CrossEntropyLoss(), optimizer, num_epochs=num_epochs, scheduler=scheduler)

torch.save(ft_network, "/kaggle/working/supervised-600-ckpt.pth")
fpr_supervised_600, tpr_supervised_600, auc_score_600 = compute_auc(ft_network, test_loader)
# Out:
# [1/100] Train Loss: 3.0995, Val Loss: 1.1203, Val Accuracy: 50.00%
#
# [2/100] Train Loss: 0.7256, Val Loss: 0.6594, Val Accuracy: 69.00%
#
# [3/100] Train Loss: 0.5421, Val Loss: 0.5345, Val Accuracy: 69.00%
#
# [4/100] Train Loss: 0.4864, Val Loss: 0.4672, Val Accuracy: 82.00%
#
# [5/100] Train Loss: 0.4192, Val Loss: 0.4724, Val Accuracy: 86.00%
#
# [6/100] Train Loss: 0.3572, Val Loss: 0.3897, Val Accuracy: 81.00%
#
# [7/100] Train Loss: 0.3126, Val Loss: 0.3453, Val Accuracy: 82.00%
#
# [8/100] Train Loss: 0.2997, Val Loss: 0.3607, Val Accuracy: 84.00%
#
# [9/100] Train Loss: 0.2764, Val Loss: 0.3070, Val Accuracy: 84.00%
#
# [10/100] Train Loss: 0.2636, Val Loss: 0.3698, Val Accuracy: 83.00%
#
# [11/100] Train Loss: 0.2710, Val Loss: 0.3628, Val Accuracy: 86.00%
#
# [12/100] Train Loss: 0.2497, Val Loss: 0.3630, Val Accuracy: 83.00%
#
# [13/100] Train Loss: 0.2301, Val Loss: 0.5454, Val Accuracy: 84.00%
#
# [14/100] Train Loss: 0.2404, Val Loss: 0.6925, Val Accuracy: 80.00%
#
# [15/100] Train Loss: 0.2644, Val Loss: 0.3875, Val Accuracy: 85.00%
#
# [16/100] Train Loss: 0.2018, Val Loss: 0.3795, Val Accuracy: 85.00%
#
# [17/100] Train Loss: 0.1982, Val Loss: 0.4747, Val Accuracy: 83.00%
#
# [18/100] Train Loss: 0.1824, Val Loss: 0.5409, Val Accuracy: 87.00%
#
# [19/100] Train Loss: 0.1686, Val Loss: 0.4384, Val Accuracy: 91.00%
#
# [20/100] Train Loss: 0.1648, Val Loss: 0.5679, Val Accuracy: 91.00%
#
# [21/100] Train Loss: 0.1783, Val Loss: 0.4842, Val Accuracy: 87.00%
#
# [22/100] Train Loss: 0.2284, Val Loss: 0.4812, Val Accuracy: 88.00%
#
# [23/100] Train Loss: 0.1980, Val Loss: 0.4835, Val Accuracy: 85.00%
#
# [24/100] Train Loss: 0.1625, Val Loss: 0.3958, Val Accuracy: 88.00%
#
# [25/100] Train Loss: 0.2062, Val Loss: 0.5042, Val Accuracy: 87.00%
#
# [26/100] Train Loss: 0.1749, Val Loss: 0.4293, Val Accuracy: 88.00%
#
# [27/100] Train Loss: 0.1302, Val Loss: 0.4775, Val Accuracy: 88.00%
#
# [28/100] Train Loss: 0.1260, Val Loss: 0.4565, Val Accuracy: 89.00%
#
# [29/100] Train Loss: 0.0951, Val Loss: 0.5421, Val Accuracy: 89.00%
#
# [30/100] Train Loss: 0.0925, Val Loss: 0.6566, Val Accuracy: 90.00%
#
# [31/100] Train Loss: 0.0911, Val Loss: 1.4309, Val Accuracy: 77.00%
#
# [32/100] Train Loss: 0.2072, Val Loss: 0.6406, Val Accuracy: 89.00%
#
# [33/100] Train Loss: 0.1524, Val Loss: 0.7636, Val Accuracy: 82.00%
#
# [34/100] Train Loss: 0.1286, Val Loss: 0.6832, Val Accuracy: 86.00%
#
# [35/100] Train Loss: 0.1351, Val Loss: 0.5012, Val Accuracy: 87.00%
#
# [36/100] Train Loss: 0.1286, Val Loss: 0.4901, Val Accuracy: 89.00%
#
# [37/100] Train Loss: 0.1045, Val Loss: 0.5155, Val Accuracy: 89.00%
#
# [38/100] Train Loss: 0.0974, Val Loss: 0.6216, Val Accuracy: 89.00%
#
# [39/100] Train Loss: 0.1053, Val Loss: 0.7839, Val Accuracy: 88.00%
#
# [40/100] Train Loss: 0.1018, Val Loss: 0.5549, Val Accuracy: 93.00%
#
# [41/100] Train Loss: 0.0899, Val Loss: 0.6540, Val Accuracy: 91.00%
#
# [42/100] Train Loss: 0.0983, Val Loss: 0.6193, Val Accuracy: 87.00%
#
# [43/100] Train Loss: 0.0631, Val Loss: 0.5812, Val Accuracy: 88.00%
#
# [44/100] Train Loss: 0.0552, Val Loss: 0.5859, Val Accuracy: 90.00%
#
# [45/100] Train Loss: 0.0402, Val Loss: 0.7070, Val Accuracy: 90.00%
#
# [46/100] Train Loss: 0.0330, Val Loss: 0.8176, Val Accuracy: 89.00%
#
# [47/100] Train Loss: 0.0364, Val Loss: 0.8440, Val Accuracy: 86.00%
#
# [48/100] Train Loss: 0.0704, Val Loss: 0.7714, Val Accuracy: 90.00%
#
# [49/100] Train Loss: 0.0640, Val Loss: 0.8823, Val Accuracy: 86.00%
#
# [50/100] Train Loss: 0.0386, Val Loss: 0.7845, Val Accuracy: 89.00%
#
# [51/100] Train Loss: 0.0469, Val Loss: 0.8796, Val Accuracy: 90.00%
#
# [52/100] Train Loss: 0.0513, Val Loss: 0.6392, Val Accuracy: 91.00%
#
# [53/100] Train Loss: 0.0394, Val Loss: 0.7838, Val Accuracy: 91.00%
#
# [54/100] Train Loss: 0.0395, Val Loss: 0.8113, Val Accuracy: 91.00%
#
# [55/100] Train Loss: 0.0169, Val Loss: 0.8028, Val Accuracy: 92.00%
#
# [56/100] Train Loss: 0.0335, Val Loss: 0.8433, Val Accuracy: 90.00%
#
# [57/100] Train Loss: 0.0582, Val Loss: 1.0709, Val Accuracy: 90.00%
#
# [58/100] Train Loss: 0.0410, Val Loss: 0.9398, Val Accuracy: 90.00%
#
# [59/100] Train Loss: 0.0345, Val Loss: 0.7070, Val Accuracy: 90.00%
#
# [60/100] Train Loss: 0.0254, Val Loss: 0.7559, Val Accuracy: 92.00%
#
# [61/100] Train Loss: 0.0244, Val Loss: 0.8259, Val Accuracy: 90.00%
#
# [62/100] Train Loss: 0.0154, Val Loss: 0.9117, Val Accuracy: 91.00%
#
# [63/100] Train Loss: 0.0132, Val Loss: 0.9210, Val Accuracy: 92.00%
#
# [64/100] Train Loss: 0.0094, Val Loss: 0.9155, Val Accuracy: 92.00%
#
# [65/100] Train Loss: 0.0126, Val Loss: 1.0591, Val Accuracy: 90.00%
#
# [66/100] Train Loss: 0.0245, Val Loss: 0.9072, Val Accuracy: 88.00%
#
# [67/100] Train Loss: 0.0125, Val Loss: 0.8781, Val Accuracy: 91.00%
#
# [68/100] Train Loss: 0.0107, Val Loss: 0.9270, Val Accuracy: 90.00%
#
# [69/100] Train Loss: 0.0365, Val Loss: 0.9878, Val Accuracy: 91.00%
#
# [70/100] Train Loss: 0.0292, Val Loss: 0.8635, Val Accuracy: 90.00%
#
# [71/100] Train Loss: 0.0199, Val Loss: 0.8779, Val Accuracy: 90.00%
#
# [72/100] Train Loss: 0.0120, Val Loss: 0.9232, Val Accuracy: 91.00%
#
# [73/100] Train Loss: 0.0088, Val Loss: 0.9295, Val Accuracy: 92.00%
#
# [74/100] Train Loss: 0.0110, Val Loss: 0.9271, Val Accuracy: 91.00%
#
# [75/100] Train Loss: 0.0132, Val Loss: 0.9844, Val Accuracy: 92.00%
#
# [76/100] Train Loss: 0.0086, Val Loss: 0.9493, Val Accuracy: 91.00%
#
# [77/100] Train Loss: 0.0090, Val Loss: 0.9791, Val Accuracy: 91.00%
#
# [78/100] Train Loss: 0.0120, Val Loss: 1.0542, Val Accuracy: 92.00%
#
# [79/100] Train Loss: 0.0065, Val Loss: 0.9949, Val Accuracy: 91.00%
#
# [80/100] Train Loss: 0.0166, Val Loss: 1.0053, Val Accuracy: 91.00%
#
# [81/100] Train Loss: 0.0052, Val Loss: 1.0333, Val Accuracy: 91.00%
#
# [82/100] Train Loss: 0.0025, Val Loss: 1.0204, Val Accuracy: 91.00%
#
# [83/100] Train Loss: 0.0109, Val Loss: 1.0087, Val Accuracy: 91.00%
#
# [84/100] Train Loss: 0.0065, Val Loss: 1.0205, Val Accuracy: 92.00%
#
# [85/100] Train Loss: 0.0116, Val Loss: 1.0921, Val Accuracy: 92.00%
#
# [86/100] Train Loss: 0.0177, Val Loss: 1.0344, Val Accuracy: 91.00%
#
# [87/100] Train Loss: 0.0019, Val Loss: 0.9767, Val Accuracy: 91.00%
#
# [88/100] Train Loss: 0.0118, Val Loss: 0.9647, Val Accuracy: 90.00%
#
# [89/100] Train Loss: 0.0139, Val Loss: 0.9712, Val Accuracy: 91.00%
#
# [90/100] Train Loss: 0.0052, Val Loss: 0.9769, Val Accuracy: 91.00%
#
# [91/100] Train Loss: 0.0141, Val Loss: 0.9897, Val Accuracy: 91.00%
#
# [92/100] Train Loss: 0.0148, Val Loss: 0.9852, Val Accuracy: 91.00%
#
# [93/100] Train Loss: 0.0020, Val Loss: 0.9830, Val Accuracy: 91.00%
#
# [94/100] Train Loss: 0.0041, Val Loss: 0.9844, Val Accuracy: 91.00%
#
# [95/100] Train Loss: 0.0283, Val Loss: 0.9904, Val Accuracy: 91.00%
#
# [96/100] Train Loss: 0.0054, Val Loss: 0.9945, Val Accuracy: 91.00%
#
# [97/100] Train Loss: 0.0095, Val Loss: 0.9946, Val Accuracy: 91.00%
#
# [98/100] Train Loss: 0.0046, Val Loss: 0.9942, Val Accuracy: 91.00%
#
# [99/100] Train Loss: 0.0052, Val Loss: 0.9939, Val Accuracy: 91.00%
#
# [100/100] Train Loss: 0.0032, Val Loss: 0.9939, Val Accuracy: 91.00%

# %%
_, _, acc_supervised_600_val, auc_supervised_600_val = test_(ft_network, val_loader, nn.CrossEntropyLoss())
# Out:
# Evaluation on held out test dataset
# Confusion Matrix
# +----------------+------------------+---------------------+
# |                | predicted lenses | predicted nonlenses |
# +----------------+------------------+---------------------+
# |  true lenses   |        48        |          2          |
# | true nonlenses |        7         |          43         |
# +----------------+------------------+---------------------+
# Test Metrics
# +-----------+----------+
# |  accuracy | 91.0000% |
# |    loss   |  0.8425  |
# | auc score |  0.9376  |
# +-----------+----------+
# +----------------+-----------+--------+---------+---------+
# |                | precision | recall | f-score | support |
# +----------------+-----------+--------+---------+---------+
# |     lenses     |   0.8727  | 0.9600 |  0.9143 |    50   |
# |   nonlenses    |   0.9556  | 0.8600 |  0.9053 |    50   |
# | macro averaged |   0.9141  | 0.9100 |  0.9098 |         |
# +----------------+-----------+--------+---------+---------+

# %%
_, _, acc_supervised_600_test, auc_supervised_600_test = test_(ft_network, test_loader, nn.CrossEntropyLoss())
# Out:
# Evaluation on held out test dataset
# Confusion Matrix
# +----------------+------------------+---------------------+
# |                | predicted lenses | predicted nonlenses |
# +----------------+------------------+---------------------+
# |  true lenses   |       260        |          33         |
# | true nonlenses |        36        |         264         |
# +----------------+------------------+---------------------+
# Test Metrics
# +-----------+----------+
# |  accuracy | 88.3642% |
# |    loss   |  0.2156  |
# | auc score |  0.9371  |
# +-----------+----------+
# +----------------+-----------+--------+---------+---------+
# |                | precision | recall | f-score | support |
# +----------------+-----------+--------+---------+---------+
# |     lenses     |   0.8784  | 0.8874 |  0.8829 |   293   |
# |   nonlenses    |   0.8889  | 0.8800 |  0.8844 |   300   |
# | macro averaged |   0.8836  | 0.8837 |  0.8836 |         |
# +----------------+-----------+--------+---------+---------+

# %% [markdown]
# ### ViT Base Classifier trained on 1200 labelled datapoints through supervised learning

# %%
set_seed(12)
train_loader, val_loader, test_loader = get_datasets(1200)
ft_network = Classifier(mode = "finetune", backbone = Backbone(arch="vit_base", image_size=32, input_channels=3, patch_size=8))
optimizer = torch.optim.Adam(ft_network.parameters(), lr=1e-4, weight_decay=1e-8)
num_epochs = 100
scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, eta_min=1e-8, T_max=num_epochs)
ft_network, ft_network_best_loss = train(ft_network, train_loader, val_loader, nn.CrossEntropyLoss(), optimizer, num_epochs=num_epochs, scheduler=scheduler)

torch.save(ft_network, "/kaggle/working/supervised-1200-ckpt.pth")
fpr_supervised_1200, tpr_supervised_1200, auc_score_1200 = compute_auc(ft_network, test_loader)
# Out:
# [1/100] Train Loss: 1.6568, Val Loss: 0.5223, Val Accuracy: 71.00%
#
# [2/100] Train Loss: 0.4739, Val Loss: 0.4019, Val Accuracy: 76.00%
#
# [3/100] Train Loss: 0.3737, Val Loss: 0.3447, Val Accuracy: 83.00%
#
# [4/100] Train Loss: 0.3443, Val Loss: 0.3675, Val Accuracy: 86.00%
#
# [5/100] Train Loss: 0.3093, Val Loss: 0.2766, Val Accuracy: 84.00%
#
# [6/100] Train Loss: 0.3060, Val Loss: 0.3662, Val Accuracy: 82.00%
#
# [7/100] Train Loss: 0.2838, Val Loss: 0.3120, Val Accuracy: 83.00%
#
# [8/100] Train Loss: 0.2658, Val Loss: 0.3935, Val Accuracy: 83.00%
#
# [9/100] Train Loss: 0.2550, Val Loss: 0.2585, Val Accuracy: 85.00%
#
# [10/100] Train Loss: 0.2303, Val Loss: 0.2688, Val Accuracy: 89.00%
#
# [11/100] Train Loss: 0.1993, Val Loss: 0.2543, Val Accuracy: 88.00%
#
# [12/100] Train Loss: 0.1956, Val Loss: 0.3439, Val Accuracy: 85.00%
#
# [13/100] Train Loss: 0.1984, Val Loss: 0.2796, Val Accuracy: 91.00%
#
# [14/100] Train Loss: 0.1955, Val Loss: 0.2503, Val Accuracy: 89.00%
#
# [15/100] Train Loss: 0.1596, Val Loss: 0.2466, Val Accuracy: 88.00%
#
# [16/100] Train Loss: 0.1584, Val Loss: 0.4694, Val Accuracy: 83.00%
#
# [17/100] Train Loss: 0.1788, Val Loss: 0.2662, Val Accuracy: 88.00%
#
# [18/100] Train Loss: 0.1623, Val Loss: 0.3540, Val Accuracy: 88.00%
#
# [19/100] Train Loss: 0.1308, Val Loss: 0.4502, Val Accuracy: 85.00%
#
# [20/100] Train Loss: 0.1090, Val Loss: 0.3685, Val Accuracy: 86.00%
#
# [21/100] Train Loss: 0.1049, Val Loss: 0.2738, Val Accuracy: 89.00%
#
# [22/100] Train Loss: 0.1316, Val Loss: 0.3660, Val Accuracy: 90.00%
#
# [23/100] Train Loss: 0.1043, Val Loss: 0.3699, Val Accuracy: 89.00%
#
# [24/100] Train Loss: 0.1351, Val Loss: 0.4461, Val Accuracy: 87.00%
#
# [25/100] Train Loss: 0.0999, Val Loss: 0.4540, Val Accuracy: 87.00%
#
# [26/100] Train Loss: 0.0782, Val Loss: 0.4007, Val Accuracy: 87.00%
#
# [27/100] Train Loss: 0.0596, Val Loss: 0.4249, Val Accuracy: 90.00%
#
# [28/100] Train Loss: 0.0683, Val Loss: 0.4435, Val Accuracy: 88.00%
#
# [29/100] Train Loss: 0.0599, Val Loss: 0.4775, Val Accuracy: 91.00%
#
# [30/100] Train Loss: 0.0629, Val Loss: 0.3991, Val Accuracy: 89.00%
#
# [31/100] Train Loss: 0.0518, Val Loss: 0.4242, Val Accuracy: 87.00%
#
# [32/100] Train Loss: 0.0473, Val Loss: 0.6029, Val Accuracy: 88.00%
#
# [33/100] Train Loss: 0.0337, Val Loss: 0.4641, Val Accuracy: 88.00%
#
# [34/100] Train Loss: 0.0356, Val Loss: 1.4085, Val Accuracy: 82.00%
#
# [35/100] Train Loss: 0.1772, Val Loss: 0.4132, Val Accuracy: 88.00%
#
# [36/100] Train Loss: 0.1105, Val Loss: 0.2729, Val Accuracy: 90.00%
#
# [37/100] Train Loss: 0.0582, Val Loss: 0.3528, Val Accuracy: 89.00%
#
# [38/100] Train Loss: 0.0477, Val Loss: 0.4948, Val Accuracy: 87.00%
#
# [39/100] Train Loss: 0.0375, Val Loss: 0.5697, Val Accuracy: 88.00%
#
# [40/100] Train Loss: 0.0478, Val Loss: 0.4903, Val Accuracy: 88.00%
#
# [41/100] Train Loss: 0.0411, Val Loss: 0.4137, Val Accuracy: 90.00%
#
# [42/100] Train Loss: 0.0183, Val Loss: 0.3401, Val Accuracy: 90.00%
#
# [43/100] Train Loss: 0.0154, Val Loss: 0.7135, Val Accuracy: 88.00%
#
# [44/100] Train Loss: 0.0756, Val Loss: 0.4178, Val Accuracy: 89.00%
#
# [45/100] Train Loss: 0.0279, Val Loss: 0.5003, Val Accuracy: 86.00%
#
# [46/100] Train Loss: 0.0383, Val Loss: 0.5146, Val Accuracy: 87.00%
#
# [47/100] Train Loss: 0.0205, Val Loss: 0.4878, Val Accuracy: 91.00%
#
# [48/100] Train Loss: 0.0144, Val Loss: 0.5234, Val Accuracy: 90.00%
#
# [49/100] Train Loss: 0.0155, Val Loss: 0.5875, Val Accuracy: 87.00%
#
# [50/100] Train Loss: 0.0220, Val Loss: 0.5528, Val Accuracy: 89.00%
#
# [51/100] Train Loss: 0.0109, Val Loss: 0.6536, Val Accuracy: 89.00%
#
# [52/100] Train Loss: 0.0135, Val Loss: 0.5176, Val Accuracy: 90.00%
#
# [53/100] Train Loss: 0.0106, Val Loss: 0.5746, Val Accuracy: 90.00%
#
# [54/100] Train Loss: 0.0110, Val Loss: 0.6823, Val Accuracy: 88.00%
#
# [55/100] Train Loss: 0.0115, Val Loss: 0.5500, Val Accuracy: 91.00%
#
# [56/100] Train Loss: 0.0113, Val Loss: 0.7941, Val Accuracy: 85.00%
#
# [57/100] Train Loss: 0.0124, Val Loss: 0.5218, Val Accuracy: 91.00%
#
# [58/100] Train Loss: 0.0044, Val Loss: 0.8414, Val Accuracy: 89.00%
#
# [59/100] Train Loss: 0.0037, Val Loss: 0.5553, Val Accuracy: 89.00%
#
# [60/100] Train Loss: 0.0140, Val Loss: 0.6472, Val Accuracy: 91.00%
#
# [61/100] Train Loss: 0.0108, Val Loss: 0.8113, Val Accuracy: 89.00%
#
# [62/100] Train Loss: 0.0074, Val Loss: 0.9674, Val Accuracy: 85.00%
#
# [63/100] Train Loss: 0.0087, Val Loss: 0.6742, Val Accuracy: 89.00%
#
# [64/100] Train Loss: 0.0040, Val Loss: 0.6828, Val Accuracy: 91.00%
#
# [65/100] Train Loss: 0.0043, Val Loss: 0.7693, Val Accuracy: 88.00%
#
# [66/100] Train Loss: 0.0068, Val Loss: 0.7481, Val Accuracy: 89.00%
#
# [67/100] Train Loss: 0.0085, Val Loss: 0.6529, Val Accuracy: 90.00%
#
# [68/100] Train Loss: 0.0035, Val Loss: 0.6820, Val Accuracy: 90.00%
#
# [69/100] Train Loss: 0.0089, Val Loss: 0.7585, Val Accuracy: 88.00%
#
# [70/100] Train Loss: 0.0064, Val Loss: 0.5959, Val Accuracy: 90.00%
#
# [71/100] Train Loss: 0.0058, Val Loss: 0.7168, Val Accuracy: 89.00%
#
# [72/100] Train Loss: 0.0008, Val Loss: 0.6121, Val Accuracy: 92.00%
#
# [73/100] Train Loss: 0.0032, Val Loss: 0.6540, Val Accuracy: 93.00%
#
# [74/100] Train Loss: 0.0022, Val Loss: 0.6938, Val Accuracy: 92.00%
#
# [75/100] Train Loss: 0.0025, Val Loss: 0.6873, Val Accuracy: 92.00%
#
# [76/100] Train Loss: 0.0004, Val Loss: 0.7006, Val Accuracy: 91.00%
#
# [77/100] Train Loss: 0.0016, Val Loss: 0.7090, Val Accuracy: 92.00%
#
# [78/100] Train Loss: 0.0005, Val Loss: 0.7074, Val Accuracy: 92.00%
#
# [79/100] Train Loss: 0.0006, Val Loss: 0.7150, Val Accuracy: 92.00%
#
# [80/100] Train Loss: 0.0004, Val Loss: 0.7131, Val Accuracy: 92.00%
#
# [81/100] Train Loss: 0.0011, Val Loss: 0.7329, Val Accuracy: 92.00%
#
# [82/100] Train Loss: 0.0002, Val Loss: 0.7214, Val Accuracy: 92.00%
#
# [83/100] Train Loss: 0.0017, Val Loss: 0.7544, Val Accuracy: 92.00%
#
# [84/100] Train Loss: 0.0003, Val Loss: 0.7458, Val Accuracy: 92.00%
#
# [85/100] Train Loss: 0.0015, Val Loss: 0.7250, Val Accuracy: 92.00%
#
# [86/100] Train Loss: 0.0012, Val Loss: 0.6720, Val Accuracy: 92.00%
#
# [87/100] Train Loss: 0.0005, Val Loss: 0.6720, Val Accuracy: 92.00%
#
# [88/100] Train Loss: 0.0002, Val Loss: 0.6774, Val Accuracy: 92.00%
#
# [89/100] Train Loss: 0.0012, Val Loss: 0.6828, Val Accuracy: 93.00%
#
# [90/100] Train Loss: 0.0008, Val Loss: 0.6900, Val Accuracy: 93.00%
#
# [91/100] Train Loss: 0.0010, Val Loss: 0.6845, Val Accuracy: 93.00%
#
# [92/100] Train Loss: 0.0028, Val Loss: 0.6887, Val Accuracy: 93.00%
#
# [93/100] Train Loss: 0.0002, Val Loss: 0.6959, Val Accuracy: 92.00%
#
# [94/100] Train Loss: 0.0013, Val Loss: 0.7020, Val Accuracy: 92.00%
#
# [95/100] Train Loss: 0.0013, Val Loss: 0.7067, Val Accuracy: 92.00%
#
# [96/100] Train Loss: 0.0005, Val Loss: 0.7069, Val Accuracy: 92.00%
#
# [97/100] Train Loss: 0.0010, Val Loss: 0.7076, Val Accuracy: 92.00%
#
# [98/100] Train Loss: 0.0020, Val Loss: 0.7096, Val Accuracy: 92.00%
#
# [99/100] Train Loss: 0.0003, Val Loss: 0.7103, Val Accuracy: 92.00%
#
# [100/100] Train Loss: 0.0030, Val Loss: 0.7107, Val Accuracy: 92.00%

# %%
_, _, acc_supervised_1200_val, auc_supervised_1200_val = test_(ft_network, val_loader, nn.CrossEntropyLoss())
# Out:
# Evaluation on held out test dataset
# Confusion Matrix
# +----------------+------------------+---------------------+
# |                | predicted lenses | predicted nonlenses |
# +----------------+------------------+---------------------+
# |  true lenses   |        48        |          2          |
# | true nonlenses |        6         |          44         |
# +----------------+------------------+---------------------+
# Test Metrics
# +-----------+----------+
# |  accuracy | 92.0000% |
# |    loss   |  0.4403  |
# | auc score |  0.9704  |
# +-----------+----------+
# +----------------+-----------+--------+---------+---------+
# |                | precision | recall | f-score | support |
# +----------------+-----------+--------+---------+---------+
# |     lenses     |   0.8889  | 0.9600 |  0.9231 |    50   |
# |   nonlenses    |   0.9565  | 0.8800 |  0.9167 |    50   |
# | macro averaged |   0.9227  | 0.9200 |  0.9199 |         |
# +----------------+-----------+--------+---------+---------+

# %%
_, _, acc_supervised_1200_test, auc_supervised_1200_test = test_(ft_network, test_loader, nn.CrossEntropyLoss())
# Out:
# Evaluation on held out test dataset
# Confusion Matrix
# +----------------+------------------+---------------------+
# |                | predicted lenses | predicted nonlenses |
# +----------------+------------------+---------------------+
# |  true lenses   |       266        |          27         |
# | true nonlenses |        28        |         272         |
# +----------------+------------------+---------------------+
# Test Metrics
# +-----------+----------+
# |  accuracy | 90.7251% |
# |    loss   |  0.0576  |
# | auc score |  0.9698  |
# +-----------+----------+
# +----------------+-----------+--------+---------+---------+
# |                | precision | recall | f-score | support |
# +----------------+-----------+--------+---------+---------+
# |     lenses     |   0.9048  | 0.9078 |  0.9063 |   293   |
# |   nonlenses    |   0.9097  | 0.9067 |  0.9082 |   300   |
# | macro averaged |   0.9072  | 0.9073 |  0.9072 |         |
# +----------------+-----------+--------+---------+---------+

# %% [markdown]
# ### ViT Base Classifier trained on all labelled datapoints through supervised learning

# %%
set_seed(12)
train_loader, val_loader, test_loader = get_datasets(None)
ft_network = Classifier(mode = "finetune", backbone = Backbone(arch="vit_base", image_size=32, input_channels=3, patch_size=8))
optimizer = torch.optim.Adam(ft_network.parameters(), lr=1e-4, weight_decay=1e-5)
num_epochs = 100
scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, eta_min=1e-8, T_max=num_epochs)
ft_network, ft_network_best_loss = train(ft_network, train_loader, val_loader, nn.CrossEntropyLoss(), optimizer, num_epochs=num_epochs, scheduler=scheduler)

torch.save(ft_network, "/kaggle/working/supervised-all-ckpt.pth")
fpr_supervised_all, tpr_supervised_all, auc_score_all = compute_auc(ft_network, test_loader)
# Out:
# [1/100] Train Loss: 1.2012, Val Loss: 0.5332, Val Accuracy: 69.00%
#
# [2/100] Train Loss: 0.3989, Val Loss: 0.3516, Val Accuracy: 85.00%
#
# [3/100] Train Loss: 0.3569, Val Loss: 0.3616, Val Accuracy: 88.00%
#
# [4/100] Train Loss: 0.3412, Val Loss: 0.3391, Val Accuracy: 85.00%
#
# [5/100] Train Loss: 0.3054, Val Loss: 0.3641, Val Accuracy: 84.00%
#
# [6/100] Train Loss: 0.2924, Val Loss: 0.2283, Val Accuracy: 91.00%
#
# [7/100] Train Loss: 0.2695, Val Loss: 0.2996, Val Accuracy: 86.00%
#
# [8/100] Train Loss: 0.2260, Val Loss: 0.2162, Val Accuracy: 90.00%
#
# [9/100] Train Loss: 0.2074, Val Loss: 0.1683, Val Accuracy: 91.00%
#
# [10/100] Train Loss: 0.2088, Val Loss: 0.1840, Val Accuracy: 91.00%
#
# [11/100] Train Loss: 0.1926, Val Loss: 0.2233, Val Accuracy: 90.00%
#
# [12/100] Train Loss: 0.2032, Val Loss: 0.1522, Val Accuracy: 92.00%
#
# [13/100] Train Loss: 0.1706, Val Loss: 0.1766, Val Accuracy: 92.00%
#
# [14/100] Train Loss: 0.1596, Val Loss: 0.1967, Val Accuracy: 92.00%
#
# [15/100] Train Loss: 0.1492, Val Loss: 0.1942, Val Accuracy: 92.00%
#
# [16/100] Train Loss: 0.1467, Val Loss: 0.1343, Val Accuracy: 91.00%
#
# [17/100] Train Loss: 0.1253, Val Loss: 0.2134, Val Accuracy: 88.00%
#
# [18/100] Train Loss: 0.1221, Val Loss: 0.1401, Val Accuracy: 94.00%
#
# [19/100] Train Loss: 0.1189, Val Loss: 0.2271, Val Accuracy: 89.00%
#
# [20/100] Train Loss: 0.1263, Val Loss: 0.1529, Val Accuracy: 94.00%
#
# [21/100] Train Loss: 0.1229, Val Loss: 0.1336, Val Accuracy: 93.00%
#
# [22/100] Train Loss: 0.1071, Val Loss: 0.1021, Val Accuracy: 96.00%
#
# [23/100] Train Loss: 0.1032, Val Loss: 0.1909, Val Accuracy: 94.00%
#
# [24/100] Train Loss: 0.0694, Val Loss: 0.3956, Val Accuracy: 93.00%
#
# [25/100] Train Loss: 0.1021, Val Loss: 0.0873, Val Accuracy: 97.00%
#
# [26/100] Train Loss: 0.0945, Val Loss: 0.2001, Val Accuracy: 91.00%
#
# [27/100] Train Loss: 0.0749, Val Loss: 0.1453, Val Accuracy: 96.00%
#
# [28/100] Train Loss: 0.0694, Val Loss: 0.2385, Val Accuracy: 93.00%
#
# [29/100] Train Loss: 0.0709, Val Loss: 0.1824, Val Accuracy: 93.00%
#
# [30/100] Train Loss: 0.0540, Val Loss: 0.5718, Val Accuracy: 90.00%
#
# [31/100] Train Loss: 0.0803, Val Loss: 0.2030, Val Accuracy: 94.00%
#
# [32/100] Train Loss: 0.0681, Val Loss: 0.2603, Val Accuracy: 93.00%
#
# [33/100] Train Loss: 0.0726, Val Loss: 0.1209, Val Accuracy: 93.00%
#
# [34/100] Train Loss: 0.0634, Val Loss: 0.2195, Val Accuracy: 96.00%
#
# [35/100] Train Loss: 0.0408, Val Loss: 0.2404, Val Accuracy: 90.00%
#
# [36/100] Train Loss: 0.0508, Val Loss: 0.0846, Val Accuracy: 96.00%
#
# [37/100] Train Loss: 0.0366, Val Loss: 0.2561, Val Accuracy: 93.00%
#
# [38/100] Train Loss: 0.0559, Val Loss: 0.3550, Val Accuracy: 91.00%
#
# [39/100] Train Loss: 0.0371, Val Loss: 0.3212, Val Accuracy: 92.00%
#
# [40/100] Train Loss: 0.0347, Val Loss: 0.1398, Val Accuracy: 92.00%
#
# [41/100] Train Loss: 0.0374, Val Loss: 0.2484, Val Accuracy: 93.00%
#
# [42/100] Train Loss: 0.0349, Val Loss: 0.2071, Val Accuracy: 94.00%
#
# [43/100] Train Loss: 0.0274, Val Loss: 0.6862, Val Accuracy: 86.00%
#
# [44/100] Train Loss: 0.0301, Val Loss: 0.1897, Val Accuracy: 94.00%
#
# [45/100] Train Loss: 0.0247, Val Loss: 0.4234, Val Accuracy: 94.00%
#
# [46/100] Train Loss: 0.0169, Val Loss: 0.3165, Val Accuracy: 93.00%
#
# [47/100] Train Loss: 0.0202, Val Loss: 0.3223, Val Accuracy: 91.00%
#
# [48/100] Train Loss: 0.0282, Val Loss: 0.2086, Val Accuracy: 95.00%
#
# [49/100] Train Loss: 0.0242, Val Loss: 0.1946, Val Accuracy: 94.00%
#
# [50/100] Train Loss: 0.0117, Val Loss: 0.2315, Val Accuracy: 96.00%
#
# [51/100] Train Loss: 0.0092, Val Loss: 0.3378, Val Accuracy: 95.00%
#
# [52/100] Train Loss: 0.0092, Val Loss: 0.2137, Val Accuracy: 95.00%
#
# [53/100] Train Loss: 0.0120, Val Loss: 0.3077, Val Accuracy: 95.00%
#
# [54/100] Train Loss: 0.0120, Val Loss: 0.3524, Val Accuracy: 94.00%
#
# [55/100] Train Loss: 0.0231, Val Loss: 0.3991, Val Accuracy: 93.00%
#
# [56/100] Train Loss: 0.0147, Val Loss: 0.2463, Val Accuracy: 95.00%
#
# [57/100] Train Loss: 0.0075, Val Loss: 0.3062, Val Accuracy: 96.00%
#
# [58/100] Train Loss: 0.0026, Val Loss: 0.2452, Val Accuracy: 96.00%
#
# [59/100] Train Loss: 0.0017, Val Loss: 0.4648, Val Accuracy: 94.00%
#
# [60/100] Train Loss: 0.0020, Val Loss: 0.5014, Val Accuracy: 93.00%
#
# [61/100] Train Loss: 0.0012, Val Loss: 0.4122, Val Accuracy: 96.00%
#
# [62/100] Train Loss: 0.0015, Val Loss: 0.4987, Val Accuracy: 94.00%
#
# [63/100] Train Loss: 0.0014, Val Loss: 0.5853, Val Accuracy: 92.00%
#
# [64/100] Train Loss: 0.0019, Val Loss: 0.7371, Val Accuracy: 92.00%
#
# [65/100] Train Loss: 0.0016, Val Loss: 0.5728, Val Accuracy: 92.00%
#
# [66/100] Train Loss: 0.0015, Val Loss: 0.4677, Val Accuracy: 94.00%
#
# [67/100] Train Loss: 0.0018, Val Loss: 0.4616, Val Accuracy: 93.00%
#
# [68/100] Train Loss: 0.0016, Val Loss: 0.6415, Val Accuracy: 92.00%
#
# [69/100] Train Loss: 0.0030, Val Loss: 0.5311, Val Accuracy: 95.00%
#
# [70/100] Train Loss: 0.0020, Val Loss: 0.7009, Val Accuracy: 94.00%
#
# [71/100] Train Loss: 0.0072, Val Loss: 0.5381, Val Accuracy: 94.00%
#
# [72/100] Train Loss: 0.0034, Val Loss: 0.4880, Val Accuracy: 93.00%
#
# [73/100] Train Loss: 0.0012, Val Loss: 0.4547, Val Accuracy: 95.00%
#
# [74/100] Train Loss: 0.0011, Val Loss: 0.4813, Val Accuracy: 95.00%
#
# [75/100] Train Loss: 0.0009, Val Loss: 0.5035, Val Accuracy: 95.00%
#
# [76/100] Train Loss: 0.0011, Val Loss: 0.5785, Val Accuracy: 94.00%
#
# [77/100] Train Loss: 0.0015, Val Loss: 0.4896, Val Accuracy: 95.00%
#
# [78/100] Train Loss: 0.0003, Val Loss: 0.4453, Val Accuracy: 95.00%
#
# [79/100] Train Loss: 0.0012, Val Loss: 0.4900, Val Accuracy: 95.00%
#
# [80/100] Train Loss: 0.0014, Val Loss: 0.4360, Val Accuracy: 95.00%
#
# [81/100] Train Loss: 0.0004, Val Loss: 0.4619, Val Accuracy: 95.00%
#
# [82/100] Train Loss: 0.0010, Val Loss: 0.4938, Val Accuracy: 95.00%
#
# [83/100] Train Loss: 0.0006, Val Loss: 0.5076, Val Accuracy: 95.00%
#
# [84/100] Train Loss: 0.0004, Val Loss: 0.4956, Val Accuracy: 95.00%
#
# [85/100] Train Loss: 0.0017, Val Loss: 0.4791, Val Accuracy: 95.00%
#
# [86/100] Train Loss: 0.0005, Val Loss: 0.4654, Val Accuracy: 95.00%
#
# [87/100] Train Loss: 0.0004, Val Loss: 0.4932, Val Accuracy: 95.00%
#
# [88/100] Train Loss: 0.0005, Val Loss: 0.4876, Val Accuracy: 95.00%
#
# [89/100] Train Loss: 0.0007, Val Loss: 0.4931, Val Accuracy: 95.00%
#
# [90/100] Train Loss: 0.0005, Val Loss: 0.4902, Val Accuracy: 95.00%
#
# [91/100] Train Loss: 0.0011, Val Loss: 0.5130, Val Accuracy: 95.00%
#
# [92/100] Train Loss: 0.0006, Val Loss: 0.5083, Val Accuracy: 95.00%
#
# [93/100] Train Loss: 0.0005, Val Loss: 0.5043, Val Accuracy: 95.00%
#
# [94/100] Train Loss: 0.0002, Val Loss: 0.5031, Val Accuracy: 95.00%
#
# [95/100] Train Loss: 0.0006, Val Loss: 0.5066, Val Accuracy: 95.00%
#
# [96/100] Train Loss: 0.0008, Val Loss: 0.5076, Val Accuracy: 95.00%
#
# [97/100] Train Loss: 0.0005, Val Loss: 0.5075, Val Accuracy: 95.00%
#
# [98/100] Train Loss: 0.0008, Val Loss: 0.5086, Val Accuracy: 95.00%
#
# [99/100] Train Loss: 0.0008, Val Loss: 0.5072, Val Accuracy: 95.00%
#
# [100/100] Train Loss: 0.0003, Val Loss: 0.5071, Val Accuracy: 95.00%

# %%
_, _, acc_supervised_all_val, auc_supervised_all_val = test_(ft_network, val_loader, nn.CrossEntropyLoss())
# Out:
# Evaluation on held out test dataset
# Confusion Matrix
# +----------------+------------------+---------------------+
# |                | predicted lenses | predicted nonlenses |
# +----------------+------------------+---------------------+
# |  true lenses   |        48        |          2          |
# | true nonlenses |        3         |          47         |
# +----------------+------------------+---------------------+
# Test Metrics
# +-----------+----------+
# |  accuracy | 95.0000% |
# |    loss   |  0.3598  |
# | auc score |  0.9888  |
# +-----------+----------+
# +----------------+-----------+--------+---------+---------+
# |                | precision | recall | f-score | support |
# +----------------+-----------+--------+---------+---------+
# |     lenses     |   0.9412  | 0.9600 |  0.9505 |    50   |
# |   nonlenses    |   0.9592  | 0.9400 |  0.9495 |    50   |
# | macro averaged |   0.9502  | 0.9500 |  0.9500 |         |
# +----------------+-----------+--------+---------+---------+

# %%
_, _, acc_supervised_all_test, auc_supervised_all_test = test_(ft_network, test_loader, nn.CrossEntropyLoss())
# Out:
# Evaluation on held out test dataset
# Confusion Matrix
# +----------------+------------------+---------------------+
# |                | predicted lenses | predicted nonlenses |
# +----------------+------------------+---------------------+
# |  true lenses   |       270        |          23         |
# | true nonlenses |        18        |         282         |
# +----------------+------------------+---------------------+
# Test Metrics
# +-----------+----------+
# |  accuracy | 93.0860% |
# |    loss   |  0.0006  |
# | auc score |  0.9786  |
# +-----------+----------+
# +----------------+-----------+--------+---------+---------+
# |                | precision | recall | f-score | support |
# +----------------+-----------+--------+---------+---------+
# |     lenses     |   0.9375  | 0.9215 |  0.9294 |   293   |
# |   nonlenses    |   0.9246  | 0.9400 |  0.9322 |   300   |
# | macro averaged |   0.9310  | 0.9308 |  0.9308 |         |
# +----------------+-----------+--------+---------+---------+

# %% [markdown]
# ### ROC Curves for the supervised models are plotted below

# %%
plt.figure(figsize=(15, 15))
plt.title('ROC')
plt.plot(fpr_supervised_300, tpr_supervised_300, 'r', label = 'AUC (trained on 300 labelled data, supervised) = %0.4f' % auc_score_300)
plt.plot(fpr_supervised_600, tpr_supervised_600, 'm', label = 'AUC (trained on 600 labelled data, supervised) = %0.4f' % auc_score_600)
plt.plot(fpr_supervised_1200, tpr_supervised_1200, 'g', label = 'AUC (trained on 1200 labelled data, supervised) = %0.4f' % auc_score_1200)
plt.plot(fpr_supervised_all, tpr_supervised_all, 'b', label = 'AUC (trained on all labelled data, supervised) = %0.4f' % auc_score_all)

plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.savefig("auc_supervised.png")
plt.show()

# %% [markdown]
# ### ViT Base backbone pretrained with DINO

# %%
state = torch.load("/kaggle/input/deeplense-ssl-sreehari-iyer/dino-vit-base-checkpoint-new.pth")
# Out:
# /tmp/ipykernel_23/1023994332.py:1: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state = torch.load("/kaggle/input/deeplense-ssl-sreehari-iyer/dino-vit-base-checkpoint-new.pth")

# %% [markdown]
# ### ViT Base pretrained backbone finetuned on 300 labelled datapoints

# %%
set_seed(12)
train_loader, val_loader, test_loader = get_datasets(300)
ft_network = Classifier(mode = "finetune", backbone = copy.deepcopy(state["student"].backbone))
optimizer = torch.optim.Adam(ft_network.parameters(), lr=1e-4, weight_decay=1e-5)
num_epochs = 100
scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, eta_min=1e-8, T_max=num_epochs)
ft_network, ft_network_best_loss = train(ft_network, train_loader, val_loader, nn.CrossEntropyLoss(), optimizer, num_epochs=num_epochs, scheduler=scheduler)

torch.save(ft_network, "/kaggle/working/dino-finetuned-300-ckpt.pth")
fpr_dino_finetuned_300, tpr_dino_finetuned_300, auc_score_dino_finetuned_300 = compute_auc(ft_network, test_loader)
# Out:
# [1/100] Train Loss: 1.3072, Val Loss: 1.3843, Val Accuracy: 50.00%
#
# [2/100] Train Loss: 0.7087, Val Loss: 0.6521, Val Accuracy: 55.00%
#
# [3/100] Train Loss: 0.6174, Val Loss: 0.7686, Val Accuracy: 50.00%
#
# [4/100] Train Loss: 0.6259, Val Loss: 0.5518, Val Accuracy: 56.00%
#
# [5/100] Train Loss: 0.5264, Val Loss: 0.6127, Val Accuracy: 80.00%
#
# [6/100] Train Loss: 0.4888, Val Loss: 0.4607, Val Accuracy: 74.00%
#
# [7/100] Train Loss: 0.4298, Val Loss: 0.5202, Val Accuracy: 83.00%
#
# [8/100] Train Loss: 0.4000, Val Loss: 0.4143, Val Accuracy: 77.00%
#
# [9/100] Train Loss: 0.3920, Val Loss: 0.4767, Val Accuracy: 87.00%
#
# [10/100] Train Loss: 0.3712, Val Loss: 0.3848, Val Accuracy: 87.00%
#
# [11/100] Train Loss: 0.3548, Val Loss: 0.4460, Val Accuracy: 86.00%
#
# [12/100] Train Loss: 0.3000, Val Loss: 0.3630, Val Accuracy: 86.00%
#
# [13/100] Train Loss: 0.3151, Val Loss: 0.4019, Val Accuracy: 85.00%
#
# [14/100] Train Loss: 0.2897, Val Loss: 0.3352, Val Accuracy: 86.00%
#
# [15/100] Train Loss: 0.2398, Val Loss: 0.4241, Val Accuracy: 86.00%
#
# [16/100] Train Loss: 0.2575, Val Loss: 0.3319, Val Accuracy: 86.00%
#
# [17/100] Train Loss: 0.2399, Val Loss: 0.4422, Val Accuracy: 86.00%
#
# [18/100] Train Loss: 0.2206, Val Loss: 0.3154, Val Accuracy: 87.00%
#
# [19/100] Train Loss: 0.1625, Val Loss: 0.4548, Val Accuracy: 86.00%
#
# [20/100] Train Loss: 0.1687, Val Loss: 0.3525, Val Accuracy: 87.00%
#
# [21/100] Train Loss: 0.2010, Val Loss: 0.3945, Val Accuracy: 88.00%
#
# [22/100] Train Loss: 0.1415, Val Loss: 0.3500, Val Accuracy: 90.00%
#
# [23/100] Train Loss: 0.1271, Val Loss: 0.3682, Val Accuracy: 88.00%
#
# [24/100] Train Loss: 0.1067, Val Loss: 0.4566, Val Accuracy: 88.00%
#
# [25/100] Train Loss: 0.1020, Val Loss: 0.4580, Val Accuracy: 91.00%
#
# [26/100] Train Loss: 0.0931, Val Loss: 0.4300, Val Accuracy: 89.00%
#
# [27/100] Train Loss: 0.1168, Val Loss: 0.3654, Val Accuracy: 91.00%
#
# [28/100] Train Loss: 0.0627, Val Loss: 0.4922, Val Accuracy: 89.00%
#
# [29/100] Train Loss: 0.0652, Val Loss: 0.4620, Val Accuracy: 92.00%
#
# [30/100] Train Loss: 0.0520, Val Loss: 0.6952, Val Accuracy: 88.00%
#
# [31/100] Train Loss: 0.0481, Val Loss: 0.5690, Val Accuracy: 90.00%
#
# [32/100] Train Loss: 0.0720, Val Loss: 0.5985, Val Accuracy: 89.00%
#
# [33/100] Train Loss: 0.0505, Val Loss: 0.5042, Val Accuracy: 89.00%
#
# [34/100] Train Loss: 0.0368, Val Loss: 0.5479, Val Accuracy: 90.00%
#
# [35/100] Train Loss: 0.0311, Val Loss: 0.4756, Val Accuracy: 91.00%
#
# [36/100] Train Loss: 0.0334, Val Loss: 0.4648, Val Accuracy: 89.00%
#
# [37/100] Train Loss: 0.0373, Val Loss: 0.4885, Val Accuracy: 91.00%
#
# [38/100] Train Loss: 0.0138, Val Loss: 0.5383, Val Accuracy: 90.00%
#
# [39/100] Train Loss: 0.0217, Val Loss: 0.6926, Val Accuracy: 88.00%
#
# [40/100] Train Loss: 0.0337, Val Loss: 0.5557, Val Accuracy: 92.00%
#
# [41/100] Train Loss: 0.0379, Val Loss: 0.7188, Val Accuracy: 91.00%
#
# [42/100] Train Loss: 0.0256, Val Loss: 0.5579, Val Accuracy: 93.00%
#
# [43/100] Train Loss: 0.0182, Val Loss: 0.5767, Val Accuracy: 93.00%
#
# [44/100] Train Loss: 0.0181, Val Loss: 0.5421, Val Accuracy: 91.00%
#
# [45/100] Train Loss: 0.0302, Val Loss: 0.6248, Val Accuracy: 91.00%
#
# [46/100] Train Loss: 0.0428, Val Loss: 0.6696, Val Accuracy: 89.00%
#
# [47/100] Train Loss: 0.0161, Val Loss: 0.5567, Val Accuracy: 90.00%
#
# [48/100] Train Loss: 0.0489, Val Loss: 0.9246, Val Accuracy: 86.00%
#
# [49/100] Train Loss: 0.0301, Val Loss: 0.4543, Val Accuracy: 90.00%
#
# [50/100] Train Loss: 0.0192, Val Loss: 0.4249, Val Accuracy: 91.00%
#
# [51/100] Train Loss: 0.0050, Val Loss: 0.4374, Val Accuracy: 95.00%
#
# [52/100] Train Loss: 0.0047, Val Loss: 0.4597, Val Accuracy: 94.00%
#
# [53/100] Train Loss: 0.0054, Val Loss: 0.4915, Val Accuracy: 94.00%
#
# [54/100] Train Loss: 0.0024, Val Loss: 0.5410, Val Accuracy: 93.00%
#
# [55/100] Train Loss: 0.0070, Val Loss: 0.5258, Val Accuracy: 94.00%
#
# [56/100] Train Loss: 0.0015, Val Loss: 0.5213, Val Accuracy: 92.00%
#
# [57/100] Train Loss: 0.0026, Val Loss: 0.5368, Val Accuracy: 93.00%
#
# [58/100] Train Loss: 0.0009, Val Loss: 0.5549, Val Accuracy: 94.00%
#
# [59/100] Train Loss: 0.0317, Val Loss: 0.5643, Val Accuracy: 93.00%
#
# [60/100] Train Loss: 0.0051, Val Loss: 0.5389, Val Accuracy: 93.00%
#
# [61/100] Train Loss: 0.0016, Val Loss: 0.5212, Val Accuracy: 92.00%
#
# [62/100] Train Loss: 0.0081, Val Loss: 0.5160, Val Accuracy: 93.00%
#
# [63/100] Train Loss: 0.0055, Val Loss: 0.6945, Val Accuracy: 90.00%
#
# [64/100] Train Loss: 0.0025, Val Loss: 0.7291, Val Accuracy: 90.00%
#
# [65/100] Train Loss: 0.0040, Val Loss: 0.6719, Val Accuracy: 90.00%
#
# [66/100] Train Loss: 0.0138, Val Loss: 0.8229, Val Accuracy: 89.00%
#
# [67/100] Train Loss: 0.0200, Val Loss: 0.7601, Val Accuracy: 90.00%
#
# [68/100] Train Loss: 0.0017, Val Loss: 0.5255, Val Accuracy: 92.00%
#
# [69/100] Train Loss: 0.0015, Val Loss: 0.5323, Val Accuracy: 91.00%
#
# [70/100] Train Loss: 0.0048, Val Loss: 0.5390, Val Accuracy: 92.00%
#
# [71/100] Train Loss: 0.0006, Val Loss: 0.5632, Val Accuracy: 90.00%
#
# [72/100] Train Loss: 0.0018, Val Loss: 0.5993, Val Accuracy: 90.00%
#
# [73/100] Train Loss: 0.0006, Val Loss: 0.6584, Val Accuracy: 91.00%
#
# [74/100] Train Loss: 0.0011, Val Loss: 0.6723, Val Accuracy: 91.00%
#
# [75/100] Train Loss: 0.0008, Val Loss: 0.6367, Val Accuracy: 91.00%
#
# [76/100] Train Loss: 0.0034, Val Loss: 0.5158, Val Accuracy: 94.00%
#
# [77/100] Train Loss: 0.0256, Val Loss: 0.5447, Val Accuracy: 93.00%
#
# [78/100] Train Loss: 0.0098, Val Loss: 0.5491, Val Accuracy: 93.00%
#
# [79/100] Train Loss: 0.0169, Val Loss: 0.5830, Val Accuracy: 95.00%
#
# [80/100] Train Loss: 0.0045, Val Loss: 0.7478, Val Accuracy: 89.00%
#
# [81/100] Train Loss: 0.0117, Val Loss: 0.7528, Val Accuracy: 90.00%
#
# [82/100] Train Loss: 0.0019, Val Loss: 0.6952, Val Accuracy: 90.00%
#
# [83/100] Train Loss: 0.0032, Val Loss: 0.6361, Val Accuracy: 90.00%
#
# [84/100] Train Loss: 0.0032, Val Loss: 0.5740, Val Accuracy: 92.00%
#
# [85/100] Train Loss: 0.0046, Val Loss: 0.5549, Val Accuracy: 93.00%
#
# [86/100] Train Loss: 0.0011, Val Loss: 0.5470, Val Accuracy: 92.00%
#
# [87/100] Train Loss: 0.0075, Val Loss: 0.5495, Val Accuracy: 92.00%
#
# [88/100] Train Loss: 0.0008, Val Loss: 0.5528, Val Accuracy: 92.00%
#
# [89/100] Train Loss: 0.0007, Val Loss: 0.5551, Val Accuracy: 91.00%
#
# [90/100] Train Loss: 0.0006, Val Loss: 0.5564, Val Accuracy: 91.00%
#
# [91/100] Train Loss: 0.0022, Val Loss: 0.5531, Val Accuracy: 91.00%
#
# [92/100] Train Loss: 0.0004, Val Loss: 0.5513, Val Accuracy: 92.00%
#
# [93/100] Train Loss: 0.0020, Val Loss: 0.5513, Val Accuracy: 91.00%
#
# [94/100] Train Loss: 0.0018, Val Loss: 0.5498, Val Accuracy: 92.00%
#
# [95/100] Train Loss: 0.0037, Val Loss: 0.5498, Val Accuracy: 92.00%
#
# [96/100] Train Loss: 0.0029, Val Loss: 0.5494, Val Accuracy: 92.00%
#
# [97/100] Train Loss: 0.0003, Val Loss: 0.5492, Val Accuracy: 92.00%
#
# [98/100] Train Loss: 0.0019, Val Loss: 0.5491, Val Accuracy: 92.00%
#
# [99/100] Train Loss: 0.0055, Val Loss: 0.5486, Val Accuracy: 93.00%
#
# [100/100] Train Loss: 0.0039, Val Loss: 0.5485, Val Accuracy: 93.00%

# %%
_, _, acc_dino_finetuned_300, auc_dino_finetuned_300 = test_(ft_network, val_loader, nn.CrossEntropyLoss())
# Out:
# Evaluation on held out test dataset
# Confusion Matrix
# +----------------+------------------+---------------------+
# |                | predicted lenses | predicted nonlenses |
# +----------------+------------------+---------------------+
# |  true lenses   |        48        |          2          |
# | true nonlenses |        5         |          45         |
# +----------------+------------------+---------------------+
# Test Metrics
# +-----------+----------+
# |  accuracy | 93.0000% |
# |    loss   |  0.3745  |
# | auc score |  0.9776  |
# +-----------+----------+
# +----------------+-----------+--------+---------+---------+
# |                | precision | recall | f-score | support |
# +----------------+-----------+--------+---------+---------+
# |     lenses     |   0.9057  | 0.9600 |  0.9320 |    50   |
# |   nonlenses    |   0.9574  | 0.9000 |  0.9278 |    50   |
# | macro averaged |   0.9316  | 0.9300 |  0.9299 |         |
# +----------------+-----------+--------+---------+---------+

# %%
_, _, acc_dino_finetuned_300, auc_dino_finetuned_300 = test_(ft_network, test_loader, nn.CrossEntropyLoss())
# Out:
# Evaluation on held out test dataset
# Confusion Matrix
# +----------------+------------------+---------------------+
# |                | predicted lenses | predicted nonlenses |
# +----------------+------------------+---------------------+
# |  true lenses   |       269        |          24         |
# | true nonlenses |        38        |         262         |
# +----------------+------------------+---------------------+
# Test Metrics
# +-----------+----------+
# |  accuracy | 89.5447% |
# |    loss   |  0.0976  |
# | auc score |  0.9487  |
# +-----------+----------+
# +----------------+-----------+--------+---------+---------+
# |                | precision | recall | f-score | support |
# +----------------+-----------+--------+---------+---------+
# |     lenses     |   0.8762  | 0.9181 |  0.8967 |   293   |
# |   nonlenses    |   0.9161  | 0.8733 |  0.8942 |   300   |
# | macro averaged |   0.8962  | 0.8957 |  0.8954 |         |
# +----------------+-----------+--------+---------+---------+

# %% [markdown]
# ### ViT Base pretrained backbone finetuned on 600 labelled datapoints

# %%
set_seed(12)
train_loader, val_loader, test_loader = get_datasets(600)
ft_network = Classifier(mode = "finetune", backbone = copy.deepcopy(state["student"].backbone))
optimizer = torch.optim.Adam(ft_network.parameters(), lr=1e-4, weight_decay=1e-5)
num_epochs = 100
scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, eta_min=1e-8, T_max=num_epochs)
ft_network, ft_network_best_loss = train(ft_network, train_loader, val_loader, nn.CrossEntropyLoss(), optimizer, num_epochs=num_epochs, scheduler=scheduler)

torch.save(ft_network, "/kaggle/working/dino-finetuned-600-ckpt.pth")
fpr_dino_finetuned_600, tpr_dino_finetuned_600, auc_score_dino_finetuned_600 = compute_auc(ft_network, test_loader)
# Out:
# [1/100] Train Loss: 0.9556, Val Loss: 0.4745, Val Accuracy: 66.00%
#
# [2/100] Train Loss: 0.4433, Val Loss: 0.4673, Val Accuracy: 83.00%
#
# [3/100] Train Loss: 0.3507, Val Loss: 0.3527, Val Accuracy: 82.00%
#
# [4/100] Train Loss: 0.3403, Val Loss: 0.3353, Val Accuracy: 82.00%
#
# [5/100] Train Loss: 0.4207, Val Loss: 0.6796, Val Accuracy: 81.00%
#
# [6/100] Train Loss: 0.3061, Val Loss: 0.5377, Val Accuracy: 86.00%
#
# [7/100] Train Loss: 0.2428, Val Loss: 0.3411, Val Accuracy: 90.00%
#
# [8/100] Train Loss: 0.2076, Val Loss: 0.3246, Val Accuracy: 90.00%
#
# [9/100] Train Loss: 0.1739, Val Loss: 0.3069, Val Accuracy: 89.00%
#
# [10/100] Train Loss: 0.1609, Val Loss: 0.3385, Val Accuracy: 91.00%
#
# [11/100] Train Loss: 0.1703, Val Loss: 0.3014, Val Accuracy: 90.00%
#
# [12/100] Train Loss: 0.1367, Val Loss: 0.3362, Val Accuracy: 91.00%
#
# [13/100] Train Loss: 0.1116, Val Loss: 0.3573, Val Accuracy: 91.00%
#
# [14/100] Train Loss: 0.1111, Val Loss: 0.2895, Val Accuracy: 91.00%
#
# [15/100] Train Loss: 0.1002, Val Loss: 0.2861, Val Accuracy: 93.00%
#
# [16/100] Train Loss: 0.1035, Val Loss: 0.3494, Val Accuracy: 92.00%
#
# [17/100] Train Loss: 0.1275, Val Loss: 0.3109, Val Accuracy: 93.00%
#
# [18/100] Train Loss: 0.1137, Val Loss: 0.3317, Val Accuracy: 90.00%
#
# [19/100] Train Loss: 0.0986, Val Loss: 0.3419, Val Accuracy: 87.00%
#
# [20/100] Train Loss: 0.0991, Val Loss: 0.3309, Val Accuracy: 90.00%
#
# [21/100] Train Loss: 0.0589, Val Loss: 0.3911, Val Accuracy: 90.00%
#
# [22/100] Train Loss: 0.0596, Val Loss: 0.3977, Val Accuracy: 90.00%
#
# [23/100] Train Loss: 0.1196, Val Loss: 0.6644, Val Accuracy: 81.00%
#
# [24/100] Train Loss: 0.3184, Val Loss: 0.4701, Val Accuracy: 89.00%
#
# [25/100] Train Loss: 0.1890, Val Loss: 0.3651, Val Accuracy: 89.00%
#
# [26/100] Train Loss: 0.1393, Val Loss: 0.3725, Val Accuracy: 90.00%
#
# [27/100] Train Loss: 0.0917, Val Loss: 0.4541, Val Accuracy: 90.00%
#
# [28/100] Train Loss: 0.0769, Val Loss: 0.3585, Val Accuracy: 92.00%
#
# [29/100] Train Loss: 0.0629, Val Loss: 0.3703, Val Accuracy: 90.00%
#
# [30/100] Train Loss: 0.0833, Val Loss: 0.4372, Val Accuracy: 91.00%
#
# [31/100] Train Loss: 0.0649, Val Loss: 0.4244, Val Accuracy: 92.00%
#
# [32/100] Train Loss: 0.0481, Val Loss: 0.4532, Val Accuracy: 90.00%
#
# [33/100] Train Loss: 0.0325, Val Loss: 0.3721, Val Accuracy: 93.00%
#
# [34/100] Train Loss: 0.0359, Val Loss: 0.4012, Val Accuracy: 93.00%
#
# [35/100] Train Loss: 0.0695, Val Loss: 0.4959, Val Accuracy: 92.00%
#
# [36/100] Train Loss: 0.1241, Val Loss: 0.3718, Val Accuracy: 89.00%
#
# [37/100] Train Loss: 0.0523, Val Loss: 0.3337, Val Accuracy: 91.00%
#
# [38/100] Train Loss: 0.2574, Val Loss: 0.7217, Val Accuracy: 67.00%
#
# [39/100] Train Loss: 0.4636, Val Loss: 0.4780, Val Accuracy: 79.00%
#
# [40/100] Train Loss: 0.2705, Val Loss: 0.3481, Val Accuracy: 85.00%
#
# [41/100] Train Loss: 0.1705, Val Loss: 0.4871, Val Accuracy: 88.00%
#
# [42/100] Train Loss: 0.1117, Val Loss: 0.3919, Val Accuracy: 89.00%
#
# [43/100] Train Loss: 0.0760, Val Loss: 0.4470, Val Accuracy: 88.00%
#
# [44/100] Train Loss: 0.0669, Val Loss: 0.4699, Val Accuracy: 91.00%
#
# [45/100] Train Loss: 0.0582, Val Loss: 0.4612, Val Accuracy: 90.00%
#
# [46/100] Train Loss: 0.0408, Val Loss: 0.4581, Val Accuracy: 89.00%
#
# [47/100] Train Loss: 0.0310, Val Loss: 0.5626, Val Accuracy: 87.00%
#
# [48/100] Train Loss: 0.0457, Val Loss: 0.5292, Val Accuracy: 88.00%
#
# [49/100] Train Loss: 0.0257, Val Loss: 0.4593, Val Accuracy: 91.00%
#
# [50/100] Train Loss: 0.0170, Val Loss: 0.7845, Val Accuracy: 86.00%
#
# [51/100] Train Loss: 0.0655, Val Loss: 0.6277, Val Accuracy: 90.00%
#
# [52/100] Train Loss: 0.1082, Val Loss: 0.5103, Val Accuracy: 86.00%
#
# [53/100] Train Loss: 0.0324, Val Loss: 0.6162, Val Accuracy: 89.00%
#
# [54/100] Train Loss: 0.0354, Val Loss: 0.5072, Val Accuracy: 89.00%
#
# [55/100] Train Loss: 0.0301, Val Loss: 0.5996, Val Accuracy: 92.00%
#
# [56/100] Train Loss: 0.0181, Val Loss: 0.6478, Val Accuracy: 91.00%
#
# [57/100] Train Loss: 0.0135, Val Loss: 0.7511, Val Accuracy: 91.00%
#
# [58/100] Train Loss: 0.0110, Val Loss: 0.6960, Val Accuracy: 91.00%
#
# [59/100] Train Loss: 0.0092, Val Loss: 0.7192, Val Accuracy: 90.00%
#
# [60/100] Train Loss: 0.0079, Val Loss: 0.8530, Val Accuracy: 90.00%
#
# [61/100] Train Loss: 0.0061, Val Loss: 0.8431, Val Accuracy: 90.00%
#
# [62/100] Train Loss: 0.0031, Val Loss: 0.7817, Val Accuracy: 89.00%
#
# [63/100] Train Loss: 0.0076, Val Loss: 0.7645, Val Accuracy: 90.00%
#
# [64/100] Train Loss: 0.0107, Val Loss: 0.8583, Val Accuracy: 90.00%
#
# [65/100] Train Loss: 0.0127, Val Loss: 0.8072, Val Accuracy: 88.00%
#
# [66/100] Train Loss: 0.0099, Val Loss: 0.9193, Val Accuracy: 86.00%
#
# [67/100] Train Loss: 0.0109, Val Loss: 0.8996, Val Accuracy: 88.00%
#
# [68/100] Train Loss: 0.0119, Val Loss: 0.9097, Val Accuracy: 91.00%
#
# [69/100] Train Loss: 0.0168, Val Loss: 0.8125, Val Accuracy: 89.00%
#
# [70/100] Train Loss: 0.0149, Val Loss: 1.0884, Val Accuracy: 91.00%
#
# [71/100] Train Loss: 0.0155, Val Loss: 1.0595, Val Accuracy: 90.00%
#
# [72/100] Train Loss: 0.0038, Val Loss: 0.9429, Val Accuracy: 90.00%
#
# [73/100] Train Loss: 0.0109, Val Loss: 1.2730, Val Accuracy: 90.00%
#
# [74/100] Train Loss: 0.0166, Val Loss: 1.1716, Val Accuracy: 90.00%
#
# [75/100] Train Loss: 0.0063, Val Loss: 0.9239, Val Accuracy: 91.00%
#
# [76/100] Train Loss: 0.0158, Val Loss: 1.1199, Val Accuracy: 92.00%
#
# [77/100] Train Loss: 0.0051, Val Loss: 1.1327, Val Accuracy: 92.00%
#
# [78/100] Train Loss: 0.0088, Val Loss: 1.0941, Val Accuracy: 91.00%
#
# [79/100] Train Loss: 0.0035, Val Loss: 1.0276, Val Accuracy: 91.00%
#
# [80/100] Train Loss: 0.0020, Val Loss: 1.0076, Val Accuracy: 91.00%
#
# [81/100] Train Loss: 0.0077, Val Loss: 1.1180, Val Accuracy: 91.00%
#
# [82/100] Train Loss: 0.0022, Val Loss: 1.1618, Val Accuracy: 92.00%
#
# [83/100] Train Loss: 0.0212, Val Loss: 1.1970, Val Accuracy: 92.00%
#
# [84/100] Train Loss: 0.0028, Val Loss: 1.1530, Val Accuracy: 92.00%
#
# [85/100] Train Loss: 0.0033, Val Loss: 1.1117, Val Accuracy: 91.00%
#
# [86/100] Train Loss: 0.0013, Val Loss: 1.1027, Val Accuracy: 91.00%
#
# [87/100] Train Loss: 0.0025, Val Loss: 1.1150, Val Accuracy: 91.00%
#
# [88/100] Train Loss: 0.0027, Val Loss: 1.1134, Val Accuracy: 91.00%
#
# [89/100] Train Loss: 0.0021, Val Loss: 1.0953, Val Accuracy: 91.00%
#
# [90/100] Train Loss: 0.0026, Val Loss: 1.0975, Val Accuracy: 91.00%
#
# [91/100] Train Loss: 0.0038, Val Loss: 1.1116, Val Accuracy: 91.00%
#
# [92/100] Train Loss: 0.0020, Val Loss: 1.1211, Val Accuracy: 91.00%
#
# [93/100] Train Loss: 0.0019, Val Loss: 1.1235, Val Accuracy: 91.00%
#
# [94/100] Train Loss: 0.0051, Val Loss: 1.1281, Val Accuracy: 91.00%
#
# [95/100] Train Loss: 0.0016, Val Loss: 1.1320, Val Accuracy: 91.00%
#
# [96/100] Train Loss: 0.0098, Val Loss: 1.1389, Val Accuracy: 91.00%
#
# [97/100] Train Loss: 0.0038, Val Loss: 1.1436, Val Accuracy: 91.00%
#
# [98/100] Train Loss: 0.0033, Val Loss: 1.1425, Val Accuracy: 91.00%
#
# [99/100] Train Loss: 0.0085, Val Loss: 1.1413, Val Accuracy: 91.00%
#
# [100/100] Train Loss: 0.0015, Val Loss: 1.1409, Val Accuracy: 91.00%

# %%
_, _, acc_dino_finetuned_600, auc_dino_finetuned_600 = test_(ft_network, val_loader, nn.CrossEntropyLoss())
# Out:
# Evaluation on held out test dataset
# Confusion Matrix
# +----------------+------------------+---------------------+
# |                | predicted lenses | predicted nonlenses |
# +----------------+------------------+---------------------+
# |  true lenses   |        46        |          4          |
# | true nonlenses |        5         |          45         |
# +----------------+------------------+---------------------+
# Test Metrics
# +-----------+----------+
# |  accuracy | 91.0000% |
# |    loss   |  0.8933  |
# | auc score |  0.9272  |
# +-----------+----------+
# +----------------+-----------+--------+---------+---------+
# |                | precision | recall | f-score | support |
# +----------------+-----------+--------+---------+---------+
# |     lenses     |   0.9020  | 0.9200 |  0.9109 |    50   |
# |   nonlenses    |   0.9184  | 0.9000 |  0.9091 |    50   |
# | macro averaged |   0.9102  | 0.9100 |  0.9100 |         |
# +----------------+-----------+--------+---------+---------+

# %%
_, _, acc_dino_finetuned_600, auc_dino_finetuned_600 = test_(ft_network, test_loader, nn.CrossEntropyLoss())
# Out:
# Evaluation on held out test dataset
# Confusion Matrix
# +----------------+------------------+---------------------+
# |                | predicted lenses | predicted nonlenses |
# +----------------+------------------+---------------------+
# |  true lenses   |       268        |          25         |
# | true nonlenses |        37        |         263         |
# +----------------+------------------+---------------------+
# Test Metrics
# +-----------+----------+
# |  accuracy | 89.5447% |
# |    loss   |  0.2093  |
# | auc score |  0.9376  |
# +-----------+----------+
# +----------------+-----------+--------+---------+---------+
# |                | precision | recall | f-score | support |
# +----------------+-----------+--------+---------+---------+
# |     lenses     |   0.8787  | 0.9147 |  0.8963 |   293   |
# |   nonlenses    |   0.9132  | 0.8767 |  0.8946 |   300   |
# | macro averaged |   0.8959  | 0.8957 |  0.8954 |         |
# +----------------+-----------+--------+---------+---------+

# %% [markdown]
# ### ViT Base pretrained backbone finetuned on 1200 labelled datapoints

# %%
set_seed(12)
train_loader, val_loader, test_loader = get_datasets(1200)
ft_network = Classifier(mode = "finetune", backbone = copy.deepcopy(state["student"].backbone))
optimizer = torch.optim.Adam(ft_network.parameters(), lr=1e-4, weight_decay=1e-3)
num_epochs = 100
scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, eta_min=1e-8, T_max=num_epochs)
ft_network, ft_network_best_loss = train(ft_network, train_loader, val_loader, nn.CrossEntropyLoss(), optimizer, num_epochs=num_epochs, scheduler=scheduler)

torch.save(ft_network, "/kaggle/working/dino-finetuned-1200-ckpt.pth")
fpr_dino_finetuned_1200, tpr_dino_finetuned_1200, auc_score_dino_finetuned_1200 = compute_auc(ft_network, test_loader)
# Out:
# [1/100] Train Loss: 0.6792, Val Loss: 0.4244, Val Accuracy: 85.00%
#
# [2/100] Train Loss: 0.3731, Val Loss: 0.3019, Val Accuracy: 82.00%
#
# [3/100] Train Loss: 0.2715, Val Loss: 0.3418, Val Accuracy: 88.00%
#
# [4/100] Train Loss: 0.2573, Val Loss: 0.2134, Val Accuracy: 89.00%
#
# [5/100] Train Loss: 0.2113, Val Loss: 0.2107, Val Accuracy: 90.00%
#
# [6/100] Train Loss: 0.2043, Val Loss: 0.3205, Val Accuracy: 87.00%
#
# [7/100] Train Loss: 0.1898, Val Loss: 0.2355, Val Accuracy: 90.00%
#
# [8/100] Train Loss: 0.1647, Val Loss: 0.2012, Val Accuracy: 91.00%
#
# [9/100] Train Loss: 0.1544, Val Loss: 0.1620, Val Accuracy: 91.00%
#
# [10/100] Train Loss: 0.1506, Val Loss: 0.1799, Val Accuracy: 92.00%
#
# [11/100] Train Loss: 0.1571, Val Loss: 0.2972, Val Accuracy: 88.00%
#
# [12/100] Train Loss: 0.1690, Val Loss: 0.2226, Val Accuracy: 91.00%
#
# [13/100] Train Loss: 0.1234, Val Loss: 0.3029, Val Accuracy: 90.00%
#
# [14/100] Train Loss: 0.0817, Val Loss: 0.1998, Val Accuracy: 91.00%
#
# [15/100] Train Loss: 0.0708, Val Loss: 0.1589, Val Accuracy: 93.00%
#
# [16/100] Train Loss: 0.0645, Val Loss: 0.3145, Val Accuracy: 94.00%
#
# [17/100] Train Loss: 0.1823, Val Loss: 0.2462, Val Accuracy: 91.00%
#
# [18/100] Train Loss: 0.1131, Val Loss: 0.3611, Val Accuracy: 89.00%
#
# [19/100] Train Loss: 0.0768, Val Loss: 0.1928, Val Accuracy: 95.00%
#
# [20/100] Train Loss: 0.0469, Val Loss: 0.1983, Val Accuracy: 95.00%
#
# [21/100] Train Loss: 0.0382, Val Loss: 0.2255, Val Accuracy: 94.00%
#
# [22/100] Train Loss: 0.0447, Val Loss: 0.2258, Val Accuracy: 93.00%
#
# [23/100] Train Loss: 0.0250, Val Loss: 0.3828, Val Accuracy: 91.00%
#
# [24/100] Train Loss: 0.0502, Val Loss: 0.2812, Val Accuracy: 92.00%
#
# [25/100] Train Loss: 0.0571, Val Loss: 0.1648, Val Accuracy: 94.00%
#
# [26/100] Train Loss: 0.0261, Val Loss: 0.3220, Val Accuracy: 91.00%
#
# [27/100] Train Loss: 0.0411, Val Loss: 0.2747, Val Accuracy: 93.00%
#
# [28/100] Train Loss: 0.0429, Val Loss: 0.2537, Val Accuracy: 93.00%
#
# [29/100] Train Loss: 0.0385, Val Loss: 0.2092, Val Accuracy: 95.00%
#
# [30/100] Train Loss: 0.0495, Val Loss: 0.2672, Val Accuracy: 92.00%
#
# [31/100] Train Loss: 0.0653, Val Loss: 0.5432, Val Accuracy: 90.00%
#
# [32/100] Train Loss: 0.0300, Val Loss: 0.3600, Val Accuracy: 90.00%
#
# [33/100] Train Loss: 0.0552, Val Loss: 0.3986, Val Accuracy: 92.00%
#
# [34/100] Train Loss: 0.0369, Val Loss: 0.2860, Val Accuracy: 93.00%
#
# [35/100] Train Loss: 0.0220, Val Loss: 0.3667, Val Accuracy: 93.00%
#
# [36/100] Train Loss: 0.0141, Val Loss: 0.2928, Val Accuracy: 93.00%
#
# [37/100] Train Loss: 0.0080, Val Loss: 0.3137, Val Accuracy: 92.00%
#
# [38/100] Train Loss: 0.0122, Val Loss: 0.3704, Val Accuracy: 93.00%
#
# [39/100] Train Loss: 0.0208, Val Loss: 0.2681, Val Accuracy: 93.00%
#
# [40/100] Train Loss: 0.0459, Val Loss: 0.4847, Val Accuracy: 90.00%
#
# [41/100] Train Loss: 0.0396, Val Loss: 0.1918, Val Accuracy: 95.00%
#
# [42/100] Train Loss: 0.0169, Val Loss: 0.2097, Val Accuracy: 97.00%
#
# [43/100] Train Loss: 0.0158, Val Loss: 0.3082, Val Accuracy: 94.00%
#
# [44/100] Train Loss: 0.0325, Val Loss: 0.3084, Val Accuracy: 93.00%
#
# [45/100] Train Loss: 0.0324, Val Loss: 0.2809, Val Accuracy: 93.00%
#
# [46/100] Train Loss: 0.0126, Val Loss: 0.2413, Val Accuracy: 93.00%
#
# [47/100] Train Loss: 0.0032, Val Loss: 0.2668, Val Accuracy: 95.00%
#
# [48/100] Train Loss: 0.0062, Val Loss: 0.2799, Val Accuracy: 94.00%
#
# [49/100] Train Loss: 0.0064, Val Loss: 0.3073, Val Accuracy: 95.00%
#
# [50/100] Train Loss: 0.0018, Val Loss: 0.3378, Val Accuracy: 95.00%
#
# [51/100] Train Loss: 0.0008, Val Loss: 0.3547, Val Accuracy: 95.00%
#
# [52/100] Train Loss: 0.0046, Val Loss: 0.2981, Val Accuracy: 96.00%
#
# [53/100] Train Loss: 0.0139, Val Loss: 0.3405, Val Accuracy: 94.00%
#
# [54/100] Train Loss: 0.0170, Val Loss: 0.2725, Val Accuracy: 92.00%
#
# [55/100] Train Loss: 0.0026, Val Loss: 0.3181, Val Accuracy: 93.00%
#
# [56/100] Train Loss: 0.0047, Val Loss: 0.3214, Val Accuracy: 94.00%
#
# [57/100] Train Loss: 0.0017, Val Loss: 0.3252, Val Accuracy: 94.00%
#
# [58/100] Train Loss: 0.0045, Val Loss: 0.3704, Val Accuracy: 93.00%
#
# [59/100] Train Loss: 0.0131, Val Loss: 0.5617, Val Accuracy: 90.00%
#
# [60/100] Train Loss: 0.0506, Val Loss: 0.5571, Val Accuracy: 89.00%
#
# [61/100] Train Loss: 0.1191, Val Loss: 0.2421, Val Accuracy: 92.00%
#
# [62/100] Train Loss: 0.0421, Val Loss: 0.2400, Val Accuracy: 94.00%
#
# [63/100] Train Loss: 0.0174, Val Loss: 0.2972, Val Accuracy: 94.00%
#
# [64/100] Train Loss: 0.0098, Val Loss: 0.3318, Val Accuracy: 94.00%
#
# [65/100] Train Loss: 0.0041, Val Loss: 0.9720, Val Accuracy: 88.00%
#
# [66/100] Train Loss: 0.0137, Val Loss: 0.3922, Val Accuracy: 94.00%
#
# [67/100] Train Loss: 0.0047, Val Loss: 0.3158, Val Accuracy: 95.00%
#
# [68/100] Train Loss: 0.0028, Val Loss: 0.3831, Val Accuracy: 94.00%
#
# [69/100] Train Loss: 0.0019, Val Loss: 0.4860, Val Accuracy: 93.00%
#
# [70/100] Train Loss: 0.0018, Val Loss: 0.5211, Val Accuracy: 93.00%
#
# [71/100] Train Loss: 0.0009, Val Loss: 0.5783, Val Accuracy: 93.00%
#
# [72/100] Train Loss: 0.0058, Val Loss: 0.8838, Val Accuracy: 92.00%
#
# [73/100] Train Loss: 0.0115, Val Loss: 0.3145, Val Accuracy: 93.00%
#
# [74/100] Train Loss: 0.0158, Val Loss: 0.2975, Val Accuracy: 94.00%
#
# [75/100] Train Loss: 0.0029, Val Loss: 0.2560, Val Accuracy: 95.00%
#
# [76/100] Train Loss: 0.0071, Val Loss: 0.3281, Val Accuracy: 93.00%
#
# [77/100] Train Loss: 0.0037, Val Loss: 0.3412, Val Accuracy: 93.00%
#
# [78/100] Train Loss: 0.0011, Val Loss: 0.2829, Val Accuracy: 96.00%
#
# [79/100] Train Loss: 0.0038, Val Loss: 0.3042, Val Accuracy: 93.00%
#
# [80/100] Train Loss: 0.0013, Val Loss: 0.3342, Val Accuracy: 93.00%
#
# [81/100] Train Loss: 0.0008, Val Loss: 0.3211, Val Accuracy: 93.00%
#
# [82/100] Train Loss: 0.0004, Val Loss: 0.3143, Val Accuracy: 93.00%
#
# [83/100] Train Loss: 0.0026, Val Loss: 0.2881, Val Accuracy: 94.00%
#
# [84/100] Train Loss: 0.0021, Val Loss: 0.3025, Val Accuracy: 94.00%
#
# [85/100] Train Loss: 0.0013, Val Loss: 0.3224, Val Accuracy: 93.00%
#
# [86/100] Train Loss: 0.0019, Val Loss: 0.3144, Val Accuracy: 94.00%
#
# [87/100] Train Loss: 0.0018, Val Loss: 0.3003, Val Accuracy: 95.00%
#
# [88/100] Train Loss: 0.0043, Val Loss: 0.3242, Val Accuracy: 94.00%
#
# [89/100] Train Loss: 0.0009, Val Loss: 0.3304, Val Accuracy: 94.00%
#
# [90/100] Train Loss: 0.0042, Val Loss: 0.3326, Val Accuracy: 94.00%
#
# [91/100] Train Loss: 0.0025, Val Loss: 0.3144, Val Accuracy: 94.00%
#
# [92/100] Train Loss: 0.0007, Val Loss: 0.3209, Val Accuracy: 94.00%
#
# [93/100] Train Loss: 0.0020, Val Loss: 0.3141, Val Accuracy: 94.00%
#
# [94/100] Train Loss: 0.0021, Val Loss: 0.3122, Val Accuracy: 94.00%
#
# [95/100] Train Loss: 0.0023, Val Loss: 0.3132, Val Accuracy: 94.00%
#
# [96/100] Train Loss: 0.0006, Val Loss: 0.3132, Val Accuracy: 94.00%
#
# [97/100] Train Loss: 0.0008, Val Loss: 0.3134, Val Accuracy: 94.00%
#
# [98/100] Train Loss: 0.0007, Val Loss: 0.3139, Val Accuracy: 94.00%
#
# [99/100] Train Loss: 0.0009, Val Loss: 0.3139, Val Accuracy: 94.00%
#
# [100/100] Train Loss: 0.0029, Val Loss: 0.3139, Val Accuracy: 94.00%

# %%
_, _, acc_dino_finetuned_1200, auc_dino_finetuned_1200 = test_(ft_network, val_loader, nn.CrossEntropyLoss())
# Out:
# Evaluation on held out test dataset
# Confusion Matrix
# +----------------+------------------+---------------------+
# |                | predicted lenses | predicted nonlenses |
# +----------------+------------------+---------------------+
# |  true lenses   |        47        |          3          |
# | true nonlenses |        3         |          47         |
# +----------------+------------------+---------------------+
# Test Metrics
# +-----------+----------+
# |  accuracy | 94.0000% |
# |    loss   |  0.1692  |
# | auc score |  0.9816  |
# +-----------+----------+
# +----------------+-----------+--------+---------+---------+
# |                | precision | recall | f-score | support |
# +----------------+-----------+--------+---------+---------+
# |     lenses     |   0.9400  | 0.9400 |  0.9400 |    50   |
# |   nonlenses    |   0.9400  | 0.9400 |  0.9400 |    50   |
# | macro averaged |   0.9400  | 0.9400 |  0.9400 |         |
# +----------------+-----------+--------+---------+---------+

# %%
_, _, acc_dino_finetuned_1200, auc_dino_finetuned_1200 = test_(ft_network, test_loader, nn.CrossEntropyLoss())
# Out:
# Evaluation on held out test dataset
# Confusion Matrix
# +----------------+------------------+---------------------+
# |                | predicted lenses | predicted nonlenses |
# +----------------+------------------+---------------------+
# |  true lenses   |       270        |          23         |
# | true nonlenses |        21        |         279         |
# +----------------+------------------+---------------------+
# Test Metrics
# +-----------+----------+
# |  accuracy | 92.5801% |
# |    loss   |  0.0444  |
# | auc score |  0.9768  |
# +-----------+----------+
# +----------------+-----------+--------+---------+---------+
# |                | precision | recall | f-score | support |
# +----------------+-----------+--------+---------+---------+
# |     lenses     |   0.9278  | 0.9215 |  0.9247 |   293   |
# |   nonlenses    |   0.9238  | 0.9300 |  0.9269 |   300   |
# | macro averaged |   0.9258  | 0.9258 |  0.9258 |         |
# +----------------+-----------+--------+---------+---------+

# %% [markdown]
# ### ViT Base pretrained backbone finetuned on all datapoints

# %%
set_seed(12)
train_loader, val_loader, test_loader = get_datasets(None)
ft_network = Classifier(mode = "finetune", backbone = copy.deepcopy(state["student"].backbone))
optimizer = torch.optim.Adam(ft_network.parameters(), lr=1e-4, weight_decay=1e-3)
num_epochs = 100
scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, eta_min=1e-8, T_max=num_epochs)
ft_network, ft_network_best_loss = train(ft_network, train_loader, val_loader, nn.CrossEntropyLoss(), optimizer, num_epochs=num_epochs, scheduler=scheduler)

torch.save(ft_network, "/kaggle/working/dino-finetuned-all-ckpt.pth")
fpr_dino_finetuned_all, tpr_dino_finetuned_all, auc_score_dino_finetuned_all = compute_auc(ft_network, test_loader)
# Out:
# [1/100] Train Loss: 0.4340, Val Loss: 0.3575, Val Accuracy: 87.00%
#
# [2/100] Train Loss: 0.2857, Val Loss: 0.3617, Val Accuracy: 88.00%
#
# [3/100] Train Loss: 0.2489, Val Loss: 0.2134, Val Accuracy: 91.00%
#
# [4/100] Train Loss: 0.2296, Val Loss: 0.1867, Val Accuracy: 91.00%
#
# [5/100] Train Loss: 0.2051, Val Loss: 0.1864, Val Accuracy: 92.00%
#
# [6/100] Train Loss: 0.1934, Val Loss: 0.1840, Val Accuracy: 93.00%
#
# [7/100] Train Loss: 0.2198, Val Loss: 0.1893, Val Accuracy: 91.00%
#
# [8/100] Train Loss: 0.1787, Val Loss: 0.1412, Val Accuracy: 94.00%
#
# [9/100] Train Loss: 0.1970, Val Loss: 0.1655, Val Accuracy: 94.00%
#
# [10/100] Train Loss: 0.1727, Val Loss: 0.2000, Val Accuracy: 91.00%
#
# [11/100] Train Loss: 0.3399, Val Loss: 0.7144, Val Accuracy: 68.00%
#
# [12/100] Train Loss: 0.3160, Val Loss: 0.2344, Val Accuracy: 90.00%
#
# [13/100] Train Loss: 0.1938, Val Loss: 0.2109, Val Accuracy: 88.00%
#
# [14/100] Train Loss: 0.2138, Val Loss: 0.1839, Val Accuracy: 92.00%
#
# [15/100] Train Loss: 0.1731, Val Loss: 0.1828, Val Accuracy: 92.00%
#
# [16/100] Train Loss: 0.1642, Val Loss: 0.1990, Val Accuracy: 92.00%
#
# [17/100] Train Loss: 0.1497, Val Loss: 0.1978, Val Accuracy: 93.00%
#
# [18/100] Train Loss: 0.1303, Val Loss: 0.1927, Val Accuracy: 93.00%
#
# [19/100] Train Loss: 0.1394, Val Loss: 0.1911, Val Accuracy: 93.00%
#
# [20/100] Train Loss: 0.1180, Val Loss: 0.1915, Val Accuracy: 94.00%
#
# [21/100] Train Loss: 0.1249, Val Loss: 0.2339, Val Accuracy: 92.00%
#
# [22/100] Train Loss: 0.1164, Val Loss: 0.2047, Val Accuracy: 92.00%
#
# [23/100] Train Loss: 0.1022, Val Loss: 0.4630, Val Accuracy: 81.00%
#
# [24/100] Train Loss: 0.1335, Val Loss: 0.1342, Val Accuracy: 92.00%
#
# [25/100] Train Loss: 0.0803, Val Loss: 0.1400, Val Accuracy: 93.00%
#
# [26/100] Train Loss: 0.0946, Val Loss: 0.1766, Val Accuracy: 94.00%
#
# [27/100] Train Loss: 0.0700, Val Loss: 0.2259, Val Accuracy: 93.00%
#
# [28/100] Train Loss: 0.0642, Val Loss: 0.1614, Val Accuracy: 95.00%
#
# [29/100] Train Loss: 0.0610, Val Loss: 0.1950, Val Accuracy: 94.00%
#
# [30/100] Train Loss: 0.0522, Val Loss: 0.1576, Val Accuracy: 95.00%
#
# [31/100] Train Loss: 0.0593, Val Loss: 0.1393, Val Accuracy: 95.00%
#
# [32/100] Train Loss: 0.0522, Val Loss: 0.1141, Val Accuracy: 95.00%
#
# [33/100] Train Loss: 0.0493, Val Loss: 0.1701, Val Accuracy: 95.00%
#
# [34/100] Train Loss: 0.0584, Val Loss: 0.1217, Val Accuracy: 96.00%
#
# [35/100] Train Loss: 0.0419, Val Loss: 0.1479, Val Accuracy: 94.00%
#
# [36/100] Train Loss: 0.0460, Val Loss: 0.1564, Val Accuracy: 94.00%
#
# [37/100] Train Loss: 0.0354, Val Loss: 0.1968, Val Accuracy: 94.00%
#
# [38/100] Train Loss: 0.0519, Val Loss: 0.1086, Val Accuracy: 95.00%
#
# [39/100] Train Loss: 0.0395, Val Loss: 0.1728, Val Accuracy: 96.00%
#
# [40/100] Train Loss: 0.0437, Val Loss: 0.0962, Val Accuracy: 96.00%
#
# [41/100] Train Loss: 0.0314, Val Loss: 0.1473, Val Accuracy: 96.00%
#
# [42/100] Train Loss: 0.0333, Val Loss: 0.1020, Val Accuracy: 97.00%
#
# [43/100] Train Loss: 0.0290, Val Loss: 0.1566, Val Accuracy: 94.00%
#
# [44/100] Train Loss: 0.0202, Val Loss: 0.1347, Val Accuracy: 94.00%
#
# [45/100] Train Loss: 0.0230, Val Loss: 0.2083, Val Accuracy: 93.00%
#
# [46/100] Train Loss: 0.0230, Val Loss: 0.1498, Val Accuracy: 95.00%
#
# [47/100] Train Loss: 0.0382, Val Loss: 0.1985, Val Accuracy: 92.00%
#
# [48/100] Train Loss: 0.0249, Val Loss: 0.1145, Val Accuracy: 95.00%
#
# [49/100] Train Loss: 0.0219, Val Loss: 0.1232, Val Accuracy: 95.00%
#
# [50/100] Train Loss: 0.0161, Val Loss: 0.1066, Val Accuracy: 96.00%
#
# [51/100] Train Loss: 0.0176, Val Loss: 0.2047, Val Accuracy: 95.00%
#
# [52/100] Train Loss: 0.0170, Val Loss: 0.2661, Val Accuracy: 93.00%
#
# [53/100] Train Loss: 0.0193, Val Loss: 0.1947, Val Accuracy: 96.00%
#
# [54/100] Train Loss: 0.0142, Val Loss: 0.1539, Val Accuracy: 95.00%
#
# [55/100] Train Loss: 0.0182, Val Loss: 0.2219, Val Accuracy: 93.00%
#
# [56/100] Train Loss: 0.0284, Val Loss: 0.1279, Val Accuracy: 95.00%
#
# [57/100] Train Loss: 0.0116, Val Loss: 0.0873, Val Accuracy: 95.00%
#
# [58/100] Train Loss: 0.0086, Val Loss: 0.1222, Val Accuracy: 96.00%
#
# [59/100] Train Loss: 0.0168, Val Loss: 0.1971, Val Accuracy: 94.00%
#
# [60/100] Train Loss: 0.0170, Val Loss: 0.1327, Val Accuracy: 98.00%
#
# [61/100] Train Loss: 0.0107, Val Loss: 0.1072, Val Accuracy: 96.00%
#
# [62/100] Train Loss: 0.0044, Val Loss: 0.0961, Val Accuracy: 97.00%
#
# [63/100] Train Loss: 0.0128, Val Loss: 0.1364, Val Accuracy: 97.00%
#
# [64/100] Train Loss: 0.0120, Val Loss: 0.0905, Val Accuracy: 97.00%
#
# [65/100] Train Loss: 0.0120, Val Loss: 0.0849, Val Accuracy: 97.00%
#
# [66/100] Train Loss: 0.0092, Val Loss: 0.0934, Val Accuracy: 97.00%
#
# [67/100] Train Loss: 0.0080, Val Loss: 0.0971, Val Accuracy: 95.00%
#
# [68/100] Train Loss: 0.0094, Val Loss: 0.1007, Val Accuracy: 97.00%
#
# [69/100] Train Loss: 0.0095, Val Loss: 0.1018, Val Accuracy: 97.00%
#
# [70/100] Train Loss: 0.0047, Val Loss: 0.0838, Val Accuracy: 96.00%
#
# [71/100] Train Loss: 0.0124, Val Loss: 0.0691, Val Accuracy: 98.00%
#
# [72/100] Train Loss: 0.0095, Val Loss: 0.0582, Val Accuracy: 98.00%
#
# [73/100] Train Loss: 0.0041, Val Loss: 0.0613, Val Accuracy: 98.00%
#
# [74/100] Train Loss: 0.0032, Val Loss: 0.1000, Val Accuracy: 95.00%
#
# [75/100] Train Loss: 0.0031, Val Loss: 0.0856, Val Accuracy: 97.00%
#
# [76/100] Train Loss: 0.0030, Val Loss: 0.1105, Val Accuracy: 95.00%
#
# [77/100] Train Loss: 0.0021, Val Loss: 0.1437, Val Accuracy: 96.00%
#
# [78/100] Train Loss: 0.0048, Val Loss: 0.0787, Val Accuracy: 98.00%
#
# [79/100] Train Loss: 0.0047, Val Loss: 0.1121, Val Accuracy: 98.00%
#
# [80/100] Train Loss: 0.0094, Val Loss: 0.1132, Val Accuracy: 96.00%
#
# [81/100] Train Loss: 0.0041, Val Loss: 0.0973, Val Accuracy: 97.00%
#
# [82/100] Train Loss: 0.0043, Val Loss: 0.1019, Val Accuracy: 96.00%
#
# [83/100] Train Loss: 0.0023, Val Loss: 0.0937, Val Accuracy: 97.00%
#
# [84/100] Train Loss: 0.0015, Val Loss: 0.1041, Val Accuracy: 97.00%
#
# [85/100] Train Loss: 0.0008, Val Loss: 0.0909, Val Accuracy: 97.00%
#
# [86/100] Train Loss: 0.0022, Val Loss: 0.0904, Val Accuracy: 97.00%
#
# [87/100] Train Loss: 0.0027, Val Loss: 0.0889, Val Accuracy: 97.00%
#
# [88/100] Train Loss: 0.0024, Val Loss: 0.0732, Val Accuracy: 97.00%
#
# [89/100] Train Loss: 0.0024, Val Loss: 0.1009, Val Accuracy: 97.00%
#
# [90/100] Train Loss: 0.0032, Val Loss: 0.1095, Val Accuracy: 97.00%
#
# [91/100] Train Loss: 0.0026, Val Loss: 0.0986, Val Accuracy: 97.00%
#
# [92/100] Train Loss: 0.0032, Val Loss: 0.0906, Val Accuracy: 97.00%
#
# [93/100] Train Loss: 0.0013, Val Loss: 0.1004, Val Accuracy: 97.00%
#
# [94/100] Train Loss: 0.0041, Val Loss: 0.0901, Val Accuracy: 97.00%
#
# [95/100] Train Loss: 0.0008, Val Loss: 0.0940, Val Accuracy: 97.00%
#
# [96/100] Train Loss: 0.0010, Val Loss: 0.0937, Val Accuracy: 97.00%
#
# [97/100] Train Loss: 0.0015, Val Loss: 0.0957, Val Accuracy: 97.00%
#
# [98/100] Train Loss: 0.0025, Val Loss: 0.0919, Val Accuracy: 97.00%
#
# [99/100] Train Loss: 0.0025, Val Loss: 0.0926, Val Accuracy: 97.00%
#
# [100/100] Train Loss: 0.0018, Val Loss: 0.0931, Val Accuracy: 97.00%

# %%
_, _, acc_dino_finetuned_all, auc_dino_finetuned_all = test_(ft_network, val_loader, nn.CrossEntropyLoss())
# Out:
# Evaluation on held out test dataset
# Confusion Matrix
# +----------------+------------------+---------------------+
# |                | predicted lenses | predicted nonlenses |
# +----------------+------------------+---------------------+
# |  true lenses   |        47        |          3          |
# | true nonlenses |        0         |          50         |
# +----------------+------------------+---------------------+
# Test Metrics
# +-----------+----------+
# |  accuracy | 97.0000% |
# |    loss   |  0.0027  |
# | auc score |  0.9960  |
# +-----------+----------+
# +----------------+-----------+--------+---------+---------+
# |                | precision | recall | f-score | support |
# +----------------+-----------+--------+---------+---------+
# |     lenses     |   1.0000  | 0.9400 |  0.9691 |    50   |
# |   nonlenses    |   0.9434  | 1.0000 |  0.9709 |    50   |
# | macro averaged |   0.9717  | 0.9700 |  0.9700 |         |
# +----------------+-----------+--------+---------+---------+

# %%
_, _, acc_dino_finetuned_all, auc_dino_finetuned_all = test_(ft_network, test_loader, nn.CrossEntropyLoss())
# Out:
# Evaluation on held out test dataset
# Confusion Matrix
# +----------------+------------------+---------------------+
# |                | predicted lenses | predicted nonlenses |
# +----------------+------------------+---------------------+
# |  true lenses   |       275        |          18         |
# | true nonlenses |        14        |         286         |
# +----------------+------------------+---------------------+
# Test Metrics
# +-----------+----------+
# |  accuracy | 94.6037% |
# |    loss   |  0.0146  |
# | auc score |  0.9810  |
# +-----------+----------+
# +----------------+-----------+--------+---------+---------+
# |                | precision | recall | f-score | support |
# +----------------+-----------+--------+---------+---------+
# |     lenses     |   0.9516  | 0.9386 |  0.9450 |   293   |
# |   nonlenses    |   0.9408  | 0.9533 |  0.9470 |   300   |
# | macro averaged |   0.9462  | 0.9459 |  0.9460 |         |
# +----------------+-----------+--------+---------+---------+

# %% [markdown]
# ### ROC Curves for the SSL model finetuning are plotted below

# %%
plt.figure(figsize=(15, 15))
plt.title('ROC')
plt.plot(fpr_dino_finetuned_300, tpr_dino_finetuned_300, 'r', label = 'AUC (finetuned on 300 labelled data, DINO pretrained) = %0.4f' % auc_dino_finetuned_300)
plt.plot(fpr_dino_finetuned_600, tpr_dino_finetuned_600, 'm', label = 'AUC (finetuned on 600 labelled data, DINO pretrained) = %0.4f' % auc_dino_finetuned_600)
plt.plot(fpr_dino_finetuned_1200, tpr_dino_finetuned_1200, 'g', label = 'AUC (finetuned on 1200 labelled data, DINO pretrained) = %0.4f' % auc_dino_finetuned_1200)
plt.plot(fpr_dino_finetuned_all, tpr_dino_finetuned_all, 'b', label = 'AUC (finetuned on all labelled data, DINO pretrained) = %0.4f' % auc_dino_finetuned_all)

plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.savefig("auc_ssl_dino.png")
plt.show()

# %% [markdown]
# ### ROC Curves for the SSL and supervised models are plotted below

# %%
plt.figure(figsize=(15, 15))
plt.title('ROC')
plt.plot(fpr_dino_finetuned_300, tpr_dino_finetuned_300, 'r', label = 'AUC (finetuned on 300 labelled data, DINO pretrained) = %0.4f' % auc_dino_finetuned_300)
plt.plot(fpr_dino_finetuned_600, tpr_dino_finetuned_600, 'm', label = 'AUC (finetuned on 600 labelled data, DINO pretrained) = %0.4f' % auc_dino_finetuned_600)
plt.plot(fpr_dino_finetuned_1200, tpr_dino_finetuned_1200, 'g', label = 'AUC (finetuned on 1200 labelled data, DINO pretrained) = %0.4f' % auc_dino_finetuned_1200)
plt.plot(fpr_dino_finetuned_all, tpr_dino_finetuned_all, 'b', label = 'AUC (finetuned on all labelled data, DINO pretrained) = %0.4f' % auc_dino_finetuned_all)

plt.plot(fpr_supervised_300, tpr_supervised_300, 'r:', label = 'AUC (trained on 300 labelled data, supervised) = %0.4f' % auc_score_300)
plt.plot(fpr_supervised_600, tpr_supervised_600, 'm:', label = 'AUC (trained on 600 labelled data, supervised) = %0.4f' % auc_score_600)
plt.plot(fpr_supervised_1200, tpr_supervised_1200, 'g:', label = 'AUC (trained on 1200 labelled data, supervised) = %0.4f' % auc_score_1200)
plt.plot(fpr_supervised_all, tpr_supervised_all, 'b:', label = 'AUC (trained on all labelled data, supervised) = %0.4f' % auc_score_all)

plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.savefig("auc_supervised_ssl_dino.png")
plt.show()

# %% [markdown]
# ## IBot Pretrained ViT Base Backbone

# %% [markdown]
# ---

# %% [markdown]
# For classifying lenses from non-lenses, self-supervised learning (SSL), particularly with the transformer backbones could potentially outperform traditional supervised methods with abundant unlabelled dataset. The learned representations are then evaluated on the downstream task to classify lens and non-lens images. <br>
# The train dataset contains 2333 lens images and 1530 non-lens images. The validation dataset contains 259 lens images and 170 non-lens images. The test dataset contains 458 lens images and 300 non-lens images. Each image has 3 channels, g, r and i, corresponding to green, red and infrared filters respectively. The images are center cropped to 32 × 32 pixel as this empirically resulted in better downstream prediction accuracy. <br>
# To understand how well SSL works with different fractions of labelled and unlabelled data, the model is pre-trained through self supervision on the entire train data and then finetuned on the labelled fraction of the train data and compared with supervised baseline trained only on that labeled fraction. This simulates the real world scenario where only a fraction of dataset may have associated labels. <br>
# The following table summarizes the results on the held out test dataset.

# %% [markdown]
# | # labelled data for <br> training/fine-tuning | Training | Accuracy | AUC |
# |:---:|:----------:|:----------:|:----------:|
# |300|Supervised | 90.7652% | 0.9534 |
# ||IBot | 91.9525% | 0.9668 |
# |600|Supervised | 92.6121% | 0.9579 |
# ||IBot | 92.6121% | 0.9696 |
# |1200|Supervised | 93.4037% | 0.9678 |
# ||IBot | 93.1398% | 0.9814 |
# |3863 |Supervised | 94.9868% | 0.9843 |
# ||IBot | 94.4591% | 0.9885 |

# %% [markdown]
# ROC Curves for the SSL and supervised models are plotted below
# As observed from the results above and the following ROC plot, self supervised learning outperforms supervised models only when the unlabelled data is in abundance (as observed when number of labelled points is 300).

# %% [markdown]
# ![](../assets/auc_supervised_ibot_ssl_vit_base.png)

# %% [markdown]
# ---

# %%
import sys
sys.path.append("/kaggle/input/deeplense-git/DeepLense_SSL_from_real_dataset_Sreehari_Iyer")
sys.path.append("/kaggle/input/deeplense-git/DeepLense_SSL_from_real_dataset_Sreehari_Iyer/selfsupervised")
# !pip install GPUtil
# Out:
# Collecting GPUtil
#   Downloading GPUtil-1.4.0.tar.gz (5.5 kB)
# done
# Building wheels for collected packages: GPUtil
# done
#   Created wheel for GPUtil: filename=GPUtil-1.4.0-py3-none-any.whl size=7394 sha256=81ef9773c09007968854e71e11cffd9b28acb1d0831417b2759c1dbac86de54c
#   Stored in directory: /root/.cache/pip/wheels/a9/8a/bd/81082387151853ab8b6b3ef33426e98f5cbfebc3c397a9d4d0
# Successfully built GPUtil
# Installing collected packages: GPUtil
# Successfully installed GPUtil-1.4.0

# %%
import numpy as np
import os
import torch
import torch.nn as nn
import torchvision.transforms as Transforms
from torch.utils.data import random_split, DataLoader, Dataset
from sklearn import metrics
import copy
import pickle
from utils import set_seed
from utils.eval import train
from models.backbone import Backbone
from augmentations.loader import npy_loader
from augmentations import ImageDataset
from models.classifier import Classifier
from utils.eval import test_
import matplotlib.pyplot as plt
set_seed(12)

# %%
def get_datasets(num_labelled_points):
    set_seed(12)

    eval_transforms = Transforms.Compose([
                    # Transforms.ToTensor(), # npy loader returns torch.Tensor
                    Transforms.CenterCrop(32),
                    Transforms.Normalize(mean = [0.19948305189609528, 0.6667526960372925, 1.2940289974212646],\
                                     std = [0.2700458765029907, 0.9860594868659973, 2.1648175716400146]),
                ])

    #--------------------------------------------------------------------------------------------------------

    train_test_indices = "/kaggle/input/reallenses-traintestindices/indices.pkl"
    data_path = "/kaggle/input/reallensdataset/real_lenses_dataset"
    
    train_indices_path = None
    indices = None
    with open(train_test_indices, "rb") as f:
        indices = pickle.load(f)
    train_indices = None
    
    if num_labelled_points == 300:
        train_indices_path = "/kaggle/input/reallenses-traintestindices/train_indices_300.pkl"
        with open(train_indices_path, "rb") as f:
            train_indices = pickle.load(f)
    elif num_labelled_points == 600:
        train_indices_path = "/kaggle/input/reallenses-traintestindices/train_indices_600.pkl"
        with open(train_indices_path, "rb") as f:
            train_indices = pickle.load(f)
    elif num_labelled_points == 1200:
        train_indices_path = "/kaggle/input/reallenses-traintestindices/train_indices_1200.pkl"
        with open(train_indices_path, "rb") as f:
            train_indices = pickle.load(f)
    elif num_labelled_points is None:
        train_indices_path = "/kaggle/input/reallenses-traintestindices/indices.pkl"
        with open(train_indices_path, "rb") as f:
            train_indices = pickle.load(f)
        train_indices = train_indices["train"]

    # train images and labels
    train_paths = [os.path.join(data_path, *["lenses", img]) for img in np.array(train_indices["lenses"])] +\
                    [os.path.join(data_path, *["nonlenses", img]) for img in np.array(train_indices["nonlenses"])]
    train_labels = [0]*len(train_indices["lenses"]) + [1]*len(train_indices["nonlenses"])

    # validation images and labels
    val_paths = [os.path.join(data_path, *["lenses", img]) for img in np.array(indices["val"]["lenses"])] +\
                    [os.path.join(data_path, *["nonlenses", img]) for img in np.array(indices["val"]["nonlenses"])]
    val_labels = [0]*len(indices["val"]["lenses"]) + [1]*len(indices["val"]["nonlenses"])

    # test images and labels
    test_paths = [os.path.join(data_path, *["lenses", img]) for img in np.array(indices["test"]["lenses"])] +\
                    [os.path.join(data_path, *["nonlenses", img]) for img in np.array(indices["test"]["nonlenses"])]
    test_labels = [0]*len(indices["test"]["lenses"]) + [1]*len(indices["test"]["nonlenses"])

    # sizes of the train, validation and test datasets
    train_size = len(train_paths)
    val_size = len(val_paths)
    test_size = len(test_paths)
    #--------------------------------------------------------------------------------------------------------

    dataset = ImageDataset(
        image_paths=train_paths+val_paths+test_paths,
        labels=train_labels+val_labels+test_labels,
        loader=npy_loader,
        transform=eval_transforms
    )
    train_dataset = ImageDataset(
        image_paths=train_paths,
        labels=train_labels,
        loader=npy_loader,
        transform=eval_transforms
    ) 
    val_dataset = ImageDataset(
        image_paths=val_paths,
        labels=val_labels,
        loader=npy_loader,
        transform=eval_transforms
    )
    test_dataset = ImageDataset(
        image_paths=test_paths,
        labels=test_labels,
        loader=npy_loader,
        transform=eval_transforms
    )
    data_loader = DataLoader(
        dataset,
        batch_size=64,
        num_workers=0,
        shuffle=False,
    )
    train_loader = DataLoader(
        train_dataset,
        batch_size=64,
        num_workers=0,
        shuffle=True,
    )
    val_loader = DataLoader(
        val_dataset,
        batch_size=64,
        num_workers=0,
        shuffle=False,
    )
    test_loader = DataLoader(
        test_dataset,
        batch_size=64,
        num_workers=0,
        shuffle=False,
    )
    return train_loader, val_loader, test_loader

def compute_auc(ft_network, test_loader):
    y = None
    scores = None
    ft_network.eval()
    ft_network = ft_network.cuda()
    for img, label in test_loader:
        img, label = img.cuda(), label.cuda()
        preds = ft_network(img)
        if y is None:
            y = label.detach().cpu().numpy()
        else:
            y = np.concatenate([y, label.detach().cpu().numpy()], axis=0)
        if scores is None:
            scores = preds.detach().cpu().numpy()
        else:
            scores = np.vstack((scores, preds.detach().cpu().numpy()))
    fpr, tpr, _ = metrics.roc_curve(y, scores[:,1])
    auc_score = metrics.auc(fpr, tpr)
    return fpr, tpr, auc_score

# %% [markdown]
# ### ViT Base Classifier trained on 300 labelled datapoints through supervised learning

# %%
set_seed(12)
train_loader, val_loader, test_loader = get_datasets(300)
ft_network = Classifier(mode = "finetune", backbone = Backbone(arch="vit_base", image_size=32, input_channels=3, patch_size=8))
optimizer = torch.optim.Adam(ft_network.parameters(), lr=1e-4, weight_decay=1e-3)
num_epochs = 100
scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, eta_min=1e-8, T_max=num_epochs)
ft_network, ft_network_best_loss = train(ft_network, train_loader, val_loader, nn.CrossEntropyLoss(), optimizer, num_epochs=num_epochs, scheduler=scheduler)

torch.save(ft_network, "/kaggle/working/supervised_300_ckpt.pth")

fpr_supervised_300, tpr_supervised_300, auc_score_300 = compute_auc(ft_network, test_loader)
# Out:
# [1/100] Train Loss: 4.8513, Val Loss: 0.9934, Val Accuracy: 61.31%
#
# [2/100] Train Loss: 1.1067, Val Loss: 0.8938, Val Accuracy: 60.37%
#
# [3/100] Train Loss: 0.8335, Val Loss: 0.7856, Val Accuracy: 59.67%
#
# [4/100] Train Loss: 0.6846, Val Loss: 0.5267, Val Accuracy: 64.57%
#
# [5/100] Train Loss: 0.6542, Val Loss: 0.4967, Val Accuracy: 68.76%
#
# [6/100] Train Loss: 0.6082, Val Loss: 0.4500, Val Accuracy: 81.12%
#
# [7/100] Train Loss: 0.5542, Val Loss: 0.4288, Val Accuracy: 87.18%
#
# [8/100] Train Loss: 0.4897, Val Loss: 0.4287, Val Accuracy: 75.52%
#
# [9/100] Train Loss: 0.4343, Val Loss: 0.3897, Val Accuracy: 86.25%
#
# [10/100] Train Loss: 0.4219, Val Loss: 0.3499, Val Accuracy: 86.25%
#
# [11/100] Train Loss: 0.4145, Val Loss: 0.3157, Val Accuracy: 87.88%
#
# [12/100] Train Loss: 0.4023, Val Loss: 0.3047, Val Accuracy: 87.18%
#
# [13/100] Train Loss: 0.3615, Val Loss: 0.2908, Val Accuracy: 87.41%
#
# [14/100] Train Loss: 0.3590, Val Loss: 0.3061, Val Accuracy: 87.88%
#
# [15/100] Train Loss: 0.3568, Val Loss: 0.3087, Val Accuracy: 87.88%
#
# [16/100] Train Loss: 0.3616, Val Loss: 0.2909, Val Accuracy: 87.41%
#
# [17/100] Train Loss: 0.3237, Val Loss: 0.2884, Val Accuracy: 87.88%
#
# [18/100] Train Loss: 0.3269, Val Loss: 0.3057, Val Accuracy: 88.34%
#
# [19/100] Train Loss: 0.2953, Val Loss: 0.2902, Val Accuracy: 88.81%
#
# [20/100] Train Loss: 0.3009, Val Loss: 0.2789, Val Accuracy: 88.11%
#
# [21/100] Train Loss: 0.2695, Val Loss: 0.2928, Val Accuracy: 87.41%
#
# [22/100] Train Loss: 0.2505, Val Loss: 0.2874, Val Accuracy: 88.58%
#
# [23/100] Train Loss: 0.2234, Val Loss: 0.3014, Val Accuracy: 88.34%
#
# [24/100] Train Loss: 0.2266, Val Loss: 0.3132, Val Accuracy: 88.11%
#
# [25/100] Train Loss: 0.2348, Val Loss: 0.3087, Val Accuracy: 88.34%
#
# [26/100] Train Loss: 0.2175, Val Loss: 0.3134, Val Accuracy: 87.18%
#
# [27/100] Train Loss: 0.1791, Val Loss: 0.3117, Val Accuracy: 88.34%
#
# [28/100] Train Loss: 0.1947, Val Loss: 0.4020, Val Accuracy: 87.88%
#
# [29/100] Train Loss: 0.1893, Val Loss: 0.3585, Val Accuracy: 88.58%
#
# [30/100] Train Loss: 0.2183, Val Loss: 0.3569, Val Accuracy: 88.34%
#
# [31/100] Train Loss: 0.1909, Val Loss: 0.3416, Val Accuracy: 88.34%
#
# [32/100] Train Loss: 0.2248, Val Loss: 0.3272, Val Accuracy: 87.88%
#
# [33/100] Train Loss: 0.1724, Val Loss: 0.3408, Val Accuracy: 87.65%
#
# [34/100] Train Loss: 0.1821, Val Loss: 0.4189, Val Accuracy: 85.31%
#
# [35/100] Train Loss: 0.2033, Val Loss: 0.3741, Val Accuracy: 89.28%
#
# [36/100] Train Loss: 0.2107, Val Loss: 0.3279, Val Accuracy: 89.51%
#
# [37/100] Train Loss: 0.1891, Val Loss: 0.3034, Val Accuracy: 89.98%
#
# [38/100] Train Loss: 0.1649, Val Loss: 0.2969, Val Accuracy: 90.21%
#
# [39/100] Train Loss: 0.1498, Val Loss: 0.3155, Val Accuracy: 89.51%
#
# [40/100] Train Loss: 0.1081, Val Loss: 0.3230, Val Accuracy: 90.68%
#
# [41/100] Train Loss: 0.1184, Val Loss: 0.3998, Val Accuracy: 89.51%
#
# [42/100] Train Loss: 0.1118, Val Loss: 0.3840, Val Accuracy: 89.51%
#
# [43/100] Train Loss: 0.1284, Val Loss: 0.4010, Val Accuracy: 88.34%
#
# [44/100] Train Loss: 0.0955, Val Loss: 0.3714, Val Accuracy: 90.68%
#
# [45/100] Train Loss: 0.1158, Val Loss: 0.3906, Val Accuracy: 88.11%
#
# [46/100] Train Loss: 0.1213, Val Loss: 0.3614, Val Accuracy: 90.21%
#
# [47/100] Train Loss: 0.1500, Val Loss: 0.3939, Val Accuracy: 88.34%
#
# [48/100] Train Loss: 0.0864, Val Loss: 0.3578, Val Accuracy: 91.14%
#
# [49/100] Train Loss: 0.0736, Val Loss: 0.3920, Val Accuracy: 89.74%
#
# [50/100] Train Loss: 0.0597, Val Loss: 0.3838, Val Accuracy: 91.14%
#
# [51/100] Train Loss: 0.0673, Val Loss: 0.4204, Val Accuracy: 89.98%
#
# [52/100] Train Loss: 0.0650, Val Loss: 0.4566, Val Accuracy: 88.81%
#
# [53/100] Train Loss: 0.0738, Val Loss: 0.4296, Val Accuracy: 90.44%
#
# [54/100] Train Loss: 0.0587, Val Loss: 0.4218, Val Accuracy: 90.44%
#
# [55/100] Train Loss: 0.0704, Val Loss: 0.4058, Val Accuracy: 91.14%
#
# [56/100] Train Loss: 0.0512, Val Loss: 0.4183, Val Accuracy: 91.38%
#
# [57/100] Train Loss: 0.0436, Val Loss: 0.4493, Val Accuracy: 90.21%
#
# [58/100] Train Loss: 0.0365, Val Loss: 0.4588, Val Accuracy: 89.98%
#
# [59/100] Train Loss: 0.0427, Val Loss: 0.4414, Val Accuracy: 89.98%
#
# [60/100] Train Loss: 0.0702, Val Loss: 0.4438, Val Accuracy: 89.74%
#
# [61/100] Train Loss: 0.1083, Val Loss: 0.4401, Val Accuracy: 90.68%
#
# [62/100] Train Loss: 0.0471, Val Loss: 0.4396, Val Accuracy: 90.68%
#
# [63/100] Train Loss: 0.0468, Val Loss: 0.4199, Val Accuracy: 91.61%
#
# [64/100] Train Loss: 0.0472, Val Loss: 0.4589, Val Accuracy: 90.68%
#
# [65/100] Train Loss: 0.0348, Val Loss: 0.4332, Val Accuracy: 90.91%
#
# [66/100] Train Loss: 0.0360, Val Loss: 0.4455, Val Accuracy: 90.91%
#
# [67/100] Train Loss: 0.0408, Val Loss: 0.5465, Val Accuracy: 89.04%
#
# [68/100] Train Loss: 0.0479, Val Loss: 0.4410, Val Accuracy: 90.68%
#
# [69/100] Train Loss: 0.0433, Val Loss: 0.4951, Val Accuracy: 90.44%
#
# [70/100] Train Loss: 0.0216, Val Loss: 0.5285, Val Accuracy: 89.51%
#
# [71/100] Train Loss: 0.0214, Val Loss: 0.4785, Val Accuracy: 90.91%
#
# [72/100] Train Loss: 0.0304, Val Loss: 0.4871, Val Accuracy: 90.91%
#
# [73/100] Train Loss: 0.0156, Val Loss: 0.5404, Val Accuracy: 90.44%
#
# [74/100] Train Loss: 0.0189, Val Loss: 0.5585, Val Accuracy: 90.21%
#
# [75/100] Train Loss: 0.0186, Val Loss: 0.4994, Val Accuracy: 91.84%
#
# [76/100] Train Loss: 0.0104, Val Loss: 0.4958, Val Accuracy: 91.61%
#
# [77/100] Train Loss: 0.0381, Val Loss: 0.5008, Val Accuracy: 91.61%
#
# [78/100] Train Loss: 0.0116, Val Loss: 0.5090, Val Accuracy: 91.61%
#
# [79/100] Train Loss: 0.0191, Val Loss: 0.5273, Val Accuracy: 91.38%
#
# [80/100] Train Loss: 0.0191, Val Loss: 0.5062, Val Accuracy: 91.61%
#
# [81/100] Train Loss: 0.0144, Val Loss: 0.5061, Val Accuracy: 91.38%
#
# [82/100] Train Loss: 0.0197, Val Loss: 0.5365, Val Accuracy: 91.14%
#
# [83/100] Train Loss: 0.0157, Val Loss: 0.5679, Val Accuracy: 90.21%
#
# [84/100] Train Loss: 0.0280, Val Loss: 0.5522, Val Accuracy: 90.91%
#
# [85/100] Train Loss: 0.0135, Val Loss: 0.5033, Val Accuracy: 91.38%
#
# [86/100] Train Loss: 0.0250, Val Loss: 0.5034, Val Accuracy: 91.38%
#
# [87/100] Train Loss: 0.0100, Val Loss: 0.5121, Val Accuracy: 91.61%
#
# [88/100] Train Loss: 0.0073, Val Loss: 0.5226, Val Accuracy: 91.61%
#
# [89/100] Train Loss: 0.0084, Val Loss: 0.5312, Val Accuracy: 91.14%
#
# [90/100] Train Loss: 0.0112, Val Loss: 0.5322, Val Accuracy: 91.14%
#
# [91/100] Train Loss: 0.0195, Val Loss: 0.5122, Val Accuracy: 91.84%
#
# [92/100] Train Loss: 0.0167, Val Loss: 0.5085, Val Accuracy: 91.61%
#
# [93/100] Train Loss: 0.0122, Val Loss: 0.5077, Val Accuracy: 91.38%
#
# [94/100] Train Loss: 0.0107, Val Loss: 0.5076, Val Accuracy: 91.38%
#
# [95/100] Train Loss: 0.0190, Val Loss: 0.5088, Val Accuracy: 91.61%
#
# [96/100] Train Loss: 0.0197, Val Loss: 0.5110, Val Accuracy: 91.61%
#
# [97/100] Train Loss: 0.0075, Val Loss: 0.5123, Val Accuracy: 91.84%
#
# [98/100] Train Loss: 0.0086, Val Loss: 0.5131, Val Accuracy: 91.84%
#
# [99/100] Train Loss: 0.0380, Val Loss: 0.5137, Val Accuracy: 91.84%
#
# [100/100] Train Loss: 0.0089, Val Loss: 0.5139, Val Accuracy: 91.84%

# %%
_, _, acc_supervised_300_val, auc_supervised_300_val = test_(ft_network, val_loader, nn.CrossEntropyLoss())
# Out:
# Evaluation on held out test dataset
# Confusion Matrix
# +----------------+------------------+---------------------+
# |                | predicted lenses | predicted nonlenses |
# +----------------+------------------+---------------------+
# |  true lenses   |       246        |          13         |
# | true nonlenses |        22        |         148         |
# +----------------+------------------+---------------------+
# Test Metrics
# +-----------+----------+
# |  accuracy | 91.8415% |
# |    loss   |  0.1180  |
# | auc score |  0.9578  |
# +-----------+----------+
# +----------------+-----------+--------+---------+---------+
# |                | precision | recall | f-score | support |
# +----------------+-----------+--------+---------+---------+
# |     lenses     |   0.9179  | 0.9498 |  0.9336 |   259   |
# |   nonlenses    |   0.9193  | 0.8706 |  0.8943 |   170   |
# | macro averaged |   0.9186  | 0.9102 |  0.9139 |         |
# +----------------+-----------+--------+---------+---------+

# %%
_, _, acc_supervised_300_test, auc_supervised_300_test = test_(ft_network, test_loader, nn.CrossEntropyLoss())
# Out:
# Evaluation on held out test dataset
# Confusion Matrix
# +----------------+------------------+---------------------+
# |                | predicted lenses | predicted nonlenses |
# +----------------+------------------+---------------------+
# |  true lenses   |       418        |          40         |
# | true nonlenses |        30        |         270         |
# +----------------+------------------+---------------------+
# Test Metrics
# +-----------+----------+
# |  accuracy | 90.7652% |
# |    loss   |  0.0611  |
# | auc score |  0.9534  |
# +-----------+----------+
# +----------------+-----------+--------+---------+---------+
# |                | precision | recall | f-score | support |
# +----------------+-----------+--------+---------+---------+
# |     lenses     |   0.9330  | 0.9127 |  0.9227 |   458   |
# |   nonlenses    |   0.8710  | 0.9000 |  0.8852 |   300   |
# | macro averaged |   0.9020  | 0.9063 |  0.9040 |         |
# +----------------+-----------+--------+---------+---------+

# %% [markdown]
# ### ViT Base Classifier trained on 600 labelled datapoints through supervised learning

# %%
set_seed(12)
train_loader, val_loader, test_loader = get_datasets(600)
ft_network = Classifier(mode = "finetune", backbone = Backbone(arch="vit_base", image_size=32, input_channels=3, patch_size=8))
optimizer = torch.optim.Adam(ft_network.parameters(), lr=1e-4, weight_decay=1e-5)
num_epochs = 100
scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, eta_min=1e-8, T_max=num_epochs)
ft_network, ft_network_best_loss = train(ft_network, train_loader, val_loader, nn.CrossEntropyLoss(), optimizer, num_epochs=num_epochs, scheduler=scheduler)

torch.save(ft_network, "/kaggle/working/supervised_600_ckpt.pth")
fpr_supervised_600, tpr_supervised_600, auc_score_600 = compute_auc(ft_network, test_loader)
# Out:
# [1/100] Train Loss: 3.2032, Val Loss: 0.7403, Val Accuracy: 60.37%
#
# [2/100] Train Loss: 0.7264, Val Loss: 0.4814, Val Accuracy: 81.59%
#
# [3/100] Train Loss: 0.5394, Val Loss: 0.4513, Val Accuracy: 74.36%
#
# [4/100] Train Loss: 0.4801, Val Loss: 0.3949, Val Accuracy: 85.55%
#
# [5/100] Train Loss: 0.4252, Val Loss: 0.3381, Val Accuracy: 88.34%
#
# [6/100] Train Loss: 0.3568, Val Loss: 0.3284, Val Accuracy: 88.81%
#
# [7/100] Train Loss: 0.3174, Val Loss: 0.3091, Val Accuracy: 88.34%
#
# [8/100] Train Loss: 0.2809, Val Loss: 0.3480, Val Accuracy: 87.65%
#
# [9/100] Train Loss: 0.3283, Val Loss: 0.3269, Val Accuracy: 87.88%
#
# [10/100] Train Loss: 0.2572, Val Loss: 0.3107, Val Accuracy: 87.88%
#
# [11/100] Train Loss: 0.2576, Val Loss: 0.3056, Val Accuracy: 88.81%
#
# [12/100] Train Loss: 0.2356, Val Loss: 0.3411, Val Accuracy: 87.88%
#
# [13/100] Train Loss: 0.2167, Val Loss: 0.3645, Val Accuracy: 87.65%
#
# [14/100] Train Loss: 0.2226, Val Loss: 0.3752, Val Accuracy: 87.18%
#
# [15/100] Train Loss: 0.2722, Val Loss: 0.3169, Val Accuracy: 88.34%
#
# [16/100] Train Loss: 0.2382, Val Loss: 0.3547, Val Accuracy: 87.41%
#
# [17/100] Train Loss: 0.1945, Val Loss: 0.3206, Val Accuracy: 89.04%
#
# [18/100] Train Loss: 0.1720, Val Loss: 0.3632, Val Accuracy: 89.04%
#
# [19/100] Train Loss: 0.1751, Val Loss: 0.3709, Val Accuracy: 87.88%
#
# [20/100] Train Loss: 0.2222, Val Loss: 0.3926, Val Accuracy: 88.58%
#
# [21/100] Train Loss: 0.1632, Val Loss: 0.3284, Val Accuracy: 89.04%
#
# [22/100] Train Loss: 0.1874, Val Loss: 0.3540, Val Accuracy: 89.28%
#
# [23/100] Train Loss: 0.1560, Val Loss: 0.3213, Val Accuracy: 89.74%
#
# [24/100] Train Loss: 0.1446, Val Loss: 0.3977, Val Accuracy: 89.04%
#
# [25/100] Train Loss: 0.2080, Val Loss: 0.4092, Val Accuracy: 88.81%
#
# [26/100] Train Loss: 0.1606, Val Loss: 0.3477, Val Accuracy: 88.34%
#
# [27/100] Train Loss: 0.1447, Val Loss: 0.3602, Val Accuracy: 89.28%
#
# [28/100] Train Loss: 0.1237, Val Loss: 0.4022, Val Accuracy: 89.98%
#
# [29/100] Train Loss: 0.0997, Val Loss: 0.4291, Val Accuracy: 89.04%
#
# [30/100] Train Loss: 0.0887, Val Loss: 0.4441, Val Accuracy: 89.51%
#
# [31/100] Train Loss: 0.0892, Val Loss: 0.4855, Val Accuracy: 88.58%
#
# [32/100] Train Loss: 0.1454, Val Loss: 0.4184, Val Accuracy: 90.44%
#
# [33/100] Train Loss: 0.0967, Val Loss: 0.4418, Val Accuracy: 89.51%
#
# [34/100] Train Loss: 0.1098, Val Loss: 0.4237, Val Accuracy: 89.51%
#
# [35/100] Train Loss: 0.0974, Val Loss: 0.4324, Val Accuracy: 89.98%
#
# [36/100] Train Loss: 0.1158, Val Loss: 0.4273, Val Accuracy: 89.74%
#
# [37/100] Train Loss: 0.0854, Val Loss: 0.4508, Val Accuracy: 89.74%
#
# [38/100] Train Loss: 0.0745, Val Loss: 0.5156, Val Accuracy: 89.74%
#
# [39/100] Train Loss: 0.0728, Val Loss: 0.5384, Val Accuracy: 89.98%
#
# [40/100] Train Loss: 0.0630, Val Loss: 0.5554, Val Accuracy: 90.44%
#
# [41/100] Train Loss: 0.0736, Val Loss: 0.4707, Val Accuracy: 90.68%
#
# [42/100] Train Loss: 0.1078, Val Loss: 0.4801, Val Accuracy: 90.91%
#
# [43/100] Train Loss: 0.0943, Val Loss: 0.4501, Val Accuracy: 89.51%
#
# [44/100] Train Loss: 0.0686, Val Loss: 0.4750, Val Accuracy: 88.81%
#
# [45/100] Train Loss: 0.0723, Val Loss: 0.4686, Val Accuracy: 90.44%
#
# [46/100] Train Loss: 0.0553, Val Loss: 0.4396, Val Accuracy: 89.28%
#
# [47/100] Train Loss: 0.0429, Val Loss: 0.4986, Val Accuracy: 89.51%
#
# [48/100] Train Loss: 0.0875, Val Loss: 0.4700, Val Accuracy: 90.21%
#
# [49/100] Train Loss: 0.0783, Val Loss: 0.4935, Val Accuracy: 89.51%
#
# [50/100] Train Loss: 0.0553, Val Loss: 0.5093, Val Accuracy: 89.51%
#
# [51/100] Train Loss: 0.0773, Val Loss: 0.4999, Val Accuracy: 89.51%
#
# [52/100] Train Loss: 0.0726, Val Loss: 0.4833, Val Accuracy: 89.51%
#
# [53/100] Train Loss: 0.0408, Val Loss: 0.5159, Val Accuracy: 90.44%
#
# [54/100] Train Loss: 0.0469, Val Loss: 0.5052, Val Accuracy: 89.98%
#
# [55/100] Train Loss: 0.0292, Val Loss: 0.5307, Val Accuracy: 90.68%
#
# [56/100] Train Loss: 0.0398, Val Loss: 0.4930, Val Accuracy: 90.91%
#
# [57/100] Train Loss: 0.0255, Val Loss: 0.4774, Val Accuracy: 90.44%
#
# [58/100] Train Loss: 0.0322, Val Loss: 0.4945, Val Accuracy: 91.14%
#
# [59/100] Train Loss: 0.0212, Val Loss: 0.5088, Val Accuracy: 90.91%
#
# [60/100] Train Loss: 0.0384, Val Loss: 0.5614, Val Accuracy: 90.68%
#
# [61/100] Train Loss: 0.1151, Val Loss: 0.6027, Val Accuracy: 89.74%
#
# [62/100] Train Loss: 0.0643, Val Loss: 0.4921, Val Accuracy: 89.74%
#
# [63/100] Train Loss: 0.0391, Val Loss: 0.4562, Val Accuracy: 90.21%
#
# [64/100] Train Loss: 0.0277, Val Loss: 0.4630, Val Accuracy: 89.98%
#
# [65/100] Train Loss: 0.0214, Val Loss: 0.4936, Val Accuracy: 90.44%
#
# [66/100] Train Loss: 0.0231, Val Loss: 0.5109, Val Accuracy: 90.21%
#
# [67/100] Train Loss: 0.0213, Val Loss: 0.5170, Val Accuracy: 89.74%
#
# [68/100] Train Loss: 0.0217, Val Loss: 0.5387, Val Accuracy: 89.98%
#
# [69/100] Train Loss: 0.0257, Val Loss: 0.5773, Val Accuracy: 89.98%
#
# [70/100] Train Loss: 0.0333, Val Loss: 0.5807, Val Accuracy: 90.44%
#
# [71/100] Train Loss: 0.0199, Val Loss: 0.5622, Val Accuracy: 89.98%
#
# [72/100] Train Loss: 0.0194, Val Loss: 0.5618, Val Accuracy: 89.98%
#
# [73/100] Train Loss: 0.0217, Val Loss: 0.5881, Val Accuracy: 90.91%
#
# [74/100] Train Loss: 0.0162, Val Loss: 0.5895, Val Accuracy: 89.98%
#
# [75/100] Train Loss: 0.0268, Val Loss: 0.5811, Val Accuracy: 90.21%
#
# [76/100] Train Loss: 0.0203, Val Loss: 0.5987, Val Accuracy: 90.21%
#
# [77/100] Train Loss: 0.0163, Val Loss: 0.6062, Val Accuracy: 90.68%
#
# [78/100] Train Loss: 0.0125, Val Loss: 0.6061, Val Accuracy: 90.21%
#
# [79/100] Train Loss: 0.0146, Val Loss: 0.6092, Val Accuracy: 90.21%
#
# [80/100] Train Loss: 0.0095, Val Loss: 0.6110, Val Accuracy: 89.98%
#
# [81/100] Train Loss: 0.0159, Val Loss: 0.6152, Val Accuracy: 90.21%
#
# [82/100] Train Loss: 0.0110, Val Loss: 0.6250, Val Accuracy: 90.21%
#
# [83/100] Train Loss: 0.0152, Val Loss: 0.6284, Val Accuracy: 90.21%
#
# [84/100] Train Loss: 0.0134, Val Loss: 0.6295, Val Accuracy: 90.44%
#
# [85/100] Train Loss: 0.0161, Val Loss: 0.6323, Val Accuracy: 90.21%
#
# [86/100] Train Loss: 0.0172, Val Loss: 0.6336, Val Accuracy: 90.21%
#
# [87/100] Train Loss: 0.0110, Val Loss: 0.6337, Val Accuracy: 90.21%
#
# [88/100] Train Loss: 0.0147, Val Loss: 0.6330, Val Accuracy: 90.21%
#
# [89/100] Train Loss: 0.0108, Val Loss: 0.6343, Val Accuracy: 90.44%
#
# [90/100] Train Loss: 0.0121, Val Loss: 0.6374, Val Accuracy: 90.44%
#
# [91/100] Train Loss: 0.0137, Val Loss: 0.6390, Val Accuracy: 90.44%
#
# [92/100] Train Loss: 0.0092, Val Loss: 0.6396, Val Accuracy: 90.44%
#
# [93/100] Train Loss: 0.0082, Val Loss: 0.6417, Val Accuracy: 90.44%
#
# [94/100] Train Loss: 0.0103, Val Loss: 0.6426, Val Accuracy: 90.44%
#
# [95/100] Train Loss: 0.0200, Val Loss: 0.6431, Val Accuracy: 90.44%
#
# [96/100] Train Loss: 0.0110, Val Loss: 0.6426, Val Accuracy: 90.44%
#
# [97/100] Train Loss: 0.0100, Val Loss: 0.6428, Val Accuracy: 90.44%
#
# [98/100] Train Loss: 0.0107, Val Loss: 0.6429, Val Accuracy: 90.44%
#
# [99/100] Train Loss: 0.0119, Val Loss: 0.6430, Val Accuracy: 90.44%
#
# [100/100] Train Loss: 0.0105, Val Loss: 0.6430, Val Accuracy: 90.44%

# %%
_, _, acc_supervised_600_val, auc_supervised_600_val = test_(ft_network, val_loader, nn.CrossEntropyLoss())
# Out:
# Evaluation on held out test dataset
# Confusion Matrix
# +----------------+------------------+---------------------+
# |                | predicted lenses | predicted nonlenses |
# +----------------+------------------+---------------------+
# |  true lenses   |       236        |          23         |
# | true nonlenses |        18        |         152         |
# +----------------+------------------+---------------------+
# Test Metrics
# +-----------+----------+
# |  accuracy | 90.4429% |
# |    loss   |  0.1050  |
# | auc score |  0.9481  |
# +-----------+----------+
# +----------------+-----------+--------+---------+---------+
# |                | precision | recall | f-score | support |
# +----------------+-----------+--------+---------+---------+
# |     lenses     |   0.9291  | 0.9112 |  0.9201 |   259   |
# |   nonlenses    |   0.8686  | 0.8941 |  0.8812 |   170   |
# | macro averaged |   0.8989  | 0.9027 |  0.9006 |         |
# +----------------+-----------+--------+---------+---------+

# %%
_, _, acc_supervised_600_test, auc_supervised_600_test = test_(ft_network, test_loader, nn.CrossEntropyLoss())
# Out:
# Evaluation on held out test dataset
# Confusion Matrix
# +----------------+------------------+---------------------+
# |                | predicted lenses | predicted nonlenses |
# +----------------+------------------+---------------------+
# |  true lenses   |       430        |          28         |
# | true nonlenses |        28        |         272         |
# +----------------+------------------+---------------------+
# Test Metrics
# +-----------+----------+
# |  accuracy | 92.6121% |
# |    loss   |  0.0739  |
# | auc score |  0.9579  |
# +-----------+----------+
# +----------------+-----------+--------+---------+---------+
# |                | precision | recall | f-score | support |
# +----------------+-----------+--------+---------+---------+
# |     lenses     |   0.9389  | 0.9389 |  0.9389 |   458   |
# |   nonlenses    |   0.9067  | 0.9067 |  0.9067 |   300   |
# | macro averaged |   0.9228  | 0.9228 |  0.9228 |         |
# +----------------+-----------+--------+---------+---------+

# %% [markdown]
# ### ViT Base Classifier trained on 1200 labelled datapoints through supervised learning

# %%
set_seed(12)
train_loader, val_loader, test_loader = get_datasets(1200)
ft_network = Classifier(mode = "finetune", backbone = Backbone(arch="vit_base", image_size=32, input_channels=3, patch_size=8))
optimizer = torch.optim.Adam(ft_network.parameters(), lr=1e-2, weight_decay=1e-3)
num_epochs = 100
scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, eta_min=1e-8, T_max=num_epochs)
ft_network, ft_network_best_loss = train(ft_network, train_loader, val_loader, nn.CrossEntropyLoss(), optimizer, num_epochs=num_epochs, scheduler=scheduler)

torch.save(ft_network, "/kaggle/working/supervised_1200_ckpt.pth")
fpr_supervised_1200, tpr_supervised_1200, auc_score_1200 = compute_auc(ft_network, test_loader)
# Out:
# [1/100] Train Loss: 4.3107, Val Loss: 0.6754, Val Accuracy: 60.14%
#
# [2/100] Train Loss: 0.8640, Val Loss: 0.6444, Val Accuracy: 60.37%
#
# [3/100] Train Loss: 0.7987, Val Loss: 0.7179, Val Accuracy: 60.37%
#
# [4/100] Train Loss: 0.7292, Val Loss: 1.2348, Val Accuracy: 47.32%
#
# [5/100] Train Loss: 0.6938, Val Loss: 0.6717, Val Accuracy: 60.61%
#
# [6/100] Train Loss: 0.6714, Val Loss: 0.5700, Val Accuracy: 66.20%
#
# [7/100] Train Loss: 0.8658, Val Loss: 0.9252, Val Accuracy: 60.37%
#
# [8/100] Train Loss: 0.7461, Val Loss: 0.4425, Val Accuracy: 83.68%
#
# [9/100] Train Loss: 0.4847, Val Loss: 0.4583, Val Accuracy: 79.25%
#
# [10/100] Train Loss: 0.4578, Val Loss: 0.3470, Val Accuracy: 85.31%
#
# [11/100] Train Loss: 0.4962, Val Loss: 0.3555, Val Accuracy: 86.48%
#
# [12/100] Train Loss: 0.4353, Val Loss: 0.3162, Val Accuracy: 88.58%
#
# [13/100] Train Loss: 0.4118, Val Loss: 0.3412, Val Accuracy: 84.85%
#
# [14/100] Train Loss: 0.4338, Val Loss: 0.3709, Val Accuracy: 86.01%
#
# [15/100] Train Loss: 0.4337, Val Loss: 0.3417, Val Accuracy: 87.65%
#
# [16/100] Train Loss: 0.4555, Val Loss: 0.3661, Val Accuracy: 87.88%
#
# [17/100] Train Loss: 0.4442, Val Loss: 0.3532, Val Accuracy: 84.15%
#
# [18/100] Train Loss: 0.4333, Val Loss: 0.3425, Val Accuracy: 86.48%
#
# [19/100] Train Loss: 0.4065, Val Loss: 0.4627, Val Accuracy: 80.42%
#
# [20/100] Train Loss: 0.4520, Val Loss: 0.3676, Val Accuracy: 83.45%
#
# [21/100] Train Loss: 0.4419, Val Loss: 0.3603, Val Accuracy: 87.65%
#
# [22/100] Train Loss: 0.4274, Val Loss: 0.3565, Val Accuracy: 84.85%
#
# [23/100] Train Loss: 0.4454, Val Loss: 0.4679, Val Accuracy: 78.79%
#
# [24/100] Train Loss: 0.4202, Val Loss: 0.4927, Val Accuracy: 79.02%
#
# [25/100] Train Loss: 0.4416, Val Loss: 0.3646, Val Accuracy: 86.01%
#
# [26/100] Train Loss: 0.4164, Val Loss: 0.3517, Val Accuracy: 87.88%
#
# [27/100] Train Loss: 0.3976, Val Loss: 0.3852, Val Accuracy: 82.75%
#
# [28/100] Train Loss: 0.4087, Val Loss: 0.3601, Val Accuracy: 84.85%
#
# [29/100] Train Loss: 0.3830, Val Loss: 0.3383, Val Accuracy: 86.71%
#
# [30/100] Train Loss: 0.3697, Val Loss: 0.3165, Val Accuracy: 87.18%
#
# [31/100] Train Loss: 0.3749, Val Loss: 0.3215, Val Accuracy: 87.41%
#
# [32/100] Train Loss: 0.4151, Val Loss: 0.3316, Val Accuracy: 88.34%
#
# [33/100] Train Loss: 0.4169, Val Loss: 0.3545, Val Accuracy: 87.65%
#
# [34/100] Train Loss: 0.3896, Val Loss: 0.3419, Val Accuracy: 86.95%
#
# [35/100] Train Loss: 0.3685, Val Loss: 0.3068, Val Accuracy: 86.95%
#
# [36/100] Train Loss: 0.3697, Val Loss: 0.3879, Val Accuracy: 81.12%
#
# [37/100] Train Loss: 0.3790, Val Loss: 0.3523, Val Accuracy: 85.78%
#
# [38/100] Train Loss: 0.3396, Val Loss: 0.2695, Val Accuracy: 89.74%
#
# [39/100] Train Loss: 0.3270, Val Loss: 0.2920, Val Accuracy: 89.28%
#
# [40/100] Train Loss: 0.3494, Val Loss: 0.3393, Val Accuracy: 86.48%
#
# [41/100] Train Loss: 0.3704, Val Loss: 0.3278, Val Accuracy: 88.58%
#
# [42/100] Train Loss: 0.3574, Val Loss: 0.3139, Val Accuracy: 87.41%
#
# [43/100] Train Loss: 0.3567, Val Loss: 0.2847, Val Accuracy: 90.21%
#
# [44/100] Train Loss: 0.3487, Val Loss: 0.3456, Val Accuracy: 84.15%
#
# [45/100] Train Loss: 0.3537, Val Loss: 0.2998, Val Accuracy: 89.51%
#
# [46/100] Train Loss: 0.3308, Val Loss: 0.3353, Val Accuracy: 86.71%
#
# [47/100] Train Loss: 0.3141, Val Loss: 0.2875, Val Accuracy: 88.11%
#
# [48/100] Train Loss: 0.3260, Val Loss: 0.3148, Val Accuracy: 87.18%
#
# [49/100] Train Loss: 0.3100, Val Loss: 0.2871, Val Accuracy: 89.74%
#
# [50/100] Train Loss: 0.3093, Val Loss: 0.2846, Val Accuracy: 89.04%
#
# [51/100] Train Loss: 0.3115, Val Loss: 0.2701, Val Accuracy: 90.21%
#
# [52/100] Train Loss: 0.2940, Val Loss: 0.2534, Val Accuracy: 91.14%
#
# [53/100] Train Loss: 0.2719, Val Loss: 0.2647, Val Accuracy: 91.61%
#
# [54/100] Train Loss: 0.2594, Val Loss: 0.3370, Val Accuracy: 87.65%
#
# [55/100] Train Loss: 0.3069, Val Loss: 0.2702, Val Accuracy: 89.74%
#
# [56/100] Train Loss: 0.2761, Val Loss: 0.2844, Val Accuracy: 87.65%
#
# [57/100] Train Loss: 0.2954, Val Loss: 0.2687, Val Accuracy: 89.74%
#
# [58/100] Train Loss: 0.2527, Val Loss: 0.2780, Val Accuracy: 89.28%
#
# [59/100] Train Loss: 0.2663, Val Loss: 0.2761, Val Accuracy: 88.81%
#
# [60/100] Train Loss: 0.2628, Val Loss: 0.2937, Val Accuracy: 87.88%
#
# [61/100] Train Loss: 0.2597, Val Loss: 0.2630, Val Accuracy: 89.74%
#
# [62/100] Train Loss: 0.2358, Val Loss: 0.2621, Val Accuracy: 89.28%
#
# [63/100] Train Loss: 0.2371, Val Loss: 0.2440, Val Accuracy: 89.51%
#
# [64/100] Train Loss: 0.2300, Val Loss: 0.2627, Val Accuracy: 89.04%
#
# [65/100] Train Loss: 0.2472, Val Loss: 0.2436, Val Accuracy: 89.74%
#
# [66/100] Train Loss: 0.2332, Val Loss: 0.2398, Val Accuracy: 91.84%
#
# [67/100] Train Loss: 0.2370, Val Loss: 0.2783, Val Accuracy: 88.58%
#
# [68/100] Train Loss: 0.2285, Val Loss: 0.2703, Val Accuracy: 89.74%
#
# [69/100] Train Loss: 0.2092, Val Loss: 0.2324, Val Accuracy: 90.91%
#
# [70/100] Train Loss: 0.1901, Val Loss: 0.2375, Val Accuracy: 92.54%
#
# [71/100] Train Loss: 0.1768, Val Loss: 0.2399, Val Accuracy: 92.07%
#
# [72/100] Train Loss: 0.1601, Val Loss: 0.2296, Val Accuracy: 92.07%
#
# [73/100] Train Loss: 0.1577, Val Loss: 0.2758, Val Accuracy: 90.91%
#
# [74/100] Train Loss: 0.1863, Val Loss: 0.2502, Val Accuracy: 92.07%
#
# [75/100] Train Loss: 0.1488, Val Loss: 0.2225, Val Accuracy: 92.31%
#
# [76/100] Train Loss: 0.1280, Val Loss: 0.2183, Val Accuracy: 92.54%
#
# [77/100] Train Loss: 0.1570, Val Loss: 0.2121, Val Accuracy: 93.71%
#
# [78/100] Train Loss: 0.1224, Val Loss: 0.2653, Val Accuracy: 92.54%
#
# [79/100] Train Loss: 0.1321, Val Loss: 0.2653, Val Accuracy: 92.54%
#
# [80/100] Train Loss: 0.1169, Val Loss: 0.2800, Val Accuracy: 91.14%
#
# [81/100] Train Loss: 0.1152, Val Loss: 0.2374, Val Accuracy: 93.01%
#
# [82/100] Train Loss: 0.1106, Val Loss: 0.2905, Val Accuracy: 93.24%
#
# [83/100] Train Loss: 0.1090, Val Loss: 0.2168, Val Accuracy: 94.17%
#
# [84/100] Train Loss: 0.1113, Val Loss: 0.2204, Val Accuracy: 92.77%
#
# [85/100] Train Loss: 0.0929, Val Loss: 0.2376, Val Accuracy: 94.41%
#
# [86/100] Train Loss: 0.0875, Val Loss: 0.2376, Val Accuracy: 93.71%
#
# [87/100] Train Loss: 0.0912, Val Loss: 0.2364, Val Accuracy: 94.17%
#
# [88/100] Train Loss: 0.0808, Val Loss: 0.2505, Val Accuracy: 94.17%
#
# [89/100] Train Loss: 0.0679, Val Loss: 0.2498, Val Accuracy: 93.94%
#
# [90/100] Train Loss: 0.0571, Val Loss: 0.2511, Val Accuracy: 93.94%
#
# [91/100] Train Loss: 0.0498, Val Loss: 0.2730, Val Accuracy: 94.41%
#
# [92/100] Train Loss: 0.0457, Val Loss: 0.2819, Val Accuracy: 94.17%
#
# [93/100] Train Loss: 0.0499, Val Loss: 0.2816, Val Accuracy: 93.71%
#
# [94/100] Train Loss: 0.0503, Val Loss: 0.2661, Val Accuracy: 94.17%
#
# [95/100] Train Loss: 0.0547, Val Loss: 0.2929, Val Accuracy: 94.17%
#
# [96/100] Train Loss: 0.0487, Val Loss: 0.2652, Val Accuracy: 94.17%
#
# [97/100] Train Loss: 0.0485, Val Loss: 0.2730, Val Accuracy: 93.94%
#
# [98/100] Train Loss: 0.0400, Val Loss: 0.2766, Val Accuracy: 93.94%
#
# [99/100] Train Loss: 0.0441, Val Loss: 0.2765, Val Accuracy: 93.94%
#
# [100/100] Train Loss: 0.0404, Val Loss: 0.2767, Val Accuracy: 93.94%

# %%
_, _, acc_supervised_1200_val, auc_supervised_1200_val = test_(ft_network, val_loader, nn.CrossEntropyLoss())
# Out:
# Evaluation on held out test dataset
# Confusion Matrix
# +----------------+------------------+---------------------+
# |                | predicted lenses | predicted nonlenses |
# +----------------+------------------+---------------------+
# |  true lenses   |       248        |          11         |
# | true nonlenses |        15        |         155         |
# +----------------+------------------+---------------------+
# Test Metrics
# +-----------+----------+
# |  accuracy | 93.9394% |
# |    loss   |  0.0491  |
# | auc score |  0.9731  |
# +-----------+----------+
# +----------------+-----------+--------+---------+---------+
# |                | precision | recall | f-score | support |
# +----------------+-----------+--------+---------+---------+
# |     lenses     |   0.9430  | 0.9575 |  0.9502 |   259   |
# |   nonlenses    |   0.9337  | 0.9118 |  0.9226 |   170   |
# | macro averaged |   0.9384  | 0.9346 |  0.9364 |         |
# +----------------+-----------+--------+---------+---------+

# %%
_, _, acc_supervised_1200_test, auc_supervised_1200_test = test_(ft_network, test_loader, nn.CrossEntropyLoss())
# Out:
# Evaluation on held out test dataset
# Confusion Matrix
# +----------------+------------------+---------------------+
# |                | predicted lenses | predicted nonlenses |
# +----------------+------------------+---------------------+
# |  true lenses   |       432        |          26         |
# | true nonlenses |        24        |         276         |
# +----------------+------------------+---------------------+
# Test Metrics
# +-----------+----------+
# |  accuracy | 93.4037% |
# |    loss   |  0.0506  |
# | auc score |  0.9678  |
# +-----------+----------+
# +----------------+-----------+--------+---------+---------+
# |                | precision | recall | f-score | support |
# +----------------+-----------+--------+---------+---------+
# |     lenses     |   0.9474  | 0.9432 |  0.9453 |   458   |
# |   nonlenses    |   0.9139  | 0.9200 |  0.9169 |   300   |
# | macro averaged |   0.9306  | 0.9316 |  0.9311 |         |
# +----------------+-----------+--------+---------+---------+

# %% [markdown]
# ### ViT Base Classifier trained on all labelled datapoints through supervised learning

# %%
set_seed(12)
train_loader, val_loader, test_loader = get_datasets(None)
ft_network = Classifier(mode = "finetune", backbone = Backbone(arch="vit_base", image_size=32, input_channels=3, patch_size=8))
optimizer = torch.optim.Adam(ft_network.parameters(), lr=1e-4, weight_decay=1e-5)
num_epochs = 100
scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, eta_min=1e-8, T_max=num_epochs)
ft_network, ft_network_best_loss = train(ft_network, train_loader, val_loader, nn.CrossEntropyLoss(), optimizer, num_epochs=num_epochs, scheduler=scheduler)

torch.save(ft_network, "/kaggle/working/supervised_all_ckpt.pth")
fpr_supervised_all, tpr_supervised_all, auc_score_all = compute_auc(ft_network, test_loader)
# Out:
# [1/100] Train Loss: 1.0749, Val Loss: 0.3233, Val Accuracy: 88.58%
#
# [2/100] Train Loss: 0.3308, Val Loss: 0.2644, Val Accuracy: 89.98%
#
# [3/100] Train Loss: 0.2688, Val Loss: 0.2850, Val Accuracy: 90.21%
#
# [4/100] Train Loss: 0.2596, Val Loss: 0.2340, Val Accuracy: 90.91%
#
# [5/100] Train Loss: 0.2293, Val Loss: 0.2125, Val Accuracy: 91.14%
#
# [6/100] Train Loss: 0.2074, Val Loss: 0.2070, Val Accuracy: 91.14%
#
# [7/100] Train Loss: 0.2087, Val Loss: 0.2289, Val Accuracy: 91.61%
#
# [8/100] Train Loss: 0.1775, Val Loss: 0.2103, Val Accuracy: 93.01%
#
# [9/100] Train Loss: 0.1582, Val Loss: 0.2333, Val Accuracy: 91.84%
#
# [10/100] Train Loss: 0.1795, Val Loss: 0.2539, Val Accuracy: 92.77%
#
# [11/100] Train Loss: 0.1617, Val Loss: 0.2008, Val Accuracy: 93.47%
#
# [12/100] Train Loss: 0.1380, Val Loss: 0.2143, Val Accuracy: 93.24%
#
# [13/100] Train Loss: 0.1300, Val Loss: 0.2148, Val Accuracy: 92.77%
#
# [14/100] Train Loss: 0.1318, Val Loss: 0.1790, Val Accuracy: 94.41%
#
# [15/100] Train Loss: 0.1104, Val Loss: 0.1948, Val Accuracy: 94.64%
#
# [16/100] Train Loss: 0.1135, Val Loss: 0.2314, Val Accuracy: 93.71%
#
# [17/100] Train Loss: 0.1134, Val Loss: 0.1897, Val Accuracy: 94.64%
#
# [18/100] Train Loss: 0.1073, Val Loss: 0.1894, Val Accuracy: 94.87%
#
# [19/100] Train Loss: 0.1114, Val Loss: 0.2062, Val Accuracy: 93.94%
#
# [20/100] Train Loss: 0.1087, Val Loss: 0.2111, Val Accuracy: 93.47%
#
# [21/100] Train Loss: 0.0959, Val Loss: 0.2004, Val Accuracy: 94.17%
#
# [22/100] Train Loss: 0.0854, Val Loss: 0.2405, Val Accuracy: 94.64%
#
# [23/100] Train Loss: 0.0901, Val Loss: 0.2715, Val Accuracy: 93.01%
#
# [24/100] Train Loss: 0.0794, Val Loss: 0.2439, Val Accuracy: 93.24%
#
# [25/100] Train Loss: 0.0862, Val Loss: 0.2596, Val Accuracy: 94.87%
#
# [26/100] Train Loss: 0.0721, Val Loss: 0.2381, Val Accuracy: 95.10%
#
# [27/100] Train Loss: 0.0539, Val Loss: 0.2704, Val Accuracy: 94.41%
#
# [28/100] Train Loss: 0.0826, Val Loss: 0.1879, Val Accuracy: 94.17%
#
# [29/100] Train Loss: 0.0707, Val Loss: 0.2159, Val Accuracy: 94.41%
#
# [30/100] Train Loss: 0.0586, Val Loss: 0.2357, Val Accuracy: 94.87%
#
# [31/100] Train Loss: 0.0603, Val Loss: 0.2519, Val Accuracy: 94.41%
#
# [32/100] Train Loss: 0.0600, Val Loss: 0.2365, Val Accuracy: 93.47%
#
# [33/100] Train Loss: 0.0422, Val Loss: 0.2319, Val Accuracy: 94.64%
#
# [34/100] Train Loss: 0.1422, Val Loss: 0.2680, Val Accuracy: 93.71%
#
# [35/100] Train Loss: 0.0938, Val Loss: 0.2108, Val Accuracy: 94.64%
#
# [36/100] Train Loss: 0.0701, Val Loss: 0.1960, Val Accuracy: 94.64%
#
# [37/100] Train Loss: 0.0579, Val Loss: 0.2536, Val Accuracy: 93.94%
#
# [38/100] Train Loss: 0.0596, Val Loss: 0.2512, Val Accuracy: 94.41%
#
# [39/100] Train Loss: 0.0474, Val Loss: 0.3335, Val Accuracy: 93.71%
#
# [40/100] Train Loss: 0.0603, Val Loss: 0.3371, Val Accuracy: 93.71%
#
# [41/100] Train Loss: 0.0576, Val Loss: 0.2606, Val Accuracy: 94.17%
#
# [42/100] Train Loss: 0.0450, Val Loss: 0.2604, Val Accuracy: 95.10%
#
# [43/100] Train Loss: 0.0398, Val Loss: 0.2987, Val Accuracy: 94.87%
#
# [44/100] Train Loss: 0.0332, Val Loss: 0.2419, Val Accuracy: 95.34%
#
# [45/100] Train Loss: 0.0385, Val Loss: 0.2665, Val Accuracy: 94.87%
#
# [46/100] Train Loss: 0.0388, Val Loss: 0.2353, Val Accuracy: 93.71%
#
# [47/100] Train Loss: 0.0317, Val Loss: 0.2450, Val Accuracy: 94.87%
#
# [48/100] Train Loss: 0.0313, Val Loss: 0.3012, Val Accuracy: 94.64%
#
# [49/100] Train Loss: 0.0268, Val Loss: 0.3026, Val Accuracy: 94.41%
#
# [50/100] Train Loss: 0.0252, Val Loss: 0.2662, Val Accuracy: 95.10%
#
# [51/100] Train Loss: 0.0248, Val Loss: 0.3224, Val Accuracy: 94.41%
#
# [52/100] Train Loss: 0.0280, Val Loss: 0.2815, Val Accuracy: 95.34%
#
# [53/100] Train Loss: 0.0224, Val Loss: 0.2997, Val Accuracy: 94.87%
#
# [54/100] Train Loss: 0.0148, Val Loss: 0.3069, Val Accuracy: 95.57%
#
# [55/100] Train Loss: 0.0175, Val Loss: 0.3199, Val Accuracy: 94.87%
#
# [56/100] Train Loss: 0.0145, Val Loss: 0.3496, Val Accuracy: 93.94%
#
# [57/100] Train Loss: 0.0128, Val Loss: 0.3586, Val Accuracy: 94.64%
#
# [58/100] Train Loss: 0.0114, Val Loss: 0.3130, Val Accuracy: 95.10%
#
# [59/100] Train Loss: 0.0238, Val Loss: 0.2874, Val Accuracy: 95.10%
#
# [60/100] Train Loss: 0.0178, Val Loss: 0.3147, Val Accuracy: 93.47%
#
# [61/100] Train Loss: 0.0126, Val Loss: 0.4063, Val Accuracy: 94.17%
#
# [62/100] Train Loss: 0.0130, Val Loss: 0.3804, Val Accuracy: 94.64%
#
# [63/100] Train Loss: 0.0081, Val Loss: 0.3923, Val Accuracy: 94.87%
#
# [64/100] Train Loss: 0.0074, Val Loss: 0.3930, Val Accuracy: 94.87%
#
# [65/100] Train Loss: 0.0092, Val Loss: 0.4234, Val Accuracy: 94.87%
#
# [66/100] Train Loss: 0.0083, Val Loss: 0.3845, Val Accuracy: 95.57%
#
# [67/100] Train Loss: 0.0100, Val Loss: 0.3908, Val Accuracy: 94.41%
#
# [68/100] Train Loss: 0.0137, Val Loss: 0.3490, Val Accuracy: 94.41%
#
# [69/100] Train Loss: 0.0092, Val Loss: 0.3743, Val Accuracy: 94.64%
#
# [70/100] Train Loss: 0.0093, Val Loss: 0.3403, Val Accuracy: 95.10%
#
# [71/100] Train Loss: 0.0071, Val Loss: 0.3675, Val Accuracy: 94.87%
#
# [72/100] Train Loss: 0.0052, Val Loss: 0.3932, Val Accuracy: 94.87%
#
# [73/100] Train Loss: 0.0030, Val Loss: 0.4016, Val Accuracy: 95.10%
#
# [74/100] Train Loss: 0.0050, Val Loss: 0.3847, Val Accuracy: 94.87%
#
# [75/100] Train Loss: 0.0050, Val Loss: 0.3923, Val Accuracy: 94.87%
#
# [76/100] Train Loss: 0.0044, Val Loss: 0.4118, Val Accuracy: 94.87%
#
# [77/100] Train Loss: 0.0026, Val Loss: 0.4275, Val Accuracy: 94.87%
#
# [78/100] Train Loss: 0.0038, Val Loss: 0.4414, Val Accuracy: 95.34%
#
# [79/100] Train Loss: 0.0023, Val Loss: 0.4597, Val Accuracy: 95.34%
#
# [80/100] Train Loss: 0.0034, Val Loss: 0.4658, Val Accuracy: 95.57%
#
# [81/100] Train Loss: 0.0029, Val Loss: 0.4333, Val Accuracy: 95.80%
#
# [82/100] Train Loss: 0.0019, Val Loss: 0.4384, Val Accuracy: 94.87%
#
# [83/100] Train Loss: 0.0039, Val Loss: 0.4452, Val Accuracy: 95.10%
#
# [84/100] Train Loss: 0.0020, Val Loss: 0.4557, Val Accuracy: 95.57%
#
# [85/100] Train Loss: 0.0017, Val Loss: 0.4605, Val Accuracy: 95.57%
#
# [86/100] Train Loss: 0.0028, Val Loss: 0.4648, Val Accuracy: 95.34%
#
# [87/100] Train Loss: 0.0045, Val Loss: 0.4616, Val Accuracy: 95.10%
#
# [88/100] Train Loss: 0.0022, Val Loss: 0.4610, Val Accuracy: 95.10%
#
# [89/100] Train Loss: 0.0027, Val Loss: 0.4558, Val Accuracy: 95.10%
#
# [90/100] Train Loss: 0.0014, Val Loss: 0.4613, Val Accuracy: 95.34%
#
# [91/100] Train Loss: 0.0020, Val Loss: 0.4606, Val Accuracy: 95.34%
#
# [92/100] Train Loss: 0.0021, Val Loss: 0.4628, Val Accuracy: 95.10%
#
# [93/100] Train Loss: 0.0020, Val Loss: 0.4639, Val Accuracy: 95.34%
#
# [94/100] Train Loss: 0.0019, Val Loss: 0.4653, Val Accuracy: 95.34%
#
# [95/100] Train Loss: 0.0014, Val Loss: 0.4665, Val Accuracy: 95.34%
#
# [96/100] Train Loss: 0.0017, Val Loss: 0.4671, Val Accuracy: 95.34%
#
# [97/100] Train Loss: 0.0017, Val Loss: 0.4669, Val Accuracy: 95.34%
#
# [98/100] Train Loss: 0.0034, Val Loss: 0.4668, Val Accuracy: 95.34%
#
# [99/100] Train Loss: 0.0018, Val Loss: 0.4670, Val Accuracy: 95.34%
#
# [100/100] Train Loss: 0.0027, Val Loss: 0.4669, Val Accuracy: 95.34%

# %%
_, _, acc_supervised_all_val, auc_supervised_all_val = test_(ft_network, val_loader, nn.CrossEntropyLoss())
# Out:
# Evaluation on held out test dataset
# Confusion Matrix
# +----------------+------------------+---------------------+
# |                | predicted lenses | predicted nonlenses |
# +----------------+------------------+---------------------+
# |  true lenses   |       250        |          9          |
# | true nonlenses |        11        |         159         |
# +----------------+------------------+---------------------+
# Test Metrics
# +-----------+----------+
# |  accuracy | 95.3380% |
# |    loss   |  0.1253  |
# | auc score |  0.9866  |
# +-----------+----------+
# +----------------+-----------+--------+---------+---------+
# |                | precision | recall | f-score | support |
# +----------------+-----------+--------+---------+---------+
# |     lenses     |   0.9579  | 0.9653 |  0.9615 |   259   |
# |   nonlenses    |   0.9464  | 0.9353 |  0.9408 |   170   |
# | macro averaged |   0.9521  | 0.9503 |  0.9512 |         |
# +----------------+-----------+--------+---------+---------+

# %%
_, _, acc_supervised_all_test, auc_supervised_all_test = test_(ft_network, test_loader, nn.CrossEntropyLoss())
# Out:
# Evaluation on held out test dataset
# Confusion Matrix
# +----------------+------------------+---------------------+
# |                | predicted lenses | predicted nonlenses |
# +----------------+------------------+---------------------+
# |  true lenses   |       441        |          17         |
# | true nonlenses |        21        |         279         |
# +----------------+------------------+---------------------+
# Test Metrics
# +-----------+----------+
# |  accuracy | 94.9868% |
# |    loss   |  0.0284  |
# | auc score |  0.9843  |
# +-----------+----------+
# +----------------+-----------+--------+---------+---------+
# |                | precision | recall | f-score | support |
# +----------------+-----------+--------+---------+---------+
# |     lenses     |   0.9545  | 0.9629 |  0.9587 |   458   |
# |   nonlenses    |   0.9426  | 0.9300 |  0.9362 |   300   |
# | macro averaged |   0.9486  | 0.9464 |  0.9475 |         |
# +----------------+-----------+--------+---------+---------+

# %% [markdown]
# ### ROC Curves for the supervised models are plotted below

# %%
plt.figure(figsize=(15, 15))
plt.title('ROC')
plt.plot(fpr_supervised_300, tpr_supervised_300, 'r', label = 'AUC (trained on 300 labelled data, supervised) = %0.4f' % auc_score_300)
plt.plot(fpr_supervised_600, tpr_supervised_600, 'm', label = 'AUC (trained on 600 labelled data, supervised) = %0.4f' % auc_score_600)
plt.plot(fpr_supervised_1200, tpr_supervised_1200, 'g', label = 'AUC (trained on 1200 labelled data, supervised) = %0.4f' % auc_score_1200)
plt.plot(fpr_supervised_all, tpr_supervised_all, 'b', label = 'AUC (trained on all labelled data, supervised) = %0.4f' % auc_score_all)

plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.savefig("auc_supervised.png")
plt.show()

# %% [markdown]
# ### ViT Base backbone pretrained with IBot

# %%
state = torch.load("/kaggle/input/deeplense-git/ibot-vit-base-ckpt.pth")
# Out:
# /tmp/ipykernel_24/1431652193.py:1: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state = torch.load("/kaggle/input/deeplense-git/ibot-vit-base-ckpt.pth")

# %% [markdown]
# ### ViT Base pretrained backbone finetuned on 300 labelled datapoints

# %%
set_seed(12)
train_loader, val_loader, test_loader = get_datasets(300)
ft_network = Classifier(mode = "finetune", backbone = copy.deepcopy(state["student"].backbone), backbone_return_all_tokens=True)
optimizer = torch.optim.Adam(ft_network.parameters(), lr=1e-4, weight_decay=1e-3)
num_epochs = 100
scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, eta_min=1e-8, T_max=num_epochs)
ft_network, ft_network_best_loss = train(ft_network, train_loader, val_loader, nn.CrossEntropyLoss(), optimizer, num_epochs=num_epochs, scheduler=scheduler)

torch.save(ft_network, "/kaggle/working/ibot_finetuned_300_ckpt.pth")
fpr_ibot_finetuned_300, tpr_ibot_finetuned_300, auc_score_ibot_finetuned_300 = compute_auc(ft_network, test_loader)
# Out:
# [1/100] Train Loss: 1.9053, Val Loss: 1.6486, Val Accuracy: 60.37%
#
# [2/100] Train Loss: 1.0256, Val Loss: 0.9869, Val Accuracy: 56.64%
#
# [3/100] Train Loss: 0.6548, Val Loss: 0.6095, Val Accuracy: 61.07%
#
# [4/100] Train Loss: 0.5249, Val Loss: 0.3954, Val Accuracy: 82.98%
#
# [5/100] Train Loss: 0.4011, Val Loss: 0.3444, Val Accuracy: 87.88%
#
# [6/100] Train Loss: 0.3412, Val Loss: 0.2945, Val Accuracy: 87.41%
#
# [7/100] Train Loss: 0.2901, Val Loss: 0.2861, Val Accuracy: 88.11%
#
# [8/100] Train Loss: 0.2596, Val Loss: 0.2756, Val Accuracy: 87.65%
#
# [9/100] Train Loss: 0.2529, Val Loss: 0.2706, Val Accuracy: 88.81%
#
# [10/100] Train Loss: 0.2228, Val Loss: 0.2726, Val Accuracy: 89.28%
#
# [11/100] Train Loss: 0.2177, Val Loss: 0.2753, Val Accuracy: 87.41%
#
# [12/100] Train Loss: 0.1952, Val Loss: 0.2852, Val Accuracy: 88.81%
#
# [13/100] Train Loss: 0.2216, Val Loss: 0.2719, Val Accuracy: 89.74%
#
# [14/100] Train Loss: 0.1720, Val Loss: 0.2692, Val Accuracy: 89.04%
#
# [15/100] Train Loss: 0.1622, Val Loss: 0.2584, Val Accuracy: 90.91%
#
# [16/100] Train Loss: 0.1652, Val Loss: 0.2753, Val Accuracy: 89.04%
#
# [17/100] Train Loss: 0.1405, Val Loss: 0.3089, Val Accuracy: 90.21%
#
# [18/100] Train Loss: 0.1033, Val Loss: 0.3240, Val Accuracy: 90.68%
#
# [19/100] Train Loss: 0.0620, Val Loss: 0.3725, Val Accuracy: 89.51%
#
# [20/100] Train Loss: 0.0829, Val Loss: 0.3517, Val Accuracy: 92.31%
#
# [21/100] Train Loss: 0.0631, Val Loss: 0.3626, Val Accuracy: 92.31%
#
# [22/100] Train Loss: 0.0319, Val Loss: 0.3796, Val Accuracy: 92.54%
#
# [23/100] Train Loss: 0.0727, Val Loss: 0.5206, Val Accuracy: 89.51%
#
# [24/100] Train Loss: 0.0857, Val Loss: 0.5920, Val Accuracy: 88.34%
#
# [25/100] Train Loss: 0.1766, Val Loss: 0.3131, Val Accuracy: 91.14%
#
# [26/100] Train Loss: 0.1202, Val Loss: 0.2897, Val Accuracy: 90.91%
#
# [27/100] Train Loss: 0.1054, Val Loss: 0.3412, Val Accuracy: 91.14%
#
# [28/100] Train Loss: 0.0731, Val Loss: 0.3834, Val Accuracy: 90.44%
#
# [29/100] Train Loss: 0.0517, Val Loss: 0.3278, Val Accuracy: 91.38%
#
# [30/100] Train Loss: 0.0371, Val Loss: 0.4153, Val Accuracy: 91.14%
#
# [31/100] Train Loss: 0.0295, Val Loss: 0.5398, Val Accuracy: 90.91%
#
# [32/100] Train Loss: 0.0404, Val Loss: 0.4764, Val Accuracy: 92.07%
#
# [33/100] Train Loss: 0.0447, Val Loss: 0.4642, Val Accuracy: 90.68%
#
# [34/100] Train Loss: 0.0401, Val Loss: 0.3878, Val Accuracy: 92.54%
#
# [35/100] Train Loss: 0.0260, Val Loss: 0.4901, Val Accuracy: 90.91%
#
# [36/100] Train Loss: 0.0436, Val Loss: 0.3882, Val Accuracy: 90.68%
#
# [37/100] Train Loss: 0.0884, Val Loss: 0.4583, Val Accuracy: 91.14%
#
# [38/100] Train Loss: 0.0529, Val Loss: 0.4449, Val Accuracy: 91.61%
#
# [39/100] Train Loss: 0.0373, Val Loss: 0.4664, Val Accuracy: 91.38%
#
# [40/100] Train Loss: 0.0347, Val Loss: 0.4161, Val Accuracy: 92.07%
#
# [41/100] Train Loss: 0.0148, Val Loss: 0.4114, Val Accuracy: 91.84%
#
# [42/100] Train Loss: 0.0052, Val Loss: 0.4656, Val Accuracy: 91.84%
#
# [43/100] Train Loss: 0.0106, Val Loss: 0.4427, Val Accuracy: 91.61%
#
# [44/100] Train Loss: 0.0035, Val Loss: 0.4573, Val Accuracy: 92.31%
#
# [45/100] Train Loss: 0.0050, Val Loss: 0.4819, Val Accuracy: 92.77%
#
# [46/100] Train Loss: 0.0055, Val Loss: 0.6195, Val Accuracy: 89.74%
#
# [47/100] Train Loss: 0.0078, Val Loss: 0.5192, Val Accuracy: 92.77%
#
# [48/100] Train Loss: 0.0029, Val Loss: 0.5309, Val Accuracy: 92.07%
#
# [49/100] Train Loss: 0.0161, Val Loss: 0.6091, Val Accuracy: 91.38%
#
# [50/100] Train Loss: 0.0155, Val Loss: 0.5143, Val Accuracy: 92.31%
#
# [51/100] Train Loss: 0.0315, Val Loss: 0.5706, Val Accuracy: 92.31%
#
# [52/100] Train Loss: 0.0576, Val Loss: 0.5146, Val Accuracy: 93.71%
#
# [53/100] Train Loss: 0.0232, Val Loss: 0.5025, Val Accuracy: 92.07%
#
# [54/100] Train Loss: 0.0193, Val Loss: 0.5264, Val Accuracy: 91.61%
#
# [55/100] Train Loss: 0.0062, Val Loss: 0.5563, Val Accuracy: 90.21%
#
# [56/100] Train Loss: 0.0047, Val Loss: 0.5099, Val Accuracy: 91.84%
#
# [57/100] Train Loss: 0.0048, Val Loss: 0.5151, Val Accuracy: 92.31%
#
# [58/100] Train Loss: 0.0058, Val Loss: 0.6066, Val Accuracy: 91.84%
#
# [59/100] Train Loss: 0.0040, Val Loss: 0.6510, Val Accuracy: 91.84%
#
# [60/100] Train Loss: 0.0065, Val Loss: 0.5529, Val Accuracy: 93.24%
#
# [61/100] Train Loss: 0.0008, Val Loss: 0.4980, Val Accuracy: 92.77%
#
# [62/100] Train Loss: 0.0007, Val Loss: 0.5043, Val Accuracy: 92.77%
#
# [63/100] Train Loss: 0.0028, Val Loss: 0.5212, Val Accuracy: 92.77%
#
# [64/100] Train Loss: 0.0011, Val Loss: 0.5491, Val Accuracy: 91.84%
#
# [65/100] Train Loss: 0.0017, Val Loss: 0.5685, Val Accuracy: 91.84%
#
# [66/100] Train Loss: 0.0180, Val Loss: 0.6202, Val Accuracy: 92.07%
#
# [67/100] Train Loss: 0.0020, Val Loss: 0.6631, Val Accuracy: 92.54%
#
# [68/100] Train Loss: 0.0012, Val Loss: 0.6636, Val Accuracy: 92.77%
#
# [69/100] Train Loss: 0.0007, Val Loss: 0.6594, Val Accuracy: 93.24%
#
# [70/100] Train Loss: 0.0071, Val Loss: 0.6263, Val Accuracy: 93.24%
#
# [71/100] Train Loss: 0.0083, Val Loss: 0.5797, Val Accuracy: 92.54%
#
# [72/100] Train Loss: 0.0032, Val Loss: 0.5681, Val Accuracy: 92.54%
#
# [73/100] Train Loss: 0.0022, Val Loss: 0.5976, Val Accuracy: 90.68%
#
# [74/100] Train Loss: 0.0008, Val Loss: 0.6155, Val Accuracy: 90.68%
#
# [75/100] Train Loss: 0.0044, Val Loss: 0.5929, Val Accuracy: 90.68%
#
# [76/100] Train Loss: 0.0013, Val Loss: 0.5680, Val Accuracy: 91.38%
#
# [77/100] Train Loss: 0.0005, Val Loss: 0.5511, Val Accuracy: 92.07%
#
# [78/100] Train Loss: 0.0039, Val Loss: 0.5549, Val Accuracy: 91.61%
#
# [79/100] Train Loss: 0.0005, Val Loss: 0.5601, Val Accuracy: 91.38%
#
# [80/100] Train Loss: 0.0006, Val Loss: 0.5605, Val Accuracy: 91.38%
#
# [81/100] Train Loss: 0.0008, Val Loss: 0.5580, Val Accuracy: 91.38%
#
# [82/100] Train Loss: 0.0002, Val Loss: 0.5555, Val Accuracy: 91.38%
#
# [83/100] Train Loss: 0.0022, Val Loss: 0.5636, Val Accuracy: 92.54%
#
# [84/100] Train Loss: 0.0018, Val Loss: 0.5651, Val Accuracy: 92.31%
#
# [85/100] Train Loss: 0.0004, Val Loss: 0.5641, Val Accuracy: 92.31%
#
# [86/100] Train Loss: 0.0006, Val Loss: 0.5632, Val Accuracy: 92.31%
#
# [87/100] Train Loss: 0.0096, Val Loss: 0.5702, Val Accuracy: 93.01%
#
# [88/100] Train Loss: 0.0002, Val Loss: 0.5757, Val Accuracy: 93.01%
#
# [89/100] Train Loss: 0.0014, Val Loss: 0.5773, Val Accuracy: 93.01%
#
# [90/100] Train Loss: 0.0002, Val Loss: 0.5775, Val Accuracy: 93.24%
#
# [91/100] Train Loss: 0.0006, Val Loss: 0.5771, Val Accuracy: 93.24%
#
# [92/100] Train Loss: 0.0004, Val Loss: 0.5764, Val Accuracy: 93.24%
#
# [93/100] Train Loss: 0.0011, Val Loss: 0.5757, Val Accuracy: 93.24%
#
# [94/100] Train Loss: 0.0008, Val Loss: 0.5756, Val Accuracy: 93.24%
#
# [95/100] Train Loss: 0.0039, Val Loss: 0.5746, Val Accuracy: 93.24%
#
# [96/100] Train Loss: 0.0004, Val Loss: 0.5741, Val Accuracy: 93.24%
#
# [97/100] Train Loss: 0.0003, Val Loss: 0.5738, Val Accuracy: 93.24%
#
# [98/100] Train Loss: 0.0004, Val Loss: 0.5737, Val Accuracy: 93.24%
#
# [99/100] Train Loss: 0.0005, Val Loss: 0.5737, Val Accuracy: 93.24%
#
# [100/100] Train Loss: 0.0003, Val Loss: 0.5737, Val Accuracy: 93.24%

# %%
_, _, acc_ibot_finetuned_300, auc_ibot_finetuned_300 = test_(ft_network, val_loader, nn.CrossEntropyLoss())
# Out:
# Evaluation on held out test dataset
# Confusion Matrix
# +----------------+------------------+---------------------+
# |                | predicted lenses | predicted nonlenses |
# +----------------+------------------+---------------------+
# |  true lenses   |       248        |          11         |
# | true nonlenses |        18        |         152         |
# +----------------+------------------+---------------------+
# Test Metrics
# +-----------+----------+
# |  accuracy | 93.2401% |
# |    loss   |  0.2041  |
# | auc score |  0.9640  |
# +-----------+----------+
# +----------------+-----------+--------+---------+---------+
# |                | precision | recall | f-score | support |
# +----------------+-----------+--------+---------+---------+
# |     lenses     |   0.9323  | 0.9575 |  0.9448 |   259   |
# |   nonlenses    |   0.9325  | 0.8941 |  0.9129 |   170   |
# | macro averaged |   0.9324  | 0.9258 |  0.9288 |         |
# +----------------+-----------+--------+---------+---------+

# %%
_, _, acc_ibot_finetuned_300, auc_ibot_finetuned_300 = test_(ft_network, test_loader, nn.CrossEntropyLoss())
# Out:
# Evaluation on held out test dataset
# Confusion Matrix
# +----------------+------------------+---------------------+
# |                | predicted lenses | predicted nonlenses |
# +----------------+------------------+---------------------+
# |  true lenses   |       425        |          33         |
# | true nonlenses |        28        |         272         |
# +----------------+------------------+---------------------+
# Test Metrics
# +-----------+----------+
# |  accuracy | 91.9525% |
# |    loss   |  0.0418  |
# | auc score |  0.9668  |
# +-----------+----------+
# +----------------+-----------+--------+---------+---------+
# |                | precision | recall | f-score | support |
# +----------------+-----------+--------+---------+---------+
# |     lenses     |   0.9382  | 0.9279 |  0.9330 |   458   |
# |   nonlenses    |   0.8918  | 0.9067 |  0.8992 |   300   |
# | macro averaged |   0.9150  | 0.9173 |  0.9161 |         |
# +----------------+-----------+--------+---------+---------+

# %% [markdown]
# ### ViT Base pretrained backbone finetuned on 600 labelled datapoints

# %%
set_seed(12)
train_loader, val_loader, test_loader = get_datasets(600)
ft_network = Classifier(mode = "finetune", backbone = copy.deepcopy(state["student"].backbone), backbone_return_all_tokens=True)
optimizer = torch.optim.Adam(ft_network.parameters(), lr=1e-4, weight_decay=1e-5)
num_epochs = 100
scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, eta_min=1e-8, T_max=num_epochs)
ft_network, ft_network_best_loss = train(ft_network, train_loader, val_loader, nn.CrossEntropyLoss(), optimizer, num_epochs=num_epochs, scheduler=scheduler)

torch.save(ft_network, "/kaggle/working/ibot_finetuned_600_ckpt.pth")
fpr_ibot_finetuned_600, tpr_ibot_finetuned_600, auc_score_ibot_finetuned_600 = compute_auc(ft_network, test_loader)
# Out:
# [1/100] Train Loss: 1.3359, Val Loss: 0.5903, Val Accuracy: 67.83%
#
# [2/100] Train Loss: 0.4726, Val Loss: 0.4261, Val Accuracy: 83.45%
#
# [3/100] Train Loss: 0.3152, Val Loss: 0.3191, Val Accuracy: 86.25%
#
# [4/100] Train Loss: 0.2559, Val Loss: 0.2833, Val Accuracy: 89.28%
#
# [5/100] Train Loss: 0.2158, Val Loss: 0.2973, Val Accuracy: 89.28%
#
# [6/100] Train Loss: 0.1897, Val Loss: 0.3243, Val Accuracy: 89.04%
#
# [7/100] Train Loss: 0.1764, Val Loss: 0.3024, Val Accuracy: 88.81%
#
# [8/100] Train Loss: 0.1824, Val Loss: 0.3158, Val Accuracy: 89.28%
#
# [9/100] Train Loss: 0.1993, Val Loss: 0.3137, Val Accuracy: 89.98%
#
# [10/100] Train Loss: 0.1733, Val Loss: 0.2983, Val Accuracy: 89.28%
#
# [11/100] Train Loss: 0.1594, Val Loss: 0.3293, Val Accuracy: 89.04%
#
# [12/100] Train Loss: 0.1446, Val Loss: 0.3053, Val Accuracy: 89.98%
#
# [13/100] Train Loss: 0.1027, Val Loss: 0.2515, Val Accuracy: 90.68%
#
# [14/100] Train Loss: 0.0809, Val Loss: 0.4077, Val Accuracy: 90.44%
#
# [15/100] Train Loss: 0.0807, Val Loss: 0.3835, Val Accuracy: 91.38%
#
# [16/100] Train Loss: 0.0737, Val Loss: 0.3781, Val Accuracy: 90.68%
#
# [17/100] Train Loss: 0.0719, Val Loss: 0.3888, Val Accuracy: 90.68%
#
# [18/100] Train Loss: 0.1002, Val Loss: 0.3497, Val Accuracy: 90.68%
#
# [19/100] Train Loss: 0.1027, Val Loss: 0.3842, Val Accuracy: 90.68%
#
# [20/100] Train Loss: 0.0953, Val Loss: 0.3278, Val Accuracy: 91.14%
#
# [21/100] Train Loss: 0.0618, Val Loss: 0.4128, Val Accuracy: 91.14%
#
# [22/100] Train Loss: 0.0524, Val Loss: 0.4427, Val Accuracy: 89.74%
#
# [23/100] Train Loss: 0.0330, Val Loss: 0.4176, Val Accuracy: 91.61%
#
# [24/100] Train Loss: 0.0468, Val Loss: 0.4212, Val Accuracy: 92.07%
#
# [25/100] Train Loss: 0.0542, Val Loss: 0.3784, Val Accuracy: 91.61%
#
# [26/100] Train Loss: 0.0304, Val Loss: 0.3999, Val Accuracy: 90.91%
#
# [27/100] Train Loss: 0.0329, Val Loss: 0.5099, Val Accuracy: 90.91%
#
# [28/100] Train Loss: 0.0399, Val Loss: 0.4204, Val Accuracy: 92.07%
#
# [29/100] Train Loss: 0.0190, Val Loss: 0.4289, Val Accuracy: 92.31%
#
# [30/100] Train Loss: 0.0260, Val Loss: 0.4087, Val Accuracy: 92.77%
#
# [31/100] Train Loss: 0.0204, Val Loss: 0.4751, Val Accuracy: 92.07%
#
# [32/100] Train Loss: 0.0606, Val Loss: 0.4567, Val Accuracy: 91.61%
#
# [33/100] Train Loss: 0.0367, Val Loss: 0.4035, Val Accuracy: 92.77%
#
# [34/100] Train Loss: 0.0186, Val Loss: 0.4627, Val Accuracy: 91.14%
#
# [35/100] Train Loss: 0.0103, Val Loss: 0.4935, Val Accuracy: 91.61%
#
# [36/100] Train Loss: 0.0136, Val Loss: 0.5136, Val Accuracy: 92.54%
#
# [37/100] Train Loss: 0.0077, Val Loss: 0.8131, Val Accuracy: 90.68%
#
# [38/100] Train Loss: 0.0835, Val Loss: 0.5389, Val Accuracy: 91.61%
#
# [39/100] Train Loss: 0.0423, Val Loss: 0.4911, Val Accuracy: 91.38%
#
# [40/100] Train Loss: 0.0310, Val Loss: 0.4685, Val Accuracy: 92.31%
#
# [41/100] Train Loss: 0.0225, Val Loss: 0.5478, Val Accuracy: 91.84%
#
# [42/100] Train Loss: 0.0110, Val Loss: 0.6673, Val Accuracy: 91.61%
#
# [43/100] Train Loss: 0.0037, Val Loss: 0.7054, Val Accuracy: 91.14%
#
# [44/100] Train Loss: 0.0083, Val Loss: 0.5142, Val Accuracy: 92.54%
#
# [45/100] Train Loss: 0.0050, Val Loss: 0.4888, Val Accuracy: 91.84%
#
# [46/100] Train Loss: 0.0049, Val Loss: 0.5032, Val Accuracy: 92.31%
#
# [47/100] Train Loss: 0.0055, Val Loss: 0.6266, Val Accuracy: 91.38%
#
# [48/100] Train Loss: 0.0202, Val Loss: 0.5578, Val Accuracy: 91.84%
#
# [49/100] Train Loss: 0.0191, Val Loss: 0.5440, Val Accuracy: 92.31%
#
# [50/100] Train Loss: 0.0074, Val Loss: 0.6515, Val Accuracy: 91.84%
#
# [51/100] Train Loss: 0.0071, Val Loss: 0.5529, Val Accuracy: 92.07%
#
# [52/100] Train Loss: 0.0478, Val Loss: 0.5524, Val Accuracy: 91.38%
#
# [53/100] Train Loss: 0.0755, Val Loss: 0.6235, Val Accuracy: 90.91%
#
# [54/100] Train Loss: 0.0289, Val Loss: 0.5439, Val Accuracy: 91.61%
#
# [55/100] Train Loss: 0.0131, Val Loss: 0.5617, Val Accuracy: 91.84%
#
# [56/100] Train Loss: 0.0106, Val Loss: 0.5104, Val Accuracy: 92.07%
#
# [57/100] Train Loss: 0.0063, Val Loss: 0.4924, Val Accuracy: 92.54%
#
# [58/100] Train Loss: 0.0035, Val Loss: 0.5132, Val Accuracy: 92.54%
#
# [59/100] Train Loss: 0.0023, Val Loss: 0.5209, Val Accuracy: 92.31%
#
# [60/100] Train Loss: 0.0021, Val Loss: 0.5124, Val Accuracy: 93.01%
#
# [61/100] Train Loss: 0.0019, Val Loss: 0.5212, Val Accuracy: 93.24%
#
# [62/100] Train Loss: 0.0054, Val Loss: 0.5171, Val Accuracy: 93.24%
#
# [63/100] Train Loss: 0.0091, Val Loss: 0.5049, Val Accuracy: 93.01%
#
# [64/100] Train Loss: 0.0019, Val Loss: 0.4979, Val Accuracy: 93.01%
#
# [65/100] Train Loss: 0.0069, Val Loss: 0.5060, Val Accuracy: 93.01%
#
# [66/100] Train Loss: 0.0012, Val Loss: 0.5094, Val Accuracy: 93.01%
#
# [67/100] Train Loss: 0.0070, Val Loss: 0.5088, Val Accuracy: 92.77%
#
# [68/100] Train Loss: 0.0022, Val Loss: 0.5071, Val Accuracy: 93.24%
#
# [69/100] Train Loss: 0.0016, Val Loss: 0.5100, Val Accuracy: 93.01%
#
# [70/100] Train Loss: 0.0011, Val Loss: 0.5173, Val Accuracy: 93.01%
#
# [71/100] Train Loss: 0.0006, Val Loss: 0.5293, Val Accuracy: 93.01%
#
# [72/100] Train Loss: 0.0010, Val Loss: 0.5316, Val Accuracy: 93.01%
#
# [73/100] Train Loss: 0.0060, Val Loss: 0.5423, Val Accuracy: 92.77%
#
# [74/100] Train Loss: 0.0008, Val Loss: 0.5470, Val Accuracy: 92.77%
#
# [75/100] Train Loss: 0.0007, Val Loss: 0.5480, Val Accuracy: 92.77%
#
# [76/100] Train Loss: 0.0020, Val Loss: 0.5411, Val Accuracy: 93.01%
#
# [77/100] Train Loss: 0.0007, Val Loss: 0.5390, Val Accuracy: 93.01%
#
# [78/100] Train Loss: 0.0006, Val Loss: 0.5411, Val Accuracy: 93.01%
#
# [79/100] Train Loss: 0.0005, Val Loss: 0.5466, Val Accuracy: 93.01%
#
# [80/100] Train Loss: 0.0005, Val Loss: 0.5504, Val Accuracy: 93.01%
#
# [81/100] Train Loss: 0.0003, Val Loss: 0.5531, Val Accuracy: 93.01%
#
# [82/100] Train Loss: 0.0026, Val Loss: 0.5641, Val Accuracy: 93.01%
#
# [83/100] Train Loss: 0.0020, Val Loss: 0.5665, Val Accuracy: 92.77%
#
# [84/100] Train Loss: 0.0158, Val Loss: 0.5609, Val Accuracy: 92.77%
#
# [85/100] Train Loss: 0.0003, Val Loss: 0.5255, Val Accuracy: 93.01%
#
# [86/100] Train Loss: 0.0005, Val Loss: 0.5161, Val Accuracy: 92.77%
#
# [87/100] Train Loss: 0.0017, Val Loss: 0.5173, Val Accuracy: 92.77%
#
# [88/100] Train Loss: 0.0042, Val Loss: 0.5284, Val Accuracy: 93.01%
#
# [89/100] Train Loss: 0.0006, Val Loss: 0.5335, Val Accuracy: 93.01%
#
# [90/100] Train Loss: 0.0006, Val Loss: 0.5357, Val Accuracy: 93.01%
#
# [91/100] Train Loss: 0.0006, Val Loss: 0.5369, Val Accuracy: 93.01%
#
# [92/100] Train Loss: 0.0008, Val Loss: 0.5383, Val Accuracy: 93.01%
#
# [93/100] Train Loss: 0.0008, Val Loss: 0.5396, Val Accuracy: 92.77%
#
# [94/100] Train Loss: 0.0006, Val Loss: 0.5407, Val Accuracy: 92.77%
#
# [95/100] Train Loss: 0.0017, Val Loss: 0.5416, Val Accuracy: 92.77%
#
# [96/100] Train Loss: 0.0019, Val Loss: 0.5418, Val Accuracy: 92.77%
#
# [97/100] Train Loss: 0.0005, Val Loss: 0.5416, Val Accuracy: 92.77%
#
# [98/100] Train Loss: 0.0004, Val Loss: 0.5416, Val Accuracy: 92.77%
#
# [99/100] Train Loss: 0.0003, Val Loss: 0.5416, Val Accuracy: 92.77%
#
# [100/100] Train Loss: 0.0021, Val Loss: 0.5416, Val Accuracy: 92.77%

# %%
_, _, acc_ibot_finetuned_600, auc_ibot_finetuned_600 = test_(ft_network, val_loader, nn.CrossEntropyLoss())
# Out:
# Evaluation on held out test dataset
# Confusion Matrix
# +----------------+------------------+---------------------+
# |                | predicted lenses | predicted nonlenses |
# +----------------+------------------+---------------------+
# |  true lenses   |       242        |          17         |
# | true nonlenses |        14        |         156         |
# +----------------+------------------+---------------------+
# Test Metrics
# +-----------+----------+
# |  accuracy | 92.7739% |
# |    loss   |  0.1251  |
# | auc score |  0.9727  |
# +-----------+----------+
# +----------------+-----------+--------+---------+---------+
# |                | precision | recall | f-score | support |
# +----------------+-----------+--------+---------+---------+
# |     lenses     |   0.9453  | 0.9344 |  0.9398 |   259   |
# |   nonlenses    |   0.9017  | 0.9176 |  0.9096 |   170   |
# | macro averaged |   0.9235  | 0.9260 |  0.9247 |         |
# +----------------+-----------+--------+---------+---------+

# %%
_, _, acc_ibot_finetuned_600, auc_ibot_finetuned_600 = test_(ft_network, test_loader, nn.CrossEntropyLoss())
# Out:
# Evaluation on held out test dataset
# Confusion Matrix
# +----------------+------------------+---------------------+
# |                | predicted lenses | predicted nonlenses |
# +----------------+------------------+---------------------+
# |  true lenses   |       428        |          30         |
# | true nonlenses |        26        |         274         |
# +----------------+------------------+---------------------+
# Test Metrics
# +-----------+----------+
# |  accuracy | 92.6121% |
# |    loss   |  0.0374  |
# | auc score |  0.9696  |
# +-----------+----------+
# +----------------+-----------+--------+---------+---------+
# |                | precision | recall | f-score | support |
# +----------------+-----------+--------+---------+---------+
# |     lenses     |   0.9427  | 0.9345 |  0.9386 |   458   |
# |   nonlenses    |   0.9013  | 0.9133 |  0.9073 |   300   |
# | macro averaged |   0.9220  | 0.9239 |  0.9229 |         |
# +----------------+-----------+--------+---------+---------+

# %% [markdown]
# ### ViT Base pretrained backbone finetuned on 1200 labelled datapoints

# %%
set_seed(12)
train_loader, val_loader, test_loader = get_datasets(1200)
ft_network = Classifier(mode = "finetune", backbone = copy.deepcopy(state["student"].backbone), backbone_return_all_tokens=True)
optimizer = torch.optim.Adam(ft_network.parameters(), lr=1e-4, weight_decay=1e-8)
num_epochs = 100
scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, eta_min=1e-8, T_max=num_epochs)
ft_network, ft_network_best_loss = train(ft_network, train_loader, val_loader, nn.CrossEntropyLoss(), optimizer, num_epochs=num_epochs, scheduler=scheduler)

torch.save(ft_network, "/kaggle/working/ibot_finetuned_1200_ckpt.pth")
fpr_ibot_finetuned_1200, tpr_ibot_finetuned_1200, auc_score_ibot_finetuned_1200 = compute_auc(ft_network, test_loader)
# Out:
# [1/100] Train Loss: 0.9479, Val Loss: 0.4656, Val Accuracy: 80.42%
#
# [2/100] Train Loss: 0.3636, Val Loss: 0.2755, Val Accuracy: 87.88%
#
# [3/100] Train Loss: 0.2623, Val Loss: 0.2539, Val Accuracy: 88.81%
#
# [4/100] Train Loss: 0.2154, Val Loss: 0.2455, Val Accuracy: 89.51%
#
# [5/100] Train Loss: 0.1983, Val Loss: 0.2560, Val Accuracy: 90.21%
#
# [6/100] Train Loss: 0.1729, Val Loss: 0.3106, Val Accuracy: 90.68%
#
# [7/100] Train Loss: 0.2053, Val Loss: 0.2598, Val Accuracy: 90.21%
#
# [8/100] Train Loss: 0.1486, Val Loss: 0.2144, Val Accuracy: 91.14%
#
# [9/100] Train Loss: 0.1322, Val Loss: 0.3607, Val Accuracy: 86.95%
#
# [10/100] Train Loss: 0.2205, Val Loss: 0.2507, Val Accuracy: 89.74%
#
# [11/100] Train Loss: 0.1440, Val Loss: 0.2293, Val Accuracy: 92.31%
#
# [12/100] Train Loss: 0.1240, Val Loss: 0.2961, Val Accuracy: 89.51%
#
# [13/100] Train Loss: 0.1420, Val Loss: 0.2076, Val Accuracy: 92.07%
#
# [14/100] Train Loss: 0.1063, Val Loss: 0.3163, Val Accuracy: 89.98%
#
# [15/100] Train Loss: 0.1249, Val Loss: 0.2772, Val Accuracy: 91.38%
#
# [16/100] Train Loss: 0.0882, Val Loss: 0.2507, Val Accuracy: 91.84%
#
# [17/100] Train Loss: 0.0680, Val Loss: 0.2234, Val Accuracy: 92.77%
#
# [18/100] Train Loss: 0.0722, Val Loss: 0.2817, Val Accuracy: 91.84%
#
# [19/100] Train Loss: 0.0947, Val Loss: 0.2932, Val Accuracy: 92.54%
#
# [20/100] Train Loss: 0.0686, Val Loss: 0.2172, Val Accuracy: 93.01%
#
# [21/100] Train Loss: 0.0742, Val Loss: 0.3257, Val Accuracy: 89.74%
#
# [22/100] Train Loss: 0.0636, Val Loss: 0.2921, Val Accuracy: 92.77%
#
# [23/100] Train Loss: 0.0594, Val Loss: 0.3003, Val Accuracy: 92.31%
#
# [24/100] Train Loss: 0.0314, Val Loss: 0.3215, Val Accuracy: 93.71%
#
# [25/100] Train Loss: 0.0599, Val Loss: 0.2396, Val Accuracy: 92.77%
#
# [26/100] Train Loss: 0.0568, Val Loss: 0.2956, Val Accuracy: 92.07%
#
# [27/100] Train Loss: 0.0547, Val Loss: 0.3693, Val Accuracy: 92.54%
#
# [28/100] Train Loss: 0.0291, Val Loss: 0.3905, Val Accuracy: 93.01%
#
# [29/100] Train Loss: 0.0346, Val Loss: 0.3642, Val Accuracy: 92.54%
#
# [30/100] Train Loss: 0.0101, Val Loss: 0.3587, Val Accuracy: 93.01%
#
# [31/100] Train Loss: 0.0264, Val Loss: 0.4514, Val Accuracy: 92.77%
#
# [32/100] Train Loss: 0.0296, Val Loss: 0.3155, Val Accuracy: 93.94%
#
# [33/100] Train Loss: 0.0202, Val Loss: 0.3329, Val Accuracy: 94.17%
#
# [34/100] Train Loss: 0.0395, Val Loss: 0.2932, Val Accuracy: 92.54%
#
# [35/100] Train Loss: 0.0268, Val Loss: 0.2805, Val Accuracy: 93.24%
#
# [36/100] Train Loss: 0.0095, Val Loss: 0.3131, Val Accuracy: 93.71%
#
# [37/100] Train Loss: 0.0140, Val Loss: 0.4317, Val Accuracy: 93.24%
#
# [38/100] Train Loss: 0.0081, Val Loss: 0.4843, Val Accuracy: 93.94%
#
# [39/100] Train Loss: 0.0239, Val Loss: 0.3353, Val Accuracy: 93.94%
#
# [40/100] Train Loss: 0.0271, Val Loss: 0.3666, Val Accuracy: 92.31%
#
# [41/100] Train Loss: 0.0199, Val Loss: 0.3145, Val Accuracy: 93.94%
#
# [42/100] Train Loss: 0.0235, Val Loss: 0.3497, Val Accuracy: 92.77%
#
# [43/100] Train Loss: 0.0067, Val Loss: 0.3327, Val Accuracy: 93.24%
#
# [44/100] Train Loss: 0.0125, Val Loss: 0.4102, Val Accuracy: 92.77%
#
# [45/100] Train Loss: 0.0084, Val Loss: 0.3795, Val Accuracy: 93.24%
#
# [46/100] Train Loss: 0.0224, Val Loss: 0.5081, Val Accuracy: 92.31%
#
# [47/100] Train Loss: 0.0166, Val Loss: 0.4930, Val Accuracy: 92.54%
#
# [48/100] Train Loss: 0.0465, Val Loss: 0.4238, Val Accuracy: 92.07%
#
# [49/100] Train Loss: 0.0151, Val Loss: 0.2973, Val Accuracy: 94.41%
#
# [50/100] Train Loss: 0.0133, Val Loss: 0.3334, Val Accuracy: 94.41%
#
# [51/100] Train Loss: 0.0062, Val Loss: 0.3643, Val Accuracy: 93.94%
#
# [52/100] Train Loss: 0.0041, Val Loss: 0.3907, Val Accuracy: 94.17%
#
# [53/100] Train Loss: 0.0051, Val Loss: 0.3578, Val Accuracy: 94.64%
#
# [54/100] Train Loss: 0.0010, Val Loss: 0.3516, Val Accuracy: 95.10%
#
# [55/100] Train Loss: 0.0004, Val Loss: 0.3759, Val Accuracy: 94.87%
#
# [56/100] Train Loss: 0.0005, Val Loss: 0.3823, Val Accuracy: 94.87%
#
# [57/100] Train Loss: 0.0041, Val Loss: 0.3717, Val Accuracy: 94.64%
#
# [58/100] Train Loss: 0.0009, Val Loss: 0.3727, Val Accuracy: 94.64%
#
# [59/100] Train Loss: 0.0010, Val Loss: 0.3689, Val Accuracy: 95.10%
#
# [60/100] Train Loss: 0.0004, Val Loss: 0.3981, Val Accuracy: 94.41%
#
# [61/100] Train Loss: 0.0002, Val Loss: 0.4042, Val Accuracy: 94.64%
#
# [62/100] Train Loss: 0.0001, Val Loss: 0.4048, Val Accuracy: 95.10%
#
# [63/100] Train Loss: 0.0013, Val Loss: 0.4902, Val Accuracy: 93.71%
#
# [64/100] Train Loss: 0.0005, Val Loss: 0.4634, Val Accuracy: 93.94%
#
# [65/100] Train Loss: 0.0006, Val Loss: 0.4619, Val Accuracy: 93.94%
#
# [66/100] Train Loss: 0.0027, Val Loss: 0.4413, Val Accuracy: 94.87%
#
# [67/100] Train Loss: 0.0021, Val Loss: 0.4677, Val Accuracy: 94.64%
#
# [68/100] Train Loss: 0.0002, Val Loss: 0.4510, Val Accuracy: 94.17%
#
# [69/100] Train Loss: 0.0004, Val Loss: 0.4417, Val Accuracy: 94.41%
#
# [70/100] Train Loss: 0.0004, Val Loss: 0.4659, Val Accuracy: 94.64%
#
# [71/100] Train Loss: 0.0001, Val Loss: 0.4770, Val Accuracy: 94.64%
#
# [72/100] Train Loss: 0.0001, Val Loss: 0.4757, Val Accuracy: 94.64%
#
# [73/100] Train Loss: 0.0000, Val Loss: 0.4730, Val Accuracy: 94.64%
#
# [74/100] Train Loss: 0.0002, Val Loss: 0.4603, Val Accuracy: 94.64%
#
# [75/100] Train Loss: 0.0000, Val Loss: 0.4576, Val Accuracy: 94.64%
#
# [76/100] Train Loss: 0.0000, Val Loss: 0.4584, Val Accuracy: 94.64%
#
# [77/100] Train Loss: 0.0000, Val Loss: 0.4595, Val Accuracy: 94.64%
#
# [78/100] Train Loss: 0.0005, Val Loss: 0.4924, Val Accuracy: 94.41%
#
# [79/100] Train Loss: 0.0001, Val Loss: 0.5004, Val Accuracy: 94.17%
#
# [80/100] Train Loss: 0.0001, Val Loss: 0.5002, Val Accuracy: 94.17%
#
# [81/100] Train Loss: 0.0003, Val Loss: 0.4983, Val Accuracy: 94.17%
#
# [82/100] Train Loss: 0.0004, Val Loss: 0.4863, Val Accuracy: 94.64%
#
# [83/100] Train Loss: 0.0001, Val Loss: 0.4812, Val Accuracy: 94.64%
#
# [84/100] Train Loss: 0.0011, Val Loss: 0.4836, Val Accuracy: 94.64%
#
# [85/100] Train Loss: 0.0001, Val Loss: 0.5083, Val Accuracy: 94.17%
#
# [86/100] Train Loss: 0.0004, Val Loss: 0.5004, Val Accuracy: 94.41%
#
# [87/100] Train Loss: 0.0000, Val Loss: 0.4947, Val Accuracy: 94.64%
#
# [88/100] Train Loss: 0.0002, Val Loss: 0.4982, Val Accuracy: 94.64%
#
# [89/100] Train Loss: 0.0001, Val Loss: 0.4985, Val Accuracy: 94.64%
#
# [90/100] Train Loss: 0.0000, Val Loss: 0.4987, Val Accuracy: 94.64%
#
# [91/100] Train Loss: 0.0000, Val Loss: 0.4987, Val Accuracy: 94.64%
#
# [92/100] Train Loss: 0.0004, Val Loss: 0.4968, Val Accuracy: 94.64%
#
# [93/100] Train Loss: 0.0027, Val Loss: 0.5087, Val Accuracy: 94.17%
#
# [94/100] Train Loss: 0.0009, Val Loss: 0.5114, Val Accuracy: 94.17%
#
# [95/100] Train Loss: 0.0001, Val Loss: 0.5111, Val Accuracy: 94.17%
#
# [96/100] Train Loss: 0.0002, Val Loss: 0.5109, Val Accuracy: 94.17%
#
# [97/100] Train Loss: 0.0000, Val Loss: 0.5107, Val Accuracy: 94.17%
#
# [98/100] Train Loss: 0.0013, Val Loss: 0.5099, Val Accuracy: 94.41%
#
# [99/100] Train Loss: 0.0006, Val Loss: 0.5094, Val Accuracy: 94.41%
#
# [100/100] Train Loss: 0.0001, Val Loss: 0.5094, Val Accuracy: 94.41%

# %%
_, _, acc_ibot_finetuned_1200, auc_ibot_finetuned_1200 = test_(ft_network, val_loader, nn.CrossEntropyLoss())
# Out:
# Evaluation on held out test dataset
# Confusion Matrix
# +----------------+------------------+---------------------+
# |                | predicted lenses | predicted nonlenses |
# +----------------+------------------+---------------------+
# |  true lenses   |       250        |          9          |
# | true nonlenses |        15        |         155         |
# +----------------+------------------+---------------------+
# Test Metrics
# +-----------+----------+
# |  accuracy | 94.4056% |
# |    loss   |  0.0865  |
# | auc score |  0.9820  |
# +-----------+----------+
# +----------------+-----------+--------+---------+---------+
# |                | precision | recall | f-score | support |
# +----------------+-----------+--------+---------+---------+
# |     lenses     |   0.9434  | 0.9653 |  0.9542 |   259   |
# |   nonlenses    |   0.9451  | 0.9118 |  0.9281 |   170   |
# | macro averaged |   0.9443  | 0.9385 |  0.9412 |         |
# +----------------+-----------+--------+---------+---------+

# %%
_, _, acc_ibot_finetuned_1200, auc_ibot_finetuned_1200 = test_(ft_network, test_loader, nn.CrossEntropyLoss())
# Out:
# Evaluation on held out test dataset
# Confusion Matrix
# +----------------+------------------+---------------------+
# |                | predicted lenses | predicted nonlenses |
# +----------------+------------------+---------------------+
# |  true lenses   |       429        |          29         |
# | true nonlenses |        23        |         277         |
# +----------------+------------------+---------------------+
# Test Metrics
# +-----------+----------+
# |  accuracy | 93.1398% |
# |    loss   |  0.0345  |
# | auc score |  0.9814  |
# +-----------+----------+
# +----------------+-----------+--------+---------+---------+
# |                | precision | recall | f-score | support |
# +----------------+-----------+--------+---------+---------+
# |     lenses     |   0.9491  | 0.9367 |  0.9429 |   458   |
# |   nonlenses    |   0.9052  | 0.9233 |  0.9142 |   300   |
# | macro averaged |   0.9272  | 0.9300 |  0.9285 |         |
# +----------------+-----------+--------+---------+---------+

# %% [markdown]
# ### ViT Base pretrained backbone finetuned on all datapoints

# %%
set_seed(12)
train_loader, val_loader, test_loader = get_datasets(None)
ft_network = Classifier(mode = "finetune", backbone = copy.deepcopy(state["student"].backbone), backbone_return_all_tokens=True)
optimizer = torch.optim.Adam(ft_network.parameters(), lr=1e-4, weight_decay=1e-3)
num_epochs = 100
scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, eta_min=1e-8, T_max=num_epochs)
ft_network, ft_network_best_loss = train(ft_network, train_loader, val_loader, nn.CrossEntropyLoss(), optimizer, num_epochs=num_epochs, scheduler=scheduler)

torch.save(ft_network, "/kaggle/working/ibot_finetuned_all_ckpt.pth")
fpr_ibot_finetuned_all, tpr_ibot_finetuned_all, auc_score_ibot_finetuned_all = compute_auc(ft_network, test_loader)
# Out:
# [1/100] Train Loss: 0.4935, Val Loss: 0.2496, Val Accuracy: 89.28%
#
# [2/100] Train Loss: 0.2329, Val Loss: 0.2973, Val Accuracy: 90.91%
#
# [3/100] Train Loss: 0.2112, Val Loss: 0.1975, Val Accuracy: 91.61%
#
# [4/100] Train Loss: 0.1945, Val Loss: 0.2324, Val Accuracy: 90.91%
#
# [5/100] Train Loss: 0.1856, Val Loss: 0.1943, Val Accuracy: 93.71%
#
# [6/100] Train Loss: 0.1458, Val Loss: 0.2075, Val Accuracy: 92.54%
#
# [7/100] Train Loss: 0.1385, Val Loss: 0.1686, Val Accuracy: 93.94%
#
# [8/100] Train Loss: 0.1632, Val Loss: 0.2393, Val Accuracy: 91.14%
#
# [9/100] Train Loss: 0.1292, Val Loss: 0.1833, Val Accuracy: 93.24%
#
# [10/100] Train Loss: 0.1240, Val Loss: 0.2054, Val Accuracy: 92.77%
#
# [11/100] Train Loss: 0.1102, Val Loss: 0.2491, Val Accuracy: 93.24%
#
# [12/100] Train Loss: 0.1145, Val Loss: 0.1995, Val Accuracy: 93.94%
#
# [13/100] Train Loss: 0.0855, Val Loss: 0.2226, Val Accuracy: 93.94%
#
# [14/100] Train Loss: 0.1235, Val Loss: 0.3545, Val Accuracy: 90.44%
#
# [15/100] Train Loss: 0.0997, Val Loss: 0.1816, Val Accuracy: 94.41%
#
# [16/100] Train Loss: 0.1107, Val Loss: 0.2208, Val Accuracy: 93.47%
#
# [17/100] Train Loss: 0.0717, Val Loss: 0.2395, Val Accuracy: 93.71%
#
# [18/100] Train Loss: 0.0666, Val Loss: 0.2609, Val Accuracy: 93.94%
#
# [19/100] Train Loss: 0.0660, Val Loss: 0.1964, Val Accuracy: 94.41%
#
# [20/100] Train Loss: 0.0674, Val Loss: 0.1591, Val Accuracy: 94.87%
#
# [21/100] Train Loss: 0.0445, Val Loss: 0.2251, Val Accuracy: 95.34%
#
# [22/100] Train Loss: 0.0768, Val Loss: 0.2081, Val Accuracy: 95.10%
#
# [23/100] Train Loss: 0.0637, Val Loss: 0.2146, Val Accuracy: 95.10%
#
# [24/100] Train Loss: 0.0479, Val Loss: 0.2673, Val Accuracy: 94.87%
#
# [25/100] Train Loss: 0.0567, Val Loss: 0.2436, Val Accuracy: 94.17%
#
# [26/100] Train Loss: 0.0390, Val Loss: 0.2433, Val Accuracy: 94.87%
#
# [27/100] Train Loss: 0.0503, Val Loss: 0.1738, Val Accuracy: 95.34%
#
# [28/100] Train Loss: 0.0445, Val Loss: 0.2238, Val Accuracy: 93.71%
#
# [29/100] Train Loss: 0.0429, Val Loss: 0.2509, Val Accuracy: 95.57%
#
# [30/100] Train Loss: 0.0360, Val Loss: 0.2587, Val Accuracy: 95.10%
#
# [31/100] Train Loss: 0.0358, Val Loss: 0.2752, Val Accuracy: 93.71%
#
# [32/100] Train Loss: 0.0209, Val Loss: 0.3124, Val Accuracy: 94.17%
#
# [33/100] Train Loss: 0.0273, Val Loss: 0.2386, Val Accuracy: 95.34%
#
# [34/100] Train Loss: 0.0205, Val Loss: 0.2324, Val Accuracy: 95.34%
#
# [35/100] Train Loss: 0.0237, Val Loss: 0.4277, Val Accuracy: 93.01%
#
# [36/100] Train Loss: 0.0255, Val Loss: 0.3038, Val Accuracy: 94.64%
#
# [37/100] Train Loss: 0.0177, Val Loss: 0.3390, Val Accuracy: 95.57%
#
# [38/100] Train Loss: 0.0252, Val Loss: 0.3484, Val Accuracy: 93.24%
#
# [39/100] Train Loss: 0.0327, Val Loss: 0.2529, Val Accuracy: 92.54%
#
# [40/100] Train Loss: 0.0257, Val Loss: 0.3264, Val Accuracy: 94.64%
#
# [41/100] Train Loss: 0.0090, Val Loss: 0.4823, Val Accuracy: 94.64%
#
# [42/100] Train Loss: 0.0386, Val Loss: 0.3247, Val Accuracy: 93.71%
#
# [43/100] Train Loss: 0.0146, Val Loss: 0.4023, Val Accuracy: 95.10%
#
# [44/100] Train Loss: 0.0182, Val Loss: 0.4482, Val Accuracy: 93.47%
#
# [45/100] Train Loss: 0.0158, Val Loss: 0.3295, Val Accuracy: 94.64%
#
# [46/100] Train Loss: 0.0189, Val Loss: 0.3696, Val Accuracy: 94.41%
#
# [47/100] Train Loss: 0.0091, Val Loss: 0.3274, Val Accuracy: 95.57%
#
# [48/100] Train Loss: 0.0262, Val Loss: 0.2979, Val Accuracy: 95.57%
#
# [49/100] Train Loss: 0.0101, Val Loss: 0.3684, Val Accuracy: 94.87%
#
# [50/100] Train Loss: 0.0078, Val Loss: 0.3482, Val Accuracy: 94.64%
#
# [51/100] Train Loss: 0.0050, Val Loss: 0.4516, Val Accuracy: 94.41%
#
# [52/100] Train Loss: 0.0078, Val Loss: 0.4047, Val Accuracy: 95.10%
#
# [53/100] Train Loss: 0.0054, Val Loss: 0.4713, Val Accuracy: 94.64%
#
# [54/100] Train Loss: 0.0050, Val Loss: 0.4181, Val Accuracy: 95.10%
#
# [55/100] Train Loss: 0.0074, Val Loss: 0.4148, Val Accuracy: 94.64%
#
# [56/100] Train Loss: 0.0092, Val Loss: 0.3638, Val Accuracy: 95.34%
#
# [57/100] Train Loss: 0.0060, Val Loss: 0.4049, Val Accuracy: 94.64%
#
# [58/100] Train Loss: 0.0069, Val Loss: 0.4426, Val Accuracy: 94.64%
#
# [59/100] Train Loss: 0.0110, Val Loss: 0.3261, Val Accuracy: 95.34%
#
# [60/100] Train Loss: 0.0068, Val Loss: 0.4109, Val Accuracy: 94.64%
#
# [61/100] Train Loss: 0.0051, Val Loss: 0.4980, Val Accuracy: 94.64%
#
# [62/100] Train Loss: 0.0045, Val Loss: 0.3988, Val Accuracy: 95.57%
#
# [63/100] Train Loss: 0.0056, Val Loss: 0.3634, Val Accuracy: 94.87%
#
# [64/100] Train Loss: 0.0125, Val Loss: 0.3515, Val Accuracy: 95.57%
#
# [65/100] Train Loss: 0.0045, Val Loss: 0.3905, Val Accuracy: 94.87%
#
# [66/100] Train Loss: 0.0063, Val Loss: 0.3712, Val Accuracy: 95.10%
#
# [67/100] Train Loss: 0.0047, Val Loss: 0.4079, Val Accuracy: 95.34%
#
# [68/100] Train Loss: 0.0104, Val Loss: 0.3938, Val Accuracy: 94.87%
#
# [69/100] Train Loss: 0.0038, Val Loss: 0.4509, Val Accuracy: 94.41%
#
# [70/100] Train Loss: 0.0040, Val Loss: 0.3837, Val Accuracy: 94.87%
#
# [71/100] Train Loss: 0.0025, Val Loss: 0.4349, Val Accuracy: 94.87%
#
# [72/100] Train Loss: 0.0039, Val Loss: 0.3907, Val Accuracy: 95.57%
#
# [73/100] Train Loss: 0.0040, Val Loss: 0.3875, Val Accuracy: 94.87%
#
# [74/100] Train Loss: 0.0045, Val Loss: 0.3648, Val Accuracy: 95.57%
#
# [75/100] Train Loss: 0.0026, Val Loss: 0.4453, Val Accuracy: 95.10%
#
# [76/100] Train Loss: 0.0034, Val Loss: 0.4714, Val Accuracy: 95.34%
#
# [77/100] Train Loss: 0.0034, Val Loss: 0.4663, Val Accuracy: 94.64%
#
# [78/100] Train Loss: 0.0022, Val Loss: 0.4952, Val Accuracy: 94.17%
#
# [79/100] Train Loss: 0.0024, Val Loss: 0.5143, Val Accuracy: 94.41%
#
# [80/100] Train Loss: 0.0057, Val Loss: 0.5082, Val Accuracy: 94.17%
#
# [81/100] Train Loss: 0.0027, Val Loss: 0.4891, Val Accuracy: 95.10%
#
# [82/100] Train Loss: 0.0009, Val Loss: 0.4710, Val Accuracy: 95.34%
#
# [83/100] Train Loss: 0.0031, Val Loss: 0.5050, Val Accuracy: 94.87%
#
# [84/100] Train Loss: 0.0029, Val Loss: 0.5000, Val Accuracy: 94.64%
#
# [85/100] Train Loss: 0.0020, Val Loss: 0.5019, Val Accuracy: 94.41%
#
# [86/100] Train Loss: 0.0046, Val Loss: 0.4522, Val Accuracy: 95.10%
#
# [87/100] Train Loss: 0.0044, Val Loss: 0.4365, Val Accuracy: 95.10%
#
# [88/100] Train Loss: 0.0027, Val Loss: 0.4566, Val Accuracy: 95.10%
#
# [89/100] Train Loss: 0.0015, Val Loss: 0.4475, Val Accuracy: 95.57%
#
# [90/100] Train Loss: 0.0024, Val Loss: 0.4544, Val Accuracy: 95.57%
#
# [91/100] Train Loss: 0.0021, Val Loss: 0.4486, Val Accuracy: 95.34%
#
# [92/100] Train Loss: 0.0016, Val Loss: 0.4500, Val Accuracy: 95.34%
#
# [93/100] Train Loss: 0.0021, Val Loss: 0.4598, Val Accuracy: 95.10%
#
# [94/100] Train Loss: 0.0026, Val Loss: 0.4456, Val Accuracy: 95.34%
#
# [95/100] Train Loss: 0.0021, Val Loss: 0.4462, Val Accuracy: 95.34%
#
# [96/100] Train Loss: 0.0033, Val Loss: 0.4487, Val Accuracy: 95.34%
#
# [97/100] Train Loss: 0.0011, Val Loss: 0.4508, Val Accuracy: 95.34%
#
# [98/100] Train Loss: 0.0009, Val Loss: 0.4504, Val Accuracy: 95.34%
#
# [99/100] Train Loss: 0.0018, Val Loss: 0.4512, Val Accuracy: 95.34%
#
# [100/100] Train Loss: 0.0020, Val Loss: 0.4511, Val Accuracy: 95.34%

# %%
_, _, acc_ibot_finetuned_all, auc_ibot_finetuned_all = test_(ft_network, val_loader, nn.CrossEntropyLoss())
# Out:
# Evaluation on held out test dataset
# Confusion Matrix
# +----------------+------------------+---------------------+
# |                | predicted lenses | predicted nonlenses |
# +----------------+------------------+---------------------+
# |  true lenses   |       250        |          9          |
# | true nonlenses |        11        |         159         |
# +----------------+------------------+---------------------+
# Test Metrics
# +-----------+----------+
# |  accuracy | 95.3380% |
# |    loss   |  0.1357  |
# | auc score |  0.9861  |
# +-----------+----------+
# +----------------+-----------+--------+---------+---------+
# |                | precision | recall | f-score | support |
# +----------------+-----------+--------+---------+---------+
# |     lenses     |   0.9579  | 0.9653 |  0.9615 |   259   |
# |   nonlenses    |   0.9464  | 0.9353 |  0.9408 |   170   |
# | macro averaged |   0.9521  | 0.9503 |  0.9512 |         |
# +----------------+-----------+--------+---------+---------+

# %%
_, _, acc_ibot_finetuned_all, auc_ibot_finetuned_all = test_(ft_network, test_loader, nn.CrossEntropyLoss())
# Out:
# Evaluation on held out test dataset
# Confusion Matrix
# +----------------+------------------+---------------------+
# |                | predicted lenses | predicted nonlenses |
# +----------------+------------------+---------------------+
# |  true lenses   |       435        |          23         |
# | true nonlenses |        19        |         281         |
# +----------------+------------------+---------------------+
# Test Metrics
# +-----------+----------+
# |  accuracy | 94.4591% |
# |    loss   |  0.0351  |
# | auc score |  0.9885  |
# +-----------+----------+
# +----------------+-----------+--------+---------+---------+
# |                | precision | recall | f-score | support |
# +----------------+-----------+--------+---------+---------+
# |     lenses     |   0.9581  | 0.9498 |  0.9539 |   458   |
# |   nonlenses    |   0.9243  | 0.9367 |  0.9305 |   300   |
# | macro averaged |   0.9412  | 0.9432 |  0.9422 |         |
# +----------------+-----------+--------+---------+---------+

# %% [markdown]
# ### ROC Curves for the SSL model finetuning are plotted below

# %%
plt.figure(figsize=(15, 15))
plt.title('ROC')
plt.plot(fpr_ibot_finetuned_300, tpr_ibot_finetuned_300, 'r', label = 'AUC (finetuned on 300 labelled data, ibot pretrained) = %0.4f' % auc_ibot_finetuned_300)
plt.plot(fpr_ibot_finetuned_600, tpr_ibot_finetuned_600, 'm', label = 'AUC (finetuned on 600 labelled data, ibot pretrained) = %0.4f' % auc_ibot_finetuned_600)
plt.plot(fpr_ibot_finetuned_1200, tpr_ibot_finetuned_1200, 'g', label = 'AUC (finetuned on 1200 labelled data, ibot pretrained) = %0.4f' % auc_ibot_finetuned_1200)
plt.plot(fpr_ibot_finetuned_all, tpr_ibot_finetuned_all, 'b', label = 'AUC (finetuned on all labelled data, ibot pretrained) = %0.4f' % auc_ibot_finetuned_all)

plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.savefig("auc_ssl_ibot.png")
plt.show()

# %% [markdown]
# ### ROC Curves for the SSL and supervised models are plotted below

# %%
plt.figure(figsize=(15, 15))
plt.title('ROC')
plt.plot(fpr_ibot_finetuned_300, tpr_ibot_finetuned_300, 'r', label = 'AUC (finetuned on 300 labelled data, ibot pretrained) = %0.4f' % auc_ibot_finetuned_300)
plt.plot(fpr_ibot_finetuned_600, tpr_ibot_finetuned_600, 'm', label = 'AUC (finetuned on 600 labelled data, ibot pretrained) = %0.4f' % auc_ibot_finetuned_600)
plt.plot(fpr_ibot_finetuned_1200, tpr_ibot_finetuned_1200, 'g', label = 'AUC (finetuned on 1200 labelled data, ibot pretrained) = %0.4f' % auc_ibot_finetuned_1200)
plt.plot(fpr_ibot_finetuned_all, tpr_ibot_finetuned_all, 'b', label = 'AUC (finetuned on all labelled data, ibot pretrained) = %0.4f' % auc_ibot_finetuned_all)

plt.plot(fpr_supervised_300, tpr_supervised_300, 'r:', label = 'AUC (trained on 300 labelled data, supervised) = %0.4f' % auc_score_300)
plt.plot(fpr_supervised_600, tpr_supervised_600, 'm:', label = 'AUC (trained on 600 labelled data, supervised) = %0.4f' % auc_score_600)
plt.plot(fpr_supervised_1200, tpr_supervised_1200, 'g:', label = 'AUC (trained on 1200 labelled data, supervised) = %0.4f' % auc_score_1200)
plt.plot(fpr_supervised_all, tpr_supervised_all, 'b:', label = 'AUC (trained on all labelled data, supervised) = %0.4f' % auc_score_all)

plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.savefig("auc_supervised_ssl_ibot.png")
plt.show()
